# %%
import torch as t
import torchvision.datasets as datasets
import torchvision.transforms as transforms
import torch.nn as nn
import matplotlib.pyplot as plt
import torch.optim as optim
import torch.optim.lr_scheduler as lr_scheduler
from torch.optim.lr_scheduler import ReduceLROnPlateau, StepLR, ExponentialLR

# %% [markdown]
# ### Model

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net,self).__init__()
        self.linear1 = nn.Linear(3*32*32, 10)
        self.relu = nn.ReLU()

    def forward(self, img): #convert + flatten
        x = img.view(-1, 3*32*32)
        x = self.relu(self.linear1(x))
        return x
net = Net()

# %% [markdown]
# ### Hyperparams

# %%
num_epochs=100
after_every=100
loss_fn = nn.CrossEntropyLoss()
batch_size=128

# %%
import ssl
ssl._create_default_https_context = ssl._create_unverified_context
transform = transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5)),])

mnist_trainset = datasets.CIFAR10(root='./data', train=True, download=True, transform=transform)
train_loader = t.utils.data.DataLoader(mnist_trainset, batch_size=batch_size, shuffle=True)

mnist_testset = datasets.CIFAR10(root='./data', train=False, download=True, transform=transform)
test_loader = t.utils.data.DataLoader(mnist_testset, batch_size=batch_size, shuffle=True)
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./data/cifar-10-python.tar.gz
# 100.0%
# Extracting ./data/cifar-10-python.tar.gz to ./data
# Files already downloaded and verified

# %% [markdown]
# ### Training

# %%
def train_one_epoch(model, epoch_index, optimizer, train_dataset):
    running_loss = 0.
    last_loss = 0.

    for i, data in enumerate(train_dataset):
        # Every data instance is an input + label pair
        # data.shape=torch.Size([10, 1, 28, 28]) --> 10 images,labels
        inputs, labels = data

        # Zero your gradients for every batch!
        optimizer.zero_grad()

        # Make predictions for this batch
        outputs = model(inputs.view(-1, 3*32*32))


        # Compute the loss and its gradients
        loss = loss_fn(outputs, labels)
        loss.backward()

        # Adjust learning weights
        optimizer.step()

        # Gather data and report
        running_loss += loss.item()

        if i % after_every == after_every-1:
            last_loss = running_loss / after_every # loss per after_every batches
            print(' batch {} loss: {}'.format(i + 1, last_loss))
            running_loss = 0.

    return last_loss

# %% [markdown]
# ### Evaluate

# %%
def test(model, loader):
  total=0
  correct=0
  model.eval()
  with t.no_grad():
      for data in loader:
          x, y = data
          output = model(x.view(-1, 3*32*32))
          for idx, i in enumerate(output):
              if t.argmax(i) == y[idx]:
                  correct +=1
              total +=1
  return round(correct/total, 3)*100

# %%
def train_model(model, epochs, train_dataset, test_dataset, optimizer, scheduler, LR_type):
  epoch_number = 0

  losses = []
  train_accuracy = []
  test_accuracy = []

  for epoch in range(epochs):
      print('EPOCH {}:'.format(epoch_number + 1))

      # Make sure gradient tracking is on, and do a pass over the data
      model.train(True)
      avg_loss = train_one_epoch(model, epoch_number,optimizer,train_dataset)
      losses.append(avg_loss)

      # Train accuracy
      train_acc = test(model, train_dataset)
      train_accuracy.append(train_acc)

      # Test accuracy
      test_acc = test(model, test_dataset)
      test_accuracy.append(test_acc)

      if LR_type=='Plateau':
        before_lr = optimizer.param_groups[0]["lr"]
        scheduler.step(avg_loss)
        after_lr = optimizer.param_groups[0]["lr"]
        print('lr {} -> {}'.format(before_lr, after_lr))

      elif LR_type!='None':
        before_lr = optimizer.param_groups[0]["lr"]
        scheduler.step()
        after_lr = optimizer.param_groups[0]["lr"]
        print('lr {} -> {}'.format(before_lr, after_lr))

      print('Train accuracy {}:'.format(train_acc))
      print('Test accuracy {}:'.format(test_acc))
      epoch_number += 1
  return losses, train_accuracy, test_accuracy

# %%
import datetime as dt

def train_with_scheduler(lr_type, starting_lr):
  losses_arr = []
  train_accuracy_arr = []
  test_accuracy_arr = []
  description = []
  if(lr_type=='Step'):
    gamma = 0.1
    step_sizes = [25]
    for s in step_sizes:
      net_new = Net()
      optimizerr = t.optim.SGD(net_new.parameters(), lr=starting_lr)
      scheduler = StepLR(optimizerr, 25, gamma=gamma)
      print('Scheduler: {}, Gamma: {}, current LR: {}'.format(lr_type, gamma, optimizerr.param_groups[0]["lr"]))

      losses, train_accuracy, test_accuracy = train_model(net_new, num_epochs, train_loader, test_loader, optimizerr, scheduler, 'Step')

      losses_arr.append(losses)
      train_accuracy_arr.append(train_accuracy)
      test_accuracy_arr.append(test_accuracy)
      description.append('LR={}, Scheduler=Step, Gamma: {}'.format(starting_lr, gamma))

      # save model
      ts_now = dt.datetime.now()
      unix_timestamp = dt.datetime.timestamp(ts_now)*1000
      model_save_name = str(unix_timestamp)
      path = F"{model_save_name}_{lr_type}_bs{128}_e{num_epochs}_SGD_gamma{gamma}_cifar.pt"
      t.save(net_new.state_dict(), path)

  elif(lr_type=='Plateau'):
    factor = [0.1]
    for f in factor:
      net_new = Net()
      optimizerr = t.optim.SGD(net_new.parameters(), lr=starting_lr)
      scheduler = ReduceLROnPlateau(optimizerr, mode='min', factor=f, patience=20, min_lr=1e-5, verbose=True)
      print('Scheduler: {}, Factor: {}, current LR: {}'.format(lr_type, f, optimizerr.param_groups[0]["lr"]))

      losses, train_accuracy, test_accuracy = train_model(net_new, num_epochs, train_loader, test_loader, optimizerr, scheduler, 'Plateau')

      losses_arr.append(losses)
      train_accuracy_arr.append(train_accuracy)
      test_accuracy_arr.append(test_accuracy)
      description.append('LR={}, Scheduler=Plateau'.format(starting_lr))

      # save model
      ts_now = dt.datetime.now()
      unix_timestamp = dt.datetime.timestamp(ts_now)*1000
      model_save_name = str(unix_timestamp)
      path = F"{model_save_name}_{lr_type}_bs{128}_e{num_epochs}_cifar.pt"
      t.save(net_new.state_dict(), path)

  elif(lr_type=='Exponential'):
    gamma = [0.95]
    for g in gamma:
      net_new = Net()
      optimizerr = t.optim.SGD(net_new.parameters(), lr=starting_lr, momentum=0.9)
      scheduler = ExponentialLR(optimizerr, gamma=g)
      print('Scheduler: {}, Gamma: {}, current LR: {}'.format(lr_type, g, optimizerr.param_groups[0]["lr"]))

      losses, train_accuracy, test_accuracy = train_model(net_new, num_epochs, train_loader, test_loader, optimizerr, scheduler, 'Exponential')

      losses_arr.append(losses)
      train_accuracy_arr.append(train_accuracy)
      test_accuracy_arr.append(test_accuracy)
      description.append('LR={}, Scheduler=Exponential, Gamma: {}'.format(starting_lr, g))

      # save model
      ts_now = dt.datetime.now()
      unix_timestamp = dt.datetime.timestamp(ts_now)*1000
      model_save_name = str(unix_timestamp)
      path = F"{model_save_name}_{lr_type}_bs{128}_e{num_epochs}_gamma{g}_cifar.pt"
      t.save(net_new.state_dict(), path)
  return description, losses_arr, train_accuracy_arr, test_accuracy_arr

# %%
import csv
def save_to_csv(filename, description, losses_arr, train_acc_arr, test_acc_arr):
  # Create a CSV file and write data to it
  with open(+filename+'.csv', 'w', newline='') as csvfile:
    for i, desc in enumerate(description):
      fieldnames = ['Description', 'epoch', 'train_loss', 'train_accuracy', 'test_accuracy']
      writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
      writer.writeheader()
      for epoch, (loss, train, test) in enumerate(zip(losses_arr[i], train_acc_arr[i], test_acc_arr[i]), 1):
          writer.writerow({'Description':description[i], 'epoch': epoch, 'train_loss': loss, 'train_accuracy': train, 'test_accuracy': test})

# %%
# Different LR schedulers
LR_types = ['Step', 'Plateau', 'Exponential']
losses_arr = []
train_accuracy_arr = []
test_accuracy_arr = []
description = []

for lrtype in LR_types:
    d, l, tr, test_ = train_with_scheduler(lrtype, 0.01)
    for dd in d:
        description.append(dd)
    for ll in l:
        losses_arr.append(ll)
    for tt in tr:
        train_accuracy_arr.append(tt)
    for te in test_:
        test_accuracy_arr.append(te)
# Out:
# Scheduler: Step, Gamma: 0.1, current LR: 0.01
# EPOCH 1:
#  batch 100 loss: 2.0429966795444487
#  batch 200 loss: 1.8869377171993256
#  batch 300 loss: 1.84661638379097
# lr 0.01 -> 0.01
# Train accuracy 38.800000000000004:
# Test accuracy 38.3:
# EPOCH 2:
#  batch 100 loss: 1.7870690143108368
#  batch 200 loss: 1.7850141632556915
#  batch 300 loss: 1.7838757395744325
# lr 0.01 -> 0.01
# Train accuracy 40.5:
# Test accuracy 39.7:
# EPOCH 3:
#  batch 100 loss: 1.74288152217865
#  batch 200 loss: 1.759319748878479
#  batch 300 loss: 1.7569441199302673
# lr 0.01 -> 0.01
# Train accuracy 41.699999999999996:
# Test accuracy 40.9:
# EPOCH 4:
#  batch 100 loss: 1.738431489467621
#  batch 200 loss: 1.7348064386844635
#  batch 300 loss: 1.7366662168502807
# lr 0.01 -> 0.01
# Train accuracy 41.6:
# Test accuracy 40.300000000000004:
# EPOCH 5:
#  batch 100 loss: 1.715430645942688
#  batch 200 loss: 1.7277598285675049
#  batch 300 loss: 1.7184685730934144
# lr 0.01 -> 0.01
# Train accuracy 42.3:
# Test accuracy 40.8:
# EPOCH 6:
#  batch 100 loss: 1.7007385098934173
#  batch 200 loss: 1.7121928977966308
#  batch 300 loss: 1.7148811686038972
# lr 0.01 -> 0.01
# Train accuracy 42.699999999999996:
# Test accuracy 40.9:
# EPOCH 7:
#  batch 100 loss: 1.699079246520996
#  batch 200 loss: 1.698540025949478
#  batch 300 loss: 1.7173828494548797
# lr 0.01 -> 0.01
# Train accuracy 43.1:
# Test accuracy 41.3:
# EPOCH 8:
#  batch 100 loss: 1.6992253291606902
#  batch 200 loss: 1.6978711009025573
#  batch 300 loss: 1.6958777928352355
# lr 0.01 -> 0.01
# Train accuracy 43.2:
# Test accuracy 41.3:
# EPOCH 9:
#  batch 100 loss: 1.694693478345871
#  batch 200 loss: 1.693833168745041
#  batch 300 loss: 1.6880618286132814
# lr 0.01 -> 0.01
# Train accuracy 43.2:
# Test accuracy 41.5:
# EPOCH 10:
#  batch 100 loss: 1.6916178596019744
#  batch 200 loss: 1.6855635678768157
#  batch 300 loss: 1.6876163685321808
# lr 0.01 -> 0.01
# Train accuracy 43.4:
# Test accuracy 41.3:
# EPOCH 11:
#  batch 100 loss: 1.6834309828281402
#  batch 200 loss: 1.6949166691303252
#  batch 300 loss: 1.6670190167427064
# lr 0.01 -> 0.01
# Train accuracy 44.0:
# Test accuracy 41.6:
# EPOCH 12:
#  batch 100 loss: 1.6670163249969483
#  batch 200 loss: 1.6796796309947968
#  batch 300 loss: 1.677681941986084
# lr 0.01 -> 0.01
# Train accuracy 43.8:
# Test accuracy 41.4:
# EPOCH 13:
#  batch 100 loss: 1.6675363194942474
#  batch 200 loss: 1.6851808857917785
#  batch 300 loss: 1.6741355752944946
# lr 0.01 -> 0.01
# Train accuracy 44.3:
# Test accuracy 41.4:
# EPOCH 14:
#  batch 100 loss: 1.6521924567222595
#  batch 200 loss: 1.6734755039215088
#  batch 300 loss: 1.6669641888141633
# lr 0.01 -> 0.01
# Train accuracy 44.1:
# Test accuracy 41.6:
# EPOCH 15:
#  batch 100 loss: 1.6626063227653503
#  batch 200 loss: 1.6588351833820343
#  batch 300 loss: 1.676145623922348
# lr 0.01 -> 0.01
# Train accuracy 44.3:
# Test accuracy 41.199999999999996:
# EPOCH 16:
#  batch 100 loss: 1.6576207077503204
#  batch 200 loss: 1.6540563952922822
#  batch 300 loss: 1.6706496679782867
# lr 0.01 -> 0.01
# Train accuracy 44.5:
# Test accuracy 41.699999999999996:
# EPOCH 17:
#  batch 100 loss: 1.6569720315933227
#  batch 200 loss: 1.6668105161190032
#  batch 300 loss: 1.6589576601982117
# lr 0.01 -> 0.01
# Train accuracy 44.4:
# Test accuracy 41.099999999999994:
# EPOCH 18:
#  batch 100 loss: 1.656044887304306
#  batch 200 loss: 1.6583755576610566
#  batch 300 loss: 1.6608605360984803
# lr 0.01 -> 0.01
# Train accuracy 44.5:
# Test accuracy 41.4:
# EPOCH 19:
#  batch 100 loss: 1.6664376831054688
#  batch 200 loss: 1.6477801477909089
#  batch 300 loss: 1.6641063714027404
# lr 0.01 -> 0.01
# Train accuracy 44.800000000000004:
# Test accuracy 41.699999999999996:
# EPOCH 20:
#  batch 100 loss: 1.6342210268974304
#  batch 200 loss: 1.6631506156921387
#  batch 300 loss: 1.6617257440090178
# lr 0.01 -> 0.01
# Train accuracy 44.2:
# Test accuracy 41.199999999999996:
# EPOCH 21:
#  batch 100 loss: 1.665288679599762
#  batch 200 loss: 1.6377440237998961
#  batch 300 loss: 1.6412863183021544
# lr 0.01 -> 0.01
# Train accuracy 44.4:
# Test accuracy 41.699999999999996:
# EPOCH 22:
#  batch 100 loss: 1.6493465662002564
#  batch 200 loss: 1.6465318322181701
#  batch 300 loss: 1.6597594225406647
# lr 0.01 -> 0.01
# Train accuracy 45.1:
# Test accuracy 41.6:
# EPOCH 23:
#  batch 100 loss: 1.652705156803131
#  batch 200 loss: 1.6501751017570496
#  batch 300 loss: 1.6425691866874694
# lr 0.01 -> 0.01
# Train accuracy 45.0:
# Test accuracy 41.5:
# EPOCH 24:
#  batch 100 loss: 1.6409002447128296
#  batch 200 loss: 1.6264145958423615
#  batch 300 loss: 1.6541512942314147
# lr 0.01 -> 0.01
# Train accuracy 44.9:
# Test accuracy 41.699999999999996:
# EPOCH 25:
#  batch 100 loss: 1.6463569486141205
#  batch 200 loss: 1.6470893502235413
#  batch 300 loss: 1.6361163902282714
# lr 0.01 -> 0.001
# Train accuracy 45.1:
# Test accuracy 41.4:
# EPOCH 26:
#  batch 100 loss: 1.6378325533866882
#  batch 200 loss: 1.6321073067188263
#  batch 300 loss: 1.6265994703769684
# lr 0.001 -> 0.001
# Train accuracy 45.4:
# Test accuracy 42.0:
# EPOCH 27:
#  batch 100 loss: 1.6409940540790557
#  batch 200 loss: 1.6268075037002563
#  batch 300 loss: 1.6259737813472748
# lr 0.001 -> 0.001
# Train accuracy 45.5:
# Test accuracy 41.8:
# EPOCH 28:
#  batch 100 loss: 1.6300507497787475
#  batch 200 loss: 1.6284445333480835
#  batch 300 loss: 1.6314104473590851
# lr 0.001 -> 0.001
# Train accuracy 45.5:
# Test accuracy 41.699999999999996:
# EPOCH 29:
#  batch 100 loss: 1.6417031168937684
#  batch 200 loss: 1.6264379298686982
#  batch 300 loss: 1.636986767053604
# lr 0.001 -> 0.001
# Train accuracy 45.5:
# Test accuracy 41.699999999999996:
# EPOCH 30:
#  batch 100 loss: 1.6258206462860108
#  batch 200 loss: 1.6334498476982118
#  batch 300 loss: 1.6417327916622162
# lr 0.001 -> 0.001
# Train accuracy 45.6:
# Test accuracy 41.8:
# EPOCH 31:
#  batch 100 loss: 1.6379884231090545
#  batch 200 loss: 1.6256884729862213
#  batch 300 loss: 1.6380342102050782
# lr 0.001 -> 0.001
# Train accuracy 45.6:
# Test accuracy 41.8:
# EPOCH 32:
#  batch 100 loss: 1.6360041844844817
#  batch 200 loss: 1.6284986865520477
#  batch 300 loss: 1.6324973320960998
# lr 0.001 -> 0.001
# Train accuracy 45.5:
# Test accuracy 41.8:
# EPOCH 33:
#  batch 100 loss: 1.6268250465393066
#  batch 200 loss: 1.6357079863548278
#  batch 300 loss: 1.63077246427536
# lr 0.001 -> 0.001
# Train accuracy 45.5:
# Test accuracy 41.699999999999996:
# EPOCH 34:
#  batch 100 loss: 1.6288568139076234
#  batch 200 loss: 1.6309855139255525
#  batch 300 loss: 1.6232289624214173
# lr 0.001 -> 0.001
# Train accuracy 45.5:
# Test accuracy 41.8:
# EPOCH 35:
#  batch 100 loss: 1.625627999305725
#  batch 200 loss: 1.6260942840576171
#  batch 300 loss: 1.6389895248413087
# lr 0.001 -> 0.001
# Train accuracy 45.5:
# Test accuracy 41.9:
# EPOCH 36:
#  batch 100 loss: 1.62151220202446
#  batch 200 loss: 1.6349198818206787
#  batch 300 loss: 1.6297405886650085
# lr 0.001 -> 0.001
# Train accuracy 45.5:
# Test accuracy 41.9:
# EPOCH 37:
#  batch 100 loss: 1.6270124542713165
#  batch 200 loss: 1.6308201670646667
#  batch 300 loss: 1.6222442805767059
# lr 0.001 -> 0.001
# Train accuracy 45.6:
# Test accuracy 41.9:
# EPOCH 38:
#  batch 100 loss: 1.6281383371353149
#  batch 200 loss: 1.6319693768024444
#  batch 300 loss: 1.6285252714157104
# lr 0.001 -> 0.001
# Train accuracy 45.5:
# Test accuracy 41.8:
# EPOCH 39:
#  batch 100 loss: 1.64056916475296
#  batch 200 loss: 1.615473815202713
#  batch 300 loss: 1.6213818061351777
# lr 0.001 -> 0.001
# Train accuracy 45.6:
# Test accuracy 41.699999999999996:
# EPOCH 40:
#  batch 100 loss: 1.6338127613067628
#  batch 200 loss: 1.6298702847957611
#  batch 300 loss: 1.6287442862987518
# lr 0.001 -> 0.001
# Train accuracy 45.6:
# Test accuracy 41.8:
# EPOCH 41:
#  batch 100 loss: 1.6369317162036896
#  batch 200 loss: 1.6274177253246307
#  batch 300 loss: 1.6357399499416352
# lr 0.001 -> 0.001
# Train accuracy 45.6:
# Test accuracy 42.0:
# EPOCH 42:
#  batch 100 loss: 1.6188000571727752
#  batch 200 loss: 1.6458825278282165
#  batch 300 loss: 1.6314176285266877
# lr 0.001 -> 0.001
# Train accuracy 45.5:
# Test accuracy 41.699999999999996:
# EPOCH 43:
#  batch 100 loss: 1.6380001723766326
#  batch 200 loss: 1.6191359925270081
#  batch 300 loss: 1.621753407716751
# lr 0.001 -> 0.001
# Train accuracy 45.5:
# Test accuracy 41.699999999999996:
# EPOCH 44:
#  batch 100 loss: 1.6216150140762329
#  batch 200 loss: 1.640553216934204
#  batch 300 loss: 1.616886236667633
# lr 0.001 -> 0.001
# Train accuracy 45.6:
# Test accuracy 41.9:
# EPOCH 45:
#  batch 100 loss: 1.627612851858139
#  batch 200 loss: 1.6220932960510255
#  batch 300 loss: 1.6306515967845916
# lr 0.001 -> 0.001
# Train accuracy 45.6:
# Test accuracy 41.8:
# EPOCH 46:
#  batch 100 loss: 1.6322193777561187
#  batch 200 loss: 1.6297830379009246
#  batch 300 loss: 1.6211193311214447
# lr 0.001 -> 0.001
# Train accuracy 45.6:
# Test accuracy 41.9:
# EPOCH 47:
#  batch 100 loss: 1.6296659541130065
#  batch 200 loss: 1.6316493439674378
#  batch 300 loss: 1.6324767088890075
# lr 0.001 -> 0.001
# Train accuracy 45.6:
# Test accuracy 41.8:
# EPOCH 48:
#  batch 100 loss: 1.6244959592819215
#  batch 200 loss: 1.6242909049987793
#  batch 300 loss: 1.6248149240016938
# lr 0.001 -> 0.001
# Train accuracy 45.6:
# Test accuracy 41.8:
# EPOCH 49:
#  batch 100 loss: 1.6259624409675597
#  batch 200 loss: 1.6267321372032166
#  batch 300 loss: 1.6345615375041962
# lr 0.001 -> 0.001
# Train accuracy 45.7:
# Test accuracy 41.8:
# EPOCH 50:
#  batch 100 loss: 1.6204904794692994
#  batch 200 loss: 1.6274664211273193
#  batch 300 loss: 1.637917878627777
# lr 0.001 -> 0.0001
# Train accuracy 45.6:
# Test accuracy 41.8:
# EPOCH 51:
#  batch 100 loss: 1.6163401114940643
#  batch 200 loss: 1.6438114964962005
#  batch 300 loss: 1.6148873257637024
# lr 0.0001 -> 0.0001
# Train accuracy 45.6:
# Test accuracy 41.8:
# EPOCH 52:
#  batch 100 loss: 1.6286833024024963
#  batch 200 loss: 1.6191239488124847
#  batch 300 loss: 1.6280470442771913
# lr 0.0001 -> 0.0001
# Train accuracy 45.6:
# Test accuracy 41.699999999999996:
# EPOCH 53:
#  batch 100 loss: 1.6296427047252655
#  batch 200 loss: 1.6107301259040832
#  batch 300 loss: 1.6207344400882722
# lr 0.0001 -> 0.0001
# Train accuracy 45.6:
# Test accuracy 41.699999999999996:
# EPOCH 54:
#  batch 100 loss: 1.6255749666690826
#  batch 200 loss: 1.619228231906891
#  batch 300 loss: 1.6378841280937195
# lr 0.0001 -> 0.0001
# Train accuracy 45.6:
# Test accuracy 41.699999999999996:
# EPOCH 55:
#  batch 100 loss: 1.6212535750865937
#  batch 200 loss: 1.6350369215011598
#  batch 300 loss: 1.6278577613830567
# lr 0.0001 -> 0.0001
# Train accuracy 45.6:
# Test accuracy 41.699999999999996:
# EPOCH 56:
#  batch 100 loss: 1.634500379562378
#  batch 200 loss: 1.6492610991001129
#  batch 300 loss: 1.6025517797470092
# lr 0.0001 -> 0.0001
# Train accuracy 45.6:
# Test accuracy 41.8:
# EPOCH 57:
#  batch 100 loss: 1.6183735251426696
#  batch 200 loss: 1.6122480571269988
#  batch 300 loss: 1.6240205514430999
# lr 0.0001 -> 0.0001
# Train accuracy 45.7:
# Test accuracy 41.699999999999996:
# EPOCH 58:
#  batch 100 loss: 1.625560187101364
#  batch 200 loss: 1.6335538160800933
#  batch 300 loss: 1.611483770608902
# lr 0.0001 -> 0.0001
# Train accuracy 45.7:
# Test accuracy 41.699999999999996:
# EPOCH 59:
#  batch 100 loss: 1.6228450286388396
#  batch 200 loss: 1.6275092732906342
#  batch 300 loss: 1.6164145028591157
# lr 0.0001 -> 0.0001
# Train accuracy 45.7:
# Test accuracy 41.699999999999996:
# EPOCH 60:
#  batch 100 loss: 1.6238329792022705
#  batch 200 loss: 1.618151090145111
#  batch 300 loss: 1.6255366802215576
# lr 0.0001 -> 0.0001
# Train accuracy 45.7:
# Test accuracy 41.699999999999996:
# EPOCH 61:
#  batch 100 loss: 1.6248117661476136
#  batch 200 loss: 1.6313757848739625
#  batch 300 loss: 1.6284631621837615
# lr 0.0001 -> 0.0001
# Train accuracy 45.7:
# Test accuracy 41.699999999999996:
# EPOCH 62:
#  batch 100 loss: 1.6390307939052582
#  batch 200 loss: 1.6268134653568267
#  batch 300 loss: 1.605560587644577
# lr 0.0001 -> 0.0001
# Train accuracy 45.7:
# Test accuracy 41.699999999999996:
# EPOCH 63:
#  batch 100 loss: 1.6218702650070191
#  batch 200 loss: 1.6268534255027771
#  batch 300 loss: 1.6285568404197692
# lr 0.0001 -> 0.0001
# Train accuracy 45.7:
# Test accuracy 41.699999999999996:
# EPOCH 64:
#  batch 100 loss: 1.6216876459121705
#  batch 200 loss: 1.630511234998703
#  batch 300 loss: 1.619334133863449
# lr 0.0001 -> 0.0001
# Train accuracy 45.7:
# Test accuracy 41.699999999999996:
# EPOCH 65:
#  batch 100 loss: 1.6349756228923797
#  batch 200 loss: 1.6248985099792481
#  batch 300 loss: 1.6205233681201934
# lr 0.0001 -> 0.0001
# Train accuracy 45.6:
# Test accuracy 41.699999999999996:
# EPOCH 66:
#  batch 100 loss: 1.6317512750625611
#  batch 200 loss: 1.6171378207206726
#  batch 300 loss: 1.6273606467247008
# lr 0.0001 -> 0.0001
# Train accuracy 45.7:
# Test accuracy 41.699999999999996:
# EPOCH 67:
#  batch 100 loss: 1.6122677314281464
#  batch 200 loss: 1.6203232896327973
#  batch 300 loss: 1.6354035687446595
# lr 0.0001 -> 0.0001
# Train accuracy 45.7:
# Test accuracy 41.699999999999996:
# EPOCH 68:
#  batch 100 loss: 1.6263953256607055
#  batch 200 loss: 1.6281535804271698
#  batch 300 loss: 1.6309759509563446
# lr 0.0001 -> 0.0001
# Train accuracy 45.7:
# Test accuracy 41.699999999999996:
# EPOCH 69:
#  batch 100 loss: 1.6127915060520173
#  batch 200 loss: 1.6250087428092956
#  batch 300 loss: 1.6446497225761414
# lr 0.0001 -> 0.0001
# Train accuracy 45.7:
# Test accuracy 41.699999999999996:
# EPOCH 70:
#  batch 100 loss: 1.6235180139541625
#  batch 200 loss: 1.6157504844665527
#  batch 300 loss: 1.628899005651474
# lr 0.0001 -> 0.0001
# Train accuracy 45.7:
# Test accuracy 41.699999999999996:
# EPOCH 71:
#  batch 100 loss: 1.6308108794689178
#  batch 200 loss: 1.614562519788742
#  batch 300 loss: 1.6366871356964112
# lr 0.0001 -> 0.0001
# Train accuracy 45.7:
# Test accuracy 41.699999999999996:
# EPOCH 72:
#  batch 100 loss: 1.637037261724472
#  batch 200 loss: 1.625812245607376
#  batch 300 loss: 1.6156523871421813
# lr 0.0001 -> 0.0001
# Train accuracy 45.7:
# Test accuracy 41.699999999999996:
# EPOCH 73:
#  batch 100 loss: 1.6302374196052551
#  batch 200 loss: 1.62151540517807
#  batch 300 loss: 1.613823561668396
# lr 0.0001 -> 0.0001
# Train accuracy 45.7:
# Test accuracy 41.699999999999996:
# EPOCH 74:
#  batch 100 loss: 1.628026669025421
#  batch 200 loss: 1.6255776512622833
#  batch 300 loss: 1.6238898932933807
# lr 0.0001 -> 0.0001
# Train accuracy 45.7:
# Test accuracy 41.699999999999996:
# EPOCH 75:
#  batch 100 loss: 1.6131341826915742
#  batch 200 loss: 1.6353959321975708
#  batch 300 loss: 1.6190099930763244
# lr 0.0001 -> 1e-05
# Train accuracy 45.7:
# Test accuracy 41.699999999999996:
# EPOCH 76:
#  batch 100 loss: 1.6368252789974214
#  batch 200 loss: 1.619649531841278
#  batch 300 loss: 1.6148810386657715
# lr 1e-05 -> 1e-05
# Train accuracy 45.7:
# Test accuracy 41.699999999999996:
# EPOCH 77:
#  batch 100 loss: 1.6376108610630036
#  batch 200 loss: 1.622683845758438
#  batch 300 loss: 1.6192977821826935
# lr 1e-05 -> 1e-05
# Train accuracy 45.7:
# Test accuracy 41.699999999999996:
# EPOCH 78:
#  batch 100 loss: 1.6241274988651275
#  batch 200 loss: 1.620614264011383
#  batch 300 loss: 1.6204355919361115
# lr 1e-05 -> 1e-05
# Train accuracy 45.7:
# Test accuracy 41.699999999999996:
# EPOCH 79:
#  batch 100 loss: 1.6284180104732513
#  batch 200 loss: 1.6233611106872559
#  batch 300 loss: 1.6260525703430175
# lr 1e-05 -> 1e-05
# Train accuracy 45.7:
# Test accuracy 41.699999999999996:
# EPOCH 80:
#  batch 100 loss: 1.6341348195075989
#  batch 200 loss: 1.6066756880283355
#  batch 300 loss: 1.6242721557617188
# lr 1e-05 -> 1e-05
# Train accuracy 45.7:
# Test accuracy 41.699999999999996:
# EPOCH 81:
#  batch 100 loss: 1.620795705318451
#  batch 200 loss: 1.6439059257507325
#  batch 300 loss: 1.6288964438438416
# lr 1e-05 -> 1e-05
# Train accuracy 45.7:
# Test accuracy 41.699999999999996:
# EPOCH 82:
#  batch 100 loss: 1.6317208302021027
#  batch 200 loss: 1.6218322825431823
#  batch 300 loss: 1.6250485360622406
# lr 1e-05 -> 1e-05
# Train accuracy 45.7:
# Test accuracy 41.699999999999996:
# EPOCH 83:
#  batch 100 loss: 1.6341299867630006
#  batch 200 loss: 1.6279351246356963
#  batch 300 loss: 1.6157497549057007
# lr 1e-05 -> 1e-05
# Train accuracy 45.7:
# Test accuracy 41.699999999999996:
# EPOCH 84:
#  batch 100 loss: 1.6268382608890533
#  batch 200 loss: 1.6220245444774628
#  batch 300 loss: 1.6307630634307861
# lr 1e-05 -> 1e-05
# Train accuracy 45.7:
# Test accuracy 41.699999999999996:
# EPOCH 85:
#  batch 100 loss: 1.6254769730567933
#  batch 200 loss: 1.622666426897049
#  batch 300 loss: 1.6281215751171112
# lr 1e-05 -> 1e-05
# Train accuracy 45.7:
# Test accuracy 41.699999999999996:
# EPOCH 86:
#  batch 100 loss: 1.6240976786613464
#  batch 200 loss: 1.635959680080414
#  batch 300 loss: 1.6092179596424103
# lr 1e-05 -> 1e-05
# Train accuracy 45.7:
# Test accuracy 41.699999999999996:
# EPOCH 87:
#  batch 100 loss: 1.6322528219223023
#  batch 200 loss: 1.6241940295696258
#  batch 300 loss: 1.625599557161331
# lr 1e-05 -> 1e-05
# Train accuracy 45.7:
# Test accuracy 41.699999999999996:
# EPOCH 88:
#  batch 100 loss: 1.6424805200099946
#  batch 200 loss: 1.6284817481040954
#  batch 300 loss: 1.6171254551410674
# lr 1e-05 -> 1e-05
# Train accuracy 45.7:
# Test accuracy 41.699999999999996:
# EPOCH 89:
#  batch 100 loss: 1.6212196409702302
#  batch 200 loss: 1.618409868478775
#  batch 300 loss: 1.6328486168384553
# lr 1e-05 -> 1e-05
# Train accuracy 45.7:
# Test accuracy 41.699999999999996:
# EPOCH 90:
#  batch 100 loss: 1.6245324683189393
#  batch 200 loss: 1.6089440751075745
#  batch 300 loss: 1.625198392868042
# lr 1e-05 -> 1e-05
# Train accuracy 45.7:
# Test accuracy 41.699999999999996:
# EPOCH 91:
#  batch 100 loss: 1.6283583128452301
#  batch 200 loss: 1.630180708169937
#  batch 300 loss: 1.6414993107318878
# lr 1e-05 -> 1e-05
# Train accuracy 45.7:
# Test accuracy 41.699999999999996:
# EPOCH 92:
#  batch 100 loss: 1.6415641272068024
#  batch 200 loss: 1.614203691482544
#  batch 300 loss: 1.623127702474594
# lr 1e-05 -> 1e-05
# Train accuracy 45.7:
# Test accuracy 41.699999999999996:
# EPOCH 93:
#  batch 100 loss: 1.6251205492019654
#  batch 200 loss: 1.6245254707336425
#  batch 300 loss: 1.627508555650711
# lr 1e-05 -> 1e-05
# Train accuracy 45.7:
# Test accuracy 41.699999999999996:
# EPOCH 94:
#  batch 100 loss: 1.6348256182670593
#  batch 200 loss: 1.6194974172115326
#  batch 300 loss: 1.6156349050998688
# lr 1e-05 -> 1e-05
# Train accuracy 45.7:
# Test accuracy 41.699999999999996:
# EPOCH 95:
#  batch 100 loss: 1.6286269950866699
#  batch 200 loss: 1.6263189458847045
#  batch 300 loss: 1.6223404335975646
# lr 1e-05 -> 1e-05
# Train accuracy 45.7:
# Test accuracy 41.699999999999996:
# EPOCH 96:
#  batch 100 loss: 1.6190829646587372
#  batch 200 loss: 1.62949236035347
#  batch 300 loss: 1.6256922781467438
# lr 1e-05 -> 1e-05
# Train accuracy 45.7:
# Test accuracy 41.699999999999996:
# EPOCH 97:
#  batch 100 loss: 1.6277482450008391
#  batch 200 loss: 1.6265510547161102
#  batch 300 loss: 1.6191318464279174
# lr 1e-05 -> 1e-05
# Train accuracy 45.7:
# Test accuracy 41.699999999999996:
# EPOCH 98:
#  batch 100 loss: 1.6273575699329377
#  batch 200 loss: 1.6247473073005676
#  batch 300 loss: 1.6211307084560393
# lr 1e-05 -> 1e-05
# Train accuracy 45.7:
# Test accuracy 41.699999999999996:
# EPOCH 99:
#  batch 100 loss: 1.6339641189575196
#  batch 200 loss: 1.6232181632518767
#  batch 300 loss: 1.627059165239334
# lr 1e-05 -> 1e-05
# Train accuracy 45.7:
# Test accuracy 41.699999999999996:
# EPOCH 100:
#  batch 100 loss: 1.6267621064186095
#  batch 200 loss: 1.6223819315433503
#  batch 300 loss: 1.6340165376663207
# lr 1e-05 -> 1.0000000000000002e-06
# Train accuracy 45.7:
# Test accuracy 41.699999999999996:
# Scheduler: Plateau, Factor: 0.1, current LR: 0.01
# EPOCH 1:
#  batch 100 loss: 2.0310696709156035
#  batch 200 loss: 1.8891796684265136
#  batch 300 loss: 1.8304132616519928
# lr 0.01 -> 0.01
# Train accuracy 39.2:
# Test accuracy 38.2:
# EPOCH 2:
#  batch 100 loss: 1.7993464958667755
#  batch 200 loss: 1.7919407415390014
#  batch 300 loss: 1.7715454959869386
# lr 0.01 -> 0.01
# Train accuracy 40.8:
# Test accuracy 40.0:
# EPOCH 3:
#  batch 100 loss: 1.7462304413318634
#  batch 200 loss: 1.766203134059906
#  batch 300 loss: 1.745143219232559
# lr 0.01 -> 0.01
# Train accuracy 41.6:
# Test accuracy 40.699999999999996:
# EPOCH 4:
#  batch 100 loss: 1.7411460864543915
#  batch 200 loss: 1.7281205868721008
#  batch 300 loss: 1.7363106751441955
# lr 0.01 -> 0.01
# Train accuracy 42.199999999999996:
# Test accuracy 41.099999999999994:
# EPOCH 5:
#  batch 100 loss: 1.7233079671859741
#  batch 200 loss: 1.734328693151474
#  batch 300 loss: 1.720951030254364
# lr 0.01 -> 0.01
# Train accuracy 42.5:
# Test accuracy 40.8:
# EPOCH 6:
#  batch 100 loss: 1.7065095698833466
#  batch 200 loss: 1.7134799563884735
#  batch 300 loss: 1.7101690912246703
# lr 0.01 -> 0.01
# Train accuracy 42.8:
# Test accuracy 41.3:
# EPOCH 7:
#  batch 100 loss: 1.7040875434875489
#  batch 200 loss: 1.7038670837879182
#  batch 300 loss: 1.7052747154235839
# lr 0.01 -> 0.01
# Train accuracy 43.2:
# Test accuracy 41.5:
# EPOCH 8:
#  batch 100 loss: 1.7053801107406616
#  batch 200 loss: 1.6792261159420014
#  batch 300 loss: 1.7075388169288634
# lr 0.01 -> 0.01
# Train accuracy 43.3:
# Test accuracy 41.199999999999996:
# EPOCH 9:
#  batch 100 loss: 1.685659523010254
#  batch 200 loss: 1.6796815192699432
#  batch 300 loss: 1.7013882386684418
# lr 0.01 -> 0.01
# Train accuracy 43.4:
# Test accuracy 41.099999999999994:
# EPOCH 10:
#  batch 100 loss: 1.6902689969539642
#  batch 200 loss: 1.683657977581024
#  batch 300 loss: 1.6747814238071441
# lr 0.01 -> 0.01
# Train accuracy 43.8:
# Test accuracy 41.3:
# EPOCH 11:
#  batch 100 loss: 1.6839189374446868
#  batch 200 loss: 1.6896092665195466
#  batch 300 loss: 1.67380025267601
# lr 0.01 -> 0.01
# Train accuracy 43.8:
# Test accuracy 41.099999999999994:
# EPOCH 12:
#  batch 100 loss: 1.6764581429958343
#  batch 200 loss: 1.672641407251358
#  batch 300 loss: 1.6893380880355835
# lr 0.01 -> 0.01
# Train accuracy 43.9:
# Test accuracy 41.699999999999996:
# EPOCH 13:
#  batch 100 loss: 1.6725528228282929
#  batch 200 loss: 1.6663082945346832
#  batch 300 loss: 1.6785722911357879
# lr 0.01 -> 0.01
# Train accuracy 44.2:
# Test accuracy 41.4:
# EPOCH 14:
#  batch 100 loss: 1.6652186608314514
#  batch 200 loss: 1.6741180968284608
#  batch 300 loss: 1.667281105518341
# lr 0.01 -> 0.01
# Train accuracy 44.1:
# Test accuracy 41.3:
# EPOCH 15:
#  batch 100 loss: 1.6513836181163788
#  batch 200 loss: 1.6777680027484894
#  batch 300 loss: 1.658427882194519
# lr 0.01 -> 0.01
# Train accuracy 44.6:
# Test accuracy 41.3:
# EPOCH 16:
#  batch 100 loss: 1.6637561106681824
#  batch 200 loss: 1.6772972774505615
#  batch 300 loss: 1.6518987011909485
# lr 0.01 -> 0.01
# Train accuracy 44.800000000000004:
# Test accuracy 41.699999999999996:
# EPOCH 17:
#  batch 100 loss: 1.6563777422904968
#  batch 200 loss: 1.6524283456802369
#  batch 300 loss: 1.6658825016021728
# lr 0.01 -> 0.01
# Train accuracy 44.7:
# Test accuracy 41.699999999999996:
# EPOCH 18:
#  batch 100 loss: 1.6502473282814025
#  batch 200 loss: 1.6551272249221802
#  batch 300 loss: 1.6709627258777617
# lr 0.01 -> 0.01
# Train accuracy 44.6:
# Test accuracy 41.4:
# EPOCH 19:
#  batch 100 loss: 1.6532246923446656
#  batch 200 loss: 1.648151967525482
#  batch 300 loss: 1.6572685313224793
# lr 0.01 -> 0.01
# Train accuracy 44.6:
# Test accuracy 41.4:
# EPOCH 20:
#  batch 100 loss: 1.640878391265869
#  batch 200 loss: 1.6591437363624573
#  batch 300 loss: 1.6649652314186096
# lr 0.01 -> 0.01
# Train accuracy 44.800000000000004:
# Test accuracy 41.9:
# EPOCH 21:
#  batch 100 loss: 1.6407805705070495
#  batch 200 loss: 1.6416613924503327
#  batch 300 loss: 1.6632366514205932
# lr 0.01 -> 0.01
# Train accuracy 44.9:
# Test accuracy 41.8:
# EPOCH 22:
#  batch 100 loss: 1.63641130566597
#  batch 200 loss: 1.6623761129379273
#  batch 300 loss: 1.6554378032684327
# lr 0.01 -> 0.01
# Train accuracy 44.800000000000004:
# Test accuracy 41.6:
# EPOCH 23:
#  batch 100 loss: 1.6328001010417938
#  batch 200 loss: 1.6415144884586335
#  batch 300 loss: 1.6570812118053437
# lr 0.01 -> 0.01
# Train accuracy 45.300000000000004:
# Test accuracy 41.6:
# EPOCH 24:
#  batch 100 loss: 1.6466810750961303
#  batch 200 loss: 1.64384659409523
#  batch 300 loss: 1.6430971598625184
# lr 0.01 -> 0.01
# Train accuracy 45.1:
# Test accuracy 41.6:
# EPOCH 25:
#  batch 100 loss: 1.6385315454006195
#  batch 200 loss: 1.635042542219162
#  batch 300 loss: 1.6430449652671815
# lr 0.01 -> 0.01
# Train accuracy 45.2:
# Test accuracy 41.8:
# EPOCH 26:
#  batch 100 loss: 1.6352847635746002
#  batch 200 loss: 1.651388578414917
#  batch 300 loss: 1.6441105008125305
# lr 0.01 -> 0.01
# Train accuracy 45.2:
# Test accuracy 41.5:
# EPOCH 27:
#  batch 100 loss: 1.6449599730968476
#  batch 200 loss: 1.640722600221634
#  batch 300 loss: 1.6345237624645232
# lr 0.01 -> 0.01
# Train accuracy 44.9:
# Test accuracy 41.5:
# EPOCH 28:
#  batch 100 loss: 1.6397324430942535
#  batch 200 loss: 1.6279521334171294
#  batch 300 loss: 1.6379517269134523
# lr 0.01 -> 0.01
# Train accuracy 45.300000000000004:
# Test accuracy 41.699999999999996:
# EPOCH 29:
#  batch 100 loss: 1.6350060939788817
#  batch 200 loss: 1.6223053777217864
#  batch 300 loss: 1.6449143421649932
# lr 0.01 -> 0.01
# Train accuracy 45.300000000000004:
# Test accuracy 41.5:
# EPOCH 30:
#  batch 100 loss: 1.6329620230197905
#  batch 200 loss: 1.641611967086792
#  batch 300 loss: 1.6249943685531616
# lr 0.01 -> 0.01
# Train accuracy 45.300000000000004:
# Test accuracy 41.6:
# EPOCH 31:
#  batch 100 loss: 1.6333399403095246
#  batch 200 loss: 1.6357978689670563
#  batch 300 loss: 1.626149617433548
# lr 0.01 -> 0.01
# Train accuracy 45.2:
# Test accuracy 41.4:
# EPOCH 32:
#  batch 100 loss: 1.626355390548706
#  batch 200 loss: 1.6325359773635864
#  batch 300 loss: 1.6383583199977876
# lr 0.01 -> 0.01
# Train accuracy 45.7:
# Test accuracy 41.8:
# EPOCH 33:
#  batch 100 loss: 1.631575471162796
#  batch 200 loss: 1.6252172684669495
#  batch 300 loss: 1.6282233643531798
# lr 0.01 -> 0.01
# Train accuracy 45.300000000000004:
# Test accuracy 41.4:
# EPOCH 34:
#  batch 100 loss: 1.6297785544395447
#  batch 200 loss: 1.6385141348838805
#  batch 300 loss: 1.6344341766834258
# lr 0.01 -> 0.01
# Train accuracy 45.4:
# Test accuracy 41.699999999999996:
# EPOCH 35:
#  batch 100 loss: 1.6105844819545745
#  batch 200 loss: 1.6333213353157043
#  batch 300 loss: 1.624610686302185
# lr 0.01 -> 0.01
# Train accuracy 45.6:
# Test accuracy 41.3:
# EPOCH 36:
#  batch 100 loss: 1.6239939737319946
#  batch 200 loss: 1.623500360250473
#  batch 300 loss: 1.6240625417232513
# lr 0.01 -> 0.01
# Train accuracy 45.7:
# Test accuracy 42.0:
# EPOCH 37:
#  batch 100 loss: 1.6164070415496825
#  batch 200 loss: 1.627010509967804
#  batch 300 loss: 1.636264752149582
# lr 0.01 -> 0.01
# Train accuracy 45.7:
# Test accuracy 42.0:
# EPOCH 38:
#  batch 100 loss: 1.6142051446437835
#  batch 200 loss: 1.6415847063064575
#  batch 300 loss: 1.6190639925003052
# lr 0.01 -> 0.01
# Train accuracy 45.7:
# Test accuracy 41.8:
# EPOCH 39:
#  batch 100 loss: 1.623085411787033
#  batch 200 loss: 1.6201702415943147
#  batch 300 loss: 1.6133403694629669
# lr 0.01 -> 0.01
# Train accuracy 45.9:
# Test accuracy 41.6:
# EPOCH 40:
#  batch 100 loss: 1.6224747157096864
#  batch 200 loss: 1.6257142186164857
#  batch 300 loss: 1.6320973646640777
# lr 0.01 -> 0.01
# Train accuracy 45.6:
# Test accuracy 41.699999999999996:
# EPOCH 41:
#  batch 100 loss: 1.6139500963687896
#  batch 200 loss: 1.6214765572547913
#  batch 300 loss: 1.6184327924251556
# lr 0.01 -> 0.01
# Train accuracy 45.800000000000004:
# Test accuracy 41.8:
# EPOCH 42:
#  batch 100 loss: 1.6241284239292144
#  batch 200 loss: 1.6062922859191895
#  batch 300 loss: 1.6356024193763732
# lr 0.01 -> 0.01
# Train accuracy 45.9:
# Test accuracy 42.0:
# EPOCH 43:
#  batch 100 loss: 1.620728452205658
#  batch 200 loss: 1.6227694964408874
#  batch 300 loss: 1.6157485663890838
# lr 0.01 -> 0.01
# Train accuracy 45.800000000000004:
# Test accuracy 41.9:
# EPOCH 44:
#  batch 100 loss: 1.613814915418625
#  batch 200 loss: 1.623860181570053
#  batch 300 loss: 1.603447847366333
# lr 0.01 -> 0.01
# Train accuracy 45.9:
# Test accuracy 41.6:
# EPOCH 45:
#  batch 100 loss: 1.6092256200313568
#  batch 200 loss: 1.6127882504463196
#  batch 300 loss: 1.6203025376796723
# lr 0.01 -> 0.01
# Train accuracy 45.7:
# Test accuracy 42.0:
# EPOCH 46:
#  batch 100 loss: 1.6201297771930694
#  batch 200 loss: 1.617268180847168
#  batch 300 loss: 1.6130775034427642
# lr 0.01 -> 0.01
# Train accuracy 45.800000000000004:
# Test accuracy 41.5:
# EPOCH 47:
#  batch 100 loss: 1.6064670443534852
#  batch 200 loss: 1.5988937532901764
#  batch 300 loss: 1.624769151210785
# lr 0.01 -> 0.01
# Train accuracy 46.0:
# Test accuracy 41.8:
# EPOCH 48:
#  batch 100 loss: 1.6132880568504333
#  batch 200 loss: 1.6200532126426697
#  batch 300 loss: 1.6048534643650054
# lr 0.01 -> 0.01
# Train accuracy 45.9:
# Test accuracy 41.5:
# EPOCH 49:
#  batch 100 loss: 1.6085178399085998
#  batch 200 loss: 1.6077090144157409
#  batch 300 loss: 1.6206644928455354
# lr 0.01 -> 0.01
# Train accuracy 45.6:
# Test accuracy 41.4:
# EPOCH 50:
#  batch 100 loss: 1.6121609675884248
#  batch 200 loss: 1.6177744948863984
#  batch 300 loss: 1.6151304841041565
# lr 0.01 -> 0.01
# Train accuracy 45.9:
# Test accuracy 41.0:
# EPOCH 51:
#  batch 100 loss: 1.6088802301883698
#  batch 200 loss: 1.623459014892578
#  batch 300 loss: 1.594872317314148
# lr 0.01 -> 0.01
# Train accuracy 45.800000000000004:
# Test accuracy 41.099999999999994:
# EPOCH 52:
#  batch 100 loss: 1.6045075500011443
#  batch 200 loss: 1.6070907878875733
#  batch 300 loss: 1.6017045438289643
# lr 0.01 -> 0.01
# Train accuracy 45.9:
# Test accuracy 41.199999999999996:
# EPOCH 53:
#  batch 100 loss: 1.618692102432251
#  batch 200 loss: 1.5869159698486328
#  batch 300 loss: 1.6051841962337494
# lr 0.01 -> 0.01
# Train accuracy 46.2:
# Test accuracy 41.8:
# EPOCH 54:
#  batch 100 loss: 1.610112316608429
#  batch 200 loss: 1.5969552433490752
#  batch 300 loss: 1.619884672164917
# lr 0.01 -> 0.01
# Train accuracy 46.0:
# Test accuracy 41.4:
# EPOCH 55:
#  batch 100 loss: 1.600542081594467
#  batch 200 loss: 1.6032256662845612
#  batch 300 loss: 1.609133507013321
# lr 0.01 -> 0.01
# Train accuracy 46.0:
# Test accuracy 41.699999999999996:
# EPOCH 56:
#  batch 100 loss: 1.6000315117836
#  batch 200 loss: 1.6038462030887604
#  batch 300 loss: 1.6202307164669036
# lr 0.01 -> 0.01
# Train accuracy 45.5:
# Test accuracy 41.099999999999994:
# EPOCH 57:
#  batch 100 loss: 1.6003324973583222
#  batch 200 loss: 1.60009840965271
#  batch 300 loss: 1.6076634919643402
# lr 0.01 -> 0.01
# Train accuracy 46.2:
# Test accuracy 41.3:
# EPOCH 58:
#  batch 100 loss: 1.5984918177127838
#  batch 200 loss: 1.613654646873474
#  batch 300 loss: 1.604349100589752
# lr 0.01 -> 0.01
# Train accuracy 46.2:
# Test accuracy 41.9:
# EPOCH 59:
#  batch 100 loss: 1.6143167316913605
#  batch 200 loss: 1.5958626902103423
#  batch 300 loss: 1.6056023383140563
# lr 0.01 -> 0.01
# Train accuracy 46.1:
# Test accuracy 41.699999999999996:
# EPOCH 60:
#  batch 100 loss: 1.600306144952774
#  batch 200 loss: 1.603217875957489
#  batch 300 loss: 1.5945269560813904
# lr 0.01 -> 0.01
# Train accuracy 46.2:
# Test accuracy 41.4:
# EPOCH 61:
#  batch 100 loss: 1.5987541091442108
#  batch 200 loss: 1.6107273232936858
#  batch 300 loss: 1.5966257297992705
# lr 0.01 -> 0.01
# Train accuracy 45.800000000000004:
# Test accuracy 41.3:
# EPOCH 62:
#  batch 100 loss: 1.588849627971649
#  batch 200 loss: 1.6133513855934143
#  batch 300 loss: 1.6095853638648987
# lr 0.01 -> 0.01
# Train accuracy 46.2:
# Test accuracy 41.6:
# EPOCH 63:
#  batch 100 loss: 1.5927719724178315
#  batch 200 loss: 1.606849309206009
#  batch 300 loss: 1.6104061961174012
# lr 0.01 -> 0.01
# Train accuracy 46.1:
# Test accuracy 41.5:
# EPOCH 64:
#  batch 100 loss: 1.600975625514984
#  batch 200 loss: 1.6156062412261962
#  batch 300 loss: 1.5965987026691437
# lr 0.01 -> 0.01
# Train accuracy 46.2:
# Test accuracy 41.6:
# EPOCH 65:
#  batch 100 loss: 1.6009551584720612
#  batch 200 loss: 1.599775811433792
#  batch 300 loss: 1.6042499125003815
# lr 0.01 -> 0.01
# Train accuracy 46.2:
# Test accuracy 41.6:
# EPOCH 66:
#  batch 100 loss: 1.5744678151607514
#  batch 200 loss: 1.6183588087558747
#  batch 300 loss: 1.59729816198349
# lr 0.01 -> 0.01
# Train accuracy 46.2:
# Test accuracy 41.0:
# EPOCH 67:
#  batch 100 loss: 1.6028588819503784
#  batch 200 loss: 1.604802167415619
#  batch 300 loss: 1.5967524194717406
# lr 0.01 -> 0.01
# Train accuracy 46.2:
# Test accuracy 41.6:
# EPOCH 68:
#  batch 100 loss: 1.6091929149627686
#  batch 200 loss: 1.6064537250995636
#  batch 300 loss: 1.5899128937721252
# lr 0.01 -> 0.01
# Train accuracy 46.1:
# Test accuracy 41.5:
# EPOCH 69:
#  batch 100 loss: 1.597888661623001
#  batch 200 loss: 1.5928239715099335
#  batch 300 loss: 1.6167165672779082
# lr 0.01 -> 0.01
# Train accuracy 46.400000000000006:
# Test accuracy 41.6:
# EPOCH 70:
#  batch 100 loss: 1.6044270658493043
#  batch 200 loss: 1.6043440568447114
#  batch 300 loss: 1.577654688358307
# lr 0.01 -> 0.01
# Train accuracy 46.5:
# Test accuracy 41.699999999999996:
# EPOCH 71:
#  batch 100 loss: 1.6077794408798218
#  batch 200 loss: 1.572615442276001
#  batch 300 loss: 1.6026151943206788
# lr 0.01 -> 0.01
# Train accuracy 46.2:
# Test accuracy 41.199999999999996:
# EPOCH 72:
#  batch 100 loss: 1.5964041769504547
#  batch 200 loss: 1.6033521866798401
#  batch 300 loss: 1.586999487876892
# lr 0.01 -> 0.01
# Train accuracy 46.5:
# Test accuracy 41.699999999999996:
# EPOCH 73:
#  batch 100 loss: 1.6017371201515198
#  batch 200 loss: 1.6015349209308625
#  batch 300 loss: 1.588016493320465
# lr 0.01 -> 0.01
# Train accuracy 46.1:
# Test accuracy 41.3:
# EPOCH 74:
#  batch 100 loss: 1.6048773336410522
#  batch 200 loss: 1.593030083179474
#  batch 300 loss: 1.6011673259735106
# lr 0.01 -> 0.01
# Train accuracy 46.300000000000004:
# Test accuracy 41.0:
# EPOCH 75:
#  batch 100 loss: 1.5964751541614532
#  batch 200 loss: 1.5903360271453857
#  batch 300 loss: 1.590523155927658
# lr 0.01 -> 0.01
# Train accuracy 46.7:
# Test accuracy 41.4:
# EPOCH 76:
#  batch 100 loss: 1.5791381573677064
#  batch 200 loss: 1.593857982158661
#  batch 300 loss: 1.5960242915153504
# lr 0.01 -> 0.01
# Train accuracy 46.5:
# Test accuracy 41.199999999999996:
# EPOCH 77:
#  batch 100 loss: 1.5955889689922333
#  batch 200 loss: 1.6053371357917785
#  batch 300 loss: 1.5876739454269408
# lr 0.01 -> 0.01
# Train accuracy 46.400000000000006:
# Test accuracy 41.199999999999996:
# EPOCH 78:
#  batch 100 loss: 1.6111714220046998
#  batch 200 loss: 1.5926105785369873
#  batch 300 loss: 1.573635197877884
# lr 0.01 -> 0.01
# Train accuracy 46.400000000000006:
# Test accuracy 41.4:
# EPOCH 79:
#  batch 100 loss: 1.5836734986305236
#  batch 200 loss: 1.6028740119934082
#  batch 300 loss: 1.5917293262481689
# lr 0.01 -> 0.01
# Train accuracy 46.6:
# Test accuracy 41.5:
# EPOCH 80:
#  batch 100 loss: 1.5948522984981537
#  batch 200 loss: 1.5904336190223693
#  batch 300 loss: 1.6022928166389465
# lr 0.01 -> 0.01
# Train accuracy 46.5:
# Test accuracy 41.5:
# EPOCH 81:
#  batch 100 loss: 1.5908099102973938
#  batch 200 loss: 1.5845029377937316
#  batch 300 loss: 1.6118810164928437
# lr 0.01 -> 0.01
# Train accuracy 46.2:
# Test accuracy 41.3:
# EPOCH 82:
#  batch 100 loss: 1.5800460135936738
#  batch 200 loss: 1.6083318090438843
#  batch 300 loss: 1.5832644951343537
# lr 0.01 -> 0.01
# Train accuracy 46.6:
# Test accuracy 41.099999999999994:
# EPOCH 83:
#  batch 100 loss: 1.5897585070133209
#  batch 200 loss: 1.5865592551231384
#  batch 300 loss: 1.594444888830185
# lr 0.01 -> 0.01
# Train accuracy 46.5:
# Test accuracy 41.4:
# EPOCH 84:
#  batch 100 loss: 1.587333345413208
#  batch 200 loss: 1.5746766090393067
#  batch 300 loss: 1.6021305334568023
# lr 0.01 -> 0.01
# Train accuracy 46.6:
# Test accuracy 41.699999999999996:
# EPOCH 85:
#  batch 100 loss: 1.5869327795505523
#  batch 200 loss: 1.591757084131241
#  batch 300 loss: 1.596299215555191
# lr 0.01 -> 0.01
# Train accuracy 46.300000000000004:
# Test accuracy 41.099999999999994:
# EPOCH 86:
#  batch 100 loss: 1.5843544447422027
#  batch 200 loss: 1.6035124671459198
#  batch 300 loss: 1.586270877122879
# lr 0.01 -> 0.01
# Train accuracy 46.5:
# Test accuracy 41.4:
# EPOCH 87:
#  batch 100 loss: 1.5917141890525819
#  batch 200 loss: 1.584001406431198
#  batch 300 loss: 1.5928834247589112
# lr 0.01 -> 0.01
# Train accuracy 46.800000000000004:
# Test accuracy 41.0:
# EPOCH 88:
#  batch 100 loss: 1.5843563890457153
#  batch 200 loss: 1.5891580927371978
#  batch 300 loss: 1.5899496841430665
# lr 0.01 -> 0.01
# Train accuracy 46.9:
# Test accuracy 41.5:
# EPOCH 89:
#  batch 100 loss: 1.5787771844863892
#  batch 200 loss: 1.583833907842636
#  batch 300 loss: 1.6002599382400513
# lr 0.01 -> 0.01
# Train accuracy 46.6:
# Test accuracy 41.0:
# EPOCH 90:
#  batch 100 loss: 1.581346595287323
#  batch 200 loss: 1.5955057311058045
#  batch 300 loss: 1.5782477927207947
# lr 0.01 -> 0.01
# Train accuracy 46.7:
# Test accuracy 41.4:
# EPOCH 91:
#  batch 100 loss: 1.5859126710891724
#  batch 200 loss: 1.5828168857097626
#  batch 300 loss: 1.5859276843070984
# lr 0.01 -> 0.01
# Train accuracy 46.5:
# Test accuracy 41.0:
# EPOCH 92:
#  batch 100 loss: 1.5873096573352814
#  batch 200 loss: 1.5831689250469207
#  batch 300 loss: 1.5745323944091796
# lr 0.01 -> 0.01
# Train accuracy 46.7:
# Test accuracy 41.3:
# EPOCH 93:
#  batch 100 loss: 1.576412159204483
#  batch 200 loss: 1.5924694645404815
#  batch 300 loss: 1.5872053039073943
# lr 0.01 -> 0.01
# Train accuracy 46.800000000000004:
# Test accuracy 41.3:
# EPOCH 94:
#  batch 100 loss: 1.580746486186981
#  batch 200 loss: 1.5976749491691589
#  batch 300 loss: 1.5805428743362426
# lr 0.01 -> 0.01
# Train accuracy 46.800000000000004:
# Test accuracy 41.099999999999994:
# EPOCH 95:
#  batch 100 loss: 1.5850442588329314
#  batch 200 loss: 1.570344887971878
#  batch 300 loss: 1.5915981197357179
# lr 0.01 -> 0.01
# Train accuracy 46.7:
# Test accuracy 41.3:
# EPOCH 96:
#  batch 100 loss: 1.584226154088974
#  batch 200 loss: 1.5903690469264984
#  batch 300 loss: 1.5770580494403839
# lr 0.01 -> 0.01
# Train accuracy 46.9:
# Test accuracy 41.5:
# EPOCH 97:
#  batch 100 loss: 1.5780947744846343
#  batch 200 loss: 1.5760659682750702
#  batch 300 loss: 1.5870404076576232
# lr 0.01 -> 0.01
# Train accuracy 46.800000000000004:
# Test accuracy 41.4:
# EPOCH 98:
#  batch 100 loss: 1.5657470798492432
#  batch 200 loss: 1.5956954658031464
#  batch 300 loss: 1.5875356340408324
# lr 0.01 -> 0.01
# Train accuracy 46.7:
# Test accuracy 41.3:
# EPOCH 99:
#  batch 100 loss: 1.580659704208374
#  batch 200 loss: 1.5783173048496246
#  batch 300 loss: 1.5846155130863189
# Epoch 00099: reducing learning rate of group 0 to 1.0000e-03.
# lr 0.01 -> 0.001
# Train accuracy 46.9:
# Test accuracy 41.5:
# EPOCH 100:
#  batch 100 loss: 1.5876096928119658
#  batch 200 loss: 1.5623469722270966
#  batch 300 loss: 1.5757313525676728
# lr 0.001 -> 0.001
# Train accuracy 47.199999999999996:
# Test accuracy 41.6:
# Scheduler: Exponential, Gamma: 0.95, current LR: 0.01
# EPOCH 1:
#  batch 100 loss: 1.9214555656909942
#  batch 200 loss: 1.8207245147228241
#  batch 300 loss: 1.8248119723796845
# lr 0.01 -> 0.0095
# Train accuracy 40.6:
# Test accuracy 38.9:
# EPOCH 2:
#  batch 100 loss: 1.7584679067134856
#  batch 200 loss: 1.7681479918956757
#  batch 300 loss: 1.7620446610450744
# lr 0.0095 -> 0.009025
# Train accuracy 42.1:
# Test accuracy 39.300000000000004:
# EPOCH 3:
#  batch 100 loss: 1.7368508064746857
#  batch 200 loss: 1.7319301438331605
#  batch 300 loss: 1.748064341545105
# lr 0.009025 -> 0.00857375
# Train accuracy 42.8:
# Test accuracy 40.300000000000004:
# EPOCH 4:
#  batch 100 loss: 1.7224042522907257
#  batch 200 loss: 1.7028523755073548
#  batch 300 loss: 1.7135650730133056
# lr 0.00857375 -> 0.0081450625
# Train accuracy 43.3:
# Test accuracy 40.400000000000006:
# EPOCH 5:
#  batch 100 loss: 1.6922217988967896
#  batch 200 loss: 1.6925132429599763
#  batch 300 loss: 1.7000761127471924
# lr 0.0081450625 -> 0.007737809374999999
# Train accuracy 42.5:
# Test accuracy 39.0:
# EPOCH 6:
#  batch 100 loss: 1.7002218091487884
#  batch 200 loss: 1.6821012997627258
#  batch 300 loss: 1.6931909549236297
# lr 0.007737809374999999 -> 0.007350918906249998
# Train accuracy 43.6:
# Test accuracy 39.800000000000004:
# EPOCH 7:
#  batch 100 loss: 1.6733057379722596
#  batch 200 loss: 1.6737693929672242
#  batch 300 loss: 1.6730837726593017
# lr 0.007350918906249998 -> 0.006983372960937498
# Train accuracy 43.7:
# Test accuracy 40.1:
# EPOCH 8:
#  batch 100 loss: 1.6689719355106354
#  batch 200 loss: 1.6633536565303801
#  batch 300 loss: 1.679648801088333
# lr 0.006983372960937498 -> 0.006634204312890623
# Train accuracy 43.8:
# Test accuracy 38.9:
# EPOCH 9:
#  batch 100 loss: 1.6830857634544372
#  batch 200 loss: 1.653468313217163
#  batch 300 loss: 1.656735657453537
# lr 0.006634204312890623 -> 0.006302494097246091
# Train accuracy 45.4:
# Test accuracy 41.0:
# EPOCH 10:
#  batch 100 loss: 1.6538402438163757
#  batch 200 loss: 1.6617757999897003
#  batch 300 loss: 1.6441558122634887
# lr 0.006302494097246091 -> 0.005987369392383786
# Train accuracy 44.800000000000004:
# Test accuracy 40.5:
# EPOCH 11:
#  batch 100 loss: 1.6508234989643098
#  batch 200 loss: 1.6437278592586517
#  batch 300 loss: 1.6522210431098938
# lr 0.005987369392383786 -> 0.005688000922764597
# Train accuracy 45.4:
# Test accuracy 40.1:
# EPOCH 12:
#  batch 100 loss: 1.629323650598526
#  batch 200 loss: 1.6473856246471406
#  batch 300 loss: 1.655552567243576
# lr 0.005688000922764597 -> 0.005403600876626367
# Train accuracy 45.0:
# Test accuracy 39.900000000000006:
# EPOCH 13:
#  batch 100 loss: 1.6414495027065277
#  batch 200 loss: 1.6273533129692077
#  batch 300 loss: 1.6425767385959624
# lr 0.005403600876626367 -> 0.005133420832795048
# Train accuracy 45.1:
# Test accuracy 39.900000000000006:
# EPOCH 14:
#  batch 100 loss: 1.6233224475383758
#  batch 200 loss: 1.6338816857337952
#  batch 300 loss: 1.6370620787143708
# lr 0.005133420832795048 -> 0.0048767497911552955
# Train accuracy 45.4:
# Test accuracy 40.1:
# EPOCH 15:
#  batch 100 loss: 1.6280232977867126
#  batch 200 loss: 1.628605990409851
#  batch 300 loss: 1.627133183479309
# lr 0.0048767497911552955 -> 0.00463291230159753
# Train accuracy 45.300000000000004:
# Test accuracy 39.900000000000006:
# EPOCH 16:
#  batch 100 loss: 1.6172439777851104
#  batch 200 loss: 1.6155569410324098
#  batch 300 loss: 1.6299595975875854
# lr 0.00463291230159753 -> 0.0044012666865176535
# Train accuracy 45.300000000000004:
# Test accuracy 39.7:
# EPOCH 17:
#  batch 100 loss: 1.5959630012512207
#  batch 200 loss: 1.627071043252945
#  batch 300 loss: 1.6341599464416503
# lr 0.0044012666865176535 -> 0.004181203352191771
# Train accuracy 45.7:
# Test accuracy 39.800000000000004:
# EPOCH 18:
#  batch 100 loss: 1.5862030136585235
#  batch 200 loss: 1.6093212962150574
#  batch 300 loss: 1.6309043204784393
# lr 0.004181203352191771 -> 0.003972143184582182
# Train accuracy 45.9:
# Test accuracy 40.1:
# EPOCH 19:
#  batch 100 loss: 1.6120106863975525
#  batch 200 loss: 1.601717209815979
#  batch 300 loss: 1.6255817091464997
# lr 0.003972143184582182 -> 0.0037735360253530726
# Train accuracy 46.400000000000006:
# Test accuracy 40.699999999999996:
# EPOCH 20:
#  batch 100 loss: 1.5957957708835602
#  batch 200 loss: 1.5919543755054475
#  batch 300 loss: 1.6167688417434691
# lr 0.0037735360253530726 -> 0.0035848592240854188
# Train accuracy 46.5:
# Test accuracy 41.0:
# EPOCH 21:
#  batch 100 loss: 1.5999349308013917
#  batch 200 loss: 1.593188796043396
#  batch 300 loss: 1.6102974915504455
# lr 0.0035848592240854188 -> 0.0034056162628811476
# Train accuracy 46.5:
# Test accuracy 40.400000000000006:
# EPOCH 22:
#  batch 100 loss: 1.6063771665096283
#  batch 200 loss: 1.6051596438884734
#  batch 300 loss: 1.6035153651237488
# lr 0.0034056162628811476 -> 0.0032353354497370902
# Train accuracy 47.199999999999996:
# Test accuracy 41.0:
# EPOCH 23:
#  batch 100 loss: 1.5894905173778533
#  batch 200 loss: 1.600559252500534
#  batch 300 loss: 1.5937213349342345
# lr 0.0032353354497370902 -> 0.0030735686772502355
# Train accuracy 46.5:
# Test accuracy 40.5:
# EPOCH 24:
#  batch 100 loss: 1.592349065542221
#  batch 200 loss: 1.5852369463443756
#  batch 300 loss: 1.6099612760543822
# lr 0.0030735686772502355 -> 0.0029198902433877237
# Train accuracy 46.7:
# Test accuracy 40.6:
# EPOCH 25:
#  batch 100 loss: 1.602183414697647
#  batch 200 loss: 1.5927399909496307
#  batch 300 loss: 1.588262689113617
# lr 0.0029198902433877237 -> 0.0027738957312183374
# Train accuracy 46.6:
# Test accuracy 40.8:
# EPOCH 26:
#  batch 100 loss: 1.579274207353592
#  batch 200 loss: 1.602761516571045
#  batch 300 loss: 1.5914725959300995
# lr 0.0027738957312183374 -> 0.0026352009446574203
# Train accuracy 46.5:
# Test accuracy 39.900000000000006:
# EPOCH 27:
#  batch 100 loss: 1.5693059659004212
#  batch 200 loss: 1.5912744510173797
#  batch 300 loss: 1.5980531644821168
# lr 0.0026352009446574203 -> 0.002503440897424549
# Train accuracy 47.099999999999994:
# Test accuracy 40.8:
# EPOCH 28:
#  batch 100 loss: 1.5869157254695891
#  batch 200 loss: 1.5897746610641479
#  batch 300 loss: 1.5888192451000214
# lr 0.002503440897424549 -> 0.0023782688525533216
# Train accuracy 47.4:
# Test accuracy 40.9:
# EPOCH 29:
#  batch 100 loss: 1.576786253452301
#  batch 200 loss: 1.5925937271118165
#  batch 300 loss: 1.5802670526504516
# lr 0.0023782688525533216 -> 0.0022593554099256553
# Train accuracy 47.0:
# Test accuracy 40.6:
# EPOCH 30:
#  batch 100 loss: 1.5776769566535949
#  batch 200 loss: 1.5937436246871948
#  batch 300 loss: 1.5761862730979919
# lr 0.0022593554099256553 -> 0.0021463876394293723
# Train accuracy 47.3:
# Test accuracy 40.6:
# EPOCH 31:
#  batch 100 loss: 1.568349916934967
#  batch 200 loss: 1.5772359871864319
#  batch 300 loss: 1.5913585603237153
# lr 0.0021463876394293723 -> 0.0020390682574579037
# Train accuracy 47.099999999999994:
# Test accuracy 40.699999999999996:
# EPOCH 32:
#  batch 100 loss: 1.5760613977909088
#  batch 200 loss: 1.5808634865283966
#  batch 300 loss: 1.5798987865447998
# lr 0.0020390682574579037 -> 0.0019371148445850085
# Train accuracy 47.3:
# Test accuracy 41.0:
# EPOCH 33:
#  batch 100 loss: 1.5680342841148376
#  batch 200 loss: 1.5713192975521089
#  batch 300 loss: 1.5853029465675355
# lr 0.0019371148445850085 -> 0.0018402591023557579
# Train accuracy 47.199999999999996:
# Test accuracy 40.6:
# EPOCH 34:
#  batch 100 loss: 1.5734055185317992
#  batch 200 loss: 1.5712998259067534
#  batch 300 loss: 1.5703066289424896
# lr 0.0018402591023557579 -> 0.0017482461472379698
# Train accuracy 47.3:
# Test accuracy 40.6:
# EPOCH 35:
#  batch 100 loss: 1.5654305958747863
#  batch 200 loss: 1.5710312306880951
#  batch 300 loss: 1.5767746353149414
# lr 0.0017482461472379698 -> 0.0016608338398760713
# Train accuracy 47.3:
# Test accuracy 40.9:
# EPOCH 36:
#  batch 100 loss: 1.5770251631736756
#  batch 200 loss: 1.5796493840217591
#  batch 300 loss: 1.5665917921066284
# lr 0.0016608338398760713 -> 0.0015777921478822676
# Train accuracy 47.5:
# Test accuracy 41.199999999999996:
# EPOCH 37:
#  batch 100 loss: 1.5496023869514466
#  batch 200 loss: 1.5717615401744842
#  batch 300 loss: 1.5943568992614745
# lr 0.0015777921478822676 -> 0.001498902540488154
# Train accuracy 47.4:
# Test accuracy 40.6:
# EPOCH 38:
#  batch 100 loss: 1.5646467447280883
#  batch 200 loss: 1.5717222476005555
#  batch 300 loss: 1.5756220567226409
# lr 0.001498902540488154 -> 0.0014239574134637463
# Train accuracy 47.5:
# Test accuracy 40.699999999999996:
# EPOCH 39:
#  batch 100 loss: 1.5867883908748626
#  batch 200 loss: 1.5635721802711486
#  batch 300 loss: 1.566815310716629
# lr 0.0014239574134637463 -> 0.0013527595427905588
# Train accuracy 47.3:
# Test accuracy 40.400000000000006:
# EPOCH 40:
#  batch 100 loss: 1.5502101802825927
#  batch 200 loss: 1.5805063903331757
#  batch 300 loss: 1.5824906027317047
# lr 0.0013527595427905588 -> 0.0012851215656510308
# Train accuracy 47.5:
# Test accuracy 40.6:
# EPOCH 41:
#  batch 100 loss: 1.5710856354236602
#  batch 200 loss: 1.5715119457244873
#  batch 300 loss: 1.5625061678886414
# lr 0.0012851215656510308 -> 0.0012208654873684791
# Train accuracy 47.5:
# Test accuracy 40.400000000000006:
# EPOCH 42:
#  batch 100 loss: 1.5605008697509766
#  batch 200 loss: 1.5725079274177551
#  batch 300 loss: 1.5715314376354217
# lr 0.0012208654873684791 -> 0.0011598222130000551
# Train accuracy 47.599999999999994:
# Test accuracy 40.8:
# EPOCH 43:
#  batch 100 loss: 1.5585943627357484
#  batch 200 loss: 1.5664725291728974
#  batch 300 loss: 1.55925226688385
# lr 0.0011598222130000551 -> 0.0011018311023500522
# Train accuracy 47.4:
# Test accuracy 40.5:
# EPOCH 44:
#  batch 100 loss: 1.5735961949825288
#  batch 200 loss: 1.5650611317157745
#  batch 300 loss: 1.5509024333953858
# lr 0.0011018311023500522 -> 0.0010467395472325495
# Train accuracy 47.599999999999994:
# Test accuracy 40.6:
# EPOCH 45:
#  batch 100 loss: 1.5668461263179778
#  batch 200 loss: 1.5484149992465972
#  batch 300 loss: 1.5608826184272766
# lr 0.0010467395472325495 -> 0.000994402569870922
# Train accuracy 47.8:
# Test accuracy 40.699999999999996:
# EPOCH 46:
#  batch 100 loss: 1.557409586906433
#  batch 200 loss: 1.5693796241283418
#  batch 300 loss: 1.5651476311683654
# lr 0.000994402569870922 -> 0.0009446824413773759
# Train accuracy 47.8:
# Test accuracy 40.9:
# EPOCH 47:
#  batch 100 loss: 1.5629085052013396
#  batch 200 loss: 1.5511800754070282
#  batch 300 loss: 1.565299242734909
# lr 0.0009446824413773759 -> 0.0008974483193085071
# Train accuracy 47.9:
# Test accuracy 40.8:
# EPOCH 48:
#  batch 100 loss: 1.5637878859043122
#  batch 200 loss: 1.5571372771263123
#  batch 300 loss: 1.560229879617691
# lr 0.0008974483193085071 -> 0.0008525759033430817
# Train accuracy 47.699999999999996:
# Test accuracy 40.6:
# EPOCH 49:
#  batch 100 loss: 1.5663316810131074
#  batch 200 loss: 1.555219637155533
#  batch 300 loss: 1.565557849407196
# lr 0.0008525759033430817 -> 0.0008099471081759276
# Train accuracy 47.8:
# Test accuracy 40.5:
# EPOCH 50:
#  batch 100 loss: 1.5580297124385833
#  batch 200 loss: 1.5624595820903777
#  batch 300 loss: 1.560737509727478
# lr 0.0008099471081759276 -> 0.0007694497527671312
# Train accuracy 47.8:
# Test accuracy 40.699999999999996:
# EPOCH 51:
#  batch 100 loss: 1.5529876554012298
#  batch 200 loss: 1.5606721675395965
#  batch 300 loss: 1.5419950771331787
# lr 0.0007694497527671312 -> 0.0007309772651287747
# Train accuracy 47.8:
# Test accuracy 40.5:
# EPOCH 52:
#  batch 100 loss: 1.559258154630661
#  batch 200 loss: 1.5690868735313415
#  batch 300 loss: 1.5475617790222167
# lr 0.0007309772651287747 -> 0.0006944284018723359
# Train accuracy 47.5:
# Test accuracy 40.699999999999996:
# EPOCH 53:
#  batch 100 loss: 1.5650690114498138
#  batch 200 loss: 1.5491843175888063
#  batch 300 loss: 1.5570880126953126
# lr 0.0006944284018723359 -> 0.0006597069817787191
# Train accuracy 47.9:
# Test accuracy 41.0:
# EPOCH 54:
#  batch 100 loss: 1.5502807950973512
#  batch 200 loss: 1.5611252117156982
#  batch 300 loss: 1.562487233877182
# lr 0.0006597069817787191 -> 0.0006267216326897832
# Train accuracy 47.8:
# Test accuracy 40.699999999999996:
# EPOCH 55:
#  batch 100 loss: 1.5514673781394959
#  batch 200 loss: 1.5586321973800659
#  batch 300 loss: 1.542989603281021
# lr 0.0006267216326897832 -> 0.000595385551055294
# Train accuracy 47.9:
# Test accuracy 40.699999999999996:
# EPOCH 56:
#  batch 100 loss: 1.5632498681545257
#  batch 200 loss: 1.5345264494419097
#  batch 300 loss: 1.5598103320598602
# lr 0.000595385551055294 -> 0.0005656162735025292
# Train accuracy 47.8:
# Test accuracy 40.699999999999996:
# EPOCH 57:
#  batch 100 loss: 1.5588781785964967
#  batch 200 loss: 1.5447572207450866
#  batch 300 loss: 1.556119830608368
# lr 0.0005656162735025292 -> 0.0005373354598274027
# Train accuracy 47.9:
# Test accuracy 40.8:
# EPOCH 58:
#  batch 100 loss: 1.5467057311534882
#  batch 200 loss: 1.5616541266441346
#  batch 300 loss: 1.5605341398715973
# lr 0.0005373354598274027 -> 0.0005104686868360325
# Train accuracy 47.9:
# Test accuracy 40.699999999999996:
# EPOCH 59:
#  batch 100 loss: 1.5631976771354674
#  batch 200 loss: 1.5428933644294738
#  batch 300 loss: 1.5466838705539703
# lr 0.0005104686868360325 -> 0.0004849452524942309
# Train accuracy 48.0:
# Test accuracy 40.8:
# EPOCH 60:
#  batch 100 loss: 1.5498716115951539
#  batch 200 loss: 1.5525846087932587
#  batch 300 loss: 1.5660404014587401
# lr 0.0004849452524942309 -> 0.00046069798986951934
# Train accuracy 48.1:
# Test accuracy 40.6:
# EPOCH 61:
#  batch 100 loss: 1.564604868888855
#  batch 200 loss: 1.5442719388008117
#  batch 300 loss: 1.5481919300556184
# lr 0.00046069798986951934 -> 0.0004376630903760434
# Train accuracy 47.8:
# Test accuracy 40.5:
# EPOCH 62:
#  batch 100 loss: 1.5627139401435852
#  batch 200 loss: 1.545954533815384
#  batch 300 loss: 1.5590382659435271
# lr 0.0004376630903760434 -> 0.00041577993585724117
# Train accuracy 47.9:
# Test accuracy 40.699999999999996:
# EPOCH 63:
#  batch 100 loss: 1.5439095222949981
#  batch 200 loss: 1.549256180524826
#  batch 300 loss: 1.5638784158229828
# lr 0.00041577993585724117 -> 0.0003949909390643791
# Train accuracy 47.9:
# Test accuracy 40.699999999999996:
# EPOCH 64:
#  batch 100 loss: 1.547931078672409
#  batch 200 loss: 1.5629746425151825
#  batch 300 loss: 1.5495196306705474
# lr 0.0003949909390643791 -> 0.0003752413921111601
# Train accuracy 47.9:
# Test accuracy 40.699999999999996:
# EPOCH 65:
#  batch 100 loss: 1.5566943287849426
#  batch 200 loss: 1.5450148808956146
#  batch 300 loss: 1.5570973479747772
# lr 0.0003752413921111601 -> 0.00035647932250560207
# Train accuracy 48.1:
# Test accuracy 40.699999999999996:
# EPOCH 66:
#  batch 100 loss: 1.5635968375205993
#  batch 200 loss: 1.5617831397056579
#  batch 300 loss: 1.542556631565094
# lr 0.00035647932250560207 -> 0.00033865535638032194
# Train accuracy 47.9:
# Test accuracy 40.699999999999996:
# EPOCH 67:
#  batch 100 loss: 1.5469151711463929
#  batch 200 loss: 1.5540063858032227
#  batch 300 loss: 1.5491415798664092
# lr 0.00033865535638032194 -> 0.00032172258856130585
# Train accuracy 48.0:
# Test accuracy 40.8:
# EPOCH 68:
#  batch 100 loss: 1.5431393229961394
#  batch 200 loss: 1.5477492880821229
#  batch 300 loss: 1.5616929244995117
# lr 0.00032172258856130585 -> 0.0003056364591332405
# Train accuracy 48.0:
# Test accuracy 41.0:
# EPOCH 69:
#  batch 100 loss: 1.5529912078380586
#  batch 200 loss: 1.535031019449234
#  batch 300 loss: 1.563077793121338
# lr 0.0003056364591332405 -> 0.0002903546361765785
# Train accuracy 47.9:
# Test accuracy 40.6:
# EPOCH 70:
#  batch 100 loss: 1.56922079205513
#  batch 200 loss: 1.5396939647197723
#  batch 300 loss: 1.5454424166679381
# lr 0.0002903546361765785 -> 0.00027583690436774953
# Train accuracy 48.1:
# Test accuracy 40.9:
# EPOCH 71:
#  batch 100 loss: 1.539168975353241
#  batch 200 loss: 1.554287828207016
#  batch 300 loss: 1.5615202641487123
# lr 0.00027583690436774953 -> 0.00026204505914936203
# Train accuracy 48.0:
# Test accuracy 40.8:
# EPOCH 72:
#  batch 100 loss: 1.5340802824497224
#  batch 200 loss: 1.5601789796352385
#  batch 300 loss: 1.5527931249141693
# lr 0.00026204505914936203 -> 0.00024894280619189394
# Train accuracy 48.1:
# Test accuracy 40.8:
# EPOCH 73:
#  batch 100 loss: 1.5541310262680055
#  batch 200 loss: 1.5486458230018616
#  batch 300 loss: 1.5559465992450714
# lr 0.00024894280619189394 -> 0.00023649566588229923
# Train accuracy 48.0:
# Test accuracy 40.5:
# EPOCH 74:
#  batch 100 loss: 1.546953352689743
#  batch 200 loss: 1.5498813581466675
#  batch 300 loss: 1.5531808841228485
# lr 0.00023649566588229923 -> 0.00022467088258818426
# Train accuracy 48.1:
# Test accuracy 40.699999999999996:
# EPOCH 75:
#  batch 100 loss: 1.553492432832718
#  batch 200 loss: 1.5391201674938202
#  batch 300 loss: 1.5599118494987487
# lr 0.00022467088258818426 -> 0.00021343733845877503
# Train accuracy 48.0:
# Test accuracy 40.699999999999996:
# EPOCH 76:
#  batch 100 loss: 1.5436295533180238
#  batch 200 loss: 1.541608111858368
#  batch 300 loss: 1.5485055613517762
# lr 0.00021343733845877503 -> 0.00020276547153583627
# Train accuracy 48.1:
# Test accuracy 40.8:
# EPOCH 77:
#  batch 100 loss: 1.5683612143993377
#  batch 200 loss: 1.5448373079299926
#  batch 300 loss: 1.5344416332244872
# lr 0.00020276547153583627 -> 0.00019262719795904446
# Train accuracy 47.9:
# Test accuracy 40.8:
# EPOCH 78:
#  batch 100 loss: 1.5474817597866057
#  batch 200 loss: 1.5513146364688872
#  batch 300 loss: 1.5477112710475922
# lr 0.00019262719795904446 -> 0.00018299583806109224
# Train accuracy 48.1:
# Test accuracy 40.8:
# EPOCH 79:
#  batch 100 loss: 1.5465189623832702
#  batch 200 loss: 1.5411906218528748
#  batch 300 loss: 1.5519017601013183
# lr 0.00018299583806109224 -> 0.0001738460461580376
# Train accuracy 48.1:
# Test accuracy 40.6:
# EPOCH 80:
#  batch 100 loss: 1.5476584565639495
#  batch 200 loss: 1.5458794915676117
#  batch 300 loss: 1.5462389874458313
# lr 0.0001738460461580376 -> 0.00016515374385013573
# Train accuracy 48.1:
# Test accuracy 40.699999999999996:
# EPOCH 81:
#  batch 100 loss: 1.5495567214488983
#  batch 200 loss: 1.5427104485034944
#  batch 300 loss: 1.553657922744751
# lr 0.00016515374385013573 -> 0.00015689605665762893
# Train accuracy 48.199999999999996:
# Test accuracy 40.699999999999996:
# EPOCH 82:
#  batch 100 loss: 1.5469369578361511
#  batch 200 loss: 1.5568361210823058
#  batch 300 loss: 1.5405299293994903
# lr 0.00015689605665762893 -> 0.00014905125382474747
# Train accuracy 48.1:
# Test accuracy 40.699999999999996:
# EPOCH 83:
#  batch 100 loss: 1.557054076194763
#  batch 200 loss: 1.558121725320816
#  batch 300 loss: 1.5363076663017272
# lr 0.00014905125382474747 -> 0.0001415986911335101
# Train accuracy 48.1:
# Test accuracy 40.8:
# EPOCH 84:
#  batch 100 loss: 1.533764774799347
#  batch 200 loss: 1.5513700151443481
#  batch 300 loss: 1.5492973935604095
# lr 0.0001415986911335101 -> 0.00013451875657683458
# Train accuracy 48.199999999999996:
# Test accuracy 40.699999999999996:
# EPOCH 85:
#  batch 100 loss: 1.548173269033432
#  batch 200 loss: 1.5507063674926758
#  batch 300 loss: 1.548615164756775
# lr 0.00013451875657683458 -> 0.00012779281874799285
# Train accuracy 48.0:
# Test accuracy 40.8:
# EPOCH 86:
#  batch 100 loss: 1.5519145143032074
#  batch 200 loss: 1.5388407158851622
#  batch 300 loss: 1.5564582979679107
# lr 0.00012779281874799285 -> 0.0001214031778105932
# Train accuracy 48.1:
# Test accuracy 40.6:
# EPOCH 87:
#  batch 100 loss: 1.5486915874481202
#  batch 200 loss: 1.5474586641788484
#  batch 300 loss: 1.5467933166027068
# lr 0.0001214031778105932 -> 0.00011533301892006353
# Train accuracy 48.1:
# Test accuracy 40.699999999999996:
# EPOCH 88:
#  batch 100 loss: 1.557280730009079
#  batch 200 loss: 1.5467398107051848
#  batch 300 loss: 1.54399395942688
# lr 0.00011533301892006353 -> 0.00010956636797406035
# Train accuracy 48.1:
# Test accuracy 40.699999999999996:
# EPOCH 89:
#  batch 100 loss: 1.5554858076572418
#  batch 200 loss: 1.5389496862888337
#  batch 300 loss: 1.5484276819229126
# lr 0.00010956636797406035 -> 0.00010408804957535733
# Train accuracy 48.0:
# Test accuracy 40.699999999999996:
# EPOCH 90:
#  batch 100 loss: 1.552868323326111
#  batch 200 loss: 1.5364843606948853
#  batch 300 loss: 1.559777601957321
# lr 0.00010408804957535733 -> 9.888364709658946e-05
# Train accuracy 48.0:
# Test accuracy 40.699999999999996:
# EPOCH 91:
#  batch 100 loss: 1.55742023229599
#  batch 200 loss: 1.5518007683753967
#  batch 300 loss: 1.5546118760108947
# lr 9.888364709658946e-05 -> 9.393946474175998e-05
# Train accuracy 48.1:
# Test accuracy 40.8:
# EPOCH 92:
#  batch 100 loss: 1.5456292676925658
#  batch 200 loss: 1.5476683580875397
#  batch 300 loss: 1.5515650010108948
# lr 9.393946474175998e-05 -> 8.924249150467197e-05
# Train accuracy 48.1:
# Test accuracy 40.699999999999996:
# EPOCH 93:
#  batch 100 loss: 1.5411541783809661
#  batch 200 loss: 1.5579165422916412
#  batch 300 loss: 1.5402862334251404
# lr 8.924249150467197e-05 -> 8.478036692943837e-05
# Train accuracy 48.199999999999996:
# Test accuracy 40.699999999999996:
# EPOCH 94:
#  batch 100 loss: 1.5521143412590026
#  batch 200 loss: 1.5509137666225434
#  batch 300 loss: 1.547508999109268
# lr 8.478036692943837e-05 -> 8.054134858296645e-05
# Train accuracy 48.1:
# Test accuracy 40.699999999999996:
# EPOCH 95:
#  batch 100 loss: 1.5441799020767213
#  batch 200 loss: 1.545914032459259
#  batch 300 loss: 1.556670104265213
# lr 8.054134858296645e-05 -> 7.651428115381812e-05
# Train accuracy 48.199999999999996:
# Test accuracy 40.6:
# EPOCH 96:
#  batch 100 loss: 1.5489991331100463
#  batch 200 loss: 1.5479990756511688
#  batch 300 loss: 1.557257763147354
# lr 7.651428115381812e-05 -> 7.268856709612721e-05
# Train accuracy 48.1:
# Test accuracy 40.699999999999996:
# EPOCH 97:
#  batch 100 loss: 1.548442567586899
#  batch 200 loss: 1.5604766845703124
#  batch 300 loss: 1.5454843294620515
# lr 7.268856709612721e-05 -> 6.905413874132085e-05
# Train accuracy 48.1:
# Test accuracy 40.8:
# EPOCH 98:
#  batch 100 loss: 1.5410003471374512
#  batch 200 loss: 1.5483798789978027
#  batch 300 loss: 1.5539499819278717
# lr 6.905413874132085e-05 -> 6.56014318042548e-05
# Train accuracy 48.1:
# Test accuracy 40.8:
# EPOCH 99:
#  batch 100 loss: 1.538751791715622
#  batch 200 loss: 1.5365664148330689
#  batch 300 loss: 1.5619127118587495
# lr 6.56014318042548e-05 -> 6.232136021404205e-05
# Train accuracy 48.1:
# Test accuracy 40.8:
# EPOCH 100:
#  batch 100 loss: 1.5377298486232758
#  batch 200 loss: 1.5587894070148467
#  batch 300 loss: 1.5443915677070619
# lr 6.232136021404205e-05 -> 5.920529220333995e-05
# Train accuracy 48.1:
# Test accuracy 40.699999999999996:

# %% [markdown]
# ### Plotting

# %%
import numpy as np
epochs_arr = np.arange(0, len(losses_arr[0]))

# %%
# Plot training loss
x = np.array(epochs_arr)
for i,train_loss in enumerate(losses_arr):
  ypoints = np.array(train_loss)
  plt.plot(x, ypoints, label = description[i])

plt.xlabel("Epochs")
plt.ylabel("train Loss")
plt.legend()
plt.title('LR=0.01, Batch_size=128, Optimizer=SGD, Cross entropy loss')
plt.show()

# %%
# Plot training accuracy
x = np.array(epochs_arr)
for i,train_acc in enumerate(train_accuracy_arr):
  ypoints = np.array(train_acc)
  plt.plot(x, ypoints, label = description[i])

plt.xlabel("Epochs")
plt.ylabel("train Accuracy")
plt.legend()
plt.title('LR=0.01, Batch_size=128, Optimizer=SGD')
plt.show()

# %%
# Plot test accuracy
x = np.array(epochs_arr)
for i,test_acc in enumerate(test_accuracy_arr):
  ypoints = np.array(test_acc)
  plt.plot(x, ypoints, label = description[i])

plt.xlabel("Epochs")
plt.ylabel("Test Accuracy")
plt.legend()
plt.title('LR=0.01, Batch_size=128, Optimizer=SGD')
plt.show()

# %%
# Plot test and training accuracy
x = np.array(epochs_arr)
for i,lt in enumerate(LR_types):
  ypoints_1 = np.array(train_accuracy_arr[i])
  ypoints_2 = np.array(test_accuracy_arr[i])
  plt.plot(x, ypoints_1, label = 'Train')
  plt.plot(x, ypoints_2, label = 'Test')
  plt.xlabel("Epochs")
  plt.ylabel("Accuracy")
  plt.legend()
  plt.title(F'LR=0.01, Batch_size=128, Optimizer=SGD, Scheduler={lt}')
  plt.show()

# %% [markdown]
# ### Load model

# %%
from google.colab import drive
drive.mount('/content/drive/')
model_save_name = '1695168105559.8071_Step_bs128_e30_SGD_ss10_gamma0.1_cifar'
path = F"/content/drive/MyDrive/Ell409/CIFAR/scheduler/{model_save_name}.pt"
net.load_state_dict(t.load(path))

# %%
test(net,test_loader)

# %%
#hello kuch likhlo warna inactivity timeout de dega yeh

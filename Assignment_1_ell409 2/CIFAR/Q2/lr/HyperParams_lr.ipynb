# %%
import torch as t
import torchvision.datasets as datasets
import torchvision.transforms as transforms
import torch.nn as nn
import matplotlib.pyplot as plt
import torch.optim as optim
import torch.optim.lr_scheduler as lr_scheduler
from torch.optim.lr_scheduler import ReduceLROnPlateau, StepLR, ExponentialLR

# %% [markdown]
# ### Model

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net,self).__init__()
        self.linear1 = nn.Linear(3*32*32, 10)
        self.relu = nn.ReLU()

    def forward(self, img): #convert + flatten
        x = img.view(-1, 3*32*32)
        x = self.relu(self.linear1(x))
        return x
net = Net()

# %% [markdown]
# ### Hyperparams

# %%
num_epochs=100
after_every=100
loss_fn = nn.CrossEntropyLoss()
batch_size=128

# %%
import ssl
ssl._create_default_https_context = ssl._create_unverified_context
transform = transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5)),])

mnist_trainset = datasets.CIFAR10(root='./data', train=True, download=True, transform=transform)
train_loader = t.utils.data.DataLoader(mnist_trainset, batch_size=batch_size, shuffle=True)

mnist_testset = datasets.CIFAR10(root='./data', train=False, download=True, transform=transform)
test_loader = t.utils.data.DataLoader(mnist_testset, batch_size=batch_size, shuffle=True)
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./data/cifar-10-python.tar.gz
# 100.0%
# Extracting ./data/cifar-10-python.tar.gz to ./data
# Files already downloaded and verified

# %% [markdown]
# ### Training

# %%
def train_one_epoch(model, epoch_index, optimizer, train_dataset):
    running_loss = 0.
    last_loss = 0.

    for i, data in enumerate(train_dataset):
        # Every data instance is an input + label pair
        # data.shape=torch.Size([10, 1, 28, 28]) --> 10 images,labels
        inputs, labels = data

        # Zero your gradients for every batch!
        optimizer.zero_grad()

        # Make predictions for this batch
        outputs = model(inputs.view(-1, 3*32*32))


        # Compute the loss and its gradients
        loss = loss_fn(outputs, labels)
        loss.backward()

        # Adjust learning weights
        optimizer.step()

        # Gather data and report
        running_loss += loss.item()

        if i % after_every == after_every-1:
            last_loss = running_loss / after_every # loss per after_every batches
            print(' batch {} loss: {}'.format(i + 1, last_loss))
            running_loss = 0.

    return last_loss

# %% [markdown]
# ### Evaluate

# %%
def test(model, loader):
  total=0
  correct=0
  model.eval()
  with t.no_grad():
      for data in loader:
          x, y = data
          output = model(x.view(-1, 3*32*32))
          for idx, i in enumerate(output):
              if t.argmax(i) == y[idx]:
                  correct +=1
              total +=1
  return round(correct/total, 3)*100

# %%
def train_model(model, epochs, train_dataset, test_dataset, optimizer, scheduler, LR_type):
  epoch_number = 0

  losses = []
  train_accuracy = []
  test_accuracy = []

  for epoch in range(epochs):
      print('EPOCH {}:'.format(epoch_number + 1))

      # Make sure gradient tracking is on, and do a pass over the data
      model.train(True)
      avg_loss = train_one_epoch(model, epoch_number,optimizer,train_dataset)
      losses.append(avg_loss)

      # Train accuracy
      train_acc = test(model, train_dataset)
      train_accuracy.append(train_acc)

      # Test accuracy
      test_acc = test(model, test_dataset)
      test_accuracy.append(test_acc)

      if LR_type=='Plateau':
        before_lr = optimizer.param_groups[0]["lr"]
        scheduler.step(avg_loss)
        after_lr = optimizer.param_groups[0]["lr"]
        print('lr {} -> {}'.format(before_lr, after_lr))

      elif LR_type!='None':
        before_lr = optimizer.param_groups[0]["lr"]
        scheduler.step()
        after_lr = optimizer.param_groups[0]["lr"]
        print('lr {} -> {}'.format(before_lr, after_lr))

      print('Train accuracy {}:'.format(train_acc))
      print('Test accuracy {}:'.format(test_acc))
      epoch_number += 1
  return losses, train_accuracy, test_accuracy

# %%
import datetime as dt
lrs = [1, 0.1, 0.01, 1e-3, 1e-5, 1e-7]
def train_with_lr():
  losses_arr = []
  train_accuracy_arr = []
  test_accuracy_arr = []
  description = []

  # Different learning rates
  for lr in lrs:
    print('Learning Rate {}:'.format(lr))
    net_new = Net()
    optimizerr = t.optim.SGD(net_new.parameters(), lr=lr)

    losses, train_accuracy, test_accuracy = train_model(net_new, num_epochs, train_loader, test_loader, optimizerr, '', 'None')

    losses_arr.append(losses)
    train_accuracy_arr.append(train_accuracy)
    test_accuracy_arr.append(test_accuracy)
    description.append('LR:{}'.format(lr))

    # save model
    ts_now = dt.datetime.now()
    unix_timestamp = dt.datetime.timestamp(ts_now)*1000
    model_save_name = str(unix_timestamp)
    path = F"{model_save_name}_LR={lr}_bs{128}_e{num_epochs}_SGD_.pt"
    t.save(net.state_dict(), path)

  return description, losses_arr, train_accuracy_arr, test_accuracy_arr

# %%
import csv
def save_to_csv(filename, description, losses_arr, train_acc_arr, test_acc_arr):
  # Create a CSV file and write data to it
  with open(filename+'.csv', 'w', newline='') as csvfile:
    for i, desc in enumerate(description):
      fieldnames = ['Description', 'epoch', 'train_loss', 'train_accuracy', 'test_accuracy']
      writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
      writer.writeheader()
      for epoch, (loss, train, test) in enumerate(zip(losses_arr[i], train_acc_arr[i], test_acc_arr[i]), 1):
          writer.writerow({'Description':description[i], 'epoch': epoch, 'train_loss': loss, 'train_accuracy': train, 'test_accuracy': test})

# %% [markdown]
# ### Plotting-

# %%
description, losses_arr, train_accuracy_arr, test_accuracy_arr = train_with_lr()
save_to_csv('lr', description, losses_arr, train_accuracy_arr, test_accuracy_arr)
# Out:
# Learning Rate 1:
# EPOCH 1:
#  batch 100 loss: 6.1895358800888065
#  batch 200 loss: 4.6239325499534605
#  batch 300 loss: 4.1560771894454955
# Train accuracy 15.1:
# Test accuracy 14.099999999999998:
# EPOCH 2:
#  batch 100 loss: 3.4372840189933775
#  batch 200 loss: 3.274886577129364
#  batch 300 loss: 3.792370948791504
# Train accuracy 12.5:
# Test accuracy 11.1:
# EPOCH 3:
#  batch 100 loss: 3.5943914318084715
#  batch 200 loss: 3.065787630081177
#  batch 300 loss: 3.071334800720215
# Train accuracy 14.099999999999998:
# Test accuracy 13.5:
# EPOCH 4:
#  batch 100 loss: 2.9080607986450193
#  batch 200 loss: 3.057135987281799
#  batch 300 loss: 2.9638939261436463
# Train accuracy 14.499999999999998:
# Test accuracy 13.8:
# EPOCH 5:
#  batch 100 loss: 2.8149673676490785
#  batch 200 loss: 2.7246247267723085
#  batch 300 loss: 2.80894513130188
# Train accuracy 14.799999999999999:
# Test accuracy 13.200000000000001:
# EPOCH 6:
#  batch 100 loss: 2.6235529017448425
#  batch 200 loss: 2.5294749188423156
#  batch 300 loss: 2.5906707525253294
# Train accuracy 15.1:
# Test accuracy 14.000000000000002:
# EPOCH 7:
#  batch 100 loss: 2.601167669296265
#  batch 200 loss: 2.655889477729797
#  batch 300 loss: 2.7025056529045104
# Train accuracy 14.399999999999999:
# Test accuracy 12.7:
# EPOCH 8:
#  batch 100 loss: 2.4022507858276367
#  batch 200 loss: 2.497858188152313
#  batch 300 loss: 2.3766727447509766
# Train accuracy 15.1:
# Test accuracy 13.8:
# EPOCH 9:
#  batch 100 loss: 2.4124520659446715
#  batch 200 loss: 2.3473198413848877
#  batch 300 loss: 2.3315485453605653
# Train accuracy 14.799999999999999:
# Test accuracy 13.4:
# EPOCH 10:
#  batch 100 loss: 2.311239604949951
#  batch 200 loss: 2.3157430410385134
#  batch 300 loss: 2.2970432448387146
# Train accuracy 14.799999999999999:
# Test accuracy 13.4:
# EPOCH 11:
#  batch 100 loss: 2.2634949254989625
#  batch 200 loss: 2.431582410335541
#  batch 300 loss: 2.2799822473526
# Train accuracy 13.700000000000001:
# Test accuracy 11.899999999999999:
# EPOCH 12:
#  batch 100 loss: 2.2593671321868896
#  batch 200 loss: 2.2649180090427397
#  batch 300 loss: 2.282375946044922
# Train accuracy 15.1:
# Test accuracy 13.200000000000001:
# EPOCH 13:
#  batch 100 loss: 2.3645693969726564
#  batch 200 loss: 2.2547559404373168
#  batch 300 loss: 2.2440559315681456
# Train accuracy 16.5:
# Test accuracy 14.7:
# EPOCH 14:
#  batch 100 loss: 2.3191781353950502
#  batch 200 loss: 2.22523277759552
#  batch 300 loss: 2.234164218902588
# Train accuracy 16.1:
# Test accuracy 14.7:
# EPOCH 15:
#  batch 100 loss: 2.314291703701019
#  batch 200 loss: 2.227985830307007
#  batch 300 loss: 2.227004451751709
# Train accuracy 16.900000000000002:
# Test accuracy 15.2:
# EPOCH 16:
#  batch 100 loss: 2.2072012186050416
#  batch 200 loss: 2.250969648361206
#  batch 300 loss: 2.2297554302215574
# Train accuracy 16.1:
# Test accuracy 14.000000000000002:
# EPOCH 17:
#  batch 100 loss: 2.22227979183197
#  batch 200 loss: 2.209206428527832
#  batch 300 loss: 2.2117577838897704
# Train accuracy 16.400000000000002:
# Test accuracy 14.6:
# EPOCH 18:
#  batch 100 loss: 2.2011595797538757
#  batch 200 loss: 2.226281590461731
#  batch 300 loss: 2.20774777173996
# Train accuracy 17.8:
# Test accuracy 15.6:
# EPOCH 19:
#  batch 100 loss: 2.640922803878784
#  batch 200 loss: 2.220857422351837
#  batch 300 loss: 2.2078709697723387
# Train accuracy 17.599999999999998:
# Test accuracy 16.0:
# EPOCH 20:
#  batch 100 loss: 2.1935835790634157
#  batch 200 loss: 2.4060932064056395
#  batch 300 loss: 2.1912905836105345
# Train accuracy 16.5:
# Test accuracy 14.399999999999999:
# EPOCH 21:
#  batch 100 loss: 2.188748325109482
#  batch 200 loss: 2.193208403587341
#  batch 300 loss: 2.2121630573272704
# Train accuracy 16.900000000000002:
# Test accuracy 14.499999999999998:
# EPOCH 22:
#  batch 100 loss: 2.1897613167762757
#  batch 200 loss: 2.1897537970542906
#  batch 300 loss: 2.1896826457977294
# Train accuracy 16.5:
# Test accuracy 14.299999999999999:
# EPOCH 23:
#  batch 100 loss: 2.176213585138321
#  batch 200 loss: 2.1886879420280456
#  batch 300 loss: 2.1841840982437133
# Train accuracy 17.2:
# Test accuracy 14.799999999999999:
# EPOCH 24:
#  batch 100 loss: 2.167410465478897
#  batch 200 loss: 2.2328204119205477
#  batch 300 loss: 2.1989960408210756
# Train accuracy 17.2:
# Test accuracy 14.899999999999999:
# EPOCH 25:
#  batch 100 loss: 2.1472072839736938
#  batch 200 loss: 2.1722426295280455
#  batch 300 loss: 2.191279962062836
# Train accuracy 17.4:
# Test accuracy 15.0:
# EPOCH 26:
#  batch 100 loss: 2.1592076241970064
#  batch 200 loss: 2.173790228366852
#  batch 300 loss: 2.1785086727142335
# Train accuracy 16.8:
# Test accuracy 14.2:
# EPOCH 27:
#  batch 100 loss: 2.165920547246933
#  batch 200 loss: 2.181085057258606
#  batch 300 loss: 2.3981627368927003
# Train accuracy 17.599999999999998:
# Test accuracy 15.2:
# EPOCH 28:
#  batch 100 loss: 2.162343519926071
#  batch 200 loss: 2.16189918756485
#  batch 300 loss: 2.1876132237911223
# Train accuracy 18.9:
# Test accuracy 16.6:
# EPOCH 29:
#  batch 100 loss: 2.1578438651561735
#  batch 200 loss: 2.1607435011863707
#  batch 300 loss: 2.177552922964096
# Train accuracy 20.1:
# Test accuracy 17.5:
# EPOCH 30:
#  batch 100 loss: 2.147763100862503
#  batch 200 loss: 2.154320477247238
#  batch 300 loss: 2.192058471441269
# Train accuracy 19.1:
# Test accuracy 16.2:
# EPOCH 31:
#  batch 100 loss: 2.1402796757221223
#  batch 200 loss: 2.1400599992275238
#  batch 300 loss: 2.369850835800171
# Train accuracy 18.2:
# Test accuracy 15.7:
# EPOCH 32:
#  batch 100 loss: 2.133185658454895
#  batch 200 loss: 2.1556119215488434
#  batch 300 loss: 2.1841432750225067
# Train accuracy 19.900000000000002:
# Test accuracy 17.299999999999997:
# EPOCH 33:
#  batch 100 loss: 2.1461635661125182
#  batch 200 loss: 2.1423948156833648
#  batch 300 loss: 2.145894008874893
# Train accuracy 21.6:
# Test accuracy 19.2:
# EPOCH 34:
#  batch 100 loss: 2.1368337655067444
#  batch 200 loss: 2.138560791015625
#  batch 300 loss: 2.156818734407425
# Train accuracy 19.400000000000002:
# Test accuracy 16.3:
# EPOCH 35:
#  batch 100 loss: 2.123378641605377
#  batch 200 loss: 2.1710878205299378
#  batch 300 loss: 2.233877093791962
# Train accuracy 20.599999999999998:
# Test accuracy 18.0:
# EPOCH 36:
#  batch 100 loss: 2.1183743286132812
#  batch 200 loss: 2.1550832915306093
#  batch 300 loss: 2.155386872291565
# Train accuracy 20.599999999999998:
# Test accuracy 18.0:
# EPOCH 37:
#  batch 100 loss: 2.1688594889640807
#  batch 200 loss: 2.138979904651642
#  batch 300 loss: 2.133934408426285
# Train accuracy 21.099999999999998:
# Test accuracy 18.0:
# EPOCH 38:
#  batch 100 loss: 2.1086277639865876
#  batch 200 loss: 2.128201506137848
#  batch 300 loss: 2.121006330251694
# Train accuracy 21.3:
# Test accuracy 18.2:
# EPOCH 39:
#  batch 100 loss: 2.127525497674942
#  batch 200 loss: 2.130399626493454
#  batch 300 loss: 2.128410396575928
# Train accuracy 21.3:
# Test accuracy 18.4:
# EPOCH 40:
#  batch 100 loss: 2.118480385541916
#  batch 200 loss: 2.1118474018573763
#  batch 300 loss: 2.1442041063308714
# Train accuracy 20.1:
# Test accuracy 17.2:
# EPOCH 41:
#  batch 100 loss: 2.097003222703934
#  batch 200 loss: 2.13046813249588
#  batch 300 loss: 2.1354492259025575
# Train accuracy 21.3:
# Test accuracy 18.3:
# EPOCH 42:
#  batch 100 loss: 2.111188093423843
#  batch 200 loss: 2.22849733710289
#  batch 300 loss: 2.109688185453415
# Train accuracy 21.5:
# Test accuracy 18.2:
# EPOCH 43:
#  batch 100 loss: 2.0977207350730898
#  batch 200 loss: 2.1513534772396086
#  batch 300 loss: 2.1153090500831606
# Train accuracy 21.4:
# Test accuracy 17.7:
# EPOCH 44:
#  batch 100 loss: 2.090193272829056
#  batch 200 loss: 2.096923133134842
#  batch 300 loss: 2.1041740262508393
# Train accuracy 20.599999999999998:
# Test accuracy 17.1:
# EPOCH 45:
#  batch 100 loss: 2.0804004037380217
#  batch 200 loss: 2.095996379852295
#  batch 300 loss: 2.1171648490428923
# Train accuracy 21.4:
# Test accuracy 18.2:
# EPOCH 46:
#  batch 100 loss: 2.0827375042438505
#  batch 200 loss: 2.0955020236968993
#  batch 300 loss: 2.1049287974834443
# Train accuracy 22.0:
# Test accuracy 18.8:
# EPOCH 47:
#  batch 100 loss: 2.090227073431015
#  batch 200 loss: 2.10722483754158
#  batch 300 loss: 2.109918525218964
# Train accuracy 21.8:
# Test accuracy 18.3:
# EPOCH 48:
#  batch 100 loss: 2.070963975191116
#  batch 200 loss: 2.0999825596809387
#  batch 300 loss: 2.103984388113022
# Train accuracy 21.2:
# Test accuracy 17.7:
# EPOCH 49:
#  batch 100 loss: 2.078093420267105
#  batch 200 loss: 2.0784513747692106
#  batch 300 loss: 2.092358191013336
# Train accuracy 22.5:
# Test accuracy 18.9:
# EPOCH 50:
#  batch 100 loss: 2.08730535030365
#  batch 200 loss: 2.0845567810535433
#  batch 300 loss: 2.096164231300354
# Train accuracy 21.4:
# Test accuracy 17.599999999999998:
# EPOCH 51:
#  batch 100 loss: 2.082429313659668
#  batch 200 loss: 2.076291511058807
#  batch 300 loss: 2.0861620473861695
# Train accuracy 22.400000000000002:
# Test accuracy 18.9:
# EPOCH 52:
#  batch 100 loss: 2.0697202384471893
#  batch 200 loss: 2.0851546704769133
#  batch 300 loss: 2.0882846367359162
# Train accuracy 22.7:
# Test accuracy 19.0:
# EPOCH 53:
#  batch 100 loss: 2.081376516819
#  batch 200 loss: 2.0826565372943877
#  batch 300 loss: 2.085330395698547
# Train accuracy 21.2:
# Test accuracy 17.7:
# EPOCH 54:
#  batch 100 loss: 2.0717683935165407
#  batch 200 loss: 2.0723390972614286
#  batch 300 loss: 2.0872977101802825
# Train accuracy 21.7:
# Test accuracy 17.599999999999998:
# EPOCH 55:
#  batch 100 loss: 2.113228315114975
#  batch 200 loss: 2.0892577254772187
#  batch 300 loss: 2.086746611595154
# Train accuracy 21.9:
# Test accuracy 18.2:
# EPOCH 56:
#  batch 100 loss: 2.065011413097382
#  batch 200 loss: 2.093946788311005
#  batch 300 loss: 2.077244975566864
# Train accuracy 21.8:
# Test accuracy 18.0:
# EPOCH 57:
#  batch 100 loss: 2.070672632455826
#  batch 200 loss: 2.0841514861583708
#  batch 300 loss: 2.08485476732254
# Train accuracy 22.2:
# Test accuracy 18.2:
# EPOCH 58:
#  batch 100 loss: 2.050910187959671
#  batch 200 loss: 2.070270587205887
#  batch 300 loss: 2.0842590844631195
# Train accuracy 22.5:
# Test accuracy 18.7:
# EPOCH 59:
#  batch 100 loss: 2.0717858695983886
#  batch 200 loss: 2.052385628223419
#  batch 300 loss: 2.066180723905563
# Train accuracy 22.0:
# Test accuracy 17.9:
# EPOCH 60:
#  batch 100 loss: 2.0757880389690397
#  batch 200 loss: 2.0823329520225524
#  batch 300 loss: 2.056419359445572
# Train accuracy 22.1:
# Test accuracy 18.4:
# EPOCH 61:
#  batch 100 loss: 2.054485719203949
#  batch 200 loss: 2.073163504600525
#  batch 300 loss: 2.072801570892334
# Train accuracy 22.0:
# Test accuracy 18.2:
# EPOCH 62:
#  batch 100 loss: 2.0597141647338866
#  batch 200 loss: 2.0543944489955903
#  batch 300 loss: 2.0631520664691925
# Train accuracy 23.0:
# Test accuracy 18.9:
# EPOCH 63:
#  batch 100 loss: 2.067034676074982
#  batch 200 loss: 2.0568053781986237
#  batch 300 loss: 2.046431220769882
# Train accuracy 23.0:
# Test accuracy 18.8:
# EPOCH 64:
#  batch 100 loss: 2.0570498406887054
#  batch 200 loss: 2.0435366928577423
#  batch 300 loss: 2.0640857112407685
# Train accuracy 22.6:
# Test accuracy 18.0:
# EPOCH 65:
#  batch 100 loss: 2.065886033773422
#  batch 200 loss: 2.0803692650794985
#  batch 300 loss: 2.073447971343994
# Train accuracy 21.7:
# Test accuracy 17.299999999999997:
# EPOCH 66:
#  batch 100 loss: 2.080484986305237
#  batch 200 loss: 2.1538642132282257
#  batch 300 loss: 2.083807575702667
# Train accuracy 23.400000000000002:
# Test accuracy 18.9:
# EPOCH 67:
#  batch 100 loss: 2.053972487449646
#  batch 200 loss: 2.0508108699321745
#  batch 300 loss: 2.041954851150513
# Train accuracy 22.7:
# Test accuracy 18.5:
# EPOCH 68:
#  batch 100 loss: 2.0300463151931765
#  batch 200 loss: 2.046590247154236
#  batch 300 loss: 2.038450964689255
# Train accuracy 23.799999999999997:
# Test accuracy 19.3:
# EPOCH 69:
#  batch 100 loss: 2.047580411434174
#  batch 200 loss: 2.0534536480903625
#  batch 300 loss: 2.029719413518906
# Train accuracy 22.3:
# Test accuracy 17.8:
# EPOCH 70:
#  batch 100 loss: 2.0468658065795897
#  batch 200 loss: 2.0367417979240416
#  batch 300 loss: 2.0450443744659426
# Train accuracy 23.400000000000002:
# Test accuracy 18.7:
# EPOCH 71:
#  batch 100 loss: 2.0378435707092284
#  batch 200 loss: 2.0300361490249634
#  batch 300 loss: 2.0502827548980713
# Train accuracy 23.1:
# Test accuracy 19.0:
# EPOCH 72:
#  batch 100 loss: 2.046357946395874
#  batch 200 loss: 2.03330402970314
#  batch 300 loss: 2.0406436097621916
# Train accuracy 24.2:
# Test accuracy 20.0:
# EPOCH 73:
#  batch 100 loss: 2.0377153396606444
#  batch 200 loss: 2.051089563369751
#  batch 300 loss: 2.0452012813091276
# Train accuracy 23.599999999999998:
# Test accuracy 19.2:
# EPOCH 74:
#  batch 100 loss: 2.012267702817917
#  batch 200 loss: 2.044017173051834
#  batch 300 loss: 2.0629709327220915
# Train accuracy 24.3:
# Test accuracy 20.1:
# EPOCH 75:
#  batch 100 loss: 2.0389399945735933
#  batch 200 loss: 2.0320608508586884
#  batch 300 loss: 2.0403632152080537
# Train accuracy 23.7:
# Test accuracy 18.8:
# EPOCH 76:
#  batch 100 loss: 2.0183343064785
#  batch 200 loss: 2.024206302165985
#  batch 300 loss: 2.0576146841049194
# Train accuracy 22.8:
# Test accuracy 17.7:
# EPOCH 77:
#  batch 100 loss: 2.0296225905418397
#  batch 200 loss: 2.0427544140815734
#  batch 300 loss: 2.0249411022663115
# Train accuracy 23.599999999999998:
# Test accuracy 18.9:
# EPOCH 78:
#  batch 100 loss: 2.02143230676651
#  batch 200 loss: 2.0393055546283723
#  batch 300 loss: 2.0346544182300565
# Train accuracy 23.9:
# Test accuracy 18.9:
# EPOCH 79:
#  batch 100 loss: 2.0272803044319154
#  batch 200 loss: 2.045147284269333
#  batch 300 loss: 2.037782427072525
# Train accuracy 23.200000000000003:
# Test accuracy 18.3:
# EPOCH 80:
#  batch 100 loss: 2.0088200640678404
#  batch 200 loss: 2.0270543372631074
#  batch 300 loss: 2.0326850771903993
# Train accuracy 24.7:
# Test accuracy 19.5:
# EPOCH 81:
#  batch 100 loss: 2.01479309797287
#  batch 200 loss: 2.026796814203262
#  batch 300 loss: 2.0368738555908203
# Train accuracy 23.9:
# Test accuracy 19.2:
# EPOCH 82:
#  batch 100 loss: 2.0057826602458952
#  batch 200 loss: 2.0335421335697172
#  batch 300 loss: 2.0268064439296722
# Train accuracy 24.8:
# Test accuracy 20.3:
# EPOCH 83:
#  batch 100 loss: 2.017651996612549
#  batch 200 loss: 2.01003907084465
#  batch 300 loss: 2.032091192007065
# Train accuracy 23.7:
# Test accuracy 19.2:
# EPOCH 84:
#  batch 100 loss: 2.017309659719467
#  batch 200 loss: 2.030843251943588
#  batch 300 loss: 2.0422235465049745
# Train accuracy 23.799999999999997:
# Test accuracy 18.6:
# EPOCH 85:
#  batch 100 loss: 2.012733653783798
#  batch 200 loss: 2.043442567586899
#  batch 300 loss: 1.9998008024692535
# Train accuracy 23.7:
# Test accuracy 18.8:
# EPOCH 86:
#  batch 100 loss: 1.9989683842658996
#  batch 200 loss: 2.01574392914772
#  batch 300 loss: 2.0236331939697267
# Train accuracy 23.400000000000002:
# Test accuracy 18.5:
# EPOCH 87:
#  batch 100 loss: 2.0011326253414152
#  batch 200 loss: 2.030230334997177
#  batch 300 loss: 2.017993137836456
# Train accuracy 21.8:
# Test accuracy 17.1:
# EPOCH 88:
#  batch 100 loss: 2.0080743169784547
#  batch 200 loss: 2.0035023319721224
#  batch 300 loss: 2.023081661462784
# Train accuracy 24.8:
# Test accuracy 19.400000000000002:
# EPOCH 89:
#  batch 100 loss: 2.0255920815467836
#  batch 200 loss: 2.0167031967639923
#  batch 300 loss: 2.0118445682525636
# Train accuracy 24.8:
# Test accuracy 20.599999999999998:
# EPOCH 90:
#  batch 100 loss: 2.000643935203552
#  batch 200 loss: 2.0199084627628325
#  batch 300 loss: 2.0185553526878355
# Train accuracy 24.0:
# Test accuracy 19.3:
# EPOCH 91:
#  batch 100 loss: 1.9994186222553254
#  batch 200 loss: 2.021113917827606
#  batch 300 loss: 2.007432265281677
# Train accuracy 23.3:
# Test accuracy 18.099999999999998:
# EPOCH 92:
#  batch 100 loss: 1.9885110998153686
#  batch 200 loss: 2.007065167427063
#  batch 300 loss: 2.0119607281684875
# Train accuracy 25.2:
# Test accuracy 19.900000000000002:
# EPOCH 93:
#  batch 100 loss: 1.9987137830257415
#  batch 200 loss: 2.007054282426834
#  batch 300 loss: 2.024778056144714
# Train accuracy 24.5:
# Test accuracy 19.8:
# EPOCH 94:
#  batch 100 loss: 1.9902847266197206
#  batch 200 loss: 1.9855850768089294
#  batch 300 loss: 2.0241596162319184
# Train accuracy 23.0:
# Test accuracy 17.7:
# EPOCH 95:
#  batch 100 loss: 1.9791840720176697
#  batch 200 loss: 2.0046369612216948
#  batch 300 loss: 2.0061158466339113
# Train accuracy 24.8:
# Test accuracy 19.6:
# EPOCH 96:
#  batch 100 loss: 1.9933017790317535
#  batch 200 loss: 2.0192690801620485
#  batch 300 loss: 2.0007757127285
# Train accuracy 24.099999999999998:
# Test accuracy 19.5:
# EPOCH 97:
#  batch 100 loss: 2.0044708788394927
#  batch 200 loss: 2.009606122970581
#  batch 300 loss: 2.012256416082382
# Train accuracy 24.099999999999998:
# Test accuracy 18.8:
# EPOCH 98:
#  batch 100 loss: 1.9929543507099152
#  batch 200 loss: 1.992412794828415
#  batch 300 loss: 2.015218290090561
# Train accuracy 23.7:
# Test accuracy 18.6:
# EPOCH 99:
#  batch 100 loss: 1.9778729844093323
#  batch 200 loss: 1.9957474267482758
#  batch 300 loss: 1.9995797073841095
# Train accuracy 25.1:
# Test accuracy 19.7:
# EPOCH 100:
#  batch 100 loss: 1.9814372777938842
#  batch 200 loss: 2.0097323942184446
#  batch 300 loss: 2.011701726913452
# Train accuracy 24.099999999999998:
# Test accuracy 18.7:
# Learning Rate 0.1:
# EPOCH 1:
#  batch 100 loss: 2.0010037422180176
#  batch 200 loss: 1.9016570818424225
#  batch 300 loss: 1.9013144278526306
# Train accuracy 33.6:
# Test accuracy 31.8:
# EPOCH 2:
#  batch 100 loss: 1.8327769649028778
#  batch 200 loss: 1.8518350756168365
#  batch 300 loss: 1.8035130882263184
# Train accuracy 39.300000000000004:
# Test accuracy 37.6:
# EPOCH 3:
#  batch 100 loss: 1.820730801820755
#  batch 200 loss: 1.819452314376831
#  batch 300 loss: 1.8184256517887116
# Train accuracy 38.6:
# Test accuracy 36.4:
# EPOCH 4:
#  batch 100 loss: 1.7892327332496643
#  batch 200 loss: 1.7958011710643769
#  batch 300 loss: 1.7904896283149718
# Train accuracy 41.4:
# Test accuracy 38.3:
# EPOCH 5:
#  batch 100 loss: 1.7934438848495484
#  batch 200 loss: 1.7799208343029023
#  batch 300 loss: 1.780620368719101
# Train accuracy 39.0:
# Test accuracy 36.0:
# EPOCH 6:
#  batch 100 loss: 1.7808608305454254
#  batch 200 loss: 1.7580023622512817
#  batch 300 loss: 1.7841208374500275
# Train accuracy 38.5:
# Test accuracy 34.8:
# EPOCH 7:
#  batch 100 loss: 1.7491991138458252
#  batch 200 loss: 1.7824679517745972
#  batch 300 loss: 1.7790652740001678
# Train accuracy 41.099999999999994:
# Test accuracy 37.0:
# EPOCH 8:
#  batch 100 loss: 1.7534882760047912
#  batch 200 loss: 1.7469254302978516
#  batch 300 loss: 1.7620062303543091
# Train accuracy 41.9:
# Test accuracy 38.5:
# EPOCH 9:
#  batch 100 loss: 1.7282471609115602
#  batch 200 loss: 1.7562791037559509
#  batch 300 loss: 1.7702502632141113
# Train accuracy 39.5:
# Test accuracy 35.3:
# EPOCH 10:
#  batch 100 loss: 1.7553036606311798
#  batch 200 loss: 1.7509999549388886
#  batch 300 loss: 1.7616372227668762
# Train accuracy 41.199999999999996:
# Test accuracy 36.9:
# EPOCH 11:
#  batch 100 loss: 1.7325154829025269
#  batch 200 loss: 1.755796854496002
#  batch 300 loss: 1.7528729832172394
# Train accuracy 42.8:
# Test accuracy 38.4:
# EPOCH 12:
#  batch 100 loss: 1.7312615716457367
#  batch 200 loss: 1.747182023525238
#  batch 300 loss: 1.7530032539367675
# Train accuracy 42.0:
# Test accuracy 37.6:
# EPOCH 13:
#  batch 100 loss: 1.7252511167526245
#  batch 200 loss: 1.7479903519153595
#  batch 300 loss: 1.7507729399204255
# Train accuracy 43.9:
# Test accuracy 38.800000000000004:
# EPOCH 14:
#  batch 100 loss: 1.7283534240722656
#  batch 200 loss: 1.7177498960494995
#  batch 300 loss: 1.7283003807067872
# Train accuracy 43.5:
# Test accuracy 37.3:
# EPOCH 15:
#  batch 100 loss: 1.7222521150112151
#  batch 200 loss: 1.742282828092575
#  batch 300 loss: 1.7437940430641174
# Train accuracy 41.199999999999996:
# Test accuracy 36.3:
# EPOCH 16:
#  batch 100 loss: 1.7147878313064575
#  batch 200 loss: 1.7375201642513276
#  batch 300 loss: 1.741854864358902
# Train accuracy 42.199999999999996:
# Test accuracy 37.0:
# EPOCH 17:
#  batch 100 loss: 1.755221494436264
#  batch 200 loss: 1.7081104254722594
#  batch 300 loss: 1.732795419692993
# Train accuracy 42.6:
# Test accuracy 37.6:
# EPOCH 18:
#  batch 100 loss: 1.7347318148612976
#  batch 200 loss: 1.709276418685913
#  batch 300 loss: 1.7109068942070007
# Train accuracy 43.1:
# Test accuracy 37.2:
# EPOCH 19:
#  batch 100 loss: 1.709951548576355
#  batch 200 loss: 1.7258348751068116
#  batch 300 loss: 1.7275978875160218
# Train accuracy 41.9:
# Test accuracy 36.3:
# EPOCH 20:
#  batch 100 loss: 1.7073268842697145
#  batch 200 loss: 1.709523650407791
#  batch 300 loss: 1.7327614688873292
# Train accuracy 41.6:
# Test accuracy 36.3:
# EPOCH 21:
#  batch 100 loss: 1.7093089044094085
#  batch 200 loss: 1.736259846687317
#  batch 300 loss: 1.6951856696605683
# Train accuracy 42.9:
# Test accuracy 37.7:
# EPOCH 22:
#  batch 100 loss: 1.7021210920810699
#  batch 200 loss: 1.7127626323699952
#  batch 300 loss: 1.7316192293167114
# Train accuracy 42.8:
# Test accuracy 37.4:
# EPOCH 23:
#  batch 100 loss: 1.7210176026821136
#  batch 200 loss: 1.705924369096756
#  batch 300 loss: 1.7103065752983093
# Train accuracy 42.6:
# Test accuracy 36.6:
# EPOCH 24:
#  batch 100 loss: 1.6772594046592713
#  batch 200 loss: 1.7427390146255493
#  batch 300 loss: 1.7250787270069123
# Train accuracy 38.7:
# Test accuracy 33.4:
# EPOCH 25:
#  batch 100 loss: 1.7122464299201965
#  batch 200 loss: 1.708177080154419
#  batch 300 loss: 1.6959612154960633
# Train accuracy 42.1:
# Test accuracy 37.6:
# EPOCH 26:
#  batch 100 loss: 1.7049206697940826
#  batch 200 loss: 1.70799192070961
#  batch 300 loss: 1.7125036525726318
# Train accuracy 44.0:
# Test accuracy 37.6:
# EPOCH 27:
#  batch 100 loss: 1.6694707036018372
#  batch 200 loss: 1.7075791001319884
#  batch 300 loss: 1.7183708465099334
# Train accuracy 44.6:
# Test accuracy 37.9:
# EPOCH 28:
#  batch 100 loss: 1.6972259950637818
#  batch 200 loss: 1.713121191263199
#  batch 300 loss: 1.7038320338726043
# Train accuracy 42.6:
# Test accuracy 36.9:
# EPOCH 29:
#  batch 100 loss: 1.6793693566322327
#  batch 200 loss: 1.681966780424118
#  batch 300 loss: 1.6981950855255128
# Train accuracy 44.3:
# Test accuracy 37.9:
# EPOCH 30:
#  batch 100 loss: 1.6987542235851287
#  batch 200 loss: 1.7023942482471466
#  batch 300 loss: 1.706136989593506
# Train accuracy 45.1:
# Test accuracy 38.800000000000004:
# EPOCH 31:
#  batch 100 loss: 1.6839006388187407
#  batch 200 loss: 1.7021696043014527
#  batch 300 loss: 1.7054981327056884
# Train accuracy 43.7:
# Test accuracy 37.3:
# EPOCH 32:
#  batch 100 loss: 1.6767311120033264
#  batch 200 loss: 1.6987428104877471
#  batch 300 loss: 1.689609134197235
# Train accuracy 43.0:
# Test accuracy 36.4:
# EPOCH 33:
#  batch 100 loss: 1.6841772651672364
#  batch 200 loss: 1.6962535309791564
#  batch 300 loss: 1.7091968405246734
# Train accuracy 43.8:
# Test accuracy 38.9:
# EPOCH 34:
#  batch 100 loss: 1.6795145523548127
#  batch 200 loss: 1.7019384407997131
#  batch 300 loss: 1.7095319545269012
# Train accuracy 42.6:
# Test accuracy 36.5:
# EPOCH 35:
#  batch 100 loss: 1.6839978623390197
#  batch 200 loss: 1.7186709976196288
#  batch 300 loss: 1.6791178929805755
# Train accuracy 42.699999999999996:
# Test accuracy 36.1:
# EPOCH 36:
#  batch 100 loss: 1.662649508714676
#  batch 200 loss: 1.689886212348938
#  batch 300 loss: 1.6986581361293793
# Train accuracy 42.9:
# Test accuracy 36.3:
# EPOCH 37:
#  batch 100 loss: 1.6641867899894713
#  batch 200 loss: 1.7004010570049286
#  batch 300 loss: 1.688610292673111
# Train accuracy 42.3:
# Test accuracy 35.0:
# EPOCH 38:
#  batch 100 loss: 1.6697109591960908
#  batch 200 loss: 1.6754726707935332
#  batch 300 loss: 1.7092910933494567
# Train accuracy 44.800000000000004:
# Test accuracy 37.5:
# EPOCH 39:
#  batch 100 loss: 1.6477410578727723
#  batch 200 loss: 1.6850330710411072
#  batch 300 loss: 1.6938615453243255
# Train accuracy 41.0:
# Test accuracy 34.699999999999996:
# EPOCH 40:
#  batch 100 loss: 1.6647768747806548
#  batch 200 loss: 1.6865346801280976
#  batch 300 loss: 1.6962510395050048
# Train accuracy 41.9:
# Test accuracy 35.699999999999996:
# EPOCH 41:
#  batch 100 loss: 1.678856680393219
#  batch 200 loss: 1.6768037617206573
#  batch 300 loss: 1.7125269508361816
# Train accuracy 42.8:
# Test accuracy 36.6:
# EPOCH 42:
#  batch 100 loss: 1.665093811750412
#  batch 200 loss: 1.7050240182876586
#  batch 300 loss: 1.6897325730323791
# Train accuracy 44.5:
# Test accuracy 37.8:
# EPOCH 43:
#  batch 100 loss: 1.6945149505138397
#  batch 200 loss: 1.6628806281089783
#  batch 300 loss: 1.6766927111148835
# Train accuracy 44.7:
# Test accuracy 37.8:
# EPOCH 44:
#  batch 100 loss: 1.6674935126304626
#  batch 200 loss: 1.692549422979355
#  batch 300 loss: 1.694387434720993
# Train accuracy 44.0:
# Test accuracy 37.4:
# EPOCH 45:
#  batch 100 loss: 1.6761874866485595
#  batch 200 loss: 1.6544314658641814
#  batch 300 loss: 1.6852650499343873
# Train accuracy 44.9:
# Test accuracy 36.6:
# EPOCH 46:
#  batch 100 loss: 1.670003114938736
#  batch 200 loss: 1.6844220197200774
#  batch 300 loss: 1.6887701404094697
# Train accuracy 44.2:
# Test accuracy 37.7:
# EPOCH 47:
#  batch 100 loss: 1.6682817566394805
#  batch 200 loss: 1.6793728423118592
#  batch 300 loss: 1.698586175441742
# Train accuracy 43.8:
# Test accuracy 36.3:
# EPOCH 48:
#  batch 100 loss: 1.6687089002132416
#  batch 200 loss: 1.674886931180954
#  batch 300 loss: 1.6933942604064942
# Train accuracy 42.9:
# Test accuracy 36.0:
# EPOCH 49:
#  batch 100 loss: 1.6575545370578766
#  batch 200 loss: 1.6912654221057892
#  batch 300 loss: 1.6811638808250426
# Train accuracy 45.0:
# Test accuracy 38.3:
# EPOCH 50:
#  batch 100 loss: 1.6574304926395416
#  batch 200 loss: 1.6845794320106506
#  batch 300 loss: 1.6868433880805969
# Train accuracy 43.6:
# Test accuracy 36.6:
# EPOCH 51:
#  batch 100 loss: 1.63845969080925
#  batch 200 loss: 1.6791732466220857
#  batch 300 loss: 1.6820762503147124
# Train accuracy 40.300000000000004:
# Test accuracy 33.900000000000006:
# EPOCH 52:
#  batch 100 loss: 1.6763036918640137
#  batch 200 loss: 1.6610845994949341
#  batch 300 loss: 1.6776657474040986
# Train accuracy 44.6:
# Test accuracy 37.7:
# EPOCH 53:
#  batch 100 loss: 1.6682296359539033
#  batch 200 loss: 1.6700125384330748
#  batch 300 loss: 1.6775220918655396
# Train accuracy 42.6:
# Test accuracy 36.4:
# EPOCH 54:
#  batch 100 loss: 1.643594709634781
#  batch 200 loss: 1.6694835448265075
#  batch 300 loss: 1.685232356786728
# Train accuracy 46.0:
# Test accuracy 38.3:
# EPOCH 55:
#  batch 100 loss: 1.657225536108017
#  batch 200 loss: 1.6810259485244752
#  batch 300 loss: 1.6702591240406037
# Train accuracy 43.2:
# Test accuracy 34.699999999999996:
# EPOCH 56:
#  batch 100 loss: 1.6488396620750427
#  batch 200 loss: 1.674677836894989
#  batch 300 loss: 1.6506318545341492
# Train accuracy 41.699999999999996:
# Test accuracy 34.4:
# EPOCH 57:
#  batch 100 loss: 1.6556093561649323
#  batch 200 loss: 1.6658494079113007
#  batch 300 loss: 1.6947258055210113
# Train accuracy 44.2:
# Test accuracy 36.9:
# EPOCH 58:
#  batch 100 loss: 1.64795161485672
#  batch 200 loss: 1.6726845705509186
#  batch 300 loss: 1.6777945899963378
# Train accuracy 42.699999999999996:
# Test accuracy 36.3:
# EPOCH 59:
#  batch 100 loss: 1.645966066122055
#  batch 200 loss: 1.6629323911666871
#  batch 300 loss: 1.697926902770996
# Train accuracy 42.699999999999996:
# Test accuracy 35.8:
# EPOCH 60:
#  batch 100 loss: 1.653785572052002
#  batch 200 loss: 1.6574936878681183
#  batch 300 loss: 1.6765830874443055
# Train accuracy 41.4:
# Test accuracy 34.4:
# EPOCH 61:
#  batch 100 loss: 1.6489216458797455
#  batch 200 loss: 1.6731634521484375
#  batch 300 loss: 1.6717737960815429
# Train accuracy 44.9:
# Test accuracy 36.9:
# EPOCH 62:
#  batch 100 loss: 1.6558957016468048
#  batch 200 loss: 1.6672566950321197
#  batch 300 loss: 1.685548757314682
# Train accuracy 45.2:
# Test accuracy 36.0:
# EPOCH 63:
#  batch 100 loss: 1.6252102422714234
#  batch 200 loss: 1.6612688863277436
#  batch 300 loss: 1.6678331446647645
# Train accuracy 44.800000000000004:
# Test accuracy 36.4:
# EPOCH 64:
#  batch 100 loss: 1.6323352336883545
#  batch 200 loss: 1.6699114978313445
#  batch 300 loss: 1.6726718878746032
# Train accuracy 45.300000000000004:
# Test accuracy 37.6:
# EPOCH 65:
#  batch 100 loss: 1.6533378601074218
#  batch 200 loss: 1.6591084682941437
#  batch 300 loss: 1.6781245398521423
# Train accuracy 44.6:
# Test accuracy 37.0:
# EPOCH 66:
#  batch 100 loss: 1.6485534250736236
#  batch 200 loss: 1.6697188591957093
#  batch 300 loss: 1.6673090171813965
# Train accuracy 43.7:
# Test accuracy 36.199999999999996:
# EPOCH 67:
#  batch 100 loss: 1.6532376730442047
#  batch 200 loss: 1.6463762640953064
#  batch 300 loss: 1.6547234666347503
# Train accuracy 45.9:
# Test accuracy 36.9:
# EPOCH 68:
#  batch 100 loss: 1.6528667628765106
#  batch 200 loss: 1.6554986870288848
#  batch 300 loss: 1.684841822385788
# Train accuracy 43.7:
# Test accuracy 35.5:
# EPOCH 69:
#  batch 100 loss: 1.638158094882965
#  batch 200 loss: 1.6456017184257508
#  batch 300 loss: 1.6703371715545654
# Train accuracy 40.400000000000006:
# Test accuracy 34.8:
# EPOCH 70:
#  batch 100 loss: 1.6553788042068482
#  batch 200 loss: 1.6540295743942262
#  batch 300 loss: 1.664429075717926
# Train accuracy 46.1:
# Test accuracy 37.7:
# EPOCH 71:
#  batch 100 loss: 1.6378447115421295
#  batch 200 loss: 1.685771086215973
#  batch 300 loss: 1.6628896331787109
# Train accuracy 45.0:
# Test accuracy 37.5:
# EPOCH 72:
#  batch 100 loss: 1.6441779577732085
#  batch 200 loss: 1.6516872012615205
#  batch 300 loss: 1.676081954240799
# Train accuracy 46.0:
# Test accuracy 36.9:
# EPOCH 73:
#  batch 100 loss: 1.6485604238510132
#  batch 200 loss: 1.62982825756073
#  batch 300 loss: 1.6581519424915314
# Train accuracy 43.7:
# Test accuracy 36.3:
# EPOCH 74:
#  batch 100 loss: 1.6699043428897857
#  batch 200 loss: 1.6415004241466522
#  batch 300 loss: 1.6603349232673645
# Train accuracy 46.7:
# Test accuracy 37.3:
# EPOCH 75:
#  batch 100 loss: 1.6308687686920167
#  batch 200 loss: 1.647422399520874
#  batch 300 loss: 1.6427130794525147
# Train accuracy 45.5:
# Test accuracy 37.5:
# EPOCH 76:
#  batch 100 loss: 1.6366311502456665
#  batch 200 loss: 1.672333608865738
#  batch 300 loss: 1.652932813167572
# Train accuracy 43.0:
# Test accuracy 35.099999999999994:
# EPOCH 77:
#  batch 100 loss: 1.6436137318611146
#  batch 200 loss: 1.6431325912475585
#  batch 300 loss: 1.6729926919937135
# Train accuracy 43.2:
# Test accuracy 35.4:
# EPOCH 78:
#  batch 100 loss: 1.616251151561737
#  batch 200 loss: 1.6182325387001038
#  batch 300 loss: 1.701911623477936
# Train accuracy 41.099999999999994:
# Test accuracy 33.6:
# EPOCH 79:
#  batch 100 loss: 1.6459171855449677
#  batch 200 loss: 1.6373953139781952
#  batch 300 loss: 1.6602351784706115
# Train accuracy 44.9:
# Test accuracy 37.1:
# EPOCH 80:
#  batch 100 loss: 1.6385351312160492
#  batch 200 loss: 1.6275812518596648
#  batch 300 loss: 1.6584451711177826
# Train accuracy 44.9:
# Test accuracy 36.4:
# EPOCH 81:
#  batch 100 loss: 1.639794409275055
#  batch 200 loss: 1.6512773370742797
#  batch 300 loss: 1.6650365805625915
# Train accuracy 43.4:
# Test accuracy 35.099999999999994:
# EPOCH 82:
#  batch 100 loss: 1.6227184867858886
#  batch 200 loss: 1.668258159160614
#  batch 300 loss: 1.6500744128227234
# Train accuracy 44.9:
# Test accuracy 36.6:
# EPOCH 83:
#  batch 100 loss: 1.6175133860111237
#  batch 200 loss: 1.6707071053981781
#  batch 300 loss: 1.6404053473472595
# Train accuracy 45.7:
# Test accuracy 37.3:
# EPOCH 84:
#  batch 100 loss: 1.6373767685890197
#  batch 200 loss: 1.6378271079063416
#  batch 300 loss: 1.6566855061054229
# Train accuracy 46.1:
# Test accuracy 37.2:
# EPOCH 85:
#  batch 100 loss: 1.6225223553180694
#  batch 200 loss: 1.6559598982334136
#  batch 300 loss: 1.6585862469673156
# Train accuracy 44.3:
# Test accuracy 35.699999999999996:
# EPOCH 86:
#  batch 100 loss: 1.6054078447818756
#  batch 200 loss: 1.6312647104263305
#  batch 300 loss: 1.6741956841945649
# Train accuracy 42.9:
# Test accuracy 35.0:
# EPOCH 87:
#  batch 100 loss: 1.6188448750972748
#  batch 200 loss: 1.655009171962738
#  batch 300 loss: 1.6312411582469941
# Train accuracy 44.2:
# Test accuracy 36.4:
# EPOCH 88:
#  batch 100 loss: 1.6452571952342987
#  batch 200 loss: 1.620521742105484
#  batch 300 loss: 1.6527866542339325
# Train accuracy 45.2:
# Test accuracy 36.3:
# EPOCH 89:
#  batch 100 loss: 1.6146034240722655
#  batch 200 loss: 1.6349392461776733
#  batch 300 loss: 1.644374930858612
# Train accuracy 46.5:
# Test accuracy 37.0:
# EPOCH 90:
#  batch 100 loss: 1.6124976325035094
#  batch 200 loss: 1.6370864176750184
#  batch 300 loss: 1.66624844789505
# Train accuracy 44.3:
# Test accuracy 35.4:
# EPOCH 91:
#  batch 100 loss: 1.6386197471618653
#  batch 200 loss: 1.616450070142746
#  batch 300 loss: 1.6667711234092712
# Train accuracy 43.9:
# Test accuracy 35.199999999999996:
# EPOCH 92:
#  batch 100 loss: 1.6288257908821107
#  batch 200 loss: 1.6513216519355773
#  batch 300 loss: 1.6417082738876343
# Train accuracy 46.400000000000006:
# Test accuracy 37.6:
# EPOCH 93:
#  batch 100 loss: 1.6189580273628235
#  batch 200 loss: 1.6406769144535065
#  batch 300 loss: 1.6550619387626648
# Train accuracy 42.199999999999996:
# Test accuracy 34.0:
# EPOCH 94:
#  batch 100 loss: 1.6444027638435363
#  batch 200 loss: 1.6349829578399657
#  batch 300 loss: 1.6477673196792602
# Train accuracy 43.9:
# Test accuracy 36.0:
# EPOCH 95:
#  batch 100 loss: 1.6206493031978608
#  batch 200 loss: 1.6478555405139923
#  batch 300 loss: 1.6442243468761444
# Train accuracy 42.199999999999996:
# Test accuracy 33.7:
# EPOCH 96:
#  batch 100 loss: 1.6266070520877838
#  batch 200 loss: 1.6468165028095245
#  batch 300 loss: 1.6446071815490724
# Train accuracy 46.5:
# Test accuracy 37.3:
# EPOCH 97:
#  batch 100 loss: 1.640586974620819
#  batch 200 loss: 1.646008118391037
#  batch 300 loss: 1.6387700748443603
# Train accuracy 43.6:
# Test accuracy 35.6:
# EPOCH 98:
#  batch 100 loss: 1.6328696846961974
#  batch 200 loss: 1.6586278653144837
#  batch 300 loss: 1.6331555807590485
# Train accuracy 45.5:
# Test accuracy 36.8:
# EPOCH 99:
#  batch 100 loss: 1.6133797645568848
#  batch 200 loss: 1.641844586133957
#  batch 300 loss: 1.6341458666324615
# Train accuracy 42.8:
# Test accuracy 34.699999999999996:
# EPOCH 100:
#  batch 100 loss: 1.6213090121746063
#  batch 200 loss: 1.652533892393112
#  batch 300 loss: 1.639050807952881
# Train accuracy 44.7:
# Test accuracy 35.6:
# Learning Rate 0.01:
# EPOCH 1:
#  batch 100 loss: 2.0444684338569643
#  batch 200 loss: 1.883472182750702
#  batch 300 loss: 1.8484407651424408
# Train accuracy 39.1:
# Test accuracy 38.7:
# EPOCH 2:
#  batch 100 loss: 1.7943880093097686
#  batch 200 loss: 1.794589352607727
#  batch 300 loss: 1.7761588323116302
# Train accuracy 40.8:
# Test accuracy 39.800000000000004:
# EPOCH 3:
#  batch 100 loss: 1.7560575556755067
#  batch 200 loss: 1.7443151664733887
#  batch 300 loss: 1.7445029878616334
# Train accuracy 41.699999999999996:
# Test accuracy 40.5:
# EPOCH 4:
#  batch 100 loss: 1.7378840720653534
#  batch 200 loss: 1.7386019384860993
#  batch 300 loss: 1.7387740218639374
# Train accuracy 42.1:
# Test accuracy 41.0:
# EPOCH 5:
#  batch 100 loss: 1.7108389568328857
#  batch 200 loss: 1.7324330639839172
#  batch 300 loss: 1.7251320385932922
# Train accuracy 42.699999999999996:
# Test accuracy 41.099999999999994:
# EPOCH 6:
#  batch 100 loss: 1.7110495066642761
#  batch 200 loss: 1.70443479180336
#  batch 300 loss: 1.720712854862213
# Train accuracy 43.0:
# Test accuracy 41.5:
# EPOCH 7:
#  batch 100 loss: 1.715388548374176
#  batch 200 loss: 1.702542998790741
#  batch 300 loss: 1.7020635068416596
# Train accuracy 43.0:
# Test accuracy 41.199999999999996:
# EPOCH 8:
#  batch 100 loss: 1.695216875076294
#  batch 200 loss: 1.7013586747646332
#  batch 300 loss: 1.6950853312015532
# Train accuracy 43.1:
# Test accuracy 41.3:
# EPOCH 9:
#  batch 100 loss: 1.6887452447414397
#  batch 200 loss: 1.6942289853096009
#  batch 300 loss: 1.698094139099121
# Train accuracy 43.2:
# Test accuracy 41.199999999999996:
# EPOCH 10:
#  batch 100 loss: 1.6883093845844268
#  batch 200 loss: 1.6869259703159332
#  batch 300 loss: 1.6891081988811494
# Train accuracy 43.9:
# Test accuracy 41.6:
# EPOCH 11:
#  batch 100 loss: 1.6815299129486083
#  batch 200 loss: 1.6771038901805877
#  batch 300 loss: 1.6924600160121919
# Train accuracy 43.8:
# Test accuracy 41.4:
# EPOCH 12:
#  batch 100 loss: 1.6715291917324067
#  batch 200 loss: 1.6709907126426697
#  batch 300 loss: 1.6820263409614562
# Train accuracy 44.0:
# Test accuracy 41.4:
# EPOCH 13:
#  batch 100 loss: 1.6775042963027955
#  batch 200 loss: 1.6657178151607512
#  batch 300 loss: 1.6791427052021026
# Train accuracy 44.1:
# Test accuracy 41.6:
# EPOCH 14:
#  batch 100 loss: 1.675100828409195
#  batch 200 loss: 1.6674485981464386
#  batch 300 loss: 1.6698308420181274
# Train accuracy 44.2:
# Test accuracy 41.5:
# EPOCH 15:
#  batch 100 loss: 1.6597416913509369
#  batch 200 loss: 1.67487473487854
#  batch 300 loss: 1.6731718707084655
# Train accuracy 44.6:
# Test accuracy 41.699999999999996:
# EPOCH 16:
#  batch 100 loss: 1.6764734828472136
#  batch 200 loss: 1.6559948658943175
#  batch 300 loss: 1.649153039455414
# Train accuracy 44.5:
# Test accuracy 41.3:
# EPOCH 17:
#  batch 100 loss: 1.6457302260398865
#  batch 200 loss: 1.6700988328456878
#  batch 300 loss: 1.6563339960575103
# Train accuracy 44.800000000000004:
# Test accuracy 41.8:
# EPOCH 18:
#  batch 100 loss: 1.6510012257099151
#  batch 200 loss: 1.647347707748413
#  batch 300 loss: 1.6538163816928864
# Train accuracy 44.6:
# Test accuracy 41.6:
# EPOCH 19:
#  batch 100 loss: 1.659366616010666
#  batch 200 loss: 1.661374558210373
#  batch 300 loss: 1.6443753230571747
# Train accuracy 44.800000000000004:
# Test accuracy 41.5:
# EPOCH 20:
#  batch 100 loss: 1.6581193006038666
#  batch 200 loss: 1.6515065395832063
#  batch 300 loss: 1.6538363659381867
# Train accuracy 44.9:
# Test accuracy 41.5:
# EPOCH 21:
#  batch 100 loss: 1.63843931555748
#  batch 200 loss: 1.6594013798236846
#  batch 300 loss: 1.6514668405055999
# Train accuracy 45.0:
# Test accuracy 41.5:
# EPOCH 22:
#  batch 100 loss: 1.6532671499252318
#  batch 200 loss: 1.645816727876663
#  batch 300 loss: 1.6494433236122132
# Train accuracy 44.9:
# Test accuracy 41.6:
# EPOCH 23:
#  batch 100 loss: 1.6356553876399993
#  batch 200 loss: 1.646186193227768
#  batch 300 loss: 1.6485669445991515
# Train accuracy 44.9:
# Test accuracy 41.6:
# EPOCH 24:
#  batch 100 loss: 1.6543408250808715
#  batch 200 loss: 1.639560878276825
#  batch 300 loss: 1.6502201890945434
# Train accuracy 44.6:
# Test accuracy 41.5:
# EPOCH 25:
#  batch 100 loss: 1.633524281978607
#  batch 200 loss: 1.6377348184585572
#  batch 300 loss: 1.6552360904216767
# Train accuracy 45.0:
# Test accuracy 41.4:
# EPOCH 26:
#  batch 100 loss: 1.6353862595558166
#  batch 200 loss: 1.6577152812480926
#  batch 300 loss: 1.638922621011734
# Train accuracy 45.300000000000004:
# Test accuracy 41.3:
# EPOCH 27:
#  batch 100 loss: 1.6359471893310547
#  batch 200 loss: 1.6382743692398072
#  batch 300 loss: 1.6516171395778656
# Train accuracy 45.300000000000004:
# Test accuracy 42.0:
# EPOCH 28:
#  batch 100 loss: 1.6417919707298279
#  batch 200 loss: 1.6368917608261109
#  batch 300 loss: 1.632614132165909
# Train accuracy 45.4:
# Test accuracy 41.6:
# EPOCH 29:
#  batch 100 loss: 1.636335746049881
#  batch 200 loss: 1.6309225416183473
#  batch 300 loss: 1.6252508413791658
# Train accuracy 45.300000000000004:
# Test accuracy 41.699999999999996:
# EPOCH 30:
#  batch 100 loss: 1.6295542740821838
#  batch 200 loss: 1.638691383600235
#  batch 300 loss: 1.6301191771030425
# Train accuracy 45.5:
# Test accuracy 41.8:
# EPOCH 31:
#  batch 100 loss: 1.6371801495552063
#  batch 200 loss: 1.625192062854767
#  batch 300 loss: 1.6382782220840455
# Train accuracy 45.4:
# Test accuracy 41.3:
# EPOCH 32:
#  batch 100 loss: 1.6364398682117463
#  batch 200 loss: 1.6384021151065826
#  batch 300 loss: 1.6362396824359893
# Train accuracy 45.5:
# Test accuracy 41.4:
# EPOCH 33:
#  batch 100 loss: 1.6212916564941406
#  batch 200 loss: 1.6351620221138001
#  batch 300 loss: 1.6303473377227784
# Train accuracy 45.300000000000004:
# Test accuracy 41.099999999999994:
# EPOCH 34:
#  batch 100 loss: 1.6210377049446105
#  batch 200 loss: 1.632166053056717
#  batch 300 loss: 1.636921752691269
# Train accuracy 45.5:
# Test accuracy 41.3:
# EPOCH 35:
#  batch 100 loss: 1.6235895240306855
#  batch 200 loss: 1.636533567905426
#  batch 300 loss: 1.620885866880417
# Train accuracy 45.5:
# Test accuracy 41.6:
# EPOCH 36:
#  batch 100 loss: 1.6365193331241608
#  batch 200 loss: 1.6228102731704712
#  batch 300 loss: 1.6154375791549682
# Train accuracy 45.9:
# Test accuracy 41.9:
# EPOCH 37:
#  batch 100 loss: 1.6231043136119843
#  batch 200 loss: 1.623292374610901
#  batch 300 loss: 1.6281421387195587
# Train accuracy 45.5:
# Test accuracy 41.199999999999996:
# EPOCH 38:
#  batch 100 loss: 1.6256774258613587
#  batch 200 loss: 1.6227349507808686
#  batch 300 loss: 1.6132135617733
# Train accuracy 45.7:
# Test accuracy 41.699999999999996:
# EPOCH 39:
#  batch 100 loss: 1.6187740767002106
#  batch 200 loss: 1.6226005446910858
#  batch 300 loss: 1.6307522463798523
# Train accuracy 45.9:
# Test accuracy 41.5:
# EPOCH 40:
#  batch 100 loss: 1.609942957162857
#  batch 200 loss: 1.6373809635639192
#  batch 300 loss: 1.6202710139751435
# Train accuracy 45.9:
# Test accuracy 41.699999999999996:
# EPOCH 41:
#  batch 100 loss: 1.6342508280277253
#  batch 200 loss: 1.620177652835846
#  batch 300 loss: 1.6027349770069121
# Train accuracy 45.7:
# Test accuracy 41.8:
# EPOCH 42:
#  batch 100 loss: 1.6157825326919555
#  batch 200 loss: 1.6296437680721283
#  batch 300 loss: 1.6097409796714783
# Train accuracy 45.6:
# Test accuracy 41.5:
# EPOCH 43:
#  batch 100 loss: 1.61517560839653
#  batch 200 loss: 1.6242739725112916
#  batch 300 loss: 1.615712229013443
# Train accuracy 45.9:
# Test accuracy 41.699999999999996:
# EPOCH 44:
#  batch 100 loss: 1.616911964416504
#  batch 200 loss: 1.6150446569919585
#  batch 300 loss: 1.6210611534118653
# Train accuracy 45.9:
# Test accuracy 41.5:
# EPOCH 45:
#  batch 100 loss: 1.6185875129699707
#  batch 200 loss: 1.6193439698219299
#  batch 300 loss: 1.6118755781650542
# Train accuracy 45.6:
# Test accuracy 41.6:
# EPOCH 46:
#  batch 100 loss: 1.6105872905254364
#  batch 200 loss: 1.6258672773838043
#  batch 300 loss: 1.6159525167942048
# Train accuracy 45.800000000000004:
# Test accuracy 41.5:
# EPOCH 47:
#  batch 100 loss: 1.6170359933376313
#  batch 200 loss: 1.612640711069107
#  batch 300 loss: 1.6137155425548553
# Train accuracy 46.2:
# Test accuracy 41.699999999999996:
# EPOCH 48:
#  batch 100 loss: 1.6283201253414155
#  batch 200 loss: 1.6033156430721283
#  batch 300 loss: 1.6133783125877381
# Train accuracy 45.5:
# Test accuracy 41.099999999999994:
# EPOCH 49:
#  batch 100 loss: 1.6095249021053315
#  batch 200 loss: 1.6136490714550018
#  batch 300 loss: 1.6197223150730133
# Train accuracy 45.9:
# Test accuracy 41.6:
# EPOCH 50:
#  batch 100 loss: 1.6019457530975343
#  batch 200 loss: 1.6149768114089966
#  batch 300 loss: 1.608931324481964
# Train accuracy 45.800000000000004:
# Test accuracy 41.3:
# EPOCH 51:
#  batch 100 loss: 1.6162770760059357
#  batch 200 loss: 1.6090209591388702
#  batch 300 loss: 1.6025581502914428
# Train accuracy 46.0:
# Test accuracy 41.4:
# EPOCH 52:
#  batch 100 loss: 1.6065995264053345
#  batch 200 loss: 1.6090409564971924
#  batch 300 loss: 1.6106885981559753
# Train accuracy 46.300000000000004:
# Test accuracy 41.3:
# EPOCH 53:
#  batch 100 loss: 1.6196349191665649
#  batch 200 loss: 1.6200435602664947
#  batch 300 loss: 1.6097129487991333
# Train accuracy 46.300000000000004:
# Test accuracy 41.8:
# EPOCH 54:
#  batch 100 loss: 1.6070956206321716
#  batch 200 loss: 1.5957240509986876
#  batch 300 loss: 1.6126728904247285
# Train accuracy 46.0:
# Test accuracy 41.6:
# EPOCH 55:
#  batch 100 loss: 1.610810891389847
#  batch 200 loss: 1.6021046698093415
#  batch 300 loss: 1.611370506286621
# Train accuracy 45.9:
# Test accuracy 41.099999999999994:
# EPOCH 56:
#  batch 100 loss: 1.6070093929767608
#  batch 200 loss: 1.598872721195221
#  batch 300 loss: 1.6101652216911315
# Train accuracy 46.1:
# Test accuracy 41.4:
# EPOCH 57:
#  batch 100 loss: 1.6054787957668304
#  batch 200 loss: 1.621307398080826
#  batch 300 loss: 1.5956608355045319
# Train accuracy 46.300000000000004:
# Test accuracy 41.6:
# EPOCH 58:
#  batch 100 loss: 1.6011484038829804
#  batch 200 loss: 1.6060234236717223
#  batch 300 loss: 1.6075325405597687
# Train accuracy 45.9:
# Test accuracy 41.0:
# EPOCH 59:
#  batch 100 loss: 1.5874794280529023
#  batch 200 loss: 1.5936538934707642
#  batch 300 loss: 1.6096176934242248
# Train accuracy 46.400000000000006:
# Test accuracy 41.199999999999996:
# EPOCH 60:
#  batch 100 loss: 1.6039322233200073
#  batch 200 loss: 1.617317566871643
#  batch 300 loss: 1.6031138455867768
# Train accuracy 46.2:
# Test accuracy 41.5:
# EPOCH 61:
#  batch 100 loss: 1.5992464566230773
#  batch 200 loss: 1.6062646508216858
#  batch 300 loss: 1.6109733521938323
# Train accuracy 46.400000000000006:
# Test accuracy 41.8:
# EPOCH 62:
#  batch 100 loss: 1.5869512522220612
#  batch 200 loss: 1.6024356198310852
#  batch 300 loss: 1.6213908720016479
# Train accuracy 46.2:
# Test accuracy 41.6:
# EPOCH 63:
#  batch 100 loss: 1.6047079384326934
#  batch 200 loss: 1.600331153869629
#  batch 300 loss: 1.5994891917705536
# Train accuracy 46.300000000000004:
# Test accuracy 41.199999999999996:
# EPOCH 64:
#  batch 100 loss: 1.5938055562973021
#  batch 200 loss: 1.5964605176448823
#  batch 300 loss: 1.6032823169231414
# Train accuracy 46.400000000000006:
# Test accuracy 41.699999999999996:
# EPOCH 65:
#  batch 100 loss: 1.5740379548072816
#  batch 200 loss: 1.612746568918228
#  batch 300 loss: 1.6041668581962585
# Train accuracy 46.300000000000004:
# Test accuracy 41.199999999999996:
# EPOCH 66:
#  batch 100 loss: 1.5870359063148498
#  batch 200 loss: 1.60295050740242
#  batch 300 loss: 1.6057023537158965
# Train accuracy 46.2:
# Test accuracy 41.3:
# EPOCH 67:
#  batch 100 loss: 1.5975552248954772
#  batch 200 loss: 1.6021654903888702
#  batch 300 loss: 1.602882205247879
# Train accuracy 46.400000000000006:
# Test accuracy 41.199999999999996:
# EPOCH 68:
#  batch 100 loss: 1.5954161202907562
#  batch 200 loss: 1.6109049332141876
#  batch 300 loss: 1.5903503334522247
# Train accuracy 46.400000000000006:
# Test accuracy 41.3:
# EPOCH 69:
#  batch 100 loss: 1.5987588167190552
#  batch 200 loss: 1.5923607778549194
#  batch 300 loss: 1.597303272485733
# Train accuracy 46.5:
# Test accuracy 41.4:
# EPOCH 70:
#  batch 100 loss: 1.5960107779502868
#  batch 200 loss: 1.5933304953575134
#  batch 300 loss: 1.6029491126537323
# Train accuracy 46.2:
# Test accuracy 41.199999999999996:
# EPOCH 71:
#  batch 100 loss: 1.6027973258495332
#  batch 200 loss: 1.5995877957344056
#  batch 300 loss: 1.5905458617210388
# Train accuracy 46.400000000000006:
# Test accuracy 41.3:
# EPOCH 72:
#  batch 100 loss: 1.6026526761054993
#  batch 200 loss: 1.596635582447052
#  batch 300 loss: 1.5956270480155945
# Train accuracy 46.2:
# Test accuracy 41.4:
# EPOCH 73:
#  batch 100 loss: 1.601208380460739
#  batch 200 loss: 1.60168922662735
#  batch 300 loss: 1.5849007368087769
# Train accuracy 46.300000000000004:
# Test accuracy 41.199999999999996:
# EPOCH 74:
#  batch 100 loss: 1.57290292263031
#  batch 200 loss: 1.6071727252006531
#  batch 300 loss: 1.6108502507209779
# Train accuracy 46.5:
# Test accuracy 41.4:
# EPOCH 75:
#  batch 100 loss: 1.5828470611572265
#  batch 200 loss: 1.601034482717514
#  batch 300 loss: 1.599494354724884
# Train accuracy 46.6:
# Test accuracy 41.5:
# EPOCH 76:
#  batch 100 loss: 1.5924094533920288
#  batch 200 loss: 1.581056478023529
#  batch 300 loss: 1.6013241410255432
# Train accuracy 46.400000000000006:
# Test accuracy 41.5:
# EPOCH 77:
#  batch 100 loss: 1.5955813539028167
#  batch 200 loss: 1.5907730972766876
#  batch 300 loss: 1.6080491650104523
# Train accuracy 46.300000000000004:
# Test accuracy 41.199999999999996:
# EPOCH 78:
#  batch 100 loss: 1.6006005692481995
#  batch 200 loss: 1.5855515205860138
#  batch 300 loss: 1.5991954028606414
# Train accuracy 46.5:
# Test accuracy 41.4:
# EPOCH 79:
#  batch 100 loss: 1.5928643214702607
#  batch 200 loss: 1.5866558253765106
#  batch 300 loss: 1.5844652581214904
# Train accuracy 46.400000000000006:
# Test accuracy 41.099999999999994:
# EPOCH 80:
#  batch 100 loss: 1.5902481532096864
#  batch 200 loss: 1.5923789584636687
#  batch 300 loss: 1.603528757095337
# Train accuracy 46.7:
# Test accuracy 41.199999999999996:
# EPOCH 81:
#  batch 100 loss: 1.5815976130962373
#  batch 200 loss: 1.5999807119369507
#  batch 300 loss: 1.5836432826519014
# Train accuracy 46.5:
# Test accuracy 41.4:
# EPOCH 82:
#  batch 100 loss: 1.5841208040714263
#  batch 200 loss: 1.5860287988185882
#  batch 300 loss: 1.5864755511283875
# Train accuracy 46.6:
# Test accuracy 41.4:
# EPOCH 83:
#  batch 100 loss: 1.5789021146297455
#  batch 200 loss: 1.5919825911521912
#  batch 300 loss: 1.6060498237609864
# Train accuracy 46.5:
# Test accuracy 41.199999999999996:
# EPOCH 84:
#  batch 100 loss: 1.5955566239356995
#  batch 200 loss: 1.5921425378322602
#  batch 300 loss: 1.5820707404613494
# Train accuracy 46.6:
# Test accuracy 41.199999999999996:
# EPOCH 85:
#  batch 100 loss: 1.6083055591583253
#  batch 200 loss: 1.5884962129592894
#  batch 300 loss: 1.5930114209651947
# Train accuracy 46.5:
# Test accuracy 41.4:
# EPOCH 86:
#  batch 100 loss: 1.5892085886001588
#  batch 200 loss: 1.5826355063915252
#  batch 300 loss: 1.5960734915733337
# Train accuracy 46.6:
# Test accuracy 41.5:
# EPOCH 87:
#  batch 100 loss: 1.5855891382694245
#  batch 200 loss: 1.5825755178928376
#  batch 300 loss: 1.6051731884479523
# Train accuracy 46.800000000000004:
# Test accuracy 41.3:
# EPOCH 88:
#  batch 100 loss: 1.592410341501236
#  batch 200 loss: 1.5830343759059906
#  batch 300 loss: 1.588662269115448
# Train accuracy 46.5:
# Test accuracy 41.0:
# EPOCH 89:
#  batch 100 loss: 1.5789650440216065
#  batch 200 loss: 1.5851827824115754
#  batch 300 loss: 1.587879500389099
# Train accuracy 46.6:
# Test accuracy 40.8:
# EPOCH 90:
#  batch 100 loss: 1.5793709897994994
#  batch 200 loss: 1.5954133009910583
#  batch 300 loss: 1.5847946894168854
# Train accuracy 46.800000000000004:
# Test accuracy 41.199999999999996:
# EPOCH 91:
#  batch 100 loss: 1.5830721759796142
#  batch 200 loss: 1.5896724104881286
#  batch 300 loss: 1.5847618007659912
# Train accuracy 46.6:
# Test accuracy 41.099999999999994:
# EPOCH 92:
#  batch 100 loss: 1.5819031834602355
#  batch 200 loss: 1.5947821629047394
#  batch 300 loss: 1.5859839153289794
# ...
# Train accuracy 31.900000000000002:
# Test accuracy 32.0:
# EPOCH 100:
#  batch 100 loss: 2.017849369049072
#  batch 200 loss: 2.0184785532951355
#  batch 300 loss: 2.015454696416855
# Train accuracy 32.0:
# Test accuracy 32.1:
# Learning Rate 1e-07:
# EPOCH 1:
#  batch 100 loss: 2.31237735748291
#  batch 200 loss: 2.3107354736328123
#  batch 300 loss: 2.3090994811058043
# Train accuracy 12.1:
# Test accuracy 12.3:
# EPOCH 2:
#  batch 100 loss: 2.3119088411331177
#  batch 200 loss: 2.308694541454315
#  batch 300 loss: 2.3106484317779543
# Train accuracy 12.1:
# Test accuracy 12.3:
# EPOCH 3:
#  batch 100 loss: 2.3106605434417724
#  batch 200 loss: 2.3082741570472716
#  batch 300 loss: 2.3095567059516906
# Train accuracy 12.1:
# Test accuracy 12.3:
# EPOCH 4:
#  batch 100 loss: 2.3110552763938905
#  batch 200 loss: 2.3118951296806336
#  batch 300 loss: 2.3090760636329652
# Train accuracy 12.1:
# Test accuracy 12.3:
# EPOCH 5:
#  batch 100 loss: 2.3102514290809633
#  batch 200 loss: 2.308080024719238
#  batch 300 loss: 2.3097586941719057
# Train accuracy 12.1:
# Test accuracy 12.3:
# EPOCH 6:
#  batch 100 loss: 2.3107549571990966
#  batch 200 loss: 2.3111839842796327
#  batch 300 loss: 2.3083629202842713
# Train accuracy 12.1:
# Test accuracy 12.3:
# EPOCH 7:
#  batch 100 loss: 2.3117519855499267
#  batch 200 loss: 2.310553696155548
#  batch 300 loss: 2.30738420009613
# Train accuracy 12.1:
# Test accuracy 12.3:
# EPOCH 8:
#  batch 100 loss: 2.3118707156181335
#  batch 200 loss: 2.3100982165336608
#  batch 300 loss: 2.3077911281585695
# Train accuracy 12.1:
# Test accuracy 12.3:
# EPOCH 9:
#  batch 100 loss: 2.308631007671356
#  batch 200 loss: 2.307640640735626
#  batch 300 loss: 2.312272398471832
# Train accuracy 12.1:
# Test accuracy 12.3:
# EPOCH 10:
#  batch 100 loss: 2.3072220611572267
#  batch 200 loss: 2.3096841835975646
#  batch 300 loss: 2.3100628447532654
# Train accuracy 12.1:
# Test accuracy 12.3:
# EPOCH 11:
#  batch 100 loss: 2.3092613291740416
#  batch 200 loss: 2.310576226711273
#  batch 300 loss: 2.3087611293792722
# Train accuracy 12.1:
# Test accuracy 12.3:
# EPOCH 12:
#  batch 100 loss: 2.3093860960006714
#  batch 200 loss: 2.3106193065643312
#  batch 300 loss: 2.309189064502716
# Train accuracy 12.1:
# Test accuracy 12.4:
# EPOCH 13:
#  batch 100 loss: 2.310122091770172
#  batch 200 loss: 2.3087717580795286
#  batch 300 loss: 2.309902000427246
# Train accuracy 12.1:
# Test accuracy 12.4:
# EPOCH 14:
#  batch 100 loss: 2.3127365136146545
#  batch 200 loss: 2.308346405029297
#  batch 300 loss: 2.308374192714691
# Train accuracy 12.1:
# Test accuracy 12.4:
# EPOCH 15:
#  batch 100 loss: 2.3089040660858156
#  batch 200 loss: 2.3066304302215577
#  batch 300 loss: 2.3103478288650514
# Train accuracy 12.1:
# Test accuracy 12.4:
# EPOCH 16:
#  batch 100 loss: 2.310267448425293
#  batch 200 loss: 2.308737089633942
#  batch 300 loss: 2.310730321407318
# Train accuracy 12.1:
# Test accuracy 12.4:
# EPOCH 17:
#  batch 100 loss: 2.3113576436042784
#  batch 200 loss: 2.308647565841675
#  batch 300 loss: 2.309138777256012
# Train accuracy 12.1:
# Test accuracy 12.4:
# EPOCH 18:
#  batch 100 loss: 2.3089484333992005
#  batch 200 loss: 2.309760706424713
#  batch 300 loss: 2.31118456363678
# Train accuracy 12.2:
# Test accuracy 12.4:
# EPOCH 19:
#  batch 100 loss: 2.3122738718986513
#  batch 200 loss: 2.3095573782920837
#  batch 300 loss: 2.3096513247489927
# Train accuracy 12.2:
# Test accuracy 12.4:
# EPOCH 20:
#  batch 100 loss: 2.3107122564315796
#  batch 200 loss: 2.308883798122406
#  batch 300 loss: 2.3065373134613036
# Train accuracy 12.2:
# Test accuracy 12.4:
# EPOCH 21:
#  batch 100 loss: 2.310026433467865
#  batch 200 loss: 2.3081920385360717
#  batch 300 loss: 2.3101042199134825
# Train accuracy 12.2:
# Test accuracy 12.4:
# EPOCH 22:
#  batch 100 loss: 2.3067444825172423
#  batch 200 loss: 2.312418029308319
#  batch 300 loss: 2.3090476632118224
# Train accuracy 12.2:
# Test accuracy 12.4:
# EPOCH 23:
#  batch 100 loss: 2.3079386258125307
#  batch 200 loss: 2.3089832305908202
#  batch 300 loss: 2.3116324758529663
# Train accuracy 12.2:
# Test accuracy 12.4:
# EPOCH 24:
#  batch 100 loss: 2.3089131903648377
#  batch 200 loss: 2.310433039665222
#  batch 300 loss: 2.3084587383270265
# Train accuracy 12.2:
# Test accuracy 12.4:
# EPOCH 25:
#  batch 100 loss: 2.309000849723816
#  batch 200 loss: 2.3081706094741823
#  batch 300 loss: 2.3104126548767088
# Train accuracy 12.2:
# Test accuracy 12.4:
# EPOCH 26:
#  batch 100 loss: 2.3115783667564394
#  batch 200 loss: 2.304646987915039
#  batch 300 loss: 2.311025686264038
# Train accuracy 12.2:
# Test accuracy 12.4:
# EPOCH 27:
#  batch 100 loss: 2.3101009726524353
#  batch 200 loss: 2.3088157892227175
#  batch 300 loss: 2.307396266460419
# Train accuracy 12.2:
# Test accuracy 12.4:
# EPOCH 28:
#  batch 100 loss: 2.3099773573875426
#  batch 200 loss: 2.3092813515663146
#  batch 300 loss: 2.3085046672821044
# Train accuracy 12.2:
# Test accuracy 12.4:
# EPOCH 29:
#  batch 100 loss: 2.307842812538147
#  batch 200 loss: 2.3101655530929563
#  batch 300 loss: 2.310116264820099
# Train accuracy 12.2:
# Test accuracy 12.4:
# EPOCH 30:
#  batch 100 loss: 2.309626796245575
#  batch 200 loss: 2.3089653348922727
#  batch 300 loss: 2.307096357345581
# Train accuracy 12.2:
# Test accuracy 12.4:
# EPOCH 31:
#  batch 100 loss: 2.307940092086792
#  batch 200 loss: 2.309951627254486
#  batch 300 loss: 2.3085951662063597
# Train accuracy 12.2:
# Test accuracy 12.4:
# EPOCH 32:
#  batch 100 loss: 2.3101123785972595
#  batch 200 loss: 2.3090079164505006
#  batch 300 loss: 2.3089889693260193
# Train accuracy 12.2:
# Test accuracy 12.4:
# EPOCH 33:
#  batch 100 loss: 2.3075475025177004
#  batch 200 loss: 2.312033734321594
#  batch 300 loss: 2.307574009895325
# Train accuracy 12.2:
# Test accuracy 12.4:
# EPOCH 34:
#  batch 100 loss: 2.310194182395935
#  batch 200 loss: 2.3077039694786072
#  batch 300 loss: 2.311107678413391
# Train accuracy 12.2:
# Test accuracy 12.4:
# EPOCH 35:
#  batch 100 loss: 2.310564262866974
#  batch 200 loss: 2.3060705637931824
#  batch 300 loss: 2.308558578491211
# Train accuracy 12.2:
# Test accuracy 12.4:
# EPOCH 36:
#  batch 100 loss: 2.3073232483863833
#  batch 200 loss: 2.311000726222992
#  batch 300 loss: 2.306518828868866
# Train accuracy 12.2:
# Test accuracy 12.4:
# EPOCH 37:
#  batch 100 loss: 2.3079031467437745
#  batch 200 loss: 2.3066554069519043
#  batch 300 loss: 2.311099669933319
# Train accuracy 12.2:
# Test accuracy 12.4:
# EPOCH 38:
#  batch 100 loss: 2.3071909856796267
#  batch 200 loss: 2.3060948848724365
#  batch 300 loss: 2.3106696081161497
# Train accuracy 12.2:
# Test accuracy 12.4:
# EPOCH 39:
#  batch 100 loss: 2.3083499884605407
#  batch 200 loss: 2.307420654296875
#  batch 300 loss: 2.307375736236572
# Train accuracy 12.2:
# Test accuracy 12.4:
# EPOCH 40:
#  batch 100 loss: 2.3090987396240235
#  batch 200 loss: 2.3072778820991515
#  batch 300 loss: 2.3080258536338807
# Train accuracy 12.2:
# Test accuracy 12.4:
# EPOCH 41:
#  batch 100 loss: 2.308549609184265
#  batch 200 loss: 2.307468948364258
#  batch 300 loss: 2.309694743156433
# Train accuracy 12.2:
# Test accuracy 12.4:
# EPOCH 42:
#  batch 100 loss: 2.3085580229759217
#  batch 200 loss: 2.308196015357971
#  batch 300 loss: 2.307179410457611
# Train accuracy 12.2:
# Test accuracy 12.4:
# EPOCH 43:
#  batch 100 loss: 2.3109203028678893
#  batch 200 loss: 2.309856662750244
#  batch 300 loss: 2.3067791152000425
# Train accuracy 12.2:
# Test accuracy 12.4:
# EPOCH 44:
#  batch 100 loss: 2.30961804151535
#  batch 200 loss: 2.3103024196624755
#  batch 300 loss: 2.3063340306282045
# Train accuracy 12.2:
# Test accuracy 12.4:
# EPOCH 45:
#  batch 100 loss: 2.3055733132362364
#  batch 200 loss: 2.3080345463752745
#  batch 300 loss: 2.3089576864242556
# Train accuracy 12.2:
# Test accuracy 12.5:
# EPOCH 46:
#  batch 100 loss: 2.3090067076683045
#  batch 200 loss: 2.308335371017456
#  batch 300 loss: 2.309691047668457
# Train accuracy 12.3:
# Test accuracy 12.5:
# EPOCH 47:
#  batch 100 loss: 2.3075359153747557
#  batch 200 loss: 2.3082297587394716
#  batch 300 loss: 2.3080972695350646
# Train accuracy 12.3:
# Test accuracy 12.5:
# EPOCH 48:
#  batch 100 loss: 2.3095111203193666
#  batch 200 loss: 2.305379042625427
#  batch 300 loss: 2.307996168136597
# Train accuracy 12.3:
# Test accuracy 12.5:
# EPOCH 49:
#  batch 100 loss: 2.307067856788635
#  batch 200 loss: 2.307821571826935
#  batch 300 loss: 2.3080492973327638
# Train accuracy 12.3:
# Test accuracy 12.5:
# EPOCH 50:
#  batch 100 loss: 2.310842638015747
#  batch 200 loss: 2.3059841227531432
#  batch 300 loss: 2.30828928232193
# Train accuracy 12.3:
# Test accuracy 12.5:
# EPOCH 51:
#  batch 100 loss: 2.308677887916565
#  batch 200 loss: 2.3069797444343565
#  batch 300 loss: 2.3089790630340574
# Train accuracy 12.3:
# Test accuracy 12.5:
# EPOCH 52:
#  batch 100 loss: 2.304811749458313
#  batch 200 loss: 2.307511794567108
#  batch 300 loss: 2.3088059973716737
# Train accuracy 12.3:
# Test accuracy 12.5:
# EPOCH 53:
#  batch 100 loss: 2.31050635099411
#  batch 200 loss: 2.3062541031837465
#  batch 300 loss: 2.308827130794525
# Train accuracy 12.3:
# Test accuracy 12.5:
# EPOCH 54:
#  batch 100 loss: 2.3058722710609434
#  batch 200 loss: 2.3071580505371094
#  batch 300 loss: 2.309349193572998
# Train accuracy 12.3:
# Test accuracy 12.5:
# EPOCH 55:
#  batch 100 loss: 2.3089115238189697
#  batch 200 loss: 2.306892144680023
#  batch 300 loss: 2.3065437269210816
# Train accuracy 12.3:
# Test accuracy 12.5:
# EPOCH 56:
#  batch 100 loss: 2.3075521540641786
#  batch 200 loss: 2.309327485561371
#  batch 300 loss: 2.3054073095321654
# Train accuracy 12.3:
# Test accuracy 12.5:
# EPOCH 57:
#  batch 100 loss: 2.306138095855713
#  batch 200 loss: 2.3081118392944338
#  batch 300 loss: 2.308560688495636
# Train accuracy 12.3:
# Test accuracy 12.6:
# EPOCH 58:
#  batch 100 loss: 2.305931849479675
#  batch 200 loss: 2.3078817176818847
#  batch 300 loss: 2.3088057255744934
# Train accuracy 12.3:
# Test accuracy 12.6:
# EPOCH 59:
#  batch 100 loss: 2.307855849266052
#  batch 200 loss: 2.3091013407707215
#  batch 300 loss: 2.3070887112617493
# Train accuracy 12.3:
# Test accuracy 12.6:
# EPOCH 60:
#  batch 100 loss: 2.3070805287361145
#  batch 200 loss: 2.307360103130341
#  batch 300 loss: 2.307773160934448
# Train accuracy 12.3:
# Test accuracy 12.6:
# EPOCH 61:
#  batch 100 loss: 2.3089986395835878
#  batch 200 loss: 2.3056628274917603
#  batch 300 loss: 2.307835659980774
# Train accuracy 12.3:
# Test accuracy 12.6:
# EPOCH 62:
#  batch 100 loss: 2.3064730668067934
#  batch 200 loss: 2.3099363803863526
#  batch 300 loss: 2.3065611219406126
# Train accuracy 12.3:
# Test accuracy 12.6:
# EPOCH 63:
#  batch 100 loss: 2.3078407669067382
#  batch 200 loss: 2.307608485221863
#  batch 300 loss: 2.305438621044159
# Train accuracy 12.3:
# Test accuracy 12.6:
# EPOCH 64:
#  batch 100 loss: 2.306684761047363
#  batch 200 loss: 2.307034344673157
#  batch 300 loss: 2.3061835312843324
# Train accuracy 12.3:
# Test accuracy 12.6:
# EPOCH 65:
#  batch 100 loss: 2.3072630047798155
#  batch 200 loss: 2.3077826476097107
#  batch 300 loss: 2.306860234737396
# Train accuracy 12.4:
# Test accuracy 12.6:
# EPOCH 66:
#  batch 100 loss: 2.3113620042800904
#  batch 200 loss: 2.306128225326538
#  batch 300 loss: 2.304251947402954
# Train accuracy 12.4:
# Test accuracy 12.6:
# EPOCH 67:
#  batch 100 loss: 2.3087821006774902
#  batch 200 loss: 2.307709572315216
#  batch 300 loss: 2.306599564552307
# Train accuracy 12.4:
# Test accuracy 12.6:
# EPOCH 68:
#  batch 100 loss: 2.305900115966797
#  batch 200 loss: 2.307790677547455
#  batch 300 loss: 2.3071669244766237
# Train accuracy 12.4:
# Test accuracy 12.6:
# EPOCH 69:
#  batch 100 loss: 2.3080505990982054
#  batch 200 loss: 2.306475405693054
#  batch 300 loss: 2.306321997642517
# Train accuracy 12.4:
# Test accuracy 12.6:
# EPOCH 70:
#  batch 100 loss: 2.305733344554901
#  batch 200 loss: 2.3084697222709654
#  batch 300 loss: 2.306234121322632
# Train accuracy 12.4:
# Test accuracy 12.6:
# EPOCH 71:
#  batch 100 loss: 2.306305830478668
#  batch 200 loss: 2.3070857453346254
#  batch 300 loss: 2.309197556972504
# Train accuracy 12.4:
# Test accuracy 12.6:
# EPOCH 72:
#  batch 100 loss: 2.3078740572929384
#  batch 200 loss: 2.3064308071136477
#  batch 300 loss: 2.305219511985779
# Train accuracy 12.4:
# Test accuracy 12.6:
# EPOCH 73:
#  batch 100 loss: 2.3083758306503297
#  batch 200 loss: 2.3076894378662107
#  batch 300 loss: 2.3063185715675356
# Train accuracy 12.4:
# Test accuracy 12.6:
# EPOCH 74:
#  batch 100 loss: 2.306176016330719
#  batch 200 loss: 2.3054413175582886
#  batch 300 loss: 2.30785183429718
# Train accuracy 12.4:
# Test accuracy 12.6:
# EPOCH 75:
#  batch 100 loss: 2.307660391330719
#  batch 200 loss: 2.305561239719391
#  batch 300 loss: 2.3051406717300416
# Train accuracy 12.4:
# Test accuracy 12.6:
# EPOCH 76:
#  batch 100 loss: 2.3053577446937563
#  batch 200 loss: 2.306149113178253
#  batch 300 loss: 2.3088232922554015
# Train accuracy 12.4:
# Test accuracy 12.6:
# EPOCH 77:
#  batch 100 loss: 2.3081083917617797
#  batch 200 loss: 2.306390845775604
#  batch 300 loss: 2.3079678440093994
# Train accuracy 12.4:
# Test accuracy 12.6:
# EPOCH 78:
#  batch 100 loss: 2.306319739818573
#  batch 200 loss: 2.307707486152649
#  batch 300 loss: 2.3045053696632385
# Train accuracy 12.4:
# Test accuracy 12.6:
# EPOCH 79:
#  batch 100 loss: 2.3063867545127867
#  batch 200 loss: 2.3043614292144774
#  batch 300 loss: 2.309346284866333
# Train accuracy 12.4:
# Test accuracy 12.6:
# EPOCH 80:
#  batch 100 loss: 2.307251467704773
#  batch 200 loss: 2.3054250645637513
#  batch 300 loss: 2.3080641555786134
# Train accuracy 12.4:
# Test accuracy 12.6:
# EPOCH 81:
#  batch 100 loss: 2.3044101190567017
#  batch 200 loss: 2.3058466386795042
#  batch 300 loss: 2.3073920106887815
# Train accuracy 12.4:
# Test accuracy 12.6:
# EPOCH 82:
#  batch 100 loss: 2.30827584028244
#  batch 200 loss: 2.3052383422851563
#  batch 300 loss: 2.3062967586517336
# Train accuracy 12.4:
# Test accuracy 12.6:
# EPOCH 83:
#  batch 100 loss: 2.3071068263053895
#  batch 200 loss: 2.308526403903961
#  batch 300 loss: 2.305611596107483
# Train accuracy 12.4:
# Test accuracy 12.7:
# EPOCH 84:
#  batch 100 loss: 2.309869554042816
#  batch 200 loss: 2.303603949546814
#  batch 300 loss: 2.3053508949279786
# Train accuracy 12.4:
# Test accuracy 12.7:
# EPOCH 85:
#  batch 100 loss: 2.3082392621040344
#  batch 200 loss: 2.3041425132751465
#  batch 300 loss: 2.3050205373764037
# Train accuracy 12.4:
# Test accuracy 12.7:
# EPOCH 86:
#  batch 100 loss: 2.3072393321990967
#  batch 200 loss: 2.3066894483566283
#  batch 300 loss: 2.3052516961097718
# Train accuracy 12.4:
# Test accuracy 12.7:
# EPOCH 87:
#  batch 100 loss: 2.307883198261261
#  batch 200 loss: 2.3058797264099122
#  batch 300 loss: 2.3021806049346925
# Train accuracy 12.4:
# Test accuracy 12.7:
# EPOCH 88:
#  batch 100 loss: 2.3072799587249757
#  batch 200 loss: 2.3047272300720216
#  batch 300 loss: 2.3040873861312865
# Train accuracy 12.4:
# Test accuracy 12.7:
# EPOCH 89:
#  batch 100 loss: 2.3051506376266477
#  batch 200 loss: 2.3070781230926514
#  batch 300 loss: 2.3063887619972228
# Train accuracy 12.4:
# Test accuracy 12.7:
# EPOCH 90:
#  batch 100 loss: 2.30421817779541
#  batch 200 loss: 2.3073315119743345
#  batch 300 loss: 2.3066071677207947
# Train accuracy 12.4:
# Test accuracy 12.7:
# EPOCH 91:
#  batch 100 loss: 2.307477071285248
#  batch 200 loss: 2.3059528160095213
#  batch 300 loss: 2.301511483192444
# Train accuracy 12.5:
# Test accuracy 12.7:
# EPOCH 92:
#  batch 100 loss: 2.3027922987937925
#  batch 200 loss: 2.3084413266181945
#  batch 300 loss: 2.3048616361618044
# Train accuracy 12.5:
# Test accuracy 12.7:
# EPOCH 93:
#  batch 100 loss: 2.3044717121124267
#  batch 200 loss: 2.3082974481582643
#  batch 300 loss: 2.305232222080231
# Train accuracy 12.5:
# Test accuracy 12.7:
# EPOCH 94:
#  batch 100 loss: 2.306446990966797
#  batch 200 loss: 2.3065232324600218
#  batch 300 loss: 2.3034895777702333
# Train accuracy 12.5:
# Test accuracy 12.7:
# EPOCH 95:
#  batch 100 loss: 2.308359296321869
#  batch 200 loss: 2.3060246968269347
#  batch 300 loss: 2.3040298891067503
# Train accuracy 12.5:
# Test accuracy 12.7:
# EPOCH 96:
#  batch 100 loss: 2.307454755306244
#  batch 200 loss: 2.3061828017234802
#  batch 300 loss: 2.304092757701874
# Train accuracy 12.5:
# Test accuracy 12.7:
# EPOCH 97:
#  batch 100 loss: 2.305093228816986
#  batch 200 loss: 2.304265742301941
#  batch 300 loss: 2.307034134864807
# Train accuracy 12.5:
# Test accuracy 12.7:
# EPOCH 98:
#  batch 100 loss: 2.30306494474411
#  batch 200 loss: 2.3056694746017454
#  batch 300 loss: 2.3063739347457886
# Train accuracy 12.5:
# Test accuracy 12.7:
# EPOCH 99:
#  batch 100 loss: 2.3058449530601504
#  batch 200 loss: 2.3053468012809755
#  batch 300 loss: 2.306454179286957
# Train accuracy 12.5:
# Test accuracy 12.8:
# EPOCH 100:
#  batch 100 loss: 2.3060867738723756
#  batch 200 loss: 2.3049237442016604
#  batch 300 loss: 2.307289125919342
# Train accuracy 12.5:
# Test accuracy 12.8:

# %%
import numpy as np
epochs_arr = np.arange(0, len(losses_arr[0]))

# %%
# Plot training loss
x = np.array(epochs_arr)
for i,train_loss in enumerate(losses_arr):
  ypoints = np.array(train_loss)
  plt.plot(x, ypoints, label = lrs[i])

plt.xlabel("Epochs")
plt.ylabel("train Loss")
plt.legend()
plt.title('Scheduler=None, Batch_size=128, Optimizer=SGD')
plt.show()

# %%
# Plot training accuracy
x = np.array(epochs_arr)
for i,train_acc in enumerate(train_accuracy_arr):
  ypoints = np.array(train_acc)
  plt.plot(x, ypoints, label = lrs[i])

plt.xlabel("Epochs")
plt.ylabel("train Accuracy")
plt.legend()
plt.title('Scheduler=None, Batch_size=128, Optimizer=SGD')
plt.show()

# %%
# Plot test accuracy
x = np.array(epochs_arr)
for i,test_acc in enumerate(test_accuracy_arr):
  ypoints = np.array(test_acc)
  plt.plot(x, ypoints, label = lrs[i])

plt.xlabel("Epochs")
plt.ylabel("test Accuracy")
plt.legend()
plt.title('Scheduler=None, Batch_size=128, Optimizer=SGD')
plt.show()

# %%
# Plot test and training accuracy
x = np.array(epochs_arr)
for i,lr in enumerate(lrs):
  ypoints_1 = np.array(train_accuracy_arr[i])
  ypoints_2 = np.array(test_accuracy_arr[i])
  plt.plot(x, ypoints_1, label = 'Train')
  plt.plot(x, ypoints_2, label = 'Test')
  plt.xlabel("Epochs")
  plt.ylabel("Accuracy")
  plt.legend()
  plt.title(F'Scheduler=None, Batch_size=128, Optimizer=SGD, LR={lr}')
  plt.show()

# %% [markdown]
# ### Load model

# %%
from google.colab import drive
drive.mount('/content/drive/')
model_save_name = '1695168105559.8071_Step_bs128_e30_SGD_ss10_gamma0.1_cifar'
path = F"/content/drive/MyDrive/Ell409/CIFAR/scheduler/{model_save_name}.pt"
net.load_state_dict(t.load(path))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 from google.colab import drive
#       2 drive.mount('/content/drive/')
#       3 model_save_name = '1695168105559.8071_Step_bs128_e30_SGD_ss10_gamma0.1_cifar'
#
# ModuleNotFoundError: No module named 'google.colab'

# %%
test(net,test_loader)

# %%
#hello kuch likhlo warna inactivity timeout de dega yeh

# %%
import torch as t
import torchvision.datasets as datasets
import torchvision.transforms as transforms
import torch.nn as nn
import matplotlib.pyplot as plt
import torch.optim as optim
import torch.optim.lr_scheduler as lr_scheduler
from torch.optim.lr_scheduler import ReduceLROnPlateau, StepLR, ExponentialLR

# %% [markdown]
# ### Model

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net,self).__init__()
        self.linear1 = nn.Linear(28*28, 10)
        self.relu = nn.ReLU()

    def forward(self, img): #convert + flatten
        x = img.view(-1, 28*28)
        x = self.relu(self.linear1(x))
        return x
net = Net()

# %% [markdown]
# ### Hyperparams

# %%
num_epochs=100
after_every=100
loss_fn = nn.CrossEntropyLoss()
batch_size=128

# %%
import ssl
ssl._create_default_https_context = ssl._create_unverified_context
transform = transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.5,), (0.5,)),])

mnist_trainset = datasets.MNIST(root='./data', train=True, download=True, transform=transform)
train_loader = t.utils.data.DataLoader(mnist_trainset, batch_size=batch_size, shuffle=True)

mnist_testset = datasets.MNIST(root='./data', train=False, download=True, transform=transform)
test_loader = t.utils.data.DataLoader(mnist_testset, batch_size=batch_size, shuffle=True)
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# 0.7%
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz to ./data/MNIST/raw/train-images-idx3-ubyte.gz
# 100.0%
# Extracting ./data/MNIST/raw/train-images-idx3-ubyte.gz to ./data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz to ./data/MNIST/raw/train-labels-idx1-ubyte.gz
# 100.0%
# Extracting ./data/MNIST/raw/train-labels-idx1-ubyte.gz to ./data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz to ./data/MNIST/raw/t10k-images-idx3-ubyte.gz
# 100.0%
# Extracting ./data/MNIST/raw/t10k-images-idx3-ubyte.gz to ./data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz to ./data/MNIST/raw/t10k-labels-idx1-ubyte.gz
# 100.0%
# Extracting ./data/MNIST/raw/t10k-labels-idx1-ubyte.gz to ./data/MNIST/raw

# %% [markdown]
# ### Training

# %%
def train_one_epoch(model, epoch_index, optimizer, train_dataset):
    running_loss = 0.
    last_loss = 0.

    for i, data in enumerate(train_dataset):
        # Every data instance is an input + label pair
        # data.shape=torch.Size([10, 1, 28, 28]) --> 10 images,labels
        inputs, labels = data

        # Zero your gradients for every batch!
        optimizer.zero_grad()

        # Make predictions for this batch
        outputs = model(inputs.view(-1, 28*28))


        # Compute the loss and its gradients
        loss = loss_fn(outputs, labels)
        loss.backward()

        # Adjust learning weights
        optimizer.step()

        # Gather data and report
        running_loss += loss.item()

        if i % after_every == after_every-1:
            last_loss = running_loss / after_every # loss per after_every batches
            print(' batch {} loss: {}'.format(i + 1, last_loss))
            running_loss = 0.

    return last_loss

# %% [markdown]
# ### Evaluate

# %%
def test(model, loader):
  total=0
  correct=0
  model.eval()
  with t.no_grad():
      for data in loader:
          x, y = data
          output = model(x.view(-1, 28*28))
          for idx, i in enumerate(output):
              if t.argmax(i) == y[idx]:
                  correct +=1
              total +=1
  return round(correct/total, 3)*100

# %%
def train_model(model, epochs, train_dataset, test_dataset, optimizer, scheduler, LR_type):
  epoch_number = 0

  losses = []
  train_accuracy = []
  test_accuracy = []

  for epoch in range(epochs):
      print('EPOCH {}:'.format(epoch_number + 1))

      # Make sure gradient tracking is on, and do a pass over the data
      model.train(True)
      avg_loss = train_one_epoch(model, epoch_number,optimizer,train_dataset)
      losses.append(avg_loss)

      # Train accuracy
      train_acc = test(model, train_dataset)
      train_accuracy.append(train_acc)

      # Test accuracy
      test_acc = test(model, test_dataset)
      test_accuracy.append(test_acc)

      if LR_type=='Plateau':
        before_lr = optimizer.param_groups[0]["lr"]
        scheduler.step(avg_loss)
        after_lr = optimizer.param_groups[0]["lr"]
        print('lr {} -> {}'.format(before_lr, after_lr))

      elif LR_type!='None':
        before_lr = optimizer.param_groups[0]["lr"]
        scheduler.step()
        after_lr = optimizer.param_groups[0]["lr"]
        print('lr {} -> {}'.format(before_lr, after_lr))

      print('Train accuracy {}:'.format(train_acc))
      print('Test accuracy {}:'.format(test_acc))
      epoch_number += 1
  return losses, train_accuracy, test_accuracy

# %%
import datetime as dt

def train_with_reg(starting_lr):
  losses_arr = []
  train_accuracy_arr = []
  test_accuracy_arr = []
  regularization_strengths = [0, 1e-7, 1e-5, 1e-3, 1e-1, 1.0]
  description = []

  # Different Reg strengths
  for regularization_strength in regularization_strengths:
    print('Reg Strength {}:'.format(regularization_strength))
    net_new = Net()
    optimizerr = t.optim.SGD(net_new.parameters(), lr=starting_lr, weight_decay=regularization_strength)
    scheduler = StepLR(optimizerr, 25, gamma=0.1)

    losses, train_accuracy, test_accuracy = train_model(net_new, num_epochs, train_loader, test_loader, optimizerr, scheduler, 'Step')

    losses_arr.append(losses)
    train_accuracy_arr.append(train_accuracy)
    test_accuracy_arr.append(test_accuracy)
    description.append('Starting LR:{}, L2Reg:{}'.format(starting_lr, regularization_strength))

    # save model
    ts_now = dt.datetime.now()
    unix_timestamp = dt.datetime.timestamp(ts_now)*1000
    model_save_name = str(unix_timestamp)
    path = F"{model_save_name}_L2Reg={regularization_strength}_bs{128}_e{num_epochs}_SGD_LRStep_.pt"
    t.save(net.state_dict(), path)

  return description, losses_arr, train_accuracy_arr, test_accuracy_arr

# %%
import csv
def save_to_csv(filename, description, losses_arr, train_acc_arr, test_acc_arr):
  # Create a CSV file and write data to it
  with open(filename+'.csv', 'w', newline='') as csvfile:
    for i, desc in enumerate(description):
      fieldnames = ['Description', 'epoch', 'train_loss', 'train_accuracy', 'test_accuracy']
      writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
      writer.writeheader()
      for epoch, (loss, train, test) in enumerate(zip(losses_arr[i], train_acc_arr[i], test_acc_arr[i]), 1):
          writer.writerow({'Description':description[i], 'epoch': epoch, 'train_loss': loss, 'train_accuracy': train, 'test_accuracy': test})

# %% [markdown]
# ### Plotting- Starting LR=0.01
# #### Reg strengths = [0, 1e-7, 1e-5, 1e-3, 1e-1, 1.0]

# %%
lr = 0.01
regularization_strengths = [0, 1e-7, 1e-5, 1e-3, 1e-1, 1.0]
description, losses_arr, train_accuracy_arr, test_accuracy_arr = train_with_reg(lr)
save_to_csv('Regularisation_Step', description, losses_arr, train_accuracy_arr, test_accuracy_arr)
# Out:
# Reg Strength 0:
# EPOCH 1:
#  batch 100 loss: 1.8146962416172028
#  batch 200 loss: 1.3716232657432557
#  batch 300 loss: 1.1352860486507417
#  batch 400 loss: 1.0544010519981384
# lr 0.01 -> 0.01
# Train accuracy 68.10000000000001:
# Test accuracy 68.8:
# EPOCH 2:
#  batch 100 loss: 0.9806001222133637
#  batch 200 loss: 0.9525593984127044
#  batch 300 loss: 0.9274727874994277
#  batch 400 loss: 0.9087070482969284
# lr 0.01 -> 0.01
# Train accuracy 69.39999999999999:
# Test accuracy 70.0:
# EPOCH 3:
#  batch 100 loss: 0.8817205607891083
#  batch 200 loss: 0.9036113661527634
#  batch 300 loss: 0.8832802599668503
#  batch 400 loss: 0.8704463768005372
# lr 0.01 -> 0.01
# Train accuracy 70.1:
# Test accuracy 70.39999999999999:
# EPOCH 4:
#  batch 100 loss: 0.8739921534061432
#  batch 200 loss: 0.8494431102275848
#  batch 300 loss: 0.844581225514412
#  batch 400 loss: 0.8515974736213684
# lr 0.01 -> 0.01
# Train accuracy 70.39999999999999:
# Test accuracy 71.0:
# EPOCH 5:
#  batch 100 loss: 0.8471022754907608
#  batch 200 loss: 0.8375747680664063
#  batch 300 loss: 0.8474215549230576
#  batch 400 loss: 0.8240544062852859
# lr 0.01 -> 0.01
# Train accuracy 70.5:
# Test accuracy 71.0:
# EPOCH 6:
#  batch 100 loss: 0.8212343907356262
#  batch 200 loss: 0.8291507595777512
#  batch 300 loss: 0.8230732977390289
#  batch 400 loss: 0.8110257989168167
# lr 0.01 -> 0.01
# Train accuracy 70.89999999999999:
# Test accuracy 71.3:
# EPOCH 7:
#  batch 100 loss: 0.8185497373342514
#  batch 200 loss: 0.8141791194677352
#  batch 300 loss: 0.81992755651474
#  batch 400 loss: 0.8040500086545944
# lr 0.01 -> 0.01
# Train accuracy 70.89999999999999:
# Test accuracy 71.39999999999999:
# EPOCH 8:
#  batch 100 loss: 0.8111665630340577
#  batch 200 loss: 0.8107157701253891
#  batch 300 loss: 0.8010173857212066
#  batch 400 loss: 0.7977739244699478
# lr 0.01 -> 0.01
# Train accuracy 71.2:
# Test accuracy 71.5:
# EPOCH 9:
#  batch 100 loss: 0.806463070511818
#  batch 200 loss: 0.8011753004789353
#  batch 300 loss: 0.7901600256562233
#  batch 400 loss: 0.7898389649391174
# lr 0.01 -> 0.01
# Train accuracy 71.3:
# Test accuracy 71.7:
# EPOCH 10:
#  batch 100 loss: 0.7860175943374634
#  batch 200 loss: 0.8019297248125077
#  batch 300 loss: 0.7802964642643928
#  batch 400 loss: 0.8007389205694199
# lr 0.01 -> 0.01
# Train accuracy 71.3:
# Test accuracy 71.6:
# EPOCH 11:
#  batch 100 loss: 0.7935859405994415
#  batch 200 loss: 0.8078670543432236
#  batch 300 loss: 0.7924841064214706
#  batch 400 loss: 0.7830210322141647
# lr 0.01 -> 0.01
# Train accuracy 71.5:
# Test accuracy 71.7:
# EPOCH 12:
#  batch 100 loss: 0.7802626264095306
#  batch 200 loss: 0.7715158635377883
#  batch 300 loss: 0.8030514067411423
#  batch 400 loss: 0.8025025737285614
# lr 0.01 -> 0.01
# Train accuracy 71.39999999999999:
# Test accuracy 71.6:
# EPOCH 13:
#  batch 100 loss: 0.7976488876342773
#  batch 200 loss: 0.7804345172643662
#  batch 300 loss: 0.7921881121397019
#  batch 400 loss: 0.7568418884277344
# lr 0.01 -> 0.01
# Train accuracy 71.6:
# Test accuracy 71.8:
# EPOCH 14:
#  batch 100 loss: 0.7681633293628692
#  batch 200 loss: 0.7662343209981919
#  batch 300 loss: 0.7943222177028656
#  batch 400 loss: 0.7897647374868393
# lr 0.01 -> 0.01
# Train accuracy 71.7:
# Test accuracy 71.89999999999999:
# EPOCH 15:
#  batch 100 loss: 0.776436116695404
#  batch 200 loss: 0.7770193719863892
#  batch 300 loss: 0.7709951424598693
#  batch 400 loss: 0.7774653923511505
# lr 0.01 -> 0.01
# Train accuracy 71.7:
# Test accuracy 71.89999999999999:
# EPOCH 16:
#  batch 100 loss: 0.7839714229106903
#  batch 200 loss: 0.7810645347833634
#  batch 300 loss: 0.7547766548395157
#  batch 400 loss: 0.7751421707868577
# lr 0.01 -> 0.01
# Train accuracy 71.7:
# Test accuracy 71.8:
# EPOCH 17:
#  batch 100 loss: 0.7902079880237579
#  batch 200 loss: 0.7626531082391739
#  batch 300 loss: 0.7698969089984894
#  batch 400 loss: 0.7680558031797409
# lr 0.01 -> 0.01
# Train accuracy 71.8:
# Test accuracy 71.8:
# EPOCH 18:
#  batch 100 loss: 0.7738523328304291
#  batch 200 loss: 0.774541078209877
#  batch 300 loss: 0.7778364300727845
#  batch 400 loss: 0.7573059952259064
# lr 0.01 -> 0.01
# Train accuracy 71.8:
# Test accuracy 72.0:
# EPOCH 19:
#  batch 100 loss: 0.7846970146894455
#  batch 200 loss: 0.7622104638814926
#  batch 300 loss: 0.7633929622173309
#  batch 400 loss: 0.7489945185184479
# lr 0.01 -> 0.01
# Train accuracy 71.8:
# Test accuracy 72.0:
# EPOCH 20:
#  batch 100 loss: 0.7731119912862777
#  batch 200 loss: 0.7649386954307557
#  batch 300 loss: 0.769022805094719
#  batch 400 loss: 0.7622763478755951
# lr 0.01 -> 0.01
# Train accuracy 71.89999999999999:
# Test accuracy 72.0:
# EPOCH 21:
#  batch 100 loss: 0.7541758295893669
#  batch 200 loss: 0.7637768405675888
#  batch 300 loss: 0.7570554050803184
#  batch 400 loss: 0.7719068545103073
# lr 0.01 -> 0.01
# Train accuracy 71.89999999999999:
# Test accuracy 72.1:
# EPOCH 22:
#  batch 100 loss: 0.7607431319355965
#  batch 200 loss: 0.7529204863309861
#  batch 300 loss: 0.7744255119562149
#  batch 400 loss: 0.7618112522363663
# lr 0.01 -> 0.01
# Train accuracy 72.0:
# Test accuracy 72.1:
# EPOCH 23:
#  batch 100 loss: 0.7553561890125274
#  batch 200 loss: 0.7679264086484909
#  batch 300 loss: 0.7617225793004035
#  batch 400 loss: 0.7597039014101028
# lr 0.01 -> 0.01
# Train accuracy 72.0:
# Test accuracy 72.1:
# EPOCH 24:
#  batch 100 loss: 0.7527729350328446
#  batch 200 loss: 0.7643425843119621
#  batch 300 loss: 0.7626327067613602
#  batch 400 loss: 0.7758721005916596
# lr 0.01 -> 0.01
# Train accuracy 72.1:
# Test accuracy 72.2:
# EPOCH 25:
#  batch 100 loss: 0.7629526382684708
#  batch 200 loss: 0.7718009710311889
#  batch 300 loss: 0.7436955559253693
#  batch 400 loss: 0.7529096233844758
# lr 0.01 -> 0.001
# Train accuracy 72.1:
# Test accuracy 72.2:
# EPOCH 26:
#  batch 100 loss: 0.7553549927473068
#  batch 200 loss: 0.7513543021678925
#  batch 300 loss: 0.763418881893158
#  batch 400 loss: 0.7618779897689819
# lr 0.001 -> 0.001
# Train accuracy 72.1:
# Test accuracy 72.2:
# EPOCH 27:
#  batch 100 loss: 0.7425944203138352
#  batch 200 loss: 0.7644186979532241
#  batch 300 loss: 0.7639154243469238
#  batch 400 loss: 0.7531449323892594
# lr 0.001 -> 0.001
# Train accuracy 72.1:
# Test accuracy 72.2:
# EPOCH 28:
#  batch 100 loss: 0.7484314766526222
#  batch 200 loss: 0.7657097440958023
#  batch 300 loss: 0.7549077671766281
#  batch 400 loss: 0.7558151310682297
# lr 0.001 -> 0.001
# Train accuracy 72.1:
# Test accuracy 72.2:
# EPOCH 29:
#  batch 100 loss: 0.7664656132459641
#  batch 200 loss: 0.7509920352697372
#  batch 300 loss: 0.7705198627710342
#  batch 400 loss: 0.7570785319805146
# lr 0.001 -> 0.001
# Train accuracy 72.1:
# Test accuracy 72.2:
# EPOCH 30:
#  batch 100 loss: 0.7578770565986633
#  batch 200 loss: 0.7437701985239983
#  batch 300 loss: 0.7683137530088424
#  batch 400 loss: 0.7604079449176788
# lr 0.001 -> 0.001
# Train accuracy 72.1:
# Test accuracy 72.1:
# EPOCH 31:
#  batch 100 loss: 0.7556697046756744
#  batch 200 loss: 0.7575633931159973
#  batch 300 loss: 0.7517681902647019
#  batch 400 loss: 0.7650101655721664
# lr 0.001 -> 0.001
# Train accuracy 72.1:
# Test accuracy 72.2:
# EPOCH 32:
#  batch 100 loss: 0.7727344334125519
#  batch 200 loss: 0.7551718285679817
#  batch 300 loss: 0.7403551113605499
#  batch 400 loss: 0.7564176338911056
# lr 0.001 -> 0.001
# Train accuracy 72.2:
# Test accuracy 72.2:
# EPOCH 33:
#  batch 100 loss: 0.756434673666954
#  batch 200 loss: 0.7572690159082412
#  batch 300 loss: 0.7565529894828796
#  batch 400 loss: 0.7556462222337723
# lr 0.001 -> 0.001
# Train accuracy 72.1:
# Test accuracy 72.1:
# EPOCH 34:
#  batch 100 loss: 0.7521658521890641
#  batch 200 loss: 0.7586611551046372
#  batch 300 loss: 0.7658283460140228
#  batch 400 loss: 0.7549540072679519
# lr 0.001 -> 0.001
# Train accuracy 72.1:
# Test accuracy 72.2:
# EPOCH 35:
#  batch 100 loss: 0.7657476651668549
#  batch 200 loss: 0.7611171925067901
#  batch 300 loss: 0.758108811378479
#  batch 400 loss: 0.7554777681827545
# lr 0.001 -> 0.001
# Train accuracy 72.2:
# Test accuracy 72.2:
# EPOCH 36:
#  batch 100 loss: 0.7564635944366455
#  batch 200 loss: 0.7645390886068344
#  batch 300 loss: 0.7624344968795777
#  batch 400 loss: 0.744696655869484
# lr 0.001 -> 0.001
# Train accuracy 72.2:
# Test accuracy 72.1:
# EPOCH 37:
#  batch 100 loss: 0.7453032308816909
#  batch 200 loss: 0.7581625294685364
#  batch 300 loss: 0.7681480276584626
#  batch 400 loss: 0.7563051015138627
# lr 0.001 -> 0.001
# Train accuracy 72.2:
# Test accuracy 72.2:
# EPOCH 38:
#  batch 100 loss: 0.7529108545184136
#  batch 200 loss: 0.7643094533681869
#  batch 300 loss: 0.7486014270782471
#  batch 400 loss: 0.7514048808813095
# lr 0.001 -> 0.001
# Train accuracy 72.2:
# Test accuracy 72.2:
# EPOCH 39:
#  batch 100 loss: 0.7591594582796097
#  batch 200 loss: 0.7465357834100723
#  batch 300 loss: 0.7567444568872452
#  batch 400 loss: 0.7531398743391037
# lr 0.001 -> 0.001
# Train accuracy 72.2:
# Test accuracy 72.1:
# EPOCH 40:
#  batch 100 loss: 0.7423499822616577
#  batch 200 loss: 0.7667512953281402
#  batch 300 loss: 0.7673033860325813
#  batch 400 loss: 0.7409483122825623
# lr 0.001 -> 0.001
# Train accuracy 72.2:
# Test accuracy 72.1:
# EPOCH 41:
#  batch 100 loss: 0.7567049950361252
#  batch 200 loss: 0.7625735706090927
#  batch 300 loss: 0.7422708332538605
#  batch 400 loss: 0.7564084506034852
# lr 0.001 -> 0.001
# Train accuracy 72.1:
# Test accuracy 72.1:
# EPOCH 42:
#  batch 100 loss: 0.7649889129400254
#  batch 200 loss: 0.752737095952034
#  batch 300 loss: 0.7568982231616974
#  batch 400 loss: 0.7597822213172912
# lr 0.001 -> 0.001
# Train accuracy 72.2:
# Test accuracy 72.2:
# EPOCH 43:
#  batch 100 loss: 0.7553519153594971
#  batch 200 loss: 0.7594696831703186
#  batch 300 loss: 0.7564557898044586
#  batch 400 loss: 0.7557708352804184
# lr 0.001 -> 0.001
# Train accuracy 72.2:
# Test accuracy 72.2:
# EPOCH 44:
#  batch 100 loss: 0.7590384387969971
#  batch 200 loss: 0.7549461841583252
#  batch 300 loss: 0.7703196746110916
#  batch 400 loss: 0.7478241884708404
# lr 0.001 -> 0.001
# Train accuracy 72.2:
# Test accuracy 72.2:
# EPOCH 45:
#  batch 100 loss: 0.7684204691648483
#  batch 200 loss: 0.7437976112961769
#  batch 300 loss: 0.7495147091150284
#  batch 400 loss: 0.7619499018788338
# lr 0.001 -> 0.001
# Train accuracy 72.2:
# Test accuracy 72.2:
# EPOCH 46:
#  batch 100 loss: 0.763030955195427
#  batch 200 loss: 0.741568463742733
#  batch 300 loss: 0.7532022920250893
#  batch 400 loss: 0.7749784135818482
# lr 0.001 -> 0.001
# Train accuracy 72.2:
# Test accuracy 72.2:
# EPOCH 47:
#  batch 100 loss: 0.7535479754209519
#  batch 200 loss: 0.748765441775322
#  batch 300 loss: 0.765002775490284
#  batch 400 loss: 0.7530449298024178
# lr 0.001 -> 0.001
# Train accuracy 72.2:
# Test accuracy 72.1:
# EPOCH 48:
#  batch 100 loss: 0.7504312521219254
#  batch 200 loss: 0.7642644953727722
#  batch 300 loss: 0.7500356847047805
#  batch 400 loss: 0.7432286384701728
# lr 0.001 -> 0.001
# Train accuracy 72.2:
# Test accuracy 72.2:
# EPOCH 49:
#  batch 100 loss: 0.7619529175758362
#  batch 200 loss: 0.7612465131282806
#  batch 300 loss: 0.7475340920686722
#  batch 400 loss: 0.7516693013906479
# lr 0.001 -> 0.001
# Train accuracy 72.2:
# Test accuracy 72.2:
# EPOCH 50:
#  batch 100 loss: 0.7587207895517349
#  batch 200 loss: 0.7580257254838944
#  batch 300 loss: 0.7466878986358643
#  batch 400 loss: 0.7571221235394477
# lr 0.001 -> 0.0001
# Train accuracy 72.2:
# Test accuracy 72.2:
# EPOCH 51:
#  batch 100 loss: 0.7379572483897209
#  batch 200 loss: 0.7630264520645141
#  batch 300 loss: 0.765359206199646
#  batch 400 loss: 0.7569918799400329
# lr 0.0001 -> 0.0001
# Train accuracy 72.2:
# Test accuracy 72.2:
# EPOCH 52:
#  batch 100 loss: 0.7663792562484741
#  batch 200 loss: 0.7543024945259095
#  batch 300 loss: 0.7522247314453125
#  batch 400 loss: 0.7409958064556121
# lr 0.0001 -> 0.0001
# Train accuracy 72.2:
# Test accuracy 72.2:
# EPOCH 53:
#  batch 100 loss: 0.7422403141856193
#  batch 200 loss: 0.7722398149967193
#  batch 300 loss: 0.7517191845178605
#  batch 400 loss: 0.7501162672042847
# lr 0.0001 -> 0.0001
# Train accuracy 72.2:
# Test accuracy 72.2:
# EPOCH 54:
#  batch 100 loss: 0.7549518996477127
#  batch 200 loss: 0.7542544871568679
#  batch 300 loss: 0.7482446175813675
#  batch 400 loss: 0.7589376872777939
# lr 0.0001 -> 0.0001
# Train accuracy 72.2:
# Test accuracy 72.2:
# EPOCH 55:
#  batch 100 loss: 0.7614234977960587
#  batch 200 loss: 0.7489027622342109
#  batch 300 loss: 0.7534956020116806
#  batch 400 loss: 0.7519071573019027
# lr 0.0001 -> 0.0001
# Train accuracy 72.2:
# Test accuracy 72.2:
# EPOCH 56:
#  batch 100 loss: 0.772074528336525
#  batch 200 loss: 0.7504293066263199
#  batch 300 loss: 0.7549100553989411
#  batch 400 loss: 0.7436620825529099
# lr 0.0001 -> 0.0001
# Train accuracy 72.2:
# Test accuracy 72.2:
# EPOCH 57:
#  batch 100 loss: 0.7519618356227875
#  batch 200 loss: 0.7608970639109611
#  batch 300 loss: 0.7444039672613144
#  batch 400 loss: 0.7601948660612107
# lr 0.0001 -> 0.0001
# Train accuracy 72.2:
# Test accuracy 72.2:
# EPOCH 58:
#  batch 100 loss: 0.7491170793771744
#  batch 200 loss: 0.7451291769742966
#  batch 300 loss: 0.7694641554355621
#  batch 400 loss: 0.753731359243393
# lr 0.0001 -> 0.0001
# Train accuracy 72.2:
# Test accuracy 72.2:
# EPOCH 59:
#  batch 100 loss: 0.7577201074361801
#  batch 200 loss: 0.7457433950901031
#  batch 300 loss: 0.7537113630771637
#  batch 400 loss: 0.750151042342186
# lr 0.0001 -> 0.0001
# Train accuracy 72.2:
# Test accuracy 72.2:
# EPOCH 60:
#  batch 100 loss: 0.7564989697933197
#  batch 200 loss: 0.7764803498983384
#  batch 300 loss: 0.7336030900478363
#  batch 400 loss: 0.7408989125490189
# lr 0.0001 -> 0.0001
# Train accuracy 72.2:
# Test accuracy 72.2:
# EPOCH 61:
#  batch 100 loss: 0.754562821984291
#  batch 200 loss: 0.7555499768257141
#  batch 300 loss: 0.7606156301498413
#  batch 400 loss: 0.739847751557827
# lr 0.0001 -> 0.0001
# Train accuracy 72.2:
# Test accuracy 72.2:
# EPOCH 62:
#  batch 100 loss: 0.7617088043689728
#  batch 200 loss: 0.7587629944086075
#  batch 300 loss: 0.7483287709951401
#  batch 400 loss: 0.7532634425163269
# lr 0.0001 -> 0.0001
# Train accuracy 72.2:
# Test accuracy 72.2:
# EPOCH 63:
#  batch 100 loss: 0.7438058322668075
#  batch 200 loss: 0.7673205834627151
#  batch 300 loss: 0.7708502739667893
#  batch 400 loss: 0.7542223751544952
# lr 0.0001 -> 0.0001
# Train accuracy 72.2:
# Test accuracy 72.2:
# EPOCH 64:
#  batch 100 loss: 0.7560158866643906
#  batch 200 loss: 0.7618381428718567
#  batch 300 loss: 0.7473836743831634
#  batch 400 loss: 0.7614833462238312
# lr 0.0001 -> 0.0001
# Train accuracy 72.2:
# Test accuracy 72.2:
# EPOCH 65:
#  batch 100 loss: 0.7560776716470718
#  batch 200 loss: 0.7602401787042617
#  batch 300 loss: 0.7506583410501481
#  batch 400 loss: 0.7461737525463105
# lr 0.0001 -> 0.0001
# Train accuracy 72.2:
# Test accuracy 72.2:
# EPOCH 66:
#  batch 100 loss: 0.7600163722038269
#  batch 200 loss: 0.7610796934366226
#  batch 300 loss: 0.7575762170553207
#  batch 400 loss: 0.7627940565347672
# lr 0.0001 -> 0.0001
# Train accuracy 72.2:
# Test accuracy 72.2:
# EPOCH 67:
#  batch 100 loss: 0.7569498455524445
#  batch 200 loss: 0.7514038985967636
#  batch 300 loss: 0.7423621416091919
#  batch 400 loss: 0.7692599773406983
# lr 0.0001 -> 0.0001
# Train accuracy 72.2:
# Test accuracy 72.2:
# EPOCH 68:
#  batch 100 loss: 0.7599519264698028
#  batch 200 loss: 0.7494598281383514
#  batch 300 loss: 0.7368759083747863
#  batch 400 loss: 0.7716206529736519
# lr 0.0001 -> 0.0001
# Train accuracy 72.2:
# Test accuracy 72.2:
# EPOCH 69:
#  batch 100 loss: 0.75772654235363
#  batch 200 loss: 0.753946899175644
#  batch 300 loss: 0.7592329037189484
#  batch 400 loss: 0.7473312574625015
# lr 0.0001 -> 0.0001
# Train accuracy 72.2:
# Test accuracy 72.2:
# EPOCH 70:
#  batch 100 loss: 0.7623929017782212
#  batch 200 loss: 0.7559980222582817
#  batch 300 loss: 0.7614590185880661
#  batch 400 loss: 0.7344227439165115
# lr 0.0001 -> 0.0001
# Train accuracy 72.2:
# Test accuracy 72.2:
# EPOCH 71:
#  batch 100 loss: 0.7579602897167206
#  batch 200 loss: 0.7478284978866577
#  batch 300 loss: 0.7570374745130539
#  batch 400 loss: 0.7461796867847442
# lr 0.0001 -> 0.0001
# Train accuracy 72.2:
# Test accuracy 72.2:
# EPOCH 72:
#  batch 100 loss: 0.7627902364730835
#  batch 200 loss: 0.7443624132871628
#  batch 300 loss: 0.7605091676115989
#  batch 400 loss: 0.7587944543361664
# lr 0.0001 -> 0.0001
# Train accuracy 72.2:
# Test accuracy 72.2:
# EPOCH 73:
#  batch 100 loss: 0.746371288895607
#  batch 200 loss: 0.7551864835619927
#  batch 300 loss: 0.7563593375682831
#  batch 400 loss: 0.7599866050481796
# lr 0.0001 -> 0.0001
# Train accuracy 72.2:
# Test accuracy 72.2:
# EPOCH 74:
#  batch 100 loss: 0.7577834618091583
#  batch 200 loss: 0.740548307299614
#  batch 300 loss: 0.750178102850914
#  batch 400 loss: 0.7559342414140702
# lr 0.0001 -> 0.0001
# Train accuracy 72.2:
# Test accuracy 72.2:
# EPOCH 75:
#  batch 100 loss: 0.7551376801729203
#  batch 200 loss: 0.7548281037807465
#  batch 300 loss: 0.7585512065887451
#  batch 400 loss: 0.7643173211812972
# lr 0.0001 -> 1e-05
# Train accuracy 72.2:
# Test accuracy 72.2:
# EPOCH 76:
#  batch 100 loss: 0.7369390413165092
#  batch 200 loss: 0.7702488446235657
#  batch 300 loss: 0.7610784912109375
#  batch 400 loss: 0.7456587433815003
# lr 1e-05 -> 1e-05
# Train accuracy 72.2:
# Test accuracy 72.2:
# EPOCH 77:
#  batch 100 loss: 0.7541301941871643
#  batch 200 loss: 0.7516772308945656
#  batch 300 loss: 0.7630782896280288
#  batch 400 loss: 0.7464302468299866
# lr 1e-05 -> 1e-05
# Train accuracy 72.2:
# Test accuracy 72.2:
# EPOCH 78:
#  batch 100 loss: 0.7503818309307099
#  batch 200 loss: 0.773344731926918
#  batch 300 loss: 0.731879506111145
#  batch 400 loss: 0.7598560708761215
# lr 1e-05 -> 1e-05
# Train accuracy 72.2:
# Test accuracy 72.2:
# EPOCH 79:
#  batch 100 loss: 0.7470578855276108
#  batch 200 loss: 0.7677283710241318
#  batch 300 loss: 0.7555251672863961
#  batch 400 loss: 0.751893725991249
# lr 1e-05 -> 1e-05
# Train accuracy 72.2:
# Test accuracy 72.2:
# EPOCH 80:
#  batch 100 loss: 0.7457796633243561
#  batch 200 loss: 0.746921826004982
#  batch 300 loss: 0.7582674378156662
#  batch 400 loss: 0.7631767970323563
# lr 1e-05 -> 1e-05
# Train accuracy 72.2:
# Test accuracy 72.2:
# EPOCH 81:
#  batch 100 loss: 0.7525091952085495
#  batch 200 loss: 0.7458781200647354
#  batch 300 loss: 0.7624942445755005
#  batch 400 loss: 0.758950679898262
# lr 1e-05 -> 1e-05
# Train accuracy 72.2:
# Test accuracy 72.2:
# EPOCH 82:
#  batch 100 loss: 0.7566519594192505
#  batch 200 loss: 0.7576577800512314
#  batch 300 loss: 0.7555997830629348
#  batch 400 loss: 0.7499140602350235
# lr 1e-05 -> 1e-05
# Train accuracy 72.2:
# Test accuracy 72.2:
# EPOCH 83:
#  batch 100 loss: 0.7408441287279129
#  batch 200 loss: 0.7724673271179199
#  batch 300 loss: 0.7511443728208542
#  batch 400 loss: 0.7590862911939621
# lr 1e-05 -> 1e-05
# Train accuracy 72.2:
# Test accuracy 72.2:
# EPOCH 84:
#  batch 100 loss: 0.7480664300918579
#  batch 200 loss: 0.7519542190432549
#  batch 300 loss: 0.760396466255188
#  batch 400 loss: 0.752586030960083
# lr 1e-05 -> 1e-05
# Train accuracy 72.2:
# Test accuracy 72.2:
# EPOCH 85:
#  batch 100 loss: 0.739927237033844
#  batch 200 loss: 0.7514638251066208
#  batch 300 loss: 0.7558201777935029
#  batch 400 loss: 0.7666946697235107
# lr 1e-05 -> 1e-05
# Train accuracy 72.2:
# Test accuracy 72.2:
# EPOCH 86:
#  batch 100 loss: 0.7542670327425003
#  batch 200 loss: 0.7492261403799056
#  batch 300 loss: 0.7595576822757721
#  batch 400 loss: 0.7639245408773422
# lr 1e-05 -> 1e-05
# Train accuracy 72.2:
# Test accuracy 72.2:
# EPOCH 87:
#  batch 100 loss: 0.7523449856042862
#  batch 200 loss: 0.7450490313768386
#  batch 300 loss: 0.7523156771063805
#  batch 400 loss: 0.7586135333776474
# lr 1e-05 -> 1e-05
# Train accuracy 72.2:
# Test accuracy 72.2:
# EPOCH 88:
#  batch 100 loss: 0.76085653424263
#  batch 200 loss: 0.7543793320655823
#  batch 300 loss: 0.7486794596910477
#  batch 400 loss: 0.7463539624214173
# lr 1e-05 -> 1e-05
# Train accuracy 72.2:
# Test accuracy 72.2:
# EPOCH 89:
#  batch 100 loss: 0.7659332782030106
#  batch 200 loss: 0.7345497161149979
#  batch 300 loss: 0.7425486898422241
#  batch 400 loss: 0.7617920386791229
# lr 1e-05 -> 1e-05
# Train accuracy 72.2:
# Test accuracy 72.2:
# EPOCH 90:
#  batch 100 loss: 0.7671768856048584
#  batch 200 loss: 0.7411616468429565
#  batch 300 loss: 0.7589736509323121
#  batch 400 loss: 0.7411151206493378
# lr 1e-05 -> 1e-05
# Train accuracy 72.2:
# Test accuracy 72.2:
# EPOCH 91:
#  batch 100 loss: 0.7392539444565773
#  batch 200 loss: 0.7515046826004982
#  batch 300 loss: 0.7684650260210037
#  batch 400 loss: 0.7532734084129333
# lr 1e-05 -> 1e-05
# Train accuracy 72.2:
# Test accuracy 72.2:
# EPOCH 92:
#  batch 100 loss: 0.7463077569007873
#  batch 200 loss: 0.756730275452137
#  batch 300 loss: 0.763934121131897
#  batch 400 loss: 0.7496244505047798
# lr 1e-05 -> 1e-05
# Train accuracy 72.2:
# Test accuracy 72.2:
# EPOCH 93:
#  batch 100 loss: 0.758648826777935
#  batch 200 loss: 0.7619955086708069
#  batch 300 loss: 0.7406148353219032
#  batch 400 loss: 0.7567701452970504
# lr 1e-05 -> 1e-05
# Train accuracy 72.2:
# Test accuracy 72.2:
# EPOCH 94:
#  batch 100 loss: 0.7425323241949081
#  batch 200 loss: 0.7773317331075669
#  batch 300 loss: 0.7551194676756858
#  batch 400 loss: 0.7491515511274338
# lr 1e-05 -> 1e-05
# Train accuracy 72.2:
# Test accuracy 72.2:
# EPOCH 95:
#  batch 100 loss: 0.753633183836937
#  batch 200 loss: 0.7576904499530792
#  batch 300 loss: 0.7611313909292221
#  batch 400 loss: 0.7478023046255111
# lr 1e-05 -> 1e-05
# Train accuracy 72.2:
# Test accuracy 72.2:
# EPOCH 96:
#  batch 100 loss: 0.7561858868598939
#  batch 200 loss: 0.7696792662143708
#  batch 300 loss: 0.7598485189676285
#  batch 400 loss: 0.7445642870664596
# lr 1e-05 -> 1e-05
# Train accuracy 72.2:
# Test accuracy 72.2:
# EPOCH 97:
#  batch 100 loss: 0.758219148516655
#  batch 200 loss: 0.7527513772249221
#  batch 300 loss: 0.7523519310355187
#  batch 400 loss: 0.7583240926265716
# lr 1e-05 -> 1e-05
# Train accuracy 72.2:
# Test accuracy 72.2:
# EPOCH 98:
#  batch 100 loss: 0.7664583575725555
#  batch 200 loss: 0.7564962166547775
#  batch 300 loss: 0.7449399644136429
#  batch 400 loss: 0.7453580659627914
# lr 1e-05 -> 1e-05
# Train accuracy 72.2:
# Test accuracy 72.2:
# EPOCH 99:
#  batch 100 loss: 0.7573946905136109
#  batch 200 loss: 0.756865707039833
#  batch 300 loss: 0.7441871309280396
#  batch 400 loss: 0.7593972706794738
# lr 1e-05 -> 1e-05
# Train accuracy 72.2:
# Test accuracy 72.2:
# EPOCH 100:
#  batch 100 loss: 0.7724985438585281
#  batch 200 loss: 0.7521050894260406
#  batch 300 loss: 0.7524397051334382
#  batch 400 loss: 0.7587114530801773
# lr 1e-05 -> 1.0000000000000002e-06
# Train accuracy 72.2:
# Test accuracy 72.2:
# Reg Strength 1e-07:
# EPOCH 1:
#  batch 100 loss: 1.3786757701635362
#  batch 200 loss: 0.7709179252386094
#  batch 300 loss: 0.6190055850148201
#  batch 400 loss: 0.5484096890687943
# lr 0.01 -> 0.01
# Train accuracy 87.0:
# Test accuracy 87.9:
# EPOCH 2:
#  batch 100 loss: 0.4830295169353485
#  batch 200 loss: 0.46051306307315826
#  batch 300 loss: 0.43829988956451416
#  batch 400 loss: 0.4363808073103428
# lr 0.01 -> 0.01
# Train accuracy 88.8:
# Test accuracy 89.7:
# EPOCH 3:
#  batch 100 loss: 0.4117646488547325
#  batch 200 loss: 0.40235315695405005
#  batch 300 loss: 0.39917458713054654
#  batch 400 loss: 0.37795038416981697
# lr 0.01 -> 0.01
# Train accuracy 89.60000000000001:
# Test accuracy 90.3:
# EPOCH 4:
#  batch 100 loss: 0.3750090929865837
#  batch 200 loss: 0.37888668462634084
#  batch 300 loss: 0.38570839673280716
#  batch 400 loss: 0.35694977417588236
# lr 0.01 -> 0.01
# Train accuracy 89.9:
# Test accuracy 90.5:
# EPOCH 5:
#  batch 100 loss: 0.3600360545516014
#  batch 200 loss: 0.35725962951779366
#  batch 300 loss: 0.34703718855977056
#  batch 400 loss: 0.3579317979514599
# lr 0.01 -> 0.01
# Train accuracy 90.3:
# Test accuracy 90.7:
# EPOCH 6:
#  batch 100 loss: 0.3401951217651367
#  batch 200 loss: 0.34205413088202474
#  batch 300 loss: 0.3400455790758133
#  batch 400 loss: 0.3462721872329712
# lr 0.01 -> 0.01
# Train accuracy 90.4:
# Test accuracy 90.9:
# EPOCH 7:
#  batch 100 loss: 0.34358382403850557
#  batch 200 loss: 0.32774970918893814
#  batch 300 loss: 0.3301044335961342
#  batch 400 loss: 0.3375661727786064
# lr 0.01 -> 0.01
# Train accuracy 90.60000000000001:
# Test accuracy 91.0:
# EPOCH 8:
#  batch 100 loss: 0.3317440152168274
#  batch 200 loss: 0.32390281960368156
#  batch 300 loss: 0.32871419593691825
#  batch 400 loss: 0.3228086118400097
# lr 0.01 -> 0.01
# Train accuracy 90.8:
# Test accuracy 91.2:
# EPOCH 9:
#  batch 100 loss: 0.3219681461155415
#  batch 200 loss: 0.330131716132164
#  batch 300 loss: 0.3196170412003994
#  batch 400 loss: 0.32010701939463615
# lr 0.01 -> 0.01
# Train accuracy 90.9:
# Test accuracy 91.5:
# EPOCH 10:
#  batch 100 loss: 0.320503963381052
#  batch 200 loss: 0.3294973301887512
#  batch 300 loss: 0.31335598319768904
#  batch 400 loss: 0.31992793768644334
# lr 0.01 -> 0.01
# Train accuracy 90.9:
# Test accuracy 91.5:
# EPOCH 11:
#  batch 100 loss: 0.3173051914572716
#  batch 200 loss: 0.3187638893723488
#  batch 300 loss: 0.3085160833597183
#  batch 400 loss: 0.3225748620927334
# lr 0.01 -> 0.01
# Train accuracy 91.0:
# Test accuracy 91.4:
# EPOCH 12:
#  batch 100 loss: 0.3222411087155342
#  batch 200 loss: 0.30875422224402427
#  batch 300 loss: 0.3091749928891659
#  batch 400 loss: 0.3090135583281517
# lr 0.01 -> 0.01
# Train accuracy 91.3:
# Test accuracy 91.5:
# EPOCH 13:
#  batch 100 loss: 0.3124849066138268
#  batch 200 loss: 0.3032594791054726
#  batch 300 loss: 0.30708108976483345
#  batch 400 loss: 0.30384876862168314
# lr 0.01 -> 0.01
# Train accuracy 91.3:
# Test accuracy 91.5:
# EPOCH 14:
#  batch 100 loss: 0.30758750036358834
#  batch 200 loss: 0.29888839676976203
#  batch 300 loss: 0.3040878991782665
#  batch 400 loss: 0.30466273963451385
# lr 0.01 -> 0.01
# Train accuracy 91.4:
# Test accuracy 91.60000000000001:
# EPOCH 15:
#  batch 100 loss: 0.30468558475375174
#  batch 200 loss: 0.28959422677755353
#  batch 300 loss: 0.3049416409432888
#  batch 400 loss: 0.30512920588254927
# lr 0.01 -> 0.01
# Train accuracy 91.5:
# Test accuracy 91.7:
# EPOCH 16:
#  batch 100 loss: 0.3099685275554657
#  batch 200 loss: 0.30380099833011626
#  batch 300 loss: 0.29844336688518525
#  batch 400 loss: 0.29959331303834913
# lr 0.01 -> 0.01
# Train accuracy 91.60000000000001:
# Test accuracy 91.8:
# EPOCH 17:
#  batch 100 loss: 0.29234787419438363
#  batch 200 loss: 0.3007149384915829
#  batch 300 loss: 0.3037802951037884
#  batch 400 loss: 0.29875481203198434
# lr 0.01 -> 0.01
# Train accuracy 91.60000000000001:
# Test accuracy 91.7:
# EPOCH 18:
#  batch 100 loss: 0.2994913911819458
#  batch 200 loss: 0.2945428916811943
#  batch 300 loss: 0.27989760652184487
#  batch 400 loss: 0.30136261612176896
# lr 0.01 -> 0.01
# Train accuracy 91.7:
# Test accuracy 91.9:
# EPOCH 19:
#  batch 100 loss: 0.29540479376912115
#  batch 200 loss: 0.2970648831129074
#  batch 300 loss: 0.2905788463354111
#  batch 400 loss: 0.30450554460287094
# lr 0.01 -> 0.01
# Train accuracy 91.7:
# Test accuracy 91.9:
# EPOCH 20:
#  batch 100 loss: 0.294036440551281
#  batch 200 loss: 0.3100384545326233
#  batch 300 loss: 0.28818234503269197
#  batch 400 loss: 0.2873307877779007
# lr 0.01 -> 0.01
# Train accuracy 91.8:
# Test accuracy 92.0:
# EPOCH 21:
#  batch 100 loss: 0.2920457865297794
#  batch 200 loss: 0.2898744840919971
#  batch 300 loss: 0.27809938475489615
#  batch 400 loss: 0.30027667865157126
# lr 0.01 -> 0.01
# Train accuracy 91.8:
# Test accuracy 92.0:
# EPOCH 22:
#  batch 100 loss: 0.29533887580037116
#  batch 200 loss: 0.28801434189081193
#  batch 300 loss: 0.2982160522043705
#  batch 400 loss: 0.28439006961882113
# lr 0.01 -> 0.01
# Train accuracy 91.8:
# Test accuracy 91.9:
# EPOCH 23:
#  batch 100 loss: 0.2826570224761963
#  batch 200 loss: 0.30162914052605627
#  batch 300 loss: 0.294724927097559
#  batch 400 loss: 0.2821773856878281
# lr 0.01 -> 0.01
# Train accuracy 91.8:
# Test accuracy 91.9:
# EPOCH 24:
#  batch 100 loss: 0.28815832778811457
#  batch 200 loss: 0.2862631377577782
#  batch 300 loss: 0.2874406839907169
#  batch 400 loss: 0.2883250248432159
# lr 0.01 -> 0.01
# Train accuracy 91.8:
# Test accuracy 91.9:
# EPOCH 25:
#  batch 100 loss: 0.2939040280878544
#  batch 200 loss: 0.2917116048932076
#  batch 300 loss: 0.28425963923335074
#  batch 400 loss: 0.28146448493003845
# lr 0.01 -> 0.001
# Train accuracy 91.9:
# Test accuracy 92.0:
# EPOCH 26:
#  batch 100 loss: 0.2824286715686321
#  batch 200 loss: 0.29991356655955315
#  batch 300 loss: 0.28162537440657615
#  batch 400 loss: 0.2829344268143177
# lr 0.001 -> 0.001
# Train accuracy 92.0:
# Test accuracy 92.0:
# EPOCH 27:
#  batch 100 loss: 0.3009791134297848
#  batch 200 loss: 0.2825836430490017
#  batch 300 loss: 0.272926364839077
#  batch 400 loss: 0.2873477843403816
# lr 0.001 -> 0.001
# Train accuracy 92.0:
# Test accuracy 92.0:
# EPOCH 28:
#  batch 100 loss: 0.28071690633893015
#  batch 200 loss: 0.2765881894528866
#  batch 300 loss: 0.2865694139897823
#  batch 400 loss: 0.28755109041929244
# lr 0.001 -> 0.001
# Train accuracy 92.0:
# Test accuracy 92.0:
# EPOCH 29:
#  batch 100 loss: 0.2763452453911304
#  batch 200 loss: 0.2917353494465351
#  batch 300 loss: 0.29163572877645494
#  batch 400 loss: 0.27327595978975294
# lr 0.001 -> 0.001
# Train accuracy 92.0:
# Test accuracy 92.10000000000001:
# EPOCH 30:
#  batch 100 loss: 0.3033315120637417
#  batch 200 loss: 0.2811167332530022
#  batch 300 loss: 0.2696169537305832
#  batch 400 loss: 0.2839328599721193
# lr 0.001 -> 0.001
# Train accuracy 92.0:
# Test accuracy 92.10000000000001:
# EPOCH 31:
#  batch 100 loss: 0.27853254303336145
#  batch 200 loss: 0.28199307769536974
#  batch 300 loss: 0.2889617809653282
#  batch 400 loss: 0.28315603151917457
# lr 0.001 -> 0.001
# Train accuracy 92.0:
# Test accuracy 92.0:
# EPOCH 32:
#  batch 100 loss: 0.28998287200927736
#  batch 200 loss: 0.27704144179821016
#  batch 300 loss: 0.2796623270213604
#  batch 400 loss: 0.29346271067857743
# lr 0.001 -> 0.001
# Train accuracy 92.0:
# Test accuracy 92.10000000000001:
# EPOCH 33:
#  batch 100 loss: 0.2715791635215282
#  batch 200 loss: 0.28428672432899477
#  batch 300 loss: 0.2787033730745316
#  batch 400 loss: 0.28464832067489626
# lr 0.001 -> 0.001
# Train accuracy 92.0:
# Test accuracy 92.10000000000001:
# EPOCH 34:
#  batch 100 loss: 0.28744984716176986
#  batch 200 loss: 0.28153031066060064
#  batch 300 loss: 0.2861665689945221
#  batch 400 loss: 0.27853847824037076
# lr 0.001 -> 0.001
# Train accuracy 92.0:
# Test accuracy 92.10000000000001:
# EPOCH 35:
#  batch 100 loss: 0.2848714020848274
#  batch 200 loss: 0.28145691081881524
#  batch 300 loss: 0.2916408260166645
#  batch 400 loss: 0.28020064800977706
# lr 0.001 -> 0.001
# Train accuracy 92.0:
# Test accuracy 92.10000000000001:
# EPOCH 36:
#  batch 100 loss: 0.28069684863090516
#  batch 200 loss: 0.2868135657906532
#  batch 300 loss: 0.28271982043981553
#  batch 400 loss: 0.2835346329212189
# lr 0.001 -> 0.001
# Train accuracy 92.0:
# Test accuracy 92.10000000000001:
# EPOCH 37:
#  batch 100 loss: 0.2851449567824602
#  batch 200 loss: 0.28534060999751093
#  batch 300 loss: 0.2737030566483736
#  batch 400 loss: 0.2811881500482559
# lr 0.001 -> 0.001
# Train accuracy 92.0:
# Test accuracy 92.10000000000001:
# EPOCH 38:
#  batch 100 loss: 0.2717944426834583
#  batch 200 loss: 0.28669324934482576
#  batch 300 loss: 0.2978120392560959
#  batch 400 loss: 0.2831162352859974
# lr 0.001 -> 0.001
# Train accuracy 92.0:
# Test accuracy 92.10000000000001:
# EPOCH 39:
#  batch 100 loss: 0.2785842302441597
#  batch 200 loss: 0.28251869589090345
#  batch 300 loss: 0.29080438405275344
#  batch 400 loss: 0.27313112989068034
# lr 0.001 -> 0.001
# Train accuracy 92.0:
# Test accuracy 92.10000000000001:
# EPOCH 40:
#  batch 100 loss: 0.28221895307302475
#  batch 200 loss: 0.2779851683974266
#  batch 300 loss: 0.28443300604820254
#  batch 400 loss: 0.2859031277894974
# lr 0.001 -> 0.001
# Train accuracy 92.0:
# Test accuracy 92.10000000000001:
# EPOCH 41:
#  batch 100 loss: 0.2879656778275967
#  batch 200 loss: 0.28737186968326567
#  batch 300 loss: 0.2775915513932705
#  batch 400 loss: 0.2835341314971447
# lr 0.001 -> 0.001
# Train accuracy 92.0:
# Test accuracy 92.10000000000001:
# EPOCH 42:
#  batch 100 loss: 0.28194102257490156
#  batch 200 loss: 0.29109211057424544
#  batch 300 loss: 0.2722196765244007
#  batch 400 loss: 0.2786702798306942
# lr 0.001 -> 0.001
# Train accuracy 92.0:
# Test accuracy 92.10000000000001:
# EPOCH 43:
#  batch 100 loss: 0.274322100430727
#  batch 200 loss: 0.28457831636071207
#  batch 300 loss: 0.27869717955589296
#  batch 400 loss: 0.28987025171518327
# lr 0.001 -> 0.001
# Train accuracy 92.0:
# Test accuracy 92.10000000000001:
# EPOCH 44:
#  batch 100 loss: 0.2830354112386704
#  batch 200 loss: 0.2835570004582405
#  batch 300 loss: 0.2899220947921276
#  batch 400 loss: 0.2797400389611721
# lr 0.001 -> 0.001
# Train accuracy 92.0:
# Test accuracy 92.10000000000001:
# EPOCH 45:
#  batch 100 loss: 0.2863683430850506
#  batch 200 loss: 0.2810547643899918
#  batch 300 loss: 0.28145667880773545
#  batch 400 loss: 0.2815572820603848
# lr 0.001 -> 0.001
# Train accuracy 92.0:
# Test accuracy 92.10000000000001:
# EPOCH 46:
#  batch 100 loss: 0.2845280463993549
#  batch 200 loss: 0.2831569029390812
#  batch 300 loss: 0.28916769951581955
#  batch 400 loss: 0.2769510167837143
# lr 0.001 -> 0.001
# Train accuracy 92.0:
# Test accuracy 92.10000000000001:
# EPOCH 47:
#  batch 100 loss: 0.29529736295342446
#  batch 200 loss: 0.272221192792058
#  batch 300 loss: 0.2721565013378859
#  batch 400 loss: 0.2912528647482395
# lr 0.001 -> 0.001
# Train accuracy 92.10000000000001:
# Test accuracy 92.10000000000001:
# EPOCH 48:
#  batch 100 loss: 0.27090220972895623
#  batch 200 loss: 0.2966260015964508
#  batch 300 loss: 0.2775803577899933
#  batch 400 loss: 0.2886321297287941
# lr 0.001 -> 0.001
# Train accuracy 92.0:
# Test accuracy 92.10000000000001:
# EPOCH 49:
#  batch 100 loss: 0.28311347872018816
#  batch 200 loss: 0.28282894149422644
#  batch 300 loss: 0.2748939502239227
#  batch 400 loss: 0.2887788939476013
# lr 0.001 -> 0.001
# Train accuracy 92.0:
# Test accuracy 92.10000000000001:
# EPOCH 50:
#  batch 100 loss: 0.2968961504101753
#  batch 200 loss: 0.27790364280343055
#  batch 300 loss: 0.2792514523863792
#  batch 400 loss: 0.2805897609889507
# lr 0.001 -> 0.0001
# Train accuracy 92.0:
# Test accuracy 92.10000000000001:
# EPOCH 51:
#  batch 100 loss: 0.27531969010829926
#  batch 200 loss: 0.2775221540033817
#  batch 300 loss: 0.2886811588704586
#  batch 400 loss: 0.28241149097681045
# lr 0.0001 -> 0.0001
# Train accuracy 92.0:
# Test accuracy 92.10000000000001:
# EPOCH 52:
#  batch 100 loss: 0.29019213408231737
#  batch 200 loss: 0.28307167187333104
#  batch 300 loss: 0.27776626236736773
#  batch 400 loss: 0.2765603622794151
# lr 0.0001 -> 0.0001
# Train accuracy 92.0:
# Test accuracy 92.10000000000001:
# EPOCH 53:
#  batch 100 loss: 0.2718566869199276
#  batch 200 loss: 0.26779397651553155
#  batch 300 loss: 0.2908239842951298
#  batch 400 loss: 0.2925129018723965
# lr 0.0001 -> 0.0001
# Train accuracy 92.0:
# Test accuracy 92.10000000000001:
# EPOCH 54:
#  batch 100 loss: 0.2780086500942707
#  batch 200 loss: 0.2905492483079433
#  batch 300 loss: 0.2788436049222946
#  batch 400 loss: 0.27784365341067313
# lr 0.0001 -> 0.0001
# Train accuracy 92.0:
# Test accuracy 92.10000000000001:
# EPOCH 55:
#  batch 100 loss: 0.2770667468011379
#  batch 200 loss: 0.28834711506962774
#  batch 300 loss: 0.2795145891606808
#  batch 400 loss: 0.2765980762243271
# lr 0.0001 -> 0.0001
# Train accuracy 92.10000000000001:
# Test accuracy 92.10000000000001:
# EPOCH 56:
#  batch 100 loss: 0.27828973084688186
#  batch 200 loss: 0.277752270847559
#  batch 300 loss: 0.28533546879887584
#  batch 400 loss: 0.2875651301443577
# lr 0.0001 -> 0.0001
# Train accuracy 92.0:
# Test accuracy 92.10000000000001:
# EPOCH 57:
#  batch 100 loss: 0.285984560251236
#  batch 200 loss: 0.28475861296057703
#  batch 300 loss: 0.27124474465847015
#  batch 400 loss: 0.29236905694007875
# lr 0.0001 -> 0.0001
# Train accuracy 92.10000000000001:
# Test accuracy 92.10000000000001:
# EPOCH 58:
#  batch 100 loss: 0.2783784142136574
#  batch 200 loss: 0.28296535953879354
#  batch 300 loss: 0.2832967928051949
#  batch 400 loss: 0.27877734541893007
# lr 0.0001 -> 0.0001
# Train accuracy 92.10000000000001:
# Test accuracy 92.10000000000001:
# EPOCH 59:
#  batch 100 loss: 0.27630042418837547
#  batch 200 loss: 0.2877359360456467
#  batch 300 loss: 0.2763026940077543
#  batch 400 loss: 0.29086531676352023
# lr 0.0001 -> 0.0001
# Train accuracy 92.10000000000001:
# Test accuracy 92.10000000000001:
# EPOCH 60:
#  batch 100 loss: 0.2795419493317604
#  batch 200 loss: 0.28639697551727294
#  batch 300 loss: 0.2804363140463829
#  batch 400 loss: 0.2729766871035099
# lr 0.0001 -> 0.0001
# Train accuracy 92.10000000000001:
# Test accuracy 92.10000000000001:
# EPOCH 61:
#  batch 100 loss: 0.2887843242287636
#  batch 200 loss: 0.28974694535136225
#  batch 300 loss: 0.2606743397563696
#  batch 400 loss: 0.2891917358338833
# lr 0.0001 -> 0.0001
# Train accuracy 92.10000000000001:
# Test accuracy 92.10000000000001:
# EPOCH 62:
#  batch 100 loss: 0.27977057695388796
#  batch 200 loss: 0.277564072906971
#  batch 300 loss: 0.2814793448150158
#  batch 400 loss: 0.2815555399656296
# lr 0.0001 -> 0.0001
# Train accuracy 92.10000000000001:
# Test accuracy 92.10000000000001:
# EPOCH 63:
#  batch 100 loss: 0.2841251264512539
#  batch 200 loss: 0.2746570520102978
#  batch 300 loss: 0.2817866863310337
#  batch 400 loss: 0.2817104908823967
# lr 0.0001 -> 0.0001
# Train accuracy 92.10000000000001:
# Test accuracy 92.10000000000001:
# EPOCH 64:
#  batch 100 loss: 0.28752476796507836
#  batch 200 loss: 0.27509391620755197
#  batch 300 loss: 0.2760090872645378
#  batch 400 loss: 0.27728191778063777
# lr 0.0001 -> 0.0001
# Train accuracy 92.10000000000001:
# Test accuracy 92.10000000000001:
# EPOCH 65:
#  batch 100 loss: 0.2790642376244068
#  batch 200 loss: 0.28621015533804894
#  batch 300 loss: 0.27469602681696415
#  batch 400 loss: 0.2813908036053181
# lr 0.0001 -> 0.0001
# Train accuracy 92.10000000000001:
# Test accuracy 92.10000000000001:
# EPOCH 66:
#  batch 100 loss: 0.28191886574029923
#  batch 200 loss: 0.2882987478375435
#  batch 300 loss: 0.2793473033607006
#  batch 400 loss: 0.2807091248035431
# lr 0.0001 -> 0.0001
# Train accuracy 92.10000000000001:
# Test accuracy 92.10000000000001:
# EPOCH 67:
#  batch 100 loss: 0.2724184963107109
#  batch 200 loss: 0.2950820943713188
#  batch 300 loss: 0.2872378207743168
#  batch 400 loss: 0.27572781398892404
# lr 0.0001 -> 0.0001
# Train accuracy 92.10000000000001:
# Test accuracy 92.10000000000001:
# EPOCH 68:
#  batch 100 loss: 0.2726407854259014
#  batch 200 loss: 0.289449233263731
#  batch 300 loss: 0.2842496613413095
#  batch 400 loss: 0.2777456974983215
# lr 0.0001 -> 0.0001
# Train accuracy 92.10000000000001:
# Test accuracy 92.10000000000001:
# EPOCH 69:
#  batch 100 loss: 0.2773163731396198
#  batch 200 loss: 0.2927733398973942
#  batch 300 loss: 0.27397035002708436
#  batch 400 loss: 0.2776895542442799
# lr 0.0001 -> 0.0001
# Train accuracy 92.10000000000001:
# Test accuracy 92.10000000000001:
# EPOCH 70:
#  batch 100 loss: 0.2766359902173281
#  batch 200 loss: 0.28345744833350184
#  batch 300 loss: 0.2815836764872074
#  batch 400 loss: 0.2766453185677528
# lr 0.0001 -> 0.0001
# Train accuracy 92.10000000000001:
# Test accuracy 92.10000000000001:
# EPOCH 71:
#  batch 100 loss: 0.2891944880783558
#  batch 200 loss: 0.28058004796504976
#  batch 300 loss: 0.2801294754445553
#  batch 400 loss: 0.27922201916575434
# lr 0.0001 -> 0.0001
# Train accuracy 92.10000000000001:
# Test accuracy 92.10000000000001:
# EPOCH 72:
#  batch 100 loss: 0.2758900445699692
#  batch 200 loss: 0.2902093218266964
#  batch 300 loss: 0.28434271067380906
#  batch 400 loss: 0.27736794769763945
# lr 0.0001 -> 0.0001
# Train accuracy 92.10000000000001:
# Test accuracy 92.10000000000001:
# EPOCH 73:
#  batch 100 loss: 0.27757463097572327
#  batch 200 loss: 0.2771721489727497
#  batch 300 loss: 0.28173445999622343
#  batch 400 loss: 0.29217526361346247
# lr 0.0001 -> 0.0001
# Train accuracy 92.10000000000001:
# Test accuracy 92.10000000000001:
# EPOCH 74:
#  batch 100 loss: 0.28565497845411303
#  batch 200 loss: 0.2658050474524498
#  batch 300 loss: 0.2856081667542458
#  batch 400 loss: 0.2811532594263554
# lr 0.0001 -> 0.0001
# Train accuracy 92.10000000000001:
# Test accuracy 92.10000000000001:
# EPOCH 75:
#  batch 100 loss: 0.2822954514622688
#  batch 200 loss: 0.28370805591344833
#  batch 300 loss: 0.2774028354883194
#  batch 400 loss: 0.28773627370595933
# lr 0.0001 -> 1e-05
# Train accuracy 92.10000000000001:
# Test accuracy 92.10000000000001:
# EPOCH 76:
#  batch 100 loss: 0.2866346341371536
#  batch 200 loss: 0.2858595284819603
#  batch 300 loss: 0.27083519667387007
#  batch 400 loss: 0.2776143972575664
# lr 1e-05 -> 1e-05
# Train accuracy 92.10000000000001:
# Test accuracy 92.10000000000001:
# EPOCH 77:
#  batch 100 loss: 0.2867546561360359
#  batch 200 loss: 0.28294227048754694
#  batch 300 loss: 0.2756601041555405
#  batch 400 loss: 0.28066179901361465
# lr 1e-05 -> 1e-05
# Train accuracy 92.10000000000001:
# Test accuracy 92.10000000000001:
# EPOCH 78:
#  batch 100 loss: 0.2936655867099762
#  batch 200 loss: 0.2707785414159298
#  batch 300 loss: 0.2757988749444485
#  batch 400 loss: 0.2714978960901499
# lr 1e-05 -> 1e-05
# Train accuracy 92.10000000000001:
# Test accuracy 92.10000000000001:
# EPOCH 79:
#  batch 100 loss: 0.2831141929328442
#  batch 200 loss: 0.2799935431033373
#  batch 300 loss: 0.2653932537138462
#  batch 400 loss: 0.28639931946992875
# lr 1e-05 -> 1e-05
# Train accuracy 92.10000000000001:
# Test accuracy 92.10000000000001:
# EPOCH 80:
#  batch 100 loss: 0.28185405597090724
#  batch 200 loss: 0.29429002717137337
#  batch 300 loss: 0.27378243789076806
#  batch 400 loss: 0.2787852144241333
# lr 1e-05 -> 1e-05
# Train accuracy 92.10000000000001:
# Test accuracy 92.10000000000001:
# EPOCH 81:
#  batch 100 loss: 0.2890023566782475
#  batch 200 loss: 0.2825315675139427
#  batch 300 loss: 0.2762121145427227
#  batch 400 loss: 0.2816513633728027
# lr 1e-05 -> 1e-05
# Train accuracy 92.10000000000001:
# Test accuracy 92.10000000000001:
# EPOCH 82:
#  batch 100 loss: 0.2810620881617069
#  batch 200 loss: 0.28168014451861384
#  batch 300 loss: 0.276477130651474
#  batch 400 loss: 0.2814637035131454
# lr 1e-05 -> 1e-05
# Train accuracy 92.10000000000001:
# Test accuracy 92.10000000000001:
# EPOCH 83:
#  batch 100 loss: 0.28481533721089364
#  batch 200 loss: 0.27839328899979593
#  batch 300 loss: 0.2750594810396433
#  batch 400 loss: 0.28965201377868655
# lr 1e-05 -> 1e-05
# Train accuracy 92.10000000000001:
# Test accuracy 92.10000000000001:
# EPOCH 84:
#  batch 100 loss: 0.27280600465834143
#  batch 200 loss: 0.27877559393644336
#  batch 300 loss: 0.28626170665025713
#  batch 400 loss: 0.28089006036520003
# lr 1e-05 -> 1e-05
# Train accuracy 92.10000000000001:
# Test accuracy 92.10000000000001:
# EPOCH 85:
#  batch 100 loss: 0.2798810242116451
#  batch 200 loss: 0.28305558919906615
#  batch 300 loss: 0.2811875322461128
#  batch 400 loss: 0.28774552181363106
# lr 1e-05 -> 1e-05
# Train accuracy 92.10000000000001:
# Test accuracy 92.10000000000001:
# EPOCH 86:
#  batch 100 loss: 0.2760883715748787
#  batch 200 loss: 0.28143539488315583
#  batch 300 loss: 0.28051728069782256
#  batch 400 loss: 0.28051483556628226
# lr 1e-05 -> 1e-05
# Train accuracy 92.10000000000001:
# Test accuracy 92.10000000000001:
# EPOCH 87:
#  batch 100 loss: 0.2940981614589691
#  batch 200 loss: 0.2737739948928356
#  batch 300 loss: 0.2881516969203949
#  batch 400 loss: 0.26598859891295434
# lr 1e-05 -> 1e-05
# Train accuracy 92.10000000000001:
# Test accuracy 92.10000000000001:
# EPOCH 88:
#  batch 100 loss: 0.2906741960346699
#  batch 200 loss: 0.28271190166473387
#  batch 300 loss: 0.2696044521033764
#  batch 400 loss: 0.27639541909098625
# lr 1e-05 -> 1e-05
# Train accuracy 92.10000000000001:
# Test accuracy 92.10000000000001:
# EPOCH 89:
#  batch 100 loss: 0.2680153699964285
#  batch 200 loss: 0.28848902180790903
#  batch 300 loss: 0.28209984198212623
#  batch 400 loss: 0.27873013377189637
# lr 1e-05 -> 1e-05
# Train accuracy 92.10000000000001:
# Test accuracy 92.10000000000001:
# EPOCH 90:
#  batch 100 loss: 0.2721211551129818
#  batch 200 loss: 0.2798175683617592
#  batch 300 loss: 0.29059287905693054
#  batch 400 loss: 0.2831986004114151
# lr 1e-05 -> 1e-05
# Train accuracy 92.10000000000001:
# Test accuracy 92.10000000000001:
# EPOCH 91:
#  batch 100 loss: 0.2819655703008175
#  batch 200 loss: 0.2788854816555977
#  batch 300 loss: 0.28084402859210966
#  batch 400 loss: 0.2808883789181709
# lr 1e-05 -> 1e-05
# Train accuracy 92.10000000000001:
# Test accuracy 92.10000000000001:
# EPOCH 92:
#  batch 100 loss: 0.2798428730666637
#  batch 200 loss: 0.2896293254196644
#  batch 300 loss: 0.27611950278282166
#  batch 400 loss: 0.2795081539452076
# lr 1e-05 -> 1e-05
# Train accuracy 92.10000000000001:
# Test accuracy 92.10000000000001:
# EPOCH 93:
#  batch 100 loss: 0.2781592687964439
#  batch 200 loss: 0.274884556978941
#  batch 300 loss: 0.29251730293035505
#  batch 400 loss: 0.2776016294956207
# lr 1e-05 -> 1e-05
# Train accuracy 92.10000000000001:
# Test accuracy 92.10000000000001:
# EPOCH 94:
#  batch 100 loss: 0.27552927926182746
#  batch 200 loss: 0.28539649307727816
#  batch 300 loss: 0.2893220102787018
#  batch 400 loss: 0.2797736856341362
# lr 1e-05 -> 1e-05
# Train accuracy 92.10000000000001:
# Test accuracy 92.10000000000001:
# EPOCH 95:
#  batch 100 loss: 0.2815384161472321
#  batch 200 loss: 0.2814163160324097
#  batch 300 loss: 0.2748193797469139
#  batch 400 loss: 0.28568327337503435
# lr 1e-05 -> 1e-05
# Train accuracy 92.10000000000001:
# Test accuracy 92.10000000000001:
# EPOCH 96:
#  batch 100 loss: 0.26876758024096487
#  batch 200 loss: 0.28317221991717817
#  batch 300 loss: 0.2914500367641449
#  batch 400 loss: 0.27196210592985154
# lr 1e-05 -> 1e-05
# Train accuracy 92.10000000000001:
# Test accuracy 92.10000000000001:
# EPOCH 97:
#  batch 100 loss: 0.2782684980332851
#  batch 200 loss: 0.2835319077968597
#  batch 300 loss: 0.28199591755867004
#  batch 400 loss: 0.27882930800318717
# lr 1e-05 -> 1e-05
# Train accuracy 92.10000000000001:
# Test accuracy 92.10000000000001:
# EPOCH 98:
#  batch 100 loss: 0.28655148699879646
#  batch 200 loss: 0.2812479519844055
#  batch 300 loss: 0.27978722855448723
#  batch 400 loss: 0.27641700945794584
# lr 1e-05 -> 1e-05
# Train accuracy 92.10000000000001:
# Test accuracy 92.10000000000001:
# EPOCH 99:
#  batch 100 loss: 0.27557704694569113
#  batch 200 loss: 0.2913403187692165
#  batch 300 loss: 0.290849880874157
#  batch 400 loss: 0.2748322880268097
# lr 1e-05 -> 1e-05
# Train accuracy 92.10000000000001:
# Test accuracy 92.10000000000001:
# EPOCH 100:
#  batch 100 loss: 0.26676634073257444
#  batch 200 loss: 0.28120350137352945
#  batch 300 loss: 0.2760992219299078
#  batch 400 loss: 0.30728658884763715
# lr 1e-05 -> 1.0000000000000002e-06
# Train accuracy 92.10000000000001:
# Test accuracy 92.10000000000001:
# Reg Strength 1e-05:
# EPOCH 1:
#  batch 100 loss: 1.9691557455062867
#  batch 200 loss: 1.5071675276756287
#  batch 300 loss: 1.4112886011600494
#  batch 400 loss: 1.3697154140472412
# lr 0.01 -> 0.01
# Train accuracy 54.6:
# Test accuracy 55.2:
# EPOCH 2:
#  batch 100 loss: 1.317900265455246
#  batch 200 loss: 1.2732343542575837
#  batch 300 loss: 1.1881788790225982
#  batch 400 loss: 1.160825275182724
# lr 0.01 -> 0.01
# Train accuracy 61.7:
# Test accuracy 62.0:
# EPOCH 3:
#  batch 100 loss: 1.1145623695850373
#  batch 200 loss: 1.1130483078956603
#  batch 300 loss: 1.1120843362808228
#  batch 400 loss: 1.0259628123044968
# lr 0.01 -> 0.01
# Train accuracy 69.39999999999999:
# Test accuracy 69.89999999999999:
# EPOCH 4:
#  batch 100 loss: 0.9107098317146302
#  batch 200 loss: 0.9035578954219818
#  batch 300 loss: 0.8721351552009583
#  batch 400 loss: 0.8846641463041306
# lr 0.01 -> 0.01
# Train accuracy 70.1:
# Test accuracy 70.5:
# EPOCH 5:
#  batch 100 loss: 0.8545132315158844
#  batch 200 loss: 0.8602371525764465
#  batch 300 loss: 0.8541631710529327
#  batch 400 loss: 0.8425305849313736
# lr 0.01 -> 0.01
# Train accuracy 70.5:
# Test accuracy 70.8:
# EPOCH 6:
#  batch 100 loss: 0.8415353828668595
#  batch 200 loss: 0.8215492385625839
#  batch 300 loss: 0.8410071897506713
#  batch 400 loss: 0.8457880109548569
# lr 0.01 -> 0.01
# Train accuracy 70.6:
# Test accuracy 70.89999999999999:
# EPOCH 7:
#  batch 100 loss: 0.829729630947113
#  batch 200 loss: 0.8178552943468094
#  batch 300 loss: 0.8303444838523865
#  batch 400 loss: 0.8017616993188859
# lr 0.01 -> 0.01
# Train accuracy 70.89999999999999:
# Test accuracy 71.3:
# EPOCH 8:
#  batch 100 loss: 0.81645288169384
#  batch 200 loss: 0.8076641181111336
#  batch 300 loss: 0.8131179636716843
#  batch 400 loss: 0.8175850439071656
# lr 0.01 -> 0.01
# Train accuracy 70.89999999999999:
# Test accuracy 71.2:
# EPOCH 9:
#  batch 100 loss: 0.8113418257236481
#  batch 200 loss: 0.8086647725105286
#  batch 300 loss: 0.8000191640853882
#  batch 400 loss: 0.7937319278717041
# lr 0.01 -> 0.01
# Train accuracy 71.1:
# Test accuracy 71.39999999999999:
# EPOCH 10:
#  batch 100 loss: 0.7960669177770615
#  batch 200 loss: 0.7986882168054581
#  batch 300 loss: 0.7971698415279388
#  batch 400 loss: 0.810950111746788
# lr 0.01 -> 0.01
# Train accuracy 71.2:
# Test accuracy 71.6:
# EPOCH 11:
#  batch 100 loss: 0.8121480089426041
#  batch 200 loss: 0.7947430694103241
#  batch 300 loss: 0.7923678386211396
#  batch 400 loss: 0.7758678609132766
# lr 0.01 -> 0.01
# Train accuracy 71.39999999999999:
# Test accuracy 71.6:
# EPOCH 12:
#  batch 100 loss: 0.7790200638771058
#  batch 200 loss: 0.803713185787201
#  batch 300 loss: 0.7896935051679611
#  batch 400 loss: 0.7875898602604866
# lr 0.01 -> 0.01
# Train accuracy 71.39999999999999:
# Test accuracy 71.6:
# EPOCH 13:
#  batch 100 loss: 0.7833707171678543
#  batch 200 loss: 0.7851952573657036
#  batch 300 loss: 0.7833903723955155
#  batch 400 loss: 0.7947333592176438
# lr 0.01 -> 0.01
# Train accuracy 71.39999999999999:
# Test accuracy 71.6:
# EPOCH 14:
#  batch 100 loss: 0.7802046006917953
#  batch 200 loss: 0.7744829082489013
#  batch 300 loss: 0.7885085135698319
#  batch 400 loss: 0.786846998333931
# lr 0.01 -> 0.01
# Train accuracy 71.6:
# Test accuracy 71.8:
# EPOCH 15:
#  batch 100 loss: 0.7926105824112892
#  batch 200 loss: 0.7843350976705551
#  batch 300 loss: 0.7722732132673263
#  batch 400 loss: 0.7668194562196732
# lr 0.01 -> 0.01
# Train accuracy 71.6:
# Test accuracy 71.8:
# EPOCH 16:
#  batch 100 loss: 0.7700975176692009
#  batch 200 loss: 0.7847458881139755
#  batch 300 loss: 0.7741262429952621
#  batch 400 loss: 0.7761773759126663
# lr 0.01 -> 0.01
# Train accuracy 71.7:
# ...
#  batch 400 loss: 1.6478431367874145
# lr 0.001 -> 0.001
# Train accuracy 52.6:
# Test accuracy 52.900000000000006:
# EPOCH 28:
#  batch 100 loss: 1.6470231473445893
#  batch 200 loss: 1.6585446429252624
#  batch 300 loss: 1.6508059215545654
#  batch 400 loss: 1.6641534864902496
# lr 0.001 -> 0.001
# Train accuracy 52.6:
# Test accuracy 52.800000000000004:
# EPOCH 29:
#  batch 100 loss: 1.6487016081809998
#  batch 200 loss: 1.6536533880233764
#  batch 300 loss: 1.6540718638896943
#  batch 400 loss: 1.6566892099380492
# lr 0.001 -> 0.001
# Train accuracy 52.7:
# Test accuracy 52.900000000000006:
# EPOCH 30:
#  batch 100 loss: 1.652052789926529
#  batch 200 loss: 1.6518622624874115
#  batch 300 loss: 1.653691908121109
#  batch 400 loss: 1.6620524048805236
# lr 0.001 -> 0.001
# Train accuracy 52.7:
# Test accuracy 53.0:
# EPOCH 31:
#  batch 100 loss: 1.6522867941856385
#  batch 200 loss: 1.6585907185077666
#  batch 300 loss: 1.6513151931762695
#  batch 400 loss: 1.6589863789081574
# lr 0.001 -> 0.001
# Train accuracy 52.7:
# Test accuracy 53.0:
# EPOCH 32:
#  batch 100 loss: 1.6649733150005341
#  batch 200 loss: 1.655469044446945
#  batch 300 loss: 1.658533947467804
#  batch 400 loss: 1.6546073865890503
# lr 0.001 -> 0.001
# Train accuracy 52.7:
# Test accuracy 52.900000000000006:
# EPOCH 33:
#  batch 100 loss: 1.6621590387821197
#  batch 200 loss: 1.6496227514743804
#  batch 300 loss: 1.6620465469360353
#  batch 400 loss: 1.652192724943161
# lr 0.001 -> 0.001
# Train accuracy 52.7:
# Test accuracy 53.0:
# EPOCH 34:
#  batch 100 loss: 1.657439490556717
#  batch 200 loss: 1.6483102130889893
#  batch 300 loss: 1.654348316192627
#  batch 400 loss: 1.6608337700366973
# lr 0.001 -> 0.001
# Train accuracy 52.6:
# Test accuracy 52.800000000000004:
# EPOCH 35:
#  batch 100 loss: 1.649802829027176
#  batch 200 loss: 1.6510119223594666
#  batch 300 loss: 1.649469177722931
#  batch 400 loss: 1.6562397968769074
# lr 0.001 -> 0.001
# Train accuracy 52.7:
# Test accuracy 52.800000000000004:
# EPOCH 36:
#  batch 100 loss: 1.6642701303958893
#  batch 200 loss: 1.6495875644683837
#  batch 300 loss: 1.6491027617454528
#  batch 400 loss: 1.6646164500713347
# lr 0.001 -> 0.001
# Train accuracy 52.6:
# Test accuracy 52.900000000000006:
# EPOCH 37:
#  batch 100 loss: 1.6489430046081544
#  batch 200 loss: 1.6485707128047944
#  batch 300 loss: 1.6604984664916993
#  batch 400 loss: 1.6582197010517121
# lr 0.001 -> 0.001
# Train accuracy 52.6:
# Test accuracy 52.900000000000006:
# EPOCH 38:
#  batch 100 loss: 1.6528131973743438
#  batch 200 loss: 1.6579348134994507
#  batch 300 loss: 1.664523767232895
#  batch 400 loss: 1.6555324947834016
# lr 0.001 -> 0.001
# Train accuracy 52.6:
# Test accuracy 53.0:
# EPOCH 39:
#  batch 100 loss: 1.6586705577373504
#  batch 200 loss: 1.6404093241691589
#  batch 300 loss: 1.6670304536819458
#  batch 400 loss: 1.6583633887767792
# lr 0.001 -> 0.001
# Train accuracy 52.7:
# Test accuracy 52.900000000000006:
# EPOCH 40:
#  batch 100 loss: 1.6531042766571045
#  batch 200 loss: 1.6532398748397827
#  batch 300 loss: 1.6661975705623626
#  batch 400 loss: 1.653930835723877
# lr 0.001 -> 0.001
# Train accuracy 52.6:
# Test accuracy 52.800000000000004:
# EPOCH 41:
#  batch 100 loss: 1.6584594750404358
#  batch 200 loss: 1.6539780926704406
#  batch 300 loss: 1.6555935442447662
#  batch 400 loss: 1.660341304540634
# lr 0.001 -> 0.001
# Train accuracy 52.6:
# Test accuracy 52.800000000000004:
# EPOCH 42:
#  batch 100 loss: 1.6541061842441558
#  batch 200 loss: 1.661613371372223
#  batch 300 loss: 1.640884029865265
#  batch 400 loss: 1.664476969242096
# lr 0.001 -> 0.001
# Train accuracy 52.6:
# Test accuracy 52.900000000000006:
# EPOCH 43:
#  batch 100 loss: 1.6513568782806396
#  batch 200 loss: 1.6500307369232177
#  batch 300 loss: 1.6653059256076812
#  batch 400 loss: 1.6577386951446533
# lr 0.001 -> 0.001
# Train accuracy 52.7:
# Test accuracy 52.900000000000006:
# EPOCH 44:
#  batch 100 loss: 1.6532117331027985
#  batch 200 loss: 1.666380136013031
#  batch 300 loss: 1.6600817954540252
#  batch 400 loss: 1.6456121122837066
# lr 0.001 -> 0.001
# Train accuracy 52.7:
# Test accuracy 52.900000000000006:
# EPOCH 45:
#  batch 100 loss: 1.6634339916706085
#  batch 200 loss: 1.6483587741851806
#  batch 300 loss: 1.6515003037452698
#  batch 400 loss: 1.6601709508895874
# lr 0.001 -> 0.001
# Train accuracy 52.6:
# Test accuracy 52.800000000000004:
# EPOCH 46:
#  batch 100 loss: 1.6596365749835968
#  batch 200 loss: 1.6611858093738556
#  batch 300 loss: 1.6656751537322998
#  batch 400 loss: 1.6480124723911285
# lr 0.001 -> 0.001
# Train accuracy 52.7:
# Test accuracy 53.0:
# EPOCH 47:
#  batch 100 loss: 1.65855446100235
#  batch 200 loss: 1.6588942444324493
#  batch 300 loss: 1.6461833429336548
#  batch 400 loss: 1.6570088064670563
# lr 0.001 -> 0.001
# Train accuracy 52.6:
# Test accuracy 52.900000000000006:
# EPOCH 48:
#  batch 100 loss: 1.6509140086174012
#  batch 200 loss: 1.6517146146297454
#  batch 300 loss: 1.6648469471931457
#  batch 400 loss: 1.6607917189598083
# lr 0.001 -> 0.001
# Train accuracy 52.7:
# Test accuracy 53.0:
# EPOCH 49:
#  batch 100 loss: 1.6543338978290558
#  batch 200 loss: 1.648769997358322
#  batch 300 loss: 1.6688053846359252
#  batch 400 loss: 1.6571893668174744
# lr 0.001 -> 0.001
# Train accuracy 52.6:
# Test accuracy 53.0:
# EPOCH 50:
#  batch 100 loss: 1.6683200538158416
#  batch 200 loss: 1.6606090986728668
#  batch 300 loss: 1.6567088234424592
#  batch 400 loss: 1.645870418548584
# lr 0.001 -> 0.0001
# Train accuracy 52.7:
# Test accuracy 52.900000000000006:
# EPOCH 51:
#  batch 100 loss: 1.6510645639896393
#  batch 200 loss: 1.662144751548767
#  batch 300 loss: 1.657081356048584
#  batch 400 loss: 1.6467701995372772
# lr 0.0001 -> 0.0001
# Train accuracy 52.7:
# Test accuracy 52.900000000000006:
# EPOCH 52:
#  batch 100 loss: 1.6496172785758971
#  batch 200 loss: 1.648397147655487
#  batch 300 loss: 1.666834877729416
#  batch 400 loss: 1.656231529712677
# lr 0.0001 -> 0.0001
# Train accuracy 52.7:
# Test accuracy 52.900000000000006:
# EPOCH 53:
#  batch 100 loss: 1.6543234360218049
#  batch 200 loss: 1.652827694416046
#  batch 300 loss: 1.6564976179599762
#  batch 400 loss: 1.652962168455124
# lr 0.0001 -> 0.0001
# Train accuracy 52.7:
# Test accuracy 52.900000000000006:
# EPOCH 54:
#  batch 100 loss: 1.6622334980964661
#  batch 200 loss: 1.649512333869934
#  batch 300 loss: 1.6607965111732483
#  batch 400 loss: 1.655208067893982
# lr 0.0001 -> 0.0001
# Train accuracy 52.7:
# Test accuracy 53.0:
# EPOCH 55:
#  batch 100 loss: 1.657356346845627
#  batch 200 loss: 1.6572917258739472
#  batch 300 loss: 1.650651398897171
#  batch 400 loss: 1.6566626024246216
# lr 0.0001 -> 0.0001
# Train accuracy 52.7:
# Test accuracy 52.900000000000006:
# EPOCH 56:
#  batch 100 loss: 1.6510633599758149
#  batch 200 loss: 1.6549052965641022
#  batch 300 loss: 1.660959689617157
#  batch 400 loss: 1.6547917819023132
# lr 0.0001 -> 0.0001
# Train accuracy 52.7:
# Test accuracy 53.0:
# EPOCH 57:
#  batch 100 loss: 1.6582562601566315
#  batch 200 loss: 1.6512095069885253
#  batch 300 loss: 1.6532981967926026
#  batch 400 loss: 1.6577481889724732
# lr 0.0001 -> 0.0001
# Train accuracy 52.7:
# Test accuracy 53.0:
# EPOCH 58:
#  batch 100 loss: 1.6513626217842101
#  batch 200 loss: 1.649840887784958
#  batch 300 loss: 1.6618865644931793
#  batch 400 loss: 1.6609756815433503
# lr 0.0001 -> 0.0001
# Train accuracy 52.7:
# Test accuracy 53.0:
# EPOCH 59:
#  batch 100 loss: 1.651958510875702
#  batch 200 loss: 1.6515139031410218
#  batch 300 loss: 1.6564864575862885
#  batch 400 loss: 1.6601616978645324
# lr 0.0001 -> 0.0001
# Train accuracy 52.7:
# Test accuracy 53.0:
# EPOCH 60:
#  batch 100 loss: 1.6560849046707153
#  batch 200 loss: 1.6523383581638336
#  batch 300 loss: 1.6523386645317077
#  batch 400 loss: 1.6621319246292114
# lr 0.0001 -> 0.0001
# Train accuracy 52.7:
# Test accuracy 53.0:
# EPOCH 61:
#  batch 100 loss: 1.6504178833961487
#  batch 200 loss: 1.6605359268188478
#  batch 300 loss: 1.656713035106659
#  batch 400 loss: 1.657650624513626
# lr 0.0001 -> 0.0001
# Train accuracy 52.7:
# Test accuracy 53.0:
# EPOCH 62:
#  batch 100 loss: 1.6650586640834808
#  batch 200 loss: 1.6574630570411681
#  batch 300 loss: 1.646011801958084
#  batch 400 loss: 1.6491389346122742
# lr 0.0001 -> 0.0001
# Train accuracy 52.7:
# Test accuracy 53.0:
# EPOCH 63:
#  batch 100 loss: 1.6561813354492188
#  batch 200 loss: 1.6458640062808991
#  batch 300 loss: 1.6673906338214874
#  batch 400 loss: 1.651297378540039
# lr 0.0001 -> 0.0001
# Train accuracy 52.7:
# Test accuracy 52.900000000000006:
# EPOCH 64:
#  batch 100 loss: 1.660119539499283
#  batch 200 loss: 1.6595575678348542
#  batch 300 loss: 1.649417097568512
#  batch 400 loss: 1.6457522177696229
# lr 0.0001 -> 0.0001
# Train accuracy 52.7:
# Test accuracy 52.900000000000006:
# EPOCH 65:
#  batch 100 loss: 1.664530919790268
#  batch 200 loss: 1.6600821840763091
#  batch 300 loss: 1.6539975476264954
#  batch 400 loss: 1.6473107194900514
# lr 0.0001 -> 0.0001
# Train accuracy 52.7:
# Test accuracy 52.900000000000006:
# EPOCH 66:
#  batch 100 loss: 1.655395392179489
#  batch 200 loss: 1.6491888105869292
#  batch 300 loss: 1.6521005153656005
#  batch 400 loss: 1.6644744718074798
# lr 0.0001 -> 0.0001
# Train accuracy 52.7:
# Test accuracy 53.0:
# EPOCH 67:
#  batch 100 loss: 1.643821234703064
#  batch 200 loss: 1.6513028454780578
#  batch 300 loss: 1.6671630036830902
#  batch 400 loss: 1.6541375529766082
# lr 0.0001 -> 0.0001
# Train accuracy 52.7:
# Test accuracy 53.0:
# EPOCH 68:
#  batch 100 loss: 1.6511518132686616
#  batch 200 loss: 1.6672830057144166
#  batch 300 loss: 1.663245018720627
#  batch 400 loss: 1.6434778988361358
# lr 0.0001 -> 0.0001
# Train accuracy 52.7:
# Test accuracy 53.0:
# EPOCH 69:
#  batch 100 loss: 1.645615544319153
#  batch 200 loss: 1.6564725470542907
#  batch 300 loss: 1.6590176606178284
#  batch 400 loss: 1.657992079257965
# lr 0.0001 -> 0.0001
# Train accuracy 52.7:
# Test accuracy 52.900000000000006:
# EPOCH 70:
#  batch 100 loss: 1.657798137664795
#  batch 200 loss: 1.644957286119461
#  batch 300 loss: 1.6594622910022736
#  batch 400 loss: 1.6543324947357179
# lr 0.0001 -> 0.0001
# Train accuracy 52.7:
# Test accuracy 53.0:
# EPOCH 71:
#  batch 100 loss: 1.655702213048935
#  batch 200 loss: 1.6545064151287079
#  batch 300 loss: 1.6569918715953826
#  batch 400 loss: 1.6593063247203828
# lr 0.0001 -> 0.0001
# Train accuracy 52.7:
# Test accuracy 53.0:
# EPOCH 72:
#  batch 100 loss: 1.653253014087677
#  batch 200 loss: 1.6424122583866119
#  batch 300 loss: 1.6690072059631347
#  batch 400 loss: 1.6533059978485107
# lr 0.0001 -> 0.0001
# Train accuracy 52.7:
# Test accuracy 53.0:
# EPOCH 73:
#  batch 100 loss: 1.6594117772579193
#  batch 200 loss: 1.6578187596797944
#  batch 300 loss: 1.6540947616100312
#  batch 400 loss: 1.6510992383956908
# lr 0.0001 -> 0.0001
# Train accuracy 52.7:
# Test accuracy 53.0:
# EPOCH 74:
#  batch 100 loss: 1.653387508392334
#  batch 200 loss: 1.654533063173294
#  batch 300 loss: 1.647113528251648
#  batch 400 loss: 1.6594979453086853
# lr 0.0001 -> 0.0001
# Train accuracy 52.7:
# Test accuracy 53.0:
# EPOCH 75:
#  batch 100 loss: 1.6586449539661408
#  batch 200 loss: 1.6552297472953796
#  batch 300 loss: 1.6626427280902862
#  batch 400 loss: 1.6422707664966583
# lr 0.0001 -> 1e-05
# Train accuracy 52.7:
# Test accuracy 52.900000000000006:
# EPOCH 76:
#  batch 100 loss: 1.6560350620746613
#  batch 200 loss: 1.6613720679283142
#  batch 300 loss: 1.647265943288803
#  batch 400 loss: 1.651445107460022
# lr 1e-05 -> 1e-05
# Train accuracy 52.7:
# Test accuracy 53.0:
# EPOCH 77:
#  batch 100 loss: 1.6529605853557587
#  batch 200 loss: 1.654329787492752
#  batch 300 loss: 1.6423973667621612
#  batch 400 loss: 1.665075798034668
# lr 1e-05 -> 1e-05
# Train accuracy 52.7:
# Test accuracy 53.0:
# EPOCH 78:
#  batch 100 loss: 1.6637693738937378
#  batch 200 loss: 1.6515432500839233
#  batch 300 loss: 1.6540728080272675
#  batch 400 loss: 1.659062772989273
# lr 1e-05 -> 1e-05
# Train accuracy 52.7:
# Test accuracy 53.0:
# EPOCH 79:
#  batch 100 loss: 1.6580722784996034
#  batch 200 loss: 1.6586310911178588
#  batch 300 loss: 1.6335305106639861
#  batch 400 loss: 1.6668921387195588
# lr 1e-05 -> 1e-05
# Train accuracy 52.7:
# Test accuracy 53.0:
# EPOCH 80:
#  batch 100 loss: 1.6622588324546814
#  batch 200 loss: 1.643618437051773
#  batch 300 loss: 1.6620128738880158
#  batch 400 loss: 1.662762610912323
# lr 1e-05 -> 1e-05
# Train accuracy 52.7:
# Test accuracy 53.0:
# EPOCH 81:
#  batch 100 loss: 1.6641224360466003
#  batch 200 loss: 1.6478784716129302
#  batch 300 loss: 1.657495824098587
#  batch 400 loss: 1.657628012895584
# lr 1e-05 -> 1e-05
# Train accuracy 52.7:
# Test accuracy 53.0:
# EPOCH 82:
#  batch 100 loss: 1.651264716386795
#  batch 200 loss: 1.6664041936397553
#  batch 300 loss: 1.6553347945213317
#  batch 400 loss: 1.6469201755523681
# lr 1e-05 -> 1e-05
# Train accuracy 52.7:
# Test accuracy 53.0:
# EPOCH 83:
#  batch 100 loss: 1.6615561985969542
#  batch 200 loss: 1.6452756893634797
#  batch 300 loss: 1.652763043642044
#  batch 400 loss: 1.649997682571411
# lr 1e-05 -> 1e-05
# Train accuracy 52.7:
# Test accuracy 53.0:
# EPOCH 84:
#  batch 100 loss: 1.6660278785228728
#  batch 200 loss: 1.6464767408370973
#  batch 300 loss: 1.6563086557388305
#  batch 400 loss: 1.6553664672374726
# lr 1e-05 -> 1e-05
# Train accuracy 52.7:
# Test accuracy 53.0:
# EPOCH 85:
#  batch 100 loss: 1.6614355981349944
#  batch 200 loss: 1.655625697374344
#  batch 300 loss: 1.6567522442340852
#  batch 400 loss: 1.65434494972229
# lr 1e-05 -> 1e-05
# Train accuracy 52.7:
# Test accuracy 53.0:
# EPOCH 86:
#  batch 100 loss: 1.6532970452308655
#  batch 200 loss: 1.6437482845783233
#  batch 300 loss: 1.654346525669098
#  batch 400 loss: 1.6679030108451842
# lr 1e-05 -> 1e-05
# Train accuracy 52.7:
# Test accuracy 53.0:
# EPOCH 87:
#  batch 100 loss: 1.6617734742164612
#  batch 200 loss: 1.6425301265716552
#  batch 300 loss: 1.659803831577301
#  batch 400 loss: 1.659381595849991
# lr 1e-05 -> 1e-05
# Train accuracy 52.7:
# Test accuracy 53.0:
# EPOCH 88:
#  batch 100 loss: 1.659573403596878
#  batch 200 loss: 1.6568117666244506
#  batch 300 loss: 1.6613491880893707
#  batch 400 loss: 1.645655779838562
# lr 1e-05 -> 1e-05
# Train accuracy 52.7:
# Test accuracy 53.0:
# EPOCH 89:
#  batch 100 loss: 1.652393479347229
#  batch 200 loss: 1.663337118625641
#  batch 300 loss: 1.6541076469421387
#  batch 400 loss: 1.6541576874256134
# lr 1e-05 -> 1e-05
# Train accuracy 52.7:
# Test accuracy 53.0:
# EPOCH 90:
#  batch 100 loss: 1.6523884320259095
#  batch 200 loss: 1.6599373078346253
#  batch 300 loss: 1.6548371803760529
#  batch 400 loss: 1.6518029236793519
# lr 1e-05 -> 1e-05
# Train accuracy 52.7:
# Test accuracy 53.0:
# EPOCH 91:
#  batch 100 loss: 1.6556728374958039
#  batch 200 loss: 1.6591583824157714
#  batch 300 loss: 1.651318587064743
#  batch 400 loss: 1.6512787961959838
# lr 1e-05 -> 1e-05
# Train accuracy 52.7:
# Test accuracy 53.0:
# EPOCH 92:
#  batch 100 loss: 1.6503553760051728
#  batch 200 loss: 1.6720698428153993
#  batch 300 loss: 1.6515446352958678
#  batch 400 loss: 1.6567731702327728
# lr 1e-05 -> 1e-05
# Train accuracy 52.7:
# Test accuracy 53.0:
# EPOCH 93:
#  batch 100 loss: 1.6537275981903077
#  batch 200 loss: 1.6547644197940827
#  batch 300 loss: 1.6580391371250152
#  batch 400 loss: 1.6547629678249358
# lr 1e-05 -> 1e-05
# Train accuracy 52.7:
# Test accuracy 53.0:
# EPOCH 94:
#  batch 100 loss: 1.6593880212306977
#  batch 200 loss: 1.6555818045139312
#  batch 300 loss: 1.6509054970741273
#  batch 400 loss: 1.6511976027488708
# lr 1e-05 -> 1e-05
# Train accuracy 52.7:
# Test accuracy 53.0:
# EPOCH 95:
#  batch 100 loss: 1.657542461156845
#  batch 200 loss: 1.6593096625804902
#  batch 300 loss: 1.6429931759834289
#  batch 400 loss: 1.662812225818634
# lr 1e-05 -> 1e-05
# Train accuracy 52.7:
# Test accuracy 53.0:
# EPOCH 96:
#  batch 100 loss: 1.657872008085251
#  batch 200 loss: 1.6557919681072235
#  batch 300 loss: 1.662842057943344
#  batch 400 loss: 1.644021714925766
# lr 1e-05 -> 1e-05
# Train accuracy 52.7:
# Test accuracy 53.0:
# EPOCH 97:
#  batch 100 loss: 1.652346876859665
#  batch 200 loss: 1.6551978421211242
#  batch 300 loss: 1.648972373008728
#  batch 400 loss: 1.6578278565406799
# lr 1e-05 -> 1e-05
# Train accuracy 52.7:
# Test accuracy 53.0:
# EPOCH 98:
#  batch 100 loss: 1.6457302975654602
#  batch 200 loss: 1.6566805493831636
#  batch 300 loss: 1.659644422531128
#  batch 400 loss: 1.6593671870231628
# lr 1e-05 -> 1e-05
# Train accuracy 52.7:
# Test accuracy 53.0:
# EPOCH 99:
#  batch 100 loss: 1.6689118194580077
#  batch 200 loss: 1.6411065888404845
#  batch 300 loss: 1.6525161719322206
#  batch 400 loss: 1.6581926798820497
# lr 1e-05 -> 1e-05
# Train accuracy 52.7:
# Test accuracy 53.0:
# EPOCH 100:
#  batch 100 loss: 1.649049892425537
#  batch 200 loss: 1.6528476190567016
#  batch 300 loss: 1.654343568086624
#  batch 400 loss: 1.6613408041000366
# lr 1e-05 -> 1.0000000000000002e-06
# Train accuracy 52.7:
# Test accuracy 53.0:

# %%
import numpy as np
epochs_arr = np.arange(0, len(losses_arr[0]))

# %%
# Plot training loss
x = np.array(epochs_arr)
for i,train_loss in enumerate(losses_arr):
  ypoints = np.array(train_loss)
  plt.plot(x, ypoints, label = regularization_strengths[i])

plt.xlabel("Epochs")
plt.ylabel("train Loss")
plt.legend()
plt.title('LR=0.01, Scheduler=Step, Batch_size=128, Optimizer=SGD, L2 Regularization')
plt.show()

# %%
# Plot training accuracy
x = np.array(epochs_arr)
for i,train_acc in enumerate(train_accuracy_arr):
  ypoints = np.array(train_acc)
  plt.plot(x, ypoints, label = regularization_strengths[i])

plt.xlabel("Epochs")
plt.ylabel("train Accuracy")
plt.legend()
plt.title('LR=0.01, Scheduler=Plateau, Batch_size=128, Optimizer=SGD, L2 Regularization')
plt.show()

# %%
# Plot test accuracy
x = np.array(epochs_arr)
for i,test_acc in enumerate(test_accuracy_arr):
  ypoints = np.array(test_acc)
  plt.plot(x, ypoints, label = regularization_strengths[i])

plt.xlabel("Epochs")
plt.ylabel("test Accuracy")
plt.legend()
plt.title('LR=0.01, Scheduler=Plateau, Batch_size=128, Optimizer=SGD, L2 Regularization')
plt.show()

# %%
# Plot test and training accuracy
x = np.array(epochs_arr)
for i,reg in enumerate(regularization_strengths):
  ypoints_1 = np.array(train_accuracy_arr[i])
  ypoints_2 = np.array(test_accuracy_arr[i])
  plt.plot(x, ypoints_1, label = 'Train')
  plt.plot(x, ypoints_2, label = 'Test')
  plt.xlabel("Epochs")
  plt.ylabel("Accuracy")
  plt.legend()
  plt.title(F'LR=0.01, Scheduler=Plateau, Batch_size=128, Optimizer=SGD, L2 Regularization={reg}')
  plt.show()

# %% [markdown]
# ### Load model

# %%
model_save_name = '1695168105559.8071_Step_bs128_e30_SGD_ss10_gamma0.1_cifar'
path = F"{model_save_name}.pt"
net.load_state_dict(t.load(path))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 from google.colab import drive
#       2 drive.mount('/content/drive/')
#       3 model_save_name = '1695168105559.8071_Step_bs128_e30_SGD_ss10_gamma0.1_cifar'
#
# ModuleNotFoundError: No module named 'google.colab'

# %%
test(net,test_loader)

# %%
#hello kuch likhlo warna inactivity timeout de dega yeh

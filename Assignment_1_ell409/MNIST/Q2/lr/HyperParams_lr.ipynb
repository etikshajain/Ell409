# %%
import torch as t
import torchvision.datasets as datasets
import torchvision.transforms as transforms
import torch.nn as nn
import matplotlib.pyplot as plt
import torch.optim as optim
import torch.optim.lr_scheduler as lr_scheduler
from torch.optim.lr_scheduler import ReduceLROnPlateau, StepLR, ExponentialLR

# %% [markdown]
# ### Model

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net,self).__init__()
        self.linear1 = nn.Linear(28*28, 10)
        self.relu = nn.ReLU()

    def forward(self, img): #convert + flatten
        x = img.view(-1, 28*28)
        x = self.relu(self.linear1(x))
        return x
net = Net()

# %% [markdown]
# ### Hyperparams

# %%
num_epochs=60
after_every=100
loss_fn = nn.CrossEntropyLoss()
batch_size=128

# %%
import ssl
ssl._create_default_https_context = ssl._create_unverified_context
transform = transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.5,), (0.5,)),])

mnist_trainset = datasets.MNIST(root='./data', train=True, download=True, transform=transform)
train_loader = t.utils.data.DataLoader(mnist_trainset, batch_size=batch_size, shuffle=True)

mnist_testset = datasets.MNIST(root='./data', train=False, download=True, transform=transform)
test_loader = t.utils.data.DataLoader(mnist_testset, batch_size=batch_size, shuffle=True)

# %% [markdown]
# ### Training

# %%
def train_one_epoch(model, epoch_index, optimizer, train_dataset):
    running_loss = 0.
    last_loss = 0.

    for i, data in enumerate(train_dataset):
        # Every data instance is an input + label pair
        # data.shape=torch.Size([10, 1, 28, 28]) --> 10 images,labels
        inputs, labels = data

        # Zero your gradients for every batch!
        optimizer.zero_grad()

        # Make predictions for this batch
        outputs = model(inputs.view(-1, 28*28))


        # Compute the loss and its gradients
        loss = loss_fn(outputs, labels)
        loss.backward()

        # Adjust learning weights
        optimizer.step()

        # Gather data and report
        running_loss += loss.item()

        if i % after_every == after_every-1:
            last_loss = running_loss / after_every # loss per after_every batches
            print(' batch {} loss: {}'.format(i + 1, last_loss))
            running_loss = 0.

    return last_loss

# %% [markdown]
# ### Evaluate

# %%
def test(model, loader):
  total=0
  correct=0
  model.eval()
  with t.no_grad():
      for data in loader:
          x, y = data
          output = model(x.view(-1, 28*28))
          for idx, i in enumerate(output):
              if t.argmax(i) == y[idx]:
                  correct +=1
              total +=1
  return round(correct/total, 3)*100

# %%
def train_model(model, epochs, train_dataset, test_dataset, optimizer, scheduler, LR_type):
  epoch_number = 0

  losses = []
  train_accuracy = []
  test_accuracy = []

  for epoch in range(epochs):
      print('EPOCH {}:'.format(epoch_number + 1))

      # Make sure gradient tracking is on, and do a pass over the data
      model.train(True)
      avg_loss = train_one_epoch(model, epoch_number,optimizer,train_dataset)
      losses.append(avg_loss)

      # Train accuracy
      train_acc = test(model, train_dataset)
      train_accuracy.append(train_acc)

      # Test accuracy
      test_acc = test(model, test_dataset)
      test_accuracy.append(test_acc)

      if LR_type=='Plateau':
        before_lr = optimizer.param_groups[0]["lr"]
        scheduler.step(avg_loss)
        after_lr = optimizer.param_groups[0]["lr"]
        print('lr {} -> {}'.format(before_lr, after_lr))

      elif LR_type!='None':
        before_lr = optimizer.param_groups[0]["lr"]
        scheduler.step()
        after_lr = optimizer.param_groups[0]["lr"]
        print('lr {} -> {}'.format(before_lr, after_lr))

      print('Train accuracy {}:'.format(train_acc))
      print('Test accuracy {}:'.format(test_acc))
      epoch_number += 1
  return losses, train_accuracy, test_accuracy

# %%
import datetime as dt
lrs = [1, 0.1, 0.01, 1e-3, 1e-5, 1e-7]
def train_with_lr():
  losses_arr = []
  train_accuracy_arr = []
  test_accuracy_arr = []
  description = []

  # Different learning rates
  for lr in lrs:
    print('Learning Rate {}:'.format(lr))
    net_new = Net()
    optimizerr = t.optim.SGD(net_new.parameters(), lr=lr)

    losses, train_accuracy, test_accuracy = train_model(net_new, num_epochs, train_loader, test_loader, optimizerr, '', 'None')

    losses_arr.append(losses)
    train_accuracy_arr.append(train_accuracy)
    test_accuracy_arr.append(test_accuracy)
    description.append('LR:{}'.format(lr))

    # save model
    ts_now = dt.datetime.now()
    unix_timestamp = dt.datetime.timestamp(ts_now)*1000
    model_save_name = str(unix_timestamp)
    path = F"{model_save_name}_LR={lr}_bs{128}_e{num_epochs}_SGD_.pt"
    t.save(net.state_dict(), path)

  return description, losses_arr, train_accuracy_arr, test_accuracy_arr

# %%
import csv
def save_to_csv(filename, description, losses_arr, train_acc_arr, test_acc_arr):
  # Create a CSV file and write data to it
  with open(filename+'.csv', 'w', newline='') as csvfile:
    for i, desc in enumerate(description):
      fieldnames = ['Description', 'epoch', 'train_loss', 'train_accuracy', 'test_accuracy']
      writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
      writer.writeheader()
      for epoch, (loss, train, test) in enumerate(zip(losses_arr[i], train_acc_arr[i], test_acc_arr[i]), 1):
          writer.writerow({'Description':description[i], 'epoch': epoch, 'train_loss': loss, 'train_accuracy': train, 'test_accuracy': test})

# %% [markdown]
# ### Plotting-

# %%
description, losses_arr, train_accuracy_arr, test_accuracy_arr = train_with_lr()
save_to_csv('lr', description, losses_arr, train_accuracy_arr, test_accuracy_arr)
# Out:
# Learning Rate 1:
# EPOCH 1:
#  batch 100 loss: 4.668749442100525
#  batch 200 loss: 2.3025853633880615
#  batch 300 loss: 2.3025853633880615
#  batch 400 loss: 2.3025853633880615
# Train accuracy 9.9:
# Test accuracy 9.8:
# EPOCH 2:
#  batch 100 loss: 2.3025853633880615
#  batch 200 loss: 2.3025853633880615
#  batch 300 loss: 2.3025853633880615
#  batch 400 loss: 2.3025853633880615
# Train accuracy 9.9:
# Test accuracy 9.8:
# EPOCH 3:
#  batch 100 loss: 2.3025853633880615
#  batch 200 loss: 2.3025853633880615
#  batch 300 loss: 2.3025853633880615
#  batch 400 loss: 2.3025853633880615
# Train accuracy 9.9:
# Test accuracy 9.8:
# EPOCH 4:
#  batch 100 loss: 2.3025853633880615
#  batch 200 loss: 2.3025853633880615
#  batch 300 loss: 2.3025853633880615
#  batch 400 loss: 2.3025853633880615
# Train accuracy 9.9:
# Test accuracy 9.8:
# EPOCH 5:
#  batch 100 loss: 2.3025853633880615
#  batch 200 loss: 2.3025853633880615
#  batch 300 loss: 2.3025853633880615
#  batch 400 loss: 2.3025853633880615
# Train accuracy 9.9:
# Test accuracy 9.8:
# EPOCH 6:
#  batch 100 loss: 2.3025853633880615
#  batch 200 loss: 2.3025853633880615
#  batch 300 loss: 2.3025853633880615
#  batch 400 loss: 2.3025853633880615
# Train accuracy 9.9:
# Test accuracy 9.8:
# EPOCH 7:
#  batch 100 loss: 2.3025853633880615
#  batch 200 loss: 2.3025853633880615
#  batch 300 loss: 2.3025853633880615
#  batch 400 loss: 2.3025853633880615
# Train accuracy 9.9:
# Test accuracy 9.8:
# EPOCH 8:
#  batch 100 loss: 2.3025853633880615
#  batch 200 loss: 2.3025853633880615
#  batch 300 loss: 2.3025853633880615
#  batch 400 loss: 2.3025853633880615
# Train accuracy 9.9:
# Test accuracy 9.8:
# EPOCH 9:
#  batch 100 loss: 2.3025853633880615
#  batch 200 loss: 2.3025853633880615
#  batch 300 loss: 2.3025853633880615
#  batch 400 loss: 2.3025853633880615
# Train accuracy 9.9:
# Test accuracy 9.8:
# EPOCH 10:
#  batch 100 loss: 2.3025853633880615
#  batch 200 loss: 2.3025853633880615
#  batch 300 loss: 2.3025853633880615
#  batch 400 loss: 2.3025853633880615
# Train accuracy 9.9:
# Test accuracy 9.8:
# EPOCH 11:
#  batch 100 loss: 2.3025853633880615
#  batch 200 loss: 2.3025853633880615
#  batch 300 loss: 2.3025853633880615
#  batch 400 loss: 2.3025853633880615
# Train accuracy 9.9:
# Test accuracy 9.8:
# EPOCH 12:
#  batch 100 loss: 2.3025853633880615
#  batch 200 loss: 2.3025853633880615
#  batch 300 loss: 2.3025853633880615
#  batch 400 loss: 2.3025853633880615
# Train accuracy 9.9:
# Test accuracy 9.8:
# EPOCH 13:
#  batch 100 loss: 2.3025853633880615
#  batch 200 loss: 2.3025853633880615
#  batch 300 loss: 2.3025853633880615
#  batch 400 loss: 2.3025853633880615
# Train accuracy 9.9:
# Test accuracy 9.8:
# EPOCH 14:
#  batch 100 loss: 2.3025853633880615
#  batch 200 loss: 2.3025853633880615
#  batch 300 loss: 2.3025853633880615
#  batch 400 loss: 2.3025853633880615
# Train accuracy 9.9:
# Test accuracy 9.8:
# EPOCH 15:
#  batch 100 loss: 2.3025853633880615
#  batch 200 loss: 2.3025853633880615
#  batch 300 loss: 2.3025853633880615
#  batch 400 loss: 2.3025853633880615
# Train accuracy 9.9:
# Test accuracy 9.8:
# EPOCH 16:
#  batch 100 loss: 2.3025853633880615
#  batch 200 loss: 2.3025853633880615
#  batch 300 loss: 2.3025853633880615
#  batch 400 loss: 2.3025853633880615
# Train accuracy 9.9:
# Test accuracy 9.8:
# EPOCH 17:
#  batch 100 loss: 2.3025853633880615
#  batch 200 loss: 2.3025853633880615
#  batch 300 loss: 2.3025853633880615
#  batch 400 loss: 2.3025853633880615
# Train accuracy 9.9:
# Test accuracy 9.8:
# EPOCH 18:
#  batch 100 loss: 2.3025853633880615
#  batch 200 loss: 2.3025853633880615
#  batch 300 loss: 2.3025853633880615
#  batch 400 loss: 2.3025853633880615
# Train accuracy 9.9:
# Test accuracy 9.8:
# EPOCH 19:
#  batch 100 loss: 2.3025853633880615
#  batch 200 loss: 2.3025853633880615
#  batch 300 loss: 2.3025853633880615
#  batch 400 loss: 2.3025853633880615
# Train accuracy 9.9:
# Test accuracy 9.8:
# EPOCH 20:
#  batch 100 loss: 2.3025853633880615
#  batch 200 loss: 2.3025853633880615
#  batch 300 loss: 2.3025853633880615
#  batch 400 loss: 2.3025853633880615
# Train accuracy 9.9:
# Test accuracy 9.8:
# EPOCH 21:
#  batch 100 loss: 2.3025853633880615
#  batch 200 loss: 2.3025853633880615
#  batch 300 loss: 2.3025853633880615
#  batch 400 loss: 2.3025853633880615
# Train accuracy 9.9:
# Test accuracy 9.8:
# EPOCH 22:
#  batch 100 loss: 2.3025853633880615
#  batch 200 loss: 2.3025853633880615
#  batch 300 loss: 2.3025853633880615
#  batch 400 loss: 2.3025853633880615
# Train accuracy 9.9:
# Test accuracy 9.8:
# EPOCH 23:
#  batch 100 loss: 2.3025853633880615
#  batch 200 loss: 2.3025853633880615
#  batch 300 loss: 2.3025853633880615
#  batch 400 loss: 2.3025853633880615
# Train accuracy 9.9:
# Test accuracy 9.8:
# EPOCH 24:
#  batch 100 loss: 2.3025853633880615
#  batch 200 loss: 2.3025853633880615
#  batch 300 loss: 2.3025853633880615
#  batch 400 loss: 2.3025853633880615
# Train accuracy 9.9:
# Test accuracy 9.8:
# EPOCH 25:
#  batch 100 loss: 2.3025853633880615
#  batch 200 loss: 2.3025853633880615
#  batch 300 loss: 2.3025853633880615
#  batch 400 loss: 2.3025853633880615
# Train accuracy 9.9:
# Test accuracy 9.8:
# EPOCH 26:
#  batch 100 loss: 2.3025853633880615
#  batch 200 loss: 2.3025853633880615
#  batch 300 loss: 2.3025853633880615
#  batch 400 loss: 2.3025853633880615
# Train accuracy 9.9:
# Test accuracy 9.8:
# EPOCH 27:
#  batch 100 loss: 2.3025853633880615
#  batch 200 loss: 2.3025853633880615
#  batch 300 loss: 2.3025853633880615
#  batch 400 loss: 2.3025853633880615
# Train accuracy 9.9:
# Test accuracy 9.8:
# EPOCH 28:
#  batch 100 loss: 2.3025853633880615
#  batch 200 loss: 2.3025853633880615
#  batch 300 loss: 2.3025853633880615
#  batch 400 loss: 2.3025853633880615
# Train accuracy 9.9:
# Test accuracy 9.8:
# EPOCH 29:
#  batch 100 loss: 2.3025853633880615
#  batch 200 loss: 2.3025853633880615
#  batch 300 loss: 2.3025853633880615
#  batch 400 loss: 2.3025853633880615
# Train accuracy 9.9:
# Test accuracy 9.8:
# EPOCH 30:
#  batch 100 loss: 2.3025853633880615
#  batch 200 loss: 2.3025853633880615
#  batch 300 loss: 2.3025853633880615
#  batch 400 loss: 2.3025853633880615
# Train accuracy 9.9:
# Test accuracy 9.8:
# EPOCH 31:
#  batch 100 loss: 2.3025853633880615
#  batch 200 loss: 2.3025853633880615
#  batch 300 loss: 2.3025853633880615
#  batch 400 loss: 2.3025853633880615
# Train accuracy 9.9:
# Test accuracy 9.8:
# EPOCH 32:
#  batch 100 loss: 2.3025853633880615
#  batch 200 loss: 2.3025853633880615
#  batch 300 loss: 2.3025853633880615
#  batch 400 loss: 2.3025853633880615
# Train accuracy 9.9:
# Test accuracy 9.8:
# EPOCH 33:
#  batch 100 loss: 2.3025853633880615
#  batch 200 loss: 2.3025853633880615
#  batch 300 loss: 2.3025853633880615
#  batch 400 loss: 2.3025853633880615
# Train accuracy 9.9:
# Test accuracy 9.8:
# EPOCH 34:
#  batch 100 loss: 2.3025853633880615
#  batch 200 loss: 2.3025853633880615
#  batch 300 loss: 2.3025853633880615
#  batch 400 loss: 2.3025853633880615
# Train accuracy 9.9:
# Test accuracy 9.8:
# EPOCH 35:
#  batch 100 loss: 2.3025853633880615
#  batch 200 loss: 2.3025853633880615
#  batch 300 loss: 2.3025853633880615
#  batch 400 loss: 2.3025853633880615
# Train accuracy 9.9:
# Test accuracy 9.8:
# EPOCH 36:
#  batch 100 loss: 2.3025853633880615
#  batch 200 loss: 2.3025853633880615
#  batch 300 loss: 2.3025853633880615
#  batch 400 loss: 2.3025853633880615
# Train accuracy 9.9:
# Test accuracy 9.8:
# EPOCH 37:
#  batch 100 loss: 2.3025853633880615
#  batch 200 loss: 2.3025853633880615
#  batch 300 loss: 2.3025853633880615
#  batch 400 loss: 2.3025853633880615
# Train accuracy 9.9:
# Test accuracy 9.8:
# EPOCH 38:
#  batch 100 loss: 2.3025853633880615
#  batch 200 loss: 2.3025853633880615
#  batch 300 loss: 2.3025853633880615
#  batch 400 loss: 2.3025853633880615
# Train accuracy 9.9:
# Test accuracy 9.8:
# EPOCH 39:
#  batch 100 loss: 2.3025853633880615
#  batch 200 loss: 2.3025853633880615
#  batch 300 loss: 2.3025853633880615
#  batch 400 loss: 2.3025853633880615
# Train accuracy 9.9:
# Test accuracy 9.8:
# EPOCH 40:
#  batch 100 loss: 2.3025853633880615
#  batch 200 loss: 2.3025853633880615
#  batch 300 loss: 2.3025853633880615
#  batch 400 loss: 2.3025853633880615
# Train accuracy 9.9:
# Test accuracy 9.8:
# EPOCH 41:
#  batch 100 loss: 2.3025853633880615
#  batch 200 loss: 2.3025853633880615
#  batch 300 loss: 2.3025853633880615
#  batch 400 loss: 2.3025853633880615
# Train accuracy 9.9:
# Test accuracy 9.8:
# EPOCH 42:
#  batch 100 loss: 2.3025853633880615
#  batch 200 loss: 2.3025853633880615
#  batch 300 loss: 2.3025853633880615
#  batch 400 loss: 2.3025853633880615
# Train accuracy 9.9:
# Test accuracy 9.8:
# EPOCH 43:
#  batch 100 loss: 2.3025853633880615
#  batch 200 loss: 2.3025853633880615
#  batch 300 loss: 2.3025853633880615
#  batch 400 loss: 2.3025853633880615
# Train accuracy 9.9:
# Test accuracy 9.8:
# EPOCH 44:
#  batch 100 loss: 2.3025853633880615
#  batch 200 loss: 2.3025853633880615
#  batch 300 loss: 2.3025853633880615
#  batch 400 loss: 2.3025853633880615
# Train accuracy 9.9:
# Test accuracy 9.8:
# EPOCH 45:
#  batch 100 loss: 2.3025853633880615
#  batch 200 loss: 2.3025853633880615
#  batch 300 loss: 2.3025853633880615
#  batch 400 loss: 2.3025853633880615
# Train accuracy 9.9:
# Test accuracy 9.8:
# EPOCH 46:
#  batch 100 loss: 2.3025853633880615
#  batch 200 loss: 2.3025853633880615
#  batch 300 loss: 2.3025853633880615
#  batch 400 loss: 2.3025853633880615
# Train accuracy 9.9:
# Test accuracy 9.8:
# EPOCH 47:
#  batch 100 loss: 2.3025853633880615
#  batch 200 loss: 2.3025853633880615
#  batch 300 loss: 2.3025853633880615
#  batch 400 loss: 2.3025853633880615
# Train accuracy 9.9:
# Test accuracy 9.8:
# EPOCH 48:
#  batch 100 loss: 2.3025853633880615
#  batch 200 loss: 2.3025853633880615
#  batch 300 loss: 2.3025853633880615
#  batch 400 loss: 2.3025853633880615
# Train accuracy 9.9:
# Test accuracy 9.8:
# EPOCH 49:
#  batch 100 loss: 2.3025853633880615
#  batch 200 loss: 2.3025853633880615
#  batch 300 loss: 2.3025853633880615
#  batch 400 loss: 2.3025853633880615
# Train accuracy 9.9:
# Test accuracy 9.8:
# EPOCH 50:
#  batch 100 loss: 2.3025853633880615
#  batch 200 loss: 2.3025853633880615
#  batch 300 loss: 2.3025853633880615
#  batch 400 loss: 2.3025853633880615
# Train accuracy 9.9:
# Test accuracy 9.8:
# EPOCH 51:
#  batch 100 loss: 2.3025853633880615
#  batch 200 loss: 2.3025853633880615
#  batch 300 loss: 2.3025853633880615
#  batch 400 loss: 2.3025853633880615
# Train accuracy 9.9:
# Test accuracy 9.8:
# EPOCH 52:
#  batch 100 loss: 2.3025853633880615
#  batch 200 loss: 2.3025853633880615
#  batch 300 loss: 2.3025853633880615
#  batch 400 loss: 2.3025853633880615
# Train accuracy 9.9:
# Test accuracy 9.8:
# EPOCH 53:
#  batch 100 loss: 2.3025853633880615
#  batch 200 loss: 2.3025853633880615
#  batch 300 loss: 2.3025853633880615
#  batch 400 loss: 2.3025853633880615
# Train accuracy 9.9:
# Test accuracy 9.8:
# EPOCH 54:
#  batch 100 loss: 2.3025853633880615
#  batch 200 loss: 2.3025853633880615
#  batch 300 loss: 2.3025853633880615
#  batch 400 loss: 2.3025853633880615
# Train accuracy 9.9:
# Test accuracy 9.8:
# EPOCH 55:
#  batch 100 loss: 2.3025853633880615
#  batch 200 loss: 2.3025853633880615
#  batch 300 loss: 2.3025853633880615
#  batch 400 loss: 2.3025853633880615
# Train accuracy 9.9:
# Test accuracy 9.8:
# EPOCH 56:
#  batch 100 loss: 2.3025853633880615
#  batch 200 loss: 2.3025853633880615
#  batch 300 loss: 2.3025853633880615
#  batch 400 loss: 2.3025853633880615
# Train accuracy 9.9:
# Test accuracy 9.8:
# EPOCH 57:
#  batch 100 loss: 2.3025853633880615
#  batch 200 loss: 2.3025853633880615
#  batch 300 loss: 2.3025853633880615
#  batch 400 loss: 2.3025853633880615
# Train accuracy 9.9:
# Test accuracy 9.8:
# EPOCH 58:
#  batch 100 loss: 2.3025853633880615
#  batch 200 loss: 2.3025853633880615
#  batch 300 loss: 2.3025853633880615
#  batch 400 loss: 2.3025853633880615
# Train accuracy 9.9:
# Test accuracy 9.8:
# EPOCH 59:
#  batch 100 loss: 2.3025853633880615
#  batch 200 loss: 2.3025853633880615
#  batch 300 loss: 2.3025853633880615
#  batch 400 loss: 2.3025853633880615
# Train accuracy 9.9:
# Test accuracy 9.8:
# EPOCH 60:
#  batch 100 loss: 2.3025853633880615
#  batch 200 loss: 2.3025853633880615
#  batch 300 loss: 2.3025853633880615
#  batch 400 loss: 2.3025853633880615
# Train accuracy 9.9:
# Test accuracy 9.8:
# Learning Rate 0.1:
# EPOCH 1:
#  batch 100 loss: 2.3669912695884703
#  batch 200 loss: 2.3025854134559633
#  batch 300 loss: 2.302585561275482
#  batch 400 loss: 2.3025853633880615
# Train accuracy 9.9:
# Test accuracy 9.8:
# EPOCH 2:
#  batch 100 loss: 2.3025853633880615
#  batch 200 loss: 2.3025853633880615
#  batch 300 loss: 2.3025853633880615
#  batch 400 loss: 2.3025853633880615
# Train accuracy 9.9:
# Test accuracy 9.8:
# EPOCH 3:
#  batch 100 loss: 2.3025853633880615
#  batch 200 loss: 2.3025853633880615
#  batch 300 loss: 2.3025853633880615
#  batch 400 loss: 2.3025853633880615
# Train accuracy 9.9:
# Test accuracy 9.8:
# EPOCH 4:
#  batch 100 loss: 2.3025853633880615
#  batch 200 loss: 2.3025853633880615
#  batch 300 loss: 2.3025853633880615
#  batch 400 loss: 2.3025853633880615
# Train accuracy 9.9:
# Test accuracy 9.8:
# EPOCH 5:
#  batch 100 loss: 2.3025853633880615
#  batch 200 loss: 2.3025853633880615
#  batch 300 loss: 2.3025853633880615
#  batch 400 loss: 2.3025853633880615
# Train accuracy 9.9:
# Test accuracy 9.8:
# EPOCH 6:
#  batch 100 loss: 2.3025853633880615
#  batch 200 loss: 2.3025853633880615
#  batch 300 loss: 2.3025853633880615
#  batch 400 loss: 2.3025853633880615
# Train accuracy 9.9:
# Test accuracy 9.8:
# EPOCH 7:
#  batch 100 loss: 2.3025853633880615
#  batch 200 loss: 2.3025853633880615
#  batch 300 loss: 2.3025853633880615
#  batch 400 loss: 2.3025853633880615
# Train accuracy 9.9:
# Test accuracy 9.8:
# EPOCH 8:
#  batch 100 loss: 2.3025853633880615
#  batch 200 loss: 2.3025853633880615
#  batch 300 loss: 2.3025853633880615
#  batch 400 loss: 2.3025853633880615
# Train accuracy 9.9:
# Test accuracy 9.8:
# EPOCH 9:
#  batch 100 loss: 2.3025853633880615
#  batch 200 loss: 2.3025853633880615
#  batch 300 loss: 2.3025853633880615
#  batch 400 loss: 2.3025853633880615
# Train accuracy 9.9:
# Test accuracy 9.8:
# EPOCH 10:
#  batch 100 loss: 2.3025853633880615
#  batch 200 loss: 2.3025853633880615
#  batch 300 loss: 2.3025853633880615
#  batch 400 loss: 2.3025853633880615
# Train accuracy 9.9:
# Test accuracy 9.8:
# EPOCH 11:
#  batch 100 loss: 2.3025853633880615
#  batch 200 loss: 2.3025853633880615
#  batch 300 loss: 2.3025853633880615
#  batch 400 loss: 2.3025853633880615
# Train accuracy 9.9:
# Test accuracy 9.8:
# EPOCH 12:
#  batch 100 loss: 2.3025853633880615
#  batch 200 loss: 2.3025853633880615
#  batch 300 loss: 2.3025853633880615
#  batch 400 loss: 2.3025853633880615
# Train accuracy 9.9:
# Test accuracy 9.8:
# EPOCH 13:
#  batch 100 loss: 2.3025853633880615
#  batch 200 loss: 2.3025853633880615
#  batch 300 loss: 2.3025853633880615
#  batch 400 loss: 2.3025853633880615
# Train accuracy 9.9:
# Test accuracy 9.8:
# EPOCH 14:
#  batch 100 loss: 2.3025853633880615
#  batch 200 loss: 2.3025853633880615
#  batch 300 loss: 2.3025853633880615
#  batch 400 loss: 2.3025853633880615
# Train accuracy 9.9:
# Test accuracy 9.8:
# EPOCH 15:
#  batch 100 loss: 2.3025853633880615
#  batch 200 loss: 2.3025853633880615
#  batch 300 loss: 2.3025853633880615
#  batch 400 loss: 2.3025853633880615
# Train accuracy 9.9:
# Test accuracy 9.8:
# EPOCH 16:
#  batch 100 loss: 2.3025853633880615
#  batch 200 loss: 2.3025853633880615
#  batch 300 loss: 2.3025853633880615
#  batch 400 loss: 2.3025853633880615
# Train accuracy 9.9:
# Test accuracy 9.8:
# EPOCH 17:
#  batch 100 loss: 2.3025853633880615
#  batch 200 loss: 2.3025853633880615
#  batch 300 loss: 2.3025853633880615
#  batch 400 loss: 2.3025853633880615
# Train accuracy 9.9:
# Test accuracy 9.8:
# EPOCH 18:
#  batch 100 loss: 2.3025853633880615
#  batch 200 loss: 2.3025853633880615
#  batch 300 loss: 2.3025853633880615
#  batch 400 loss: 2.3025853633880615
# Train accuracy 9.9:
# Test accuracy 9.8:
# EPOCH 19:
#  batch 100 loss: 2.3025853633880615
#  batch 200 loss: 2.3025853633880615
#  batch 300 loss: 2.3025853633880615
#  batch 400 loss: 2.3025853633880615
# Train accuracy 9.9:
# Test accuracy 9.8:
# EPOCH 20:
#  batch 100 loss: 2.3025853633880615
#  batch 200 loss: 2.3025853633880615
#  batch 300 loss: 2.3025853633880615
#  batch 400 loss: 2.3025853633880615
# Train accuracy 9.9:
# Test accuracy 9.8:
# EPOCH 21:
#  batch 100 loss: 2.3025853633880615
#  batch 200 loss: 2.3025853633880615
#  batch 300 loss: 2.3025853633880615
#  batch 400 loss: 2.3025853633880615
# Train accuracy 9.9:
# Test accuracy 9.8:
# EPOCH 22:
#  batch 100 loss: 2.3025853633880615
#  batch 200 loss: 2.3025853633880615
#  batch 300 loss: 2.3025853633880615
#  batch 400 loss: 2.3025853633880615
# Train accuracy 9.9:
# Test accuracy 9.8:
# EPOCH 23:
#  batch 100 loss: 2.3025853633880615
#  batch 200 loss: 2.3025853633880615
#  batch 300 loss: 2.3025853633880615
#  batch 400 loss: 2.3025853633880615
# Train accuracy 9.9:
# Test accuracy 9.8:
# EPOCH 24:
#  batch 100 loss: 2.3025853633880615
#  batch 200 loss: 2.3025853633880615
#  batch 300 loss: 2.3025853633880615
#  batch 400 loss: 2.3025853633880615
# Train accuracy 9.9:
# Test accuracy 9.8:
# EPOCH 25:
#  batch 100 loss: 2.3025853633880615
#  batch 200 loss: 2.3025853633880615
#  batch 300 loss: 2.3025853633880615
#  batch 400 loss: 2.3025853633880615
# Train accuracy 9.9:
# Test accuracy 9.8:
# EPOCH 26:
#  batch 100 loss: 2.3025853633880615
#  batch 200 loss: 2.3025853633880615
#  batch 300 loss: 2.3025853633880615
#  batch 400 loss: 2.3025853633880615
# Train accuracy 9.9:
# Test accuracy 9.8:
# EPOCH 27:
#  batch 100 loss: 2.3025853633880615
#  batch 200 loss: 2.3025853633880615
#  batch 300 loss: 2.3025853633880615
#  batch 400 loss: 2.3025853633880615
# Train accuracy 9.9:
# Test accuracy 9.8:
# EPOCH 28:
#  batch 100 loss: 2.3025853633880615
#  batch 200 loss: 2.3025853633880615
#  batch 300 loss: 2.3025853633880615
#  batch 400 loss: 2.3025853633880615
# Train accuracy 9.9:
# Test accuracy 9.8:
# EPOCH 29:
#  batch 100 loss: 2.3025853633880615
#  batch 200 loss: 2.3025853633880615
#  batch 300 loss: 2.3025853633880615
#  batch 400 loss: 2.3025853633880615
# Train accuracy 9.9:
# Test accuracy 9.8:
# EPOCH 30:
#  batch 100 loss: 2.3025853633880615
#  batch 200 loss: 2.3025853633880615
#  batch 300 loss: 2.3025853633880615
#  batch 400 loss: 2.3025853633880615
# Train accuracy 9.9:
# Test accuracy 9.8:
# EPOCH 31:
#  batch 100 loss: 2.3025853633880615
#  batch 200 loss: 2.3025853633880615
#  batch 300 loss: 2.3025853633880615
#  batch 400 loss: 2.3025853633880615
# Train accuracy 9.9:
# Test accuracy 9.8:
# EPOCH 32:
#  batch 100 loss: 2.3025853633880615
#  batch 200 loss: 2.3025853633880615
#  batch 300 loss: 2.3025853633880615
#  batch 400 loss: 2.3025853633880615
# Train accuracy 9.9:
# Test accuracy 9.8:
# EPOCH 33:
#  batch 100 loss: 2.3025853633880615
#  batch 200 loss: 2.3025853633880615
#  batch 300 loss: 2.3025853633880615
#  batch 400 loss: 2.3025853633880615
# Train accuracy 9.9:
# Test accuracy 9.8:
# EPOCH 34:
#  batch 100 loss: 2.3025853633880615
#  batch 200 loss: 2.3025853633880615
#  batch 300 loss: 2.3025853633880615
#  batch 400 loss: 2.3025853633880615
# Train accuracy 9.9:
# Test accuracy 9.8:
# EPOCH 35:
#  batch 100 loss: 2.3025853633880615
#  batch 200 loss: 2.3025853633880615
#  batch 300 loss: 2.3025853633880615
#  batch 400 loss: 2.3025853633880615
# Train accuracy 9.9:
# Test accuracy 9.8:
# EPOCH 36:
#  batch 100 loss: 2.3025853633880615
#  batch 200 loss: 2.3025853633880615
#  batch 300 loss: 2.3025853633880615
#  batch 400 loss: 2.3025853633880615
# Train accuracy 9.9:
# Test accuracy 9.8:
# EPOCH 37:
#  batch 100 loss: 2.3025853633880615
#  batch 200 loss: 2.3025853633880615
#  batch 300 loss: 2.3025853633880615
#  batch 400 loss: 2.3025853633880615
# Train accuracy 9.9:
# Test accuracy 9.8:
# EPOCH 38:
#  batch 100 loss: 2.3025853633880615
#  batch 200 loss: 2.3025853633880615
#  batch 300 loss: 2.3025853633880615
#  batch 400 loss: 2.3025853633880615
# Train accuracy 9.9:
# Test accuracy 9.8:
# EPOCH 39:
#  batch 100 loss: 2.3025853633880615
#  batch 200 loss: 2.3025853633880615
#  batch 300 loss: 2.3025853633880615
#  batch 400 loss: 2.3025853633880615
# Train accuracy 9.9:
# Test accuracy 9.8:
# EPOCH 40:
#  batch 100 loss: 2.3025853633880615
#  batch 200 loss: 2.3025853633880615
#  batch 300 loss: 2.3025853633880615
#  batch 400 loss: 2.3025853633880615
# Train accuracy 9.9:
# Test accuracy 9.8:
# EPOCH 41:
#  batch 100 loss: 2.3025853633880615
#  batch 200 loss: 2.3025853633880615
#  batch 300 loss: 2.3025853633880615
#  batch 400 loss: 2.3025853633880615
# Train accuracy 9.9:
# Test accuracy 9.8:
# EPOCH 42:
#  batch 100 loss: 2.3025853633880615
#  batch 200 loss: 2.3025853633880615
#  batch 300 loss: 2.3025853633880615
#  batch 400 loss: 2.3025853633880615
# Train accuracy 9.9:
# Test accuracy 9.8:
# EPOCH 43:
#  batch 100 loss: 2.3025853633880615
#  batch 200 loss: 2.3025853633880615
#  batch 300 loss: 2.3025853633880615
#  batch 400 loss: 2.3025853633880615
# Train accuracy 9.9:
# Test accuracy 9.8:
# EPOCH 44:
#  batch 100 loss: 2.3025853633880615
#  batch 200 loss: 2.3025853633880615
#  batch 300 loss: 2.3025853633880615
#  batch 400 loss: 2.3025853633880615
# Train accuracy 9.9:
# Test accuracy 9.8:
# EPOCH 45:
#  batch 100 loss: 2.3025853633880615
#  batch 200 loss: 2.3025853633880615
#  batch 300 loss: 2.3025853633880615
#  batch 400 loss: 2.3025853633880615
# Train accuracy 9.9:
# Test accuracy 9.8:
# EPOCH 46:
#  batch 100 loss: 2.3025853633880615
#  batch 200 loss: 2.3025853633880615
#  batch 300 loss: 2.3025853633880615
#  batch 400 loss: 2.3025853633880615
# Train accuracy 9.9:
# Test accuracy 9.8:
# EPOCH 47:
#  batch 100 loss: 2.3025853633880615
#  batch 200 loss: 2.3025853633880615
#  batch 300 loss: 2.3025853633880615
#  batch 400 loss: 2.3025853633880615
# Train accuracy 9.9:
# Test accuracy 9.8:
# EPOCH 48:
#  batch 100 loss: 2.3025853633880615
#  batch 200 loss: 2.3025853633880615
#  batch 300 loss: 2.3025853633880615
#  batch 400 loss: 2.3025853633880615
# Train accuracy 9.9:
# Test accuracy 9.8:
# EPOCH 49:
#  batch 100 loss: 2.3025853633880615
#  batch 200 loss: 2.3025853633880615
#  batch 300 loss: 2.3025853633880615
#  batch 400 loss: 2.3025853633880615
# Train accuracy 9.9:
# Test accuracy 9.8:
# EPOCH 50:
#  batch 100 loss: 2.3025853633880615
#  batch 200 loss: 2.3025853633880615
#  batch 300 loss: 2.3025853633880615
#  batch 400 loss: 2.3025853633880615
# Train accuracy 9.9:
# Test accuracy 9.8:
# EPOCH 51:
#  batch 100 loss: 2.3025853633880615
#  batch 200 loss: 2.3025853633880615
#  batch 300 loss: 2.3025853633880615
#  batch 400 loss: 2.3025853633880615
# Train accuracy 9.9:
# Test accuracy 9.8:
# EPOCH 52:
#  batch 100 loss: 2.3025853633880615
#  batch 200 loss: 2.3025853633880615
#  batch 300 loss: 2.3025853633880615
#  batch 400 loss: 2.3025853633880615
# Train accuracy 9.9:
# Test accuracy 9.8:
# EPOCH 53:
#  batch 100 loss: 2.3025853633880615
#  batch 200 loss: 2.3025853633880615
#  batch 300 loss: 2.3025853633880615
#  batch 400 loss: 2.3025853633880615
# Train accuracy 9.9:
# Test accuracy 9.8:
# EPOCH 54:
#  batch 100 loss: 2.3025853633880615
#  batch 200 loss: 2.3025853633880615
#  batch 300 loss: 2.3025853633880615
#  batch 400 loss: 2.3025853633880615
# Train accuracy 9.9:
# Test accuracy 9.8:
# EPOCH 55:
#  batch 100 loss: 2.3025853633880615
#  batch 200 loss: 2.3025853633880615
#  batch 300 loss: 2.3025853633880615
#  batch 400 loss: 2.3025853633880615
# Train accuracy 9.9:
# Test accuracy 9.8:
# EPOCH 56:
#  batch 100 loss: 2.3025853633880615
#  batch 200 loss: 2.3025853633880615
#  batch 300 loss: 2.3025853633880615
#  batch 400 loss: 2.3025853633880615
# Train accuracy 9.9:
# Test accuracy 9.8:
# EPOCH 57:
#  batch 100 loss: 2.3025853633880615
#  batch 200 loss: 2.3025853633880615
#  batch 300 loss: 2.3025853633880615
#  batch 400 loss: 2.3025853633880615
# Train accuracy 9.9:
# Test accuracy 9.8:
# EPOCH 58:
#  batch 100 loss: 2.3025853633880615
#  batch 200 loss: 2.3025853633880615
#  batch 300 loss: 2.3025853633880615
#  batch 400 loss: 2.3025853633880615
# Train accuracy 9.9:
# Test accuracy 9.8:
# EPOCH 59:
#  batch 100 loss: 2.3025853633880615
#  batch 200 loss: 2.3025853633880615
#  batch 300 loss: 2.3025853633880615
#  batch 400 loss: 2.3025853633880615
# Train accuracy 9.9:
# Test accuracy 9.8:
# EPOCH 60:
#  batch 100 loss: 2.3025853633880615
#  batch 200 loss: 2.3025853633880615
#  batch 300 loss: 2.3025853633880615
#  batch 400 loss: 2.3025853633880615
# Train accuracy 9.9:
# Test accuracy 9.8:
# Learning Rate 0.01:
# EPOCH 1:
#  batch 100 loss: 1.5413791501522065
#  batch 200 loss: 1.012408407330513
#  batch 300 loss: 0.8675975656509399
#  batch 400 loss: 0.7929029196500779
# Train accuracy 77.2:
# Test accuracy 77.7:
# EPOCH 2:
#  batch 100 loss: 0.7343966883420944
#  batch 200 loss: 0.7244134336709976
#  batch 300 loss: 0.7113178279995919
#  batch 400 loss: 0.6822598224878311
# Train accuracy 78.3:
# Test accuracy 78.60000000000001:
# EPOCH 3:
#  batch 100 loss: 0.6630861842632294
#  batch 200 loss: 0.6525649300217629
#  batch 300 loss: 0.6564136928319931
#  batch 400 loss: 0.6396976789832115
# Train accuracy 79.10000000000001:
# Test accuracy 79.3:
# EPOCH 4:
#  batch 100 loss: 0.6289972880482674
#  batch 200 loss: 0.6304903909564018
#  batch 300 loss: 0.6395060741901397
#  batch 400 loss: 0.6125788685679435
# Train accuracy 79.5:
# Test accuracy 79.9:
# EPOCH 5:
#  batch 100 loss: 0.6176508486270904
#  batch 200 loss: 0.6077833533287048
#  batch 300 loss: 0.6099271982908249
#  batch 400 loss: 0.6111137366294861
# Train accuracy 79.80000000000001:
# Test accuracy 80.10000000000001:
# EPOCH 6:
#  batch 100 loss: 0.6092321497201919
#  batch 200 loss: 0.5995201763510704
#  batch 300 loss: 0.5974971029162407
#  batch 400 loss: 0.5980050963163376
# Train accuracy 80.0:
# Test accuracy 80.0:
# EPOCH 7:
#  batch 100 loss: 0.6032355424761772
#  batch 200 loss: 0.5811485096812248
#  batch 300 loss: 0.5892995870113373
#  batch 400 loss: 0.597727101445198
# Train accuracy 80.2:
# Test accuracy 80.2:
# EPOCH 8:
#  batch 100 loss: 0.5976206704974174
#  batch 200 loss: 0.582725892663002
#  batch 300 loss: 0.5763602617383004
#  batch 400 loss: 0.5815337300300598
# Train accuracy 80.4:
# Test accuracy 80.4:
# EPOCH 9:
#  batch 100 loss: 0.561468380689621
#  batch 200 loss: 0.591507109105587
#  batch 300 loss: 0.5805065730214118
#  batch 400 loss: 0.5718616056442261
# Train accuracy 80.30000000000001:
# Test accuracy 80.4:
# EPOCH 10:
#  batch 100 loss: 0.5676891344785691
#  batch 200 loss: 0.5793442919850349
#  batch 300 loss: 0.5586029449105263
#  batch 400 loss: 0.5731267538666726
# Train accuracy 80.4:
# Test accuracy 80.60000000000001:
# EPOCH 11:
#  batch 100 loss: 0.5613889983296394
#  batch 200 loss: 0.5771647468209267
#  batch 300 loss: 0.5606033635139466
#  batch 400 loss: 0.5768670776486396
# Train accuracy 80.7:
# Test accuracy 80.5:
# EPOCH 12:
#  batch 100 loss: 0.5591761270165443
#  batch 200 loss: 0.564772330224514
#  batch 300 loss: 0.5754155102372169
#  batch 400 loss: 0.5597252270579338
# Train accuracy 80.7:
# Test accuracy 80.60000000000001:
# EPOCH 13:
#  batch 100 loss: 0.5581224846839905
#  batch 200 loss: 0.5675468716025353
#  batch 300 loss: 0.5588662776350976
#  batch 400 loss: 0.548230622112751
# Train accuracy 80.80000000000001:
# Test accuracy 80.60000000000001:
# EPOCH 14:
#  batch 100 loss: 0.5511646774411202
#  batch 200 loss: 0.5735438877344131
#  batch 300 loss: 0.559665664434433
#  batch 400 loss: 0.5472698324918747
# Train accuracy 80.9:
# Test accuracy 80.80000000000001:
# EPOCH 15:
#  batch 100 loss: 0.5695414409041405
#  batch 200 loss: 0.5657837370038032
#  batch 300 loss: 0.5458954504132271
#  batch 400 loss: 0.5451540145277977
# Train accuracy 80.9:
# Test accuracy 80.9:
# EPOCH 16:
#  batch 100 loss: 0.5428389692306519
#  batch 200 loss: 0.5663644516468048
#  batch 300 loss: 0.5585787075757981
#  batch 400 loss: 0.5480047670006752
# Train accuracy 81.0:
# Test accuracy 80.9:
# EPOCH 17:
#  batch 100 loss: 0.5414820063114166
#  batch 200 loss: 0.5460679572820664
#  batch 300 loss: 0.5491793549060822
#  batch 400 loss: 0.5581910488009453
# Train accuracy 81.10000000000001:
# Test accuracy 80.9:
# EPOCH 18:
#  batch 100 loss: 0.5340629285573959
#  batch 200 loss: 0.5545298209786416
#  batch 300 loss: 0.5553955534100532
#  batch 400 loss: 0.5551230815052987
# Train accuracy 81.2:
# Test accuracy 81.0:
# EPOCH 19:
#  batch 100 loss: 0.5429358568787575
#  batch 200 loss: 0.5487912294268608
#  batch 300 loss: 0.5347842654585838
#  batch 400 loss: 0.5521501711010933
# Train accuracy 81.2:
# Test accuracy 81.0:
# EPOCH 20:
#  batch 100 loss: 0.558001511991024
#  batch 200 loss: 0.5465292301774025
#  batch 300 loss: 0.5468251127004623
#  batch 400 loss: 0.5366521683335305
# Train accuracy 81.10000000000001:
# Test accuracy 80.9:
# EPOCH 21:
#  batch 100 loss: 0.5435393384099007
#  batch 200 loss: 0.5421641033887863
#  batch 300 loss: 0.5363443127274513
#  batch 400 loss: 0.5609839522838592
# Train accuracy 81.2:
# Test accuracy 81.0:
# EPOCH 22:
#  batch 100 loss: 0.5285207384824753
#  batch 200 loss: 0.5471128833293915
#  batch 300 loss: 0.5432792606949807
#  batch 400 loss: 0.5468841022253037
# Train accuracy 81.3:
# Test accuracy 81.10000000000001:
# EPOCH 23:
#  batch 100 loss: 0.5309992709755897
#  batch 200 loss: 0.5613528534770011
#  batch 300 loss: 0.5403179639577865
#  batch 400 loss: 0.5398974710702896
# Train accuracy 81.2:
# Test accuracy 80.9:
# EPOCH 24:
#  batch 100 loss: 0.5389862048625946
#  batch 200 loss: 0.5331388542056084
#  batch 300 loss: 0.521942412853241
#  batch 400 loss: 0.5518848264217376
# Train accuracy 81.3:
# Test accuracy 81.10000000000001:
# EPOCH 25:
#  batch 100 loss: 0.5239834141731262
#  batch 200 loss: 0.5295412817597389
#  batch 300 loss: 0.5551156899333001
#  batch 400 loss: 0.5447164165973664
# Train accuracy 81.39999999999999:
# Test accuracy 81.0:
# EPOCH 26:
#  batch 100 loss: 0.5325740611553192
#  batch 200 loss: 0.5335582506656646
#  batch 300 loss: 0.5438997006416321
#  batch 400 loss: 0.5415294718742371
# Train accuracy 81.3:
# Test accuracy 80.9:
# EPOCH 27:
#  batch 100 loss: 0.5536285188794136
#  batch 200 loss: 0.5309952104091644
#  batch 300 loss: 0.5246750465035439
#  batch 400 loss: 0.5457468307018281
# Train accuracy 81.5:
# Test accuracy 81.2:
# EPOCH 28:
#  batch 100 loss: 0.5393746346235275
#  batch 200 loss: 0.5401581597328186
#  batch 300 loss: 0.5292670568823814
#  batch 400 loss: 0.5332156634330749
# Train accuracy 81.5:
# Test accuracy 81.10000000000001:
# EPOCH 29:
#  batch 100 loss: 0.533096009939909
#  batch 200 loss: 0.5405814364552498
#  batch 300 loss: 0.5333085224032402
#  batch 400 loss: 0.5202997896075249
# Train accuracy 81.5:
# Test accuracy 81.2:
# EPOCH 30:
#  batch 100 loss: 0.5394440013170242
#  batch 200 loss: 0.5281505057215691
#  batch 300 loss: 0.5361533463001251
#  batch 400 loss: 0.5368424525856972
# Train accuracy 81.5:
# Test accuracy 81.2:
# EPOCH 31:
#  batch 100 loss: 0.5270649471879005
#  batch 200 loss: 0.5277371186017991
#  batch 300 loss: 0.5313336846232414
#  batch 400 loss: 0.5469619664549827
# Train accuracy 81.6:
# Test accuracy 81.2:
# EPOCH 32:
#  batch 100 loss: 0.5211697119474411
#  batch 200 loss: 0.5371204975247383
#  batch 300 loss: 0.5309448066353798
#  batch 400 loss: 0.542734709084034
# Train accuracy 81.6:
# Test accuracy 81.10000000000001:
# EPOCH 33:
#  batch 100 loss: 0.5376951640844345
#  batch 200 loss: 0.5262432837486267
#  batch 300 loss: 0.5229415148496628
#  batch 400 loss: 0.5265225115418434
# Train accuracy 81.6:
# Test accuracy 81.2:
# EPOCH 34:
#  batch 100 loss: 0.5367082038521767
#  batch 200 loss: 0.5288905420899391
#  batch 300 loss: 0.5293995743989944
#  batch 400 loss: 0.5252026489377022
# Train accuracy 81.6:
# Test accuracy 81.3:
# EPOCH 35:
#  batch 100 loss: 0.5314651373028755
#  batch 200 loss: 0.5176847308874131
#  batch 300 loss: 0.5378509831428527
#  batch 400 loss: 0.5328462848067284
# Train accuracy 81.69999999999999:
# Test accuracy 81.2:
# EPOCH 36:
#  batch 100 loss: 0.528819492161274
#  batch 200 loss: 0.5246863663196564
#  batch 300 loss: 0.5249540117383004
#  batch 400 loss: 0.5291594660282135
# Train accuracy 81.69999999999999:
# Test accuracy 81.2:
# EPOCH 37:
#  batch 100 loss: 0.5161941921710969
#  batch 200 loss: 0.5255602928996086
#  batch 300 loss: 0.5291086894273758
#  batch 400 loss: 0.5328699061274529
# Train accuracy 81.6:
# Test accuracy 81.10000000000001:
# EPOCH 38:
#  batch 100 loss: 0.521355744600296
#  batch 200 loss: 0.5245376661419868
#  batch 300 loss: 0.5315340784192085
#  batch 400 loss: 0.5246817433834076
# Train accuracy 81.69999999999999:
# Test accuracy 81.2:
# EPOCH 39:
#  batch 100 loss: 0.5315511834621429
#  batch 200 loss: 0.5223377081751823
#  batch 300 loss: 0.5332009053230286
#  batch 400 loss: 0.5155124717950821
# Train accuracy 81.69999999999999:
# Test accuracy 81.10000000000001:
# EPOCH 40:
#  batch 100 loss: 0.5199615976214409
#  batch 200 loss: 0.5243544825911521
#  batch 300 loss: 0.5278146669268609
#  batch 400 loss: 0.542330564558506
# Train accuracy 81.8:
# Test accuracy 81.3:
# EPOCH 41:
#  batch 100 loss: 0.5343442341685295
#  batch 200 loss: 0.5153416946530343
#  batch 300 loss: 0.5208397382497787
#  batch 400 loss: 0.5240029072761536
# Train accuracy 81.8:
# Test accuracy 81.3:
# EPOCH 42:
#  batch 100 loss: 0.5305816301703453
#  batch 200 loss: 0.5175089383125305
#  batch 300 loss: 0.5095416355133057
#  batch 400 loss: 0.5381813198328018
# Train accuracy 81.8:
# Test accuracy 81.3:
# EPOCH 43:
#  batch 100 loss: 0.5245323151350021
#  batch 200 loss: 0.5114446806907654
#  batch 300 loss: 0.5295696929097176
#  batch 400 loss: 0.5254369312524796
# Train accuracy 81.8:
# Test accuracy 81.2:
# EPOCH 44:
#  batch 100 loss: 0.5246561798453331
#  batch 200 loss: 0.5261334472894669
#  batch 300 loss: 0.5264259454607964
#  batch 400 loss: 0.5207393455505371
# Train accuracy 81.8:
# Test accuracy 81.2:
# EPOCH 45:
#  batch 100 loss: 0.5185165700316429
#  batch 200 loss: 0.5344735458493233
#  batch 300 loss: 0.5096694681048394
#  batch 400 loss: 0.5203096029162407
# Train accuracy 81.8:
# Test accuracy 81.3:
# EPOCH 46:
#  batch 100 loss: 0.5118742832541465
#  batch 200 loss: 0.5365100318193435
#  batch 300 loss: 0.5239275762438774
#  batch 400 loss: 0.5204449805617333
# Train accuracy 81.89999999999999:
# Test accuracy 81.3:
# EPOCH 47:
#  batch 100 loss: 0.5146273520588874
#  batch 200 loss: 0.526711154282093
#  batch 300 loss: 0.520234144628048
#  batch 400 loss: 0.5123119613528252
# Train accuracy 81.8:
# Test accuracy 81.2:
# EPOCH 48:
#  batch 100 loss: 0.5166364777088165
#  batch 200 loss: 0.5113833898305893
#  batch 300 loss: 0.5272958889603615
#  batch 400 loss: 0.5291744568943977
# Train accuracy 81.89999999999999:
# Test accuracy 81.3:
# EPOCH 49:
#  batch 100 loss: 0.5268836271762848
#  batch 200 loss: 0.5088340809941292
#  batch 300 loss: 0.5207995462417603
#  batch 400 loss: 0.518458844423294
# Train accuracy 81.89999999999999:
# Test accuracy 81.39999999999999:
# EPOCH 50:
#  batch 100 loss: 0.5193216523528099
#  batch 200 loss: 0.5220665031671524
#  batch 300 loss: 0.5228812110424041
#  batch 400 loss: 0.5325916340947151
# Train accuracy 81.89999999999999:
# Test accuracy 81.3:
# EPOCH 51:
#  batch 100 loss: 0.5134014400839806
#  batch 200 loss: 0.519408016204834
#  batch 300 loss: 0.5323281529545784
#  batch 400 loss: 0.5154297298192978
# Train accuracy 81.89999999999999:
# Test accuracy 81.2:
# EPOCH 52:
#  batch 100 loss: 0.5189909255504608
#  batch 200 loss: 0.5229091203212738
#  batch 300 loss: 0.5164118900895118
#  batch 400 loss: 0.5154899337887764
# Train accuracy 81.89999999999999:
# Test accuracy 81.2:
# EPOCH 53:
#  batch 100 loss: 0.5150729674100876
#  batch 200 loss: 0.5173984465003013
#  batch 300 loss: 0.5113148111104965
#  batch 400 loss: 0.5285494154691697
# Train accuracy 82.0:
# Test accuracy 81.39999999999999:
# EPOCH 54:
#  batch 100 loss: 0.502608188688755
#  batch 200 loss: 0.5235465234518051
#  batch 300 loss: 0.5270209935307503
#  batch 400 loss: 0.5143493691086769
# Train accuracy 82.0:
# Test accuracy 81.39999999999999:
# EPOCH 55:
#  batch 100 loss: 0.5219138705730438
#  batch 200 loss: 0.5112816262245178
#  batch 300 loss: 0.514458986222744
#  batch 400 loss: 0.5170040270686149
# Train accuracy 81.89999999999999:
# Test accuracy 81.10000000000001:
# EPOCH 56:
#  batch 100 loss: 0.5109679317474365
#  batch 200 loss: 0.5285076063871383
#  batch 300 loss: 0.5187558668851853
#  batch 400 loss: 0.5127574089169502
# Train accuracy 82.0:
# Test accuracy 81.3:
# EPOCH 57:
#  batch 100 loss: 0.5077859404683113
#  batch 200 loss: 0.5152437883615494
#  batch 300 loss: 0.5167950540781021
#  batch 400 loss: 0.5049266403913498
# Train accuracy 82.0:
# Test accuracy 81.39999999999999:
# EPOCH 58:
#  batch 100 loss: 0.5229894989728927
#  batch 200 loss: 0.5111104601621628
#  batch 300 loss: 0.5186343410611153
#  batch 400 loss: 0.5103668957948685
# Train accuracy 81.89999999999999:
# Test accuracy 81.2:
# EPOCH 59:
#  batch 100 loss: 0.5208273294568062
#  batch 200 loss: 0.5152754041552544
#  batch 300 loss: 0.5105209732055664
#  batch 400 loss: 0.5160206684470177
# Train accuracy 82.0:
# Test accuracy 81.39999999999999:
# EPOCH 60:
#  batch 100 loss: 0.5133512830734253
#  batch 200 loss: 0.5395941776037216
#  batch 300 loss: 0.5138166308403015
#  batch 400 loss: 0.5046953016519546
# Train accuracy 82.0:
# Test accuracy 81.39999999999999:
# Learning Rate 0.001:
# EPOCH 1:
#  batch 100 loss: 2.1815670561790466
#  batch 200 loss: 1.9521634101867675
#  batch 300 loss: 1.7692126059532165
#  batch 400 loss: 1.624612684249878
# Train accuracy 65.9:
# Test accuracy 66.2:
# EPOCH 2:
#  batch 100 loss: 1.4336427116394044
#  batch 200 loss: 1.3487096989154816
#  batch 300 loss: 1.2812942683696746
#  batch 400 loss: 1.2152365005016328
# Train accuracy 72.1:
# Test accuracy 72.8:
# EPOCH 3:
#  batch 100 loss: 1.1340840446949005
#  batch 200 loss: 1.117229136824608
#  batch 300 loss: 1.0695965534448624
#  batch 400 loss: 1.0504385060071946
# Train accuracy 74.3:
# Test accuracy 74.9:
# EPOCH 4:
#  batch 100 loss: 1.0027054232358932
#  batch 200 loss: 0.9851222592592239
#  batch 300 loss: 0.9642436921596527
#  batch 400 loss: 0.962722459435463
# Train accuracy 75.3:
# Test accuracy 76.0:
# EPOCH 5:
#  batch 100 loss: 0.9141576319932938
#  batch 200 loss: 0.9044545674324036
#  batch 300 loss: 0.9122803294658661
#  batch 400 loss: 0.891869455575943
# Train accuracy 75.8:
# Test accuracy 76.5:
# EPOCH 6:
#  batch 100 loss: 0.8747900408506394
#  batch 200 loss: 0.853048124909401
#  batch 300 loss: 0.8554001849889755
#  batch 400 loss: 0.8444757229089737
# Train accuracy 76.2:
# Test accuracy 76.8:
# EPOCH 7:
#  batch 100 loss: 0.8331355875730515
#  batch 200 loss: 0.8340184837579727
#  batch 300 loss: 0.817433357834816
#  batch 400 loss: 0.8108202105760575
# Train accuracy 76.6:
# Test accuracy 77.2:
# EPOCH 8:
#  batch 100 loss: 0.8049416804313659
#  batch 200 loss: 0.7893316525220871
#  batch 300 loss: 0.8103766047954559
#  batch 400 loss: 0.7827874165773392
# Train accuracy 77.0:
# Test accuracy 77.5:
# EPOCH 9:
#  batch 100 loss: 0.7822841113805771
#  batch 200 loss: 0.7771660339832306
#  batch 300 loss: 0.7703913855552673
#  batch 400 loss: 0.7753869068622589
# Train accuracy 77.2:
# Test accuracy 77.60000000000001:
# EPOCH 10:
#  batch 100 loss: 0.7707432770729065
#  batch 200 loss: 0.7641546803712845
#  batch 300 loss: 0.7543277335166931
#  batch 400 loss: 0.7350670820474625
# Train accuracy 77.3:
# Test accuracy 77.8:
# EPOCH 11:
#  batch 100 loss: 0.7346812355518341
#  batch 200 loss: 0.7315382462739944
#  batch 300 loss: 0.744344426393509
#  batch 400 loss: 0.7535380357503891
# Train accuracy 77.5:
# Test accuracy 78.0:
# EPOCH 12:
#  batch 100 loss: 0.7480879414081574
#  batch 200 loss: 0.7355806559324265
#  batch 300 loss: 0.7201988488435745
#  batch 400 loss: 0.7267613393068314
# Train accuracy 77.7:
# Test accuracy 78.0:
# EPOCH 13:
#  batch 100 loss: 0.7222230100631714
#  batch 200 loss: 0.736273443698883
#  batch 300 loss: 0.7158745741844177
#  batch 400 loss: 0.716590649485588
# Train accuracy 77.9:
# Test accuracy 78.3:
# EPOCH 14:
#  batch 100 loss: 0.7208939063549041
#  batch 200 loss: 0.7144974225759506
#  batch 300 loss: 0.7135071182250976
#  batch 400 loss: 0.702775290608406
# Train accuracy 78.0:
# Test accuracy 78.3:
# EPOCH 15:
#  batch 100 loss: 0.7085944429039955
#  batch 200 loss: 0.7131193894147873
#  batch 300 loss: 0.6930649781227112
#  batch 400 loss: 0.7003217166662217
# Train accuracy 78.2:
# Test accuracy 78.4:
# EPOCH 16:
#  batch 100 loss: 0.6839445441961288
#  batch 200 loss: 0.7029938465356826
#  batch 300 loss: 0.7006755942106246
#  batch 400 loss: 0.6962689000368119
# Train accuracy 78.3:
# Test accuracy 78.3:
# EPOCH 17:
#  batch 100 loss: 0.6942702621221543
#  batch 200 loss: 0.6868013089895249
#  batch 300 loss: 0.6914333632588386
#  batch 400 loss: 0.6832588300108909
# Train accuracy 78.4:
# Test accuracy 78.5:
# EPOCH 18:
#  batch 100 loss: 0.6803570693731308
#  batch 200 loss: 0.6761916396021843
#  batch 300 loss: 0.6840224602818489
#  batch 400 loss: 0.695693752169609
# Train accuracy 78.4:
# Test accuracy 78.5:
# EPOCH 19:
#  batch 100 loss: 0.6648903426527977
#  batch 200 loss: 0.6823991745710373
#  batch 300 loss: 0.6810250103473663
#  batch 400 loss: 0.677285082936287
# Train accuracy 78.5:
# Test accuracy 78.60000000000001:
# EPOCH 20:
#  batch 100 loss: 0.6798204064369202
#  batch 200 loss: 0.6613741967082024
#  batch 300 loss: 0.6792137855291367
#  batch 400 loss: 0.6736083015799522
# Train accuracy 78.60000000000001:
# Test accuracy 78.7:
# EPOCH 21:
#  batch 100 loss: 0.6567622667551041
#  batch 200 loss: 0.6726842170953751
#  batch 300 loss: 0.681552597284317
#  batch 400 loss: 0.6581939843297004
# Train accuracy 78.7:
# Test accuracy 78.8:
# EPOCH 22:
#  batch 100 loss: 0.6698353534936905
#  batch 200 loss: 0.6657066828012467
#  batch 300 loss: 0.6645959970355034
#  batch 400 loss: 0.6584051704406738
# Train accuracy 78.8:
# Test accuracy 78.9:
# EPOCH 23:
#  batch 100 loss: 0.6690320742130279
#  batch 200 loss: 0.6561839962005616
#  batch 300 loss: 0.6618906891345978
#  batch 400 loss: 0.6580248877406121
# Train accuracy 78.8:
# Test accuracy 78.9:
# EPOCH 24:
#  batch 100 loss: 0.6515278571844101
#  batch 200 loss: 0.6613589206337929
#  batch 300 loss: 0.6443531948328018
#  batch 400 loss: 0.6685180100798607
# Train accuracy 78.9:
# Test accuracy 79.0:
# EPOCH 25:
#  batch 100 loss: 0.6629262045025826
#  batch 200 loss: 0.651286501288414
#  batch 300 loss: 0.6494020023941993
#  batch 400 loss: 0.6474451398849488
# Train accuracy 79.0:
# Test accuracy 79.0:
# EPOCH 26:
#  batch 100 loss: 0.6511321178078652
#  batch 200 loss: 0.6634443363547325
#  batch 300 loss: 0.6418365389108658
#  batch 400 loss: 0.6377618664503097
# Train accuracy 79.0:
# Test accuracy 79.10000000000001:
# EPOCH 27:
#  batch 100 loss: 0.6484600526094436
#  batch 200 loss: 0.636473728120327
#  batch 300 loss: 0.643869370520115
#  batch 400 loss: 0.639748632311821
# Train accuracy 79.10000000000001:
# Test accuracy 79.0:
# EPOCH 28:
#  batch 100 loss: 0.646373507976532
#  batch 200 loss: 0.6401967963576317
#  batch 300 loss: 0.6473480513691903
#  batch 400 loss: 0.6347529885172843
# Train accuracy 79.10000000000001:
# Test accuracy 79.10000000000001:
# EPOCH 29:
#  batch 100 loss: 0.6449576163291931
#  batch 200 loss: 0.6410687771439553
#  batch 300 loss: 0.6461825090646743
#  batch 400 loss: 0.6208926889300347
# Train accuracy 79.2:
# Test accuracy 79.2:
# EPOCH 30:
#  batch 100 loss: 0.6372733077406884
#  batch 200 loss: 0.6341337206959724
#  batch 300 loss: 0.6310676044225693
#  batch 400 loss: 0.6486671125888824
# Train accuracy 79.2:
# Test accuracy 79.2:
# EPOCH 31:
#  batch 100 loss: 0.6265617665648461
#  batch 200 loss: 0.632395703792572
#  batch 300 loss: 0.6439210832118988
#  batch 400 loss: 0.635721384882927
# Train accuracy 79.3:
# Test accuracy 79.3:
# EPOCH 32:
#  batch 100 loss: 0.6282555416226387
#  batch 200 loss: 0.6324073481559753
#  batch 300 loss: 0.6222285154461861
#  batch 400 loss: 0.6420383670926094
# Train accuracy 79.3:
# Test accuracy 79.3:
# EPOCH 33:
#  batch 100 loss: 0.6286672422289848
#  batch 200 loss: 0.6202926826477051
#  batch 300 loss: 0.6442634969949722
#  batch 400 loss: 0.6295821967720986
# Train accuracy 79.3:
# Test accuracy 79.4:
# EPOCH 34:
#  batch 100 loss: 0.6095300981402397
#  batch 200 loss: 0.6268912354111671
#  batch 300 loss: 0.6300613099336624
#  batch 400 loss: 0.6409286567568779
# Train accuracy 79.4:
# Test accuracy 79.4:
# EPOCH 35:
#  batch 100 loss: 0.6361153465509415
#  batch 200 loss: 0.604127162694931
#  batch 300 loss: 0.62550127774477
#  batch 400 loss: 0.6297998374700546
# Train accuracy 79.4:
# Test accuracy 79.4:
# EPOCH 36:
#  batch 100 loss: 0.6224101257324218
#  batch 200 loss: 0.6277852705121041
#  batch 300 loss: 0.6185386463999748
#  batch 400 loss: 0.6366509029269218
# Train accuracy 79.5:
# Test accuracy 79.4:
# EPOCH 37:
#  batch 100 loss: 0.623292880654335
#  batch 200 loss: 0.6078447592258454
#  batch 300 loss: 0.6257408434152603
#  batch 400 loss: 0.6217884373664856
# Train accuracy 79.5:
# Test accuracy 79.5:
# EPOCH 38:
#  batch 100 loss: 0.6189359503984452
#  batch 200 loss: 0.6268578699231148
#  batch 300 loss: 0.6233726614713668
#  batch 400 loss: 0.6088968035578728
# Train accuracy 79.5:
# Test accuracy 79.5:
# EPOCH 39:
#  batch 100 loss: 0.6171026512980461
#  batch 200 loss: 0.6233363622426986
#  batch 300 loss: 0.6116253554821014
#  batch 400 loss: 0.6265439841151238
# Train accuracy 79.60000000000001:
# Test accuracy 79.60000000000001:
# EPOCH 40:
#  batch 100 loss: 0.6230735075473786
#  batch 200 loss: 0.6187639963626862
#  batch 300 loss: 0.6120944300293922
#  batch 400 loss: 0.5972545450925827
# Train accuracy 79.60000000000001:
# Test accuracy 79.60000000000001:
# EPOCH 41:
#  batch 100 loss: 0.6072752612829209
#  batch 200 loss: 0.6170293152332306
#  batch 300 loss: 0.609738150537014
#  batch 400 loss: 0.6208919978141785
# Train accuracy 79.60000000000001:
# Test accuracy 79.60000000000001:
# EPOCH 42:
#  batch 100 loss: 0.6224745315313339
#  batch 200 loss: 0.6257514107227325
#  batch 300 loss: 0.6064785107970238
#  batch 400 loss: 0.614323046207428
# Train accuracy 79.7:
# Test accuracy 79.60000000000001:
# EPOCH 43:
#  batch 100 loss: 0.6205566191673278
#  batch 200 loss: 0.6200057876110077
#  batch 300 loss: 0.6032192027568817
#  batch 400 loss: 0.60354647397995
# Train accuracy 79.60000000000001:
# Test accuracy 79.60000000000001:
# EPOCH 44:
#  batch 100 loss: 0.6205210262537002
#  batch 200 loss: 0.6081490731239318
#  batch 300 loss: 0.6011984327435493
#  batch 400 loss: 0.614830002784729
# Train accuracy 79.7:
# Test accuracy 79.7:
# EPOCH 45:
#  batch 100 loss: 0.6086271089315415
#  batch 200 loss: 0.6259220507740975
#  batch 300 loss: 0.5977215790748596
#  batch 400 loss: 0.6034358847141266
# Train accuracy 79.7:
# Test accuracy 79.7:
# EPOCH 46:
#  batch 100 loss: 0.6093247979879379
#  batch 200 loss: 0.6141370120644569
#  batch 300 loss: 0.6162997284531593
#  batch 400 loss: 0.6005701065063477
# Train accuracy 79.80000000000001:
# Test accuracy 79.80000000000001:
# EPOCH 47:
#  batch 100 loss: 0.6064797616004944
#  batch 200 loss: 0.5971842178702355
#  batch 300 loss: 0.6202160972356796
#  batch 400 loss: 0.6037932199239731
# Train accuracy 79.80000000000001:
# Test accuracy 79.7:
# EPOCH 48:
#  batch 100 loss: 0.6017970830202103
#  batch 200 loss: 0.6097159492969513
#  batch 300 loss: 0.6023119285702705
#  batch 400 loss: 0.6051967358589172
# Train accuracy 79.80000000000001:
# Test accuracy 79.9:
# EPOCH 49:
#  batch 100 loss: 0.5899055767059326
#  batch 200 loss: 0.6075028240680694
#  batch 300 loss: 0.6068723973631859
#  batch 400 loss: 0.6081333288550377
# Train accuracy 79.80000000000001:
# Test accuracy 79.80000000000001:
# EPOCH 50:
#  batch 100 loss: 0.6023074901103973
#  batch 200 loss: 0.5952453735470772
#  batch 300 loss: 0.6030095365643501
#  batch 400 loss: 0.6010030716657638
# Train accuracy 79.9:
# Test accuracy 79.80000000000001:
# EPOCH 51:
#  batch 100 loss: 0.6081532499194146
#  batch 200 loss: 0.606559753715992
#  batch 300 loss: 0.5983385255932808
#  batch 400 loss: 0.6010947927832604
# Train accuracy 79.9:
# Test accuracy 79.80000000000001:
# EPOCH 52:
#  batch 100 loss: 0.6008142602443695
#  batch 200 loss: 0.6020817396044731
#  batch 300 loss: 0.6093999269604683
#  batch 400 loss: 0.5963248857855796
# Train accuracy 79.9:
# Test accuracy 79.80000000000001:
# EPOCH 53:
#  batch 100 loss: 0.6057565310597419
#  batch 200 loss: 0.5866761031746864
#  batch 300 loss: 0.611026970744133
#  batch 400 loss: 0.6030759835243225
# Train accuracy 79.9:
# Test accuracy 79.9:
# EPOCH 54:
#  batch 100 loss: 0.6025724792480469
#  batch 200 loss: 0.6183950451016426
#  batch 300 loss: 0.5855549460649491
#  batch 400 loss: 0.5917574900388718
# Train accuracy 79.9:
# Test accuracy 79.80000000000001:
# EPOCH 55:
#  batch 100 loss: 0.5983927723765373
#  batch 200 loss: 0.6048171421885491
#  batch 300 loss: 0.587036400437355
#  batch 400 loss: 0.5967565801739693
# Train accuracy 80.0:
# Test accuracy 79.9:
# EPOCH 56:
#  batch 100 loss: 0.6000860717892647
#  batch 200 loss: 0.5905627584457398
#  batch 300 loss: 0.5820044603943825
#  batch 400 loss: 0.6043790701031685
# Train accuracy 79.9:
# Test accuracy 79.9:
# EPOCH 57:
#  batch 100 loss: 0.6012713181972503
#  batch 200 loss: 0.6004117456078529
#  batch 300 loss: 0.5785647889971733
#  batch 400 loss: 0.5973671746253967
# Train accuracy 80.0:
# Test accuracy 80.0:
# EPOCH 58:
#  batch 100 loss: 0.5982033109664917
#  batch 200 loss: 0.593737088739872
#  batch 300 loss: 0.5895815071463585
#  batch 400 loss: 0.6004178336262703
# Train accuracy 80.0:
# Test accuracy 80.0:
# EPOCH 59:
#  batch 100 loss: 0.6064787262678146
#  batch 200 loss: 0.5847757908701897
#  batch 300 loss: 0.5987703862786293
#  batch 400 loss: 0.5773101371526718
# Train accuracy 80.0:
# Test accuracy 80.0:
# EPOCH 60:
#  batch 100 loss: 0.5896191430091858
#  batch 200 loss: 0.5872277948260307
#  batch 300 loss: 0.5933185166120529
#  batch 400 loss: 0.5889866018295288
# Train accuracy 80.0:
# Test accuracy 80.0:
# Learning Rate 1e-05:
# EPOCH 1:
#  batch 100 loss: 2.346744556427002
#  batch 200 loss: 2.338395779132843
#  batch 300 loss: 2.330656278133392
#  batch 400 loss: 2.3174744749069216
# Train accuracy 13.5:
# Test accuracy 13.8:
# EPOCH 2:
#  batch 100 loss: 2.306822576522827
#  batch 200 loss: 2.3039586114883424
#  batch 300 loss: 2.293963522911072
#  batch 400 loss: 2.2925049686431884
# Train accuracy 13.200000000000001:
# Test accuracy 13.700000000000001:
# EPOCH 3:
#  batch 100 loss: 2.282533185482025
#  batch 200 loss: 2.2778021335601806
#  batch 300 loss: 2.2755528926849364
#  batch 400 loss: 2.2723709321022034
# Train accuracy 13.5:
# ...
#  batch 300 loss: 1.9647100615501403
#  batch 400 loss: 1.9597356355190276
# Train accuracy 44.3:
# Test accuracy 46.300000000000004:
# EPOCH 40:
#  batch 100 loss: 1.955362651348114
#  batch 200 loss: 1.9592181539535523
#  batch 300 loss: 1.9486991250514984
#  batch 400 loss: 1.950377094745636
# Train accuracy 44.7:
# Test accuracy 46.6:
# EPOCH 41:
#  batch 100 loss: 1.9493415546417237
#  batch 200 loss: 1.951382385492325
#  batch 300 loss: 1.9421354627609253
#  batch 400 loss: 1.9413282346725464
# Train accuracy 45.1:
# Test accuracy 47.0:
# EPOCH 42:
#  batch 100 loss: 1.9430876028537751
#  batch 200 loss: 1.9441129815578462
#  batch 300 loss: 1.9374273645877838
#  batch 400 loss: 1.9410457599163056
# Train accuracy 45.4:
# Test accuracy 47.3:
# EPOCH 43:
#  batch 100 loss: 1.9383547687530518
#  batch 200 loss: 1.9293957722187043
#  batch 300 loss: 1.935720570087433
#  batch 400 loss: 1.9325687646865846
# Train accuracy 45.7:
# Test accuracy 47.599999999999994:
# EPOCH 44:
#  batch 100 loss: 1.9270977473258972
#  batch 200 loss: 1.9317655670642853
#  batch 300 loss: 1.9203302216529847
#  batch 400 loss: 1.9287147057056426
# Train accuracy 46.1:
# Test accuracy 47.9:
# EPOCH 45:
#  batch 100 loss: 1.9270425415039063
#  batch 200 loss: 1.9232460045814515
#  batch 300 loss: 1.9108746671676635
#  batch 400 loss: 1.9234951746463775
# Train accuracy 46.300000000000004:
# Test accuracy 48.1:
# EPOCH 46:
#  batch 100 loss: 1.9138647174835206
#  batch 200 loss: 1.919966391324997
#  batch 300 loss: 1.9174356687068939
#  batch 400 loss: 1.9120666658878327
# Train accuracy 46.6:
# Test accuracy 48.4:
# EPOCH 47:
#  batch 100 loss: 1.906360808610916
#  batch 200 loss: 1.9141534352302552
#  batch 300 loss: 1.9101688575744629
#  batch 400 loss: 1.9034029400348664
# Train accuracy 46.9:
# Test accuracy 48.6:
# EPOCH 48:
#  batch 100 loss: 1.9002715647220612
#  batch 200 loss: 1.9031857335567475
#  batch 300 loss: 1.9110608506202698
#  batch 400 loss: 1.8997091460227966
# Train accuracy 47.199999999999996:
# Test accuracy 48.8:
# EPOCH 49:
#  batch 100 loss: 1.8998579120635986
#  batch 200 loss: 1.901700692176819
#  batch 300 loss: 1.8901881074905396
#  batch 400 loss: 1.8961353600025177
# Train accuracy 47.5:
# Test accuracy 49.1:
# EPOCH 50:
#  batch 100 loss: 1.891292427778244
#  batch 200 loss: 1.8904122197628022
#  batch 300 loss: 1.8976715087890625
#  batch 400 loss: 1.8914144730567932
# Train accuracy 47.699999999999996:
# Test accuracy 49.4:
# EPOCH 51:
#  batch 100 loss: 1.8857930958271027
#  batch 200 loss: 1.8823096334934235
#  batch 300 loss: 1.8930099153518676
#  batch 400 loss: 1.8853891730308532
# Train accuracy 48.0:
# Test accuracy 49.6:
# EPOCH 52:
#  batch 100 loss: 1.880917887687683
#  batch 200 loss: 1.8760984492301942
#  batch 300 loss: 1.8742097520828247
#  batch 400 loss: 1.8825243186950684
# Train accuracy 48.199999999999996:
# Test accuracy 49.8:
# EPOCH 53:
#  batch 100 loss: 1.878723338842392
#  batch 200 loss: 1.876634567975998
#  batch 300 loss: 1.8697443425655365
#  batch 400 loss: 1.865570377111435
# Train accuracy 48.4:
# Test accuracy 50.1:
# EPOCH 54:
#  batch 100 loss: 1.8807632315158844
#  batch 200 loss: 1.8722757005691528
#  batch 300 loss: 1.8639817583560943
#  batch 400 loss: 1.861215728521347
# Train accuracy 48.6:
# Test accuracy 50.3:
# EPOCH 55:
#  batch 100 loss: 1.8610568118095399
#  batch 200 loss: 1.85768838763237
#  batch 300 loss: 1.8633396220207215
#  batch 400 loss: 1.860105776786804
# Train accuracy 48.8:
# Test accuracy 50.5:
# EPOCH 56:
#  batch 100 loss: 1.8507707154750823
#  batch 200 loss: 1.854461236000061
#  batch 300 loss: 1.8480156171321869
#  batch 400 loss: 1.851338757276535
# Train accuracy 49.0:
# Test accuracy 50.6:
# EPOCH 57:
#  batch 100 loss: 1.8476598000526427
#  batch 200 loss: 1.8486573004722595
#  batch 300 loss: 1.841034497022629
#  batch 400 loss: 1.8323953223228455
# Train accuracy 49.3:
# Test accuracy 50.8:
# EPOCH 58:
#  batch 100 loss: 1.8364355623722077
#  batch 200 loss: 1.8281034433841705
#  batch 300 loss: 1.8351113414764404
#  batch 400 loss: 1.8244175124168396
# Train accuracy 49.6:
# Test accuracy 51.1:
# EPOCH 59:
#  batch 100 loss: 1.8170157361030579
#  batch 200 loss: 1.82214311003685
#  batch 300 loss: 1.8225311684608458
#  batch 400 loss: 1.8149368953704834
# Train accuracy 50.2:
# Test accuracy 51.6:
# EPOCH 60:
#  batch 100 loss: 1.8070057439804077
#  batch 200 loss: 1.8145975720882417
#  batch 300 loss: 1.8046433544158935
#  batch 400 loss: 1.8030621194839478
# Train accuracy 50.9:
# Test accuracy 52.300000000000004:
# Learning Rate 1e-07:
# EPOCH 1:
#  batch 100 loss: 2.4157001090049746
#  batch 200 loss: 2.406997573375702
#  batch 300 loss: 2.4067272925376892
#  batch 400 loss: 2.4185007572174073
# Train accuracy 9.3:
# Test accuracy 8.9:
# EPOCH 2:
#  batch 100 loss: 2.409903862476349
#  batch 200 loss: 2.410643594264984
#  batch 300 loss: 2.41212703704834
#  batch 400 loss: 2.408921480178833
# Train accuracy 9.4:
# Test accuracy 9.0:
# EPOCH 3:
#  batch 100 loss: 2.4109546446800234
#  batch 200 loss: 2.413467171192169
#  batch 300 loss: 2.407862141132355
#  batch 400 loss: 2.408212974071503
# Train accuracy 9.4:
# Test accuracy 9.0:
# EPOCH 4:
#  batch 100 loss: 2.4114301705360415
#  batch 200 loss: 2.4082210779190065
#  batch 300 loss: 2.4077978801727293
#  batch 400 loss: 2.4076517152786256
# Train accuracy 9.4:
# Test accuracy 9.0:
# EPOCH 5:
#  batch 100 loss: 2.4115014266967774
#  batch 200 loss: 2.4133859658241272
#  batch 300 loss: 2.415693700313568
#  batch 400 loss: 2.401525650024414
# Train accuracy 9.4:
# Test accuracy 9.0:
# EPOCH 6:
#  batch 100 loss: 2.4098679184913636
#  batch 200 loss: 2.4076237297058105
#  batch 300 loss: 2.4101554775238037
#  batch 400 loss: 2.4075009536743166
# Train accuracy 9.4:
# Test accuracy 9.0:
# EPOCH 7:
#  batch 100 loss: 2.402419307231903
#  batch 200 loss: 2.41270192861557
#  batch 300 loss: 2.4115300607681274
#  batch 400 loss: 2.4048652482032775
# Train accuracy 9.4:
# Test accuracy 9.0:
# EPOCH 8:
#  batch 100 loss: 2.4063512802124025
#  batch 200 loss: 2.4083012080192567
#  batch 300 loss: 2.4083817982673645
#  batch 400 loss: 2.411748285293579
# Train accuracy 9.3:
# Test accuracy 9.0:
# EPOCH 9:
#  batch 100 loss: 2.403767206668854
#  batch 200 loss: 2.4024265575408936
#  batch 300 loss: 2.4112773060798647
#  batch 400 loss: 2.409359407424927
# Train accuracy 9.4:
# Test accuracy 9.0:
# EPOCH 10:
#  batch 100 loss: 2.408382983207703
#  batch 200 loss: 2.40805037021637
#  batch 300 loss: 2.405064859390259
#  batch 400 loss: 2.410018308162689
# Train accuracy 9.4:
# Test accuracy 9.0:
# EPOCH 11:
#  batch 100 loss: 2.403406319618225
#  batch 200 loss: 2.405477566719055
#  batch 300 loss: 2.4134390902519227
#  batch 400 loss: 2.40612224817276
# Train accuracy 9.4:
# Test accuracy 9.0:
# EPOCH 12:
#  batch 100 loss: 2.4051927638053896
#  batch 200 loss: 2.4054405665397645
#  batch 300 loss: 2.4041138458251954
#  batch 400 loss: 2.4075762677192687
# Train accuracy 9.4:
# Test accuracy 9.0:
# EPOCH 13:
#  batch 100 loss: 2.4068657612800597
#  batch 200 loss: 2.4070948719978333
#  batch 300 loss: 2.402933483123779
#  batch 400 loss: 2.400879669189453
# Train accuracy 9.4:
# Test accuracy 8.9:
# EPOCH 14:
#  batch 100 loss: 2.408629412651062
#  batch 200 loss: 2.404972803592682
#  batch 300 loss: 2.3980193161964416
#  batch 400 loss: 2.4009775948524474
# Train accuracy 9.4:
# Test accuracy 8.9:
# EPOCH 15:
#  batch 100 loss: 2.402884421348572
#  batch 200 loss: 2.408254837989807
#  batch 300 loss: 2.406554341316223
#  batch 400 loss: 2.401079580783844
# Train accuracy 9.4:
# Test accuracy 8.9:
# EPOCH 16:
#  batch 100 loss: 2.3963016414642335
#  batch 200 loss: 2.402372000217438
#  batch 300 loss: 2.4063899421691897
#  batch 400 loss: 2.4062089943885803
# Train accuracy 9.4:
# Test accuracy 9.0:
# EPOCH 17:
#  batch 100 loss: 2.4032590270042418
#  batch 200 loss: 2.4071428036689757
#  batch 300 loss: 2.3982170844078063
#  batch 400 loss: 2.4030713963508608
# Train accuracy 9.4:
# Test accuracy 9.0:
# EPOCH 18:
#  batch 100 loss: 2.4061655831336974
#  batch 200 loss: 2.403995201587677
#  batch 300 loss: 2.399418902397156
#  batch 400 loss: 2.3983060574531554
# Train accuracy 9.4:
# Test accuracy 9.0:
# EPOCH 19:
#  batch 100 loss: 2.3981139731407164
#  batch 200 loss: 2.404978847503662
#  batch 300 loss: 2.4057181429862977
#  batch 400 loss: 2.401449592113495
# Train accuracy 9.4:
# Test accuracy 9.0:
# EPOCH 20:
#  batch 100 loss: 2.4023501682281494
#  batch 200 loss: 2.3994290614128113
#  batch 300 loss: 2.401230275630951
#  batch 400 loss: 2.407620828151703
# Train accuracy 9.5:
# Test accuracy 9.0:
# EPOCH 21:
#  batch 100 loss: 2.3983621120452883
#  batch 200 loss: 2.400726172924042
#  batch 300 loss: 2.4038339352607725
#  batch 400 loss: 2.403302173614502
# Train accuracy 9.5:
# Test accuracy 9.0:
# EPOCH 22:
#  batch 100 loss: 2.392973883152008
#  batch 200 loss: 2.4011115074157714
#  batch 300 loss: 2.4061058735847474
#  batch 400 loss: 2.401794629096985
# Train accuracy 9.5:
# Test accuracy 8.9:
# EPOCH 23:
#  batch 100 loss: 2.393407905101776
#  batch 200 loss: 2.401890676021576
#  batch 300 loss: 2.404687595367432
#  batch 400 loss: 2.4000006175041197
# Train accuracy 9.5:
# Test accuracy 8.9:
# EPOCH 24:
#  batch 100 loss: 2.3933752822875975
#  batch 200 loss: 2.403033587932587
#  batch 300 loss: 2.398504891395569
#  batch 400 loss: 2.400030300617218
# Train accuracy 9.5:
# Test accuracy 8.9:
# EPOCH 25:
#  batch 100 loss: 2.4006973123550415
#  batch 200 loss: 2.399919693470001
#  batch 300 loss: 2.3983641147613524
#  batch 400 loss: 2.3983200573921204
# Train accuracy 9.5:
# Test accuracy 8.9:
# EPOCH 26:
#  batch 100 loss: 2.3983654236793517
#  batch 200 loss: 2.4018038177490233
#  batch 300 loss: 2.3969155240058897
#  batch 400 loss: 2.3953831076622008
# Train accuracy 9.5:
# Test accuracy 9.0:
# EPOCH 27:
#  batch 100 loss: 2.3904498505592344
#  batch 200 loss: 2.3999012017250063
#  batch 300 loss: 2.4022963643074036
#  batch 400 loss: 2.3988005781173705
# Train accuracy 9.5:
# Test accuracy 9.0:
# EPOCH 28:
#  batch 100 loss: 2.4009740948677063
#  batch 200 loss: 2.3970956802368164
#  batch 300 loss: 2.3973758578300477
#  batch 400 loss: 2.396980700492859
# Train accuracy 9.5:
# Test accuracy 9.0:
# EPOCH 29:
#  batch 100 loss: 2.393684253692627
#  batch 200 loss: 2.3982378244400024
#  batch 300 loss: 2.3959078407287597
#  batch 400 loss: 2.400261526107788
# Train accuracy 9.5:
# Test accuracy 9.0:
# EPOCH 30:
#  batch 100 loss: 2.401255521774292
#  batch 200 loss: 2.392339584827423
#  batch 300 loss: 2.401253509521484
#  batch 400 loss: 2.3943072748184204
# Train accuracy 9.5:
# Test accuracy 9.0:
# EPOCH 31:
#  batch 100 loss: 2.398677632808685
#  batch 200 loss: 2.3961509704589843
#  batch 300 loss: 2.3939520215988157
#  batch 400 loss: 2.3921573114395143
# Train accuracy 9.5:
# Test accuracy 9.0:
# EPOCH 32:
#  batch 100 loss: 2.3993595838546753
#  batch 200 loss: 2.393244857788086
#  batch 300 loss: 2.3952999901771546
#  batch 400 loss: 2.394233436584473
# Train accuracy 9.6:
# Test accuracy 9.1:
# EPOCH 33:
#  batch 100 loss: 2.3884753489494326
#  batch 200 loss: 2.3942890691757204
#  batch 300 loss: 2.3962785696983335
#  batch 400 loss: 2.397984519004822
# Train accuracy 9.6:
# Test accuracy 9.0:
# EPOCH 34:
#  batch 100 loss: 2.392841250896454
#  batch 200 loss: 2.395302233695984
#  batch 300 loss: 2.3952675533294676
#  batch 400 loss: 2.3936481285095215
# Train accuracy 9.6:
# Test accuracy 9.0:
# EPOCH 35:
#  batch 100 loss: 2.396166820526123
#  batch 200 loss: 2.391722915172577
#  batch 300 loss: 2.3903513956069946
#  batch 400 loss: 2.3989340901374816
# Train accuracy 9.6:
# Test accuracy 9.1:
# EPOCH 36:
#  batch 100 loss: 2.3961413311958313
#  batch 200 loss: 2.3923672437667847
#  batch 300 loss: 2.3897530031204224
#  batch 400 loss: 2.3955670189857483
# Train accuracy 9.700000000000001:
# Test accuracy 9.1:
# EPOCH 37:
#  batch 100 loss: 2.392861495018005
#  batch 200 loss: 2.3942768955230713
#  batch 300 loss: 2.389700086116791
#  batch 400 loss: 2.3934438753128053
# Train accuracy 9.700000000000001:
# Test accuracy 9.1:
# EPOCH 38:
#  batch 100 loss: 2.388263578414917
#  batch 200 loss: 2.3947169470787046
#  batch 300 loss: 2.3934127569198607
#  batch 400 loss: 2.3925698804855347
# Train accuracy 9.700000000000001:
# Test accuracy 9.1:
# EPOCH 39:
#  batch 100 loss: 2.3939047932624815
#  batch 200 loss: 2.3908088326454164
#  batch 300 loss: 2.392813873291016
#  batch 400 loss: 2.3900144577026365
# Train accuracy 9.700000000000001:
# Test accuracy 9.2:
# EPOCH 40:
#  batch 100 loss: 2.395376400947571
#  batch 200 loss: 2.3949172067642213
#  batch 300 loss: 2.390176751613617
#  batch 400 loss: 2.39067373752594
# Train accuracy 9.700000000000001:
# Test accuracy 9.2:
# EPOCH 41:
#  batch 100 loss: 2.3895791506767274
#  batch 200 loss: 2.3955216240882873
#  batch 300 loss: 2.385744309425354
#  batch 400 loss: 2.392647089958191
# Train accuracy 9.8:
# Test accuracy 9.2:
# EPOCH 42:
#  batch 100 loss: 2.3881894636154173
#  batch 200 loss: 2.386785991191864
#  batch 300 loss: 2.3916308522224425
#  batch 400 loss: 2.393929784297943
# Train accuracy 9.8:
# Test accuracy 9.2:
# EPOCH 43:
#  batch 100 loss: 2.3894325160980223
#  batch 200 loss: 2.383966724872589
#  batch 300 loss: 2.3988825559616087
#  batch 400 loss: 2.387021336555481
# Train accuracy 9.8:
# Test accuracy 9.3:
# EPOCH 44:
#  batch 100 loss: 2.396270260810852
#  batch 200 loss: 2.3870557165145874
#  batch 300 loss: 2.3889808464050293
#  batch 400 loss: 2.38334908246994
# Train accuracy 9.9:
# Test accuracy 9.2:
# EPOCH 45:
#  batch 100 loss: 2.389704782962799
#  batch 200 loss: 2.3916474962234497
#  batch 300 loss: 2.387538311481476
#  batch 400 loss: 2.388226408958435
# Train accuracy 9.9:
# Test accuracy 9.3:
# EPOCH 46:
#  batch 100 loss: 2.3962892627716066
#  batch 200 loss: 2.3905797362327577
#  batch 300 loss: 2.388572220802307
#  batch 400 loss: 2.3836772441864014
# Train accuracy 9.9:
# Test accuracy 9.3:
# EPOCH 47:
#  batch 100 loss: 2.3942895698547364
#  batch 200 loss: 2.383615646362305
#  batch 300 loss: 2.3853747129440306
#  batch 400 loss: 2.3877189922332764
# Train accuracy 10.0:
# Test accuracy 9.3:
# EPOCH 48:
#  batch 100 loss: 2.392269332408905
#  batch 200 loss: 2.3920516109466554
#  batch 300 loss: 2.38764315366745
#  batch 400 loss: 2.382165579795837
# Train accuracy 10.0:
# Test accuracy 9.3:
# EPOCH 49:
#  batch 100 loss: 2.3902643442153932
#  batch 200 loss: 2.393307776451111
#  batch 300 loss: 2.386401183605194
#  batch 400 loss: 2.387799859046936
# Train accuracy 10.0:
# Test accuracy 9.4:
# EPOCH 50:
#  batch 100 loss: 2.3837429022789003
#  batch 200 loss: 2.3859748911857603
#  batch 300 loss: 2.385849242210388
#  batch 400 loss: 2.3875359654426576
# Train accuracy 10.0:
# Test accuracy 9.4:
# EPOCH 51:
#  batch 100 loss: 2.3822792291641237
#  batch 200 loss: 2.3867075443267822
#  batch 300 loss: 2.3894008231163024
#  batch 400 loss: 2.385983588695526
# Train accuracy 10.100000000000001:
# Test accuracy 9.4:
# EPOCH 52:
#  batch 100 loss: 2.3871712613105776
#  batch 200 loss: 2.3895937776565552
#  batch 300 loss: 2.3868120527267456
#  batch 400 loss: 2.3796546459198
# Train accuracy 10.100000000000001:
# Test accuracy 9.5:
# EPOCH 53:
#  batch 100 loss: 2.3859943556785583
#  batch 200 loss: 2.385691421031952
#  batch 300 loss: 2.385469746589661
#  batch 400 loss: 2.3863242936134337
# Train accuracy 10.100000000000001:
# Test accuracy 9.5:
# EPOCH 54:
#  batch 100 loss: 2.3851257753372193
#  batch 200 loss: 2.386648075580597
#  batch 300 loss: 2.382741210460663
#  batch 400 loss: 2.3805884671211244
# Train accuracy 10.2:
# Test accuracy 9.5:
# EPOCH 55:
#  batch 100 loss: 2.3863140606880187
#  batch 200 loss: 2.3834706354141235
#  batch 300 loss: 2.3862746286392214
#  batch 400 loss: 2.378420832157135
# Train accuracy 10.2:
# Test accuracy 9.5:
# EPOCH 56:
#  batch 100 loss: 2.3813860392570496
#  batch 200 loss: 2.3873652029037475
#  batch 300 loss: 2.3881380581855773
#  batch 400 loss: 2.3788676261901855
# Train accuracy 10.299999999999999:
# Test accuracy 9.5:
# EPOCH 57:
#  batch 100 loss: 2.383852744102478
#  batch 200 loss: 2.381528067588806
#  batch 300 loss: 2.384029884338379
#  batch 400 loss: 2.388584690093994
# Train accuracy 10.299999999999999:
# Test accuracy 9.6:
# EPOCH 58:
#  batch 100 loss: 2.3822762393951415
#  batch 200 loss: 2.384854881763458
#  batch 300 loss: 2.3824937605857848
#  batch 400 loss: 2.3840554475784304
# Train accuracy 10.299999999999999:
# Test accuracy 9.6:
# EPOCH 59:
#  batch 100 loss: 2.382192542552948
#  batch 200 loss: 2.386259973049164
#  batch 300 loss: 2.3811566114425657
#  batch 400 loss: 2.3842579102516175
# Train accuracy 10.299999999999999:
# Test accuracy 9.700000000000001:
# EPOCH 60:
#  batch 100 loss: 2.3846883368492127
#  batch 200 loss: 2.382340660095215
#  batch 300 loss: 2.382503478527069
#  batch 400 loss: 2.382993381023407
# Train accuracy 10.4:
# Test accuracy 9.700000000000001:

# %%
import numpy as np
epochs_arr = np.arange(0, len(losses_arr[0]))

# %%
# Plot training loss
x = np.array(epochs_arr)
for i,train_loss in enumerate(losses_arr):
  ypoints = np.array(train_loss)
  plt.plot(x, ypoints, label = lrs[i])

plt.xlabel("Epochs")
plt.ylabel("train Loss")
plt.legend()
plt.title('Scheduler=None, Batch_size=128, Optimizer=SGD')
plt.show()

# %%
# Plot training accuracy
x = np.array(epochs_arr)
for i,train_acc in enumerate(train_accuracy_arr):
  ypoints = np.array(train_acc)
  plt.plot(x, ypoints, label = lrs[i])

plt.xlabel("Epochs")
plt.ylabel("train Accuracy")
plt.legend()
plt.title('Scheduler=None, Batch_size=128, Optimizer=SGD')
plt.show()

# %%
# Plot test accuracy
x = np.array(epochs_arr)
for i,test_acc in enumerate(test_accuracy_arr):
  ypoints = np.array(test_acc)
  plt.plot(x, ypoints, label = lrs[i])

plt.xlabel("Epochs")
plt.ylabel("test Accuracy")
plt.legend()
plt.title('Scheduler=None, Batch_size=128, Optimizer=SGD')
plt.show()

# %%
# Plot test and training accuracy
x = np.array(epochs_arr)
for i,lr in enumerate(lrs):
  ypoints_1 = np.array(train_accuracy_arr[i])
  ypoints_2 = np.array(test_accuracy_arr[i])
  plt.plot(x, ypoints_1, label = 'Train')
  plt.plot(x, ypoints_2, label = 'Test')
  plt.xlabel("Epochs")
  plt.ylabel("Accuracy")
  plt.legend()
  plt.title(F'Scheduler=None, Batch_size=128, Optimizer=SGD, LR={lr}')
  plt.show()

# %% [markdown]
# ### Load model

# %%
from google.colab import drive
drive.mount('/content/drive/')
model_save_name = '1695168105559.8071_Step_bs128_e30_SGD_ss10_gamma0.1_cifar'
path = F"/content/drive/MyDrive/Ell409/CIFAR/scheduler/{model_save_name}.pt"
net.load_state_dict(t.load(path))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 from google.colab import drive
#       2 drive.mount('/content/drive/')
#       3 model_save_name = '1695168105559.8071_Step_bs128_e30_SGD_ss10_gamma0.1_cifar'
#
# ModuleNotFoundError: No module named 'google.colab'

# %%
test(net,test_loader)

# %%
#hello kuch likhlo warna inactivity timeout de dega yeh

# %%
import torch as t
import torchvision.datasets as datasets
import torchvision.transforms as transforms
import torch.nn as nn
import matplotlib.pyplot as plt
import torch.optim as optim
import torch.optim.lr_scheduler as lr_scheduler
from torch.optim.lr_scheduler import ReduceLROnPlateau, StepLR, ExponentialLR

# %% [markdown]
# ### Model

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net,self).__init__()
        self.linear1 = nn.Linear(3*32*32, 10)
        self.relu = nn.ReLU()

    def forward(self, img): #convert + flatten
        x = img.view(-1, 3*32*32)
        x = self.relu(self.linear1(x))
        return x
net = Net()

# %% [markdown]
# ### Hyperparams

# %%
num_epochs=80
after_every=100
loss_fn = nn.CrossEntropyLoss()

# %%
import ssl
ssl._create_default_https_context = ssl._create_unverified_context
transform = transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5)),])

mnist_trainset = datasets.CIFAR10(root='./data', train=True, download=True, transform=transform)
# train_loader = t.utils.data.DataLoader(mnist_trainset, batch_size=batch_size, shuffle=True)

mnist_testset = datasets.CIFAR10(root='./data', train=False, download=True, transform=transform)
# test_loader = t.utils.data.DataLoader(mnist_testset, batch_size=batch_size, shuffle=True)
mnist_testset.data.shape
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# (10000, 32, 32, 3)

# %% [markdown]
# ### Training

# %%
def train_one_epoch(model, epoch_index, optimizer, train_dataset):
    running_loss = 0.
    last_loss = 0.

    for i, data in enumerate(train_dataset):
        # Every data instance is an input + label pair
        # data.shape=torch.Size([10, 1, 28, 28]) --> 10 images,labels
        inputs, labels = data

        # Zero your gradients for every batch!
        optimizer.zero_grad()

        # Make predictions for this batch
        outputs = model(inputs.view(-1, 3*32*32))


        # Compute the loss and its gradients
        loss = loss_fn(outputs, labels)
        loss.backward()

        # Adjust learning weights
        optimizer.step()

        # Gather data and report
        running_loss += loss.item()

        if i % after_every == after_every-1:
            last_loss = running_loss / after_every # loss per after_every batches
            print(' batch {} loss: {}'.format(i + 1, last_loss))
            running_loss = 0.

    return last_loss

# %% [markdown]
# ### Evaluate

# %%
def test(model, loader):
  total=0
  correct=0
  model.eval()
  with t.no_grad():
      for data in loader:
          x, y = data
          output = model(x.view(-1, 3*32*32))
          for idx, i in enumerate(output):
              if t.argmax(i) == y[idx]:
                  correct +=1
              total +=1
  return round(correct/total, 3)*100

# %%
def train_model(model, epochs, train_dataset, test_dataset, optimizer, scheduler, LR_type):
  epoch_number = 0

  losses = []
  train_accuracy = []
  test_accuracy = []

  for epoch in range(epochs):
      print('EPOCH {}:'.format(epoch_number + 1))

      # Make sure gradient tracking is on, and do a pass over the data
      model.train(True)
      avg_loss = train_one_epoch(model, epoch_number,optimizer,train_dataset)
      losses.append(avg_loss)

      # Train accuracy
      train_acc = test(model, train_dataset)
      train_accuracy.append(train_acc)

      # Test accuracy
      test_acc = test(model, test_dataset)
      test_accuracy.append(test_acc)

      if LR_type=='Plateau':
        before_lr = optimizer.param_groups[0]["lr"]
        scheduler.step(avg_loss)
        after_lr = optimizer.param_groups[0]["lr"]
        print('lr {} -> {}'.format(before_lr, after_lr))

      elif LR_type!='None':
        before_lr = optimizer.param_groups[0]["lr"]
        scheduler.step()
        after_lr = optimizer.param_groups[0]["lr"]
        print('lr {} -> {}'.format(before_lr, after_lr))

      print('Train accuracy {}:'.format(train_acc))
      print('Test accuracy {}:'.format(test_acc))
      epoch_number += 1
  return losses, train_accuracy, test_accuracy

# %%
import datetime as dt

def train_with_batches(starting_lr, l2reg):
  losses_arr = []
  train_accuracy_arr = []
  test_accuracy_arr = []
  batch_sizes = [1, 32, 64, 128, 256, 1000, 10000, 50000]
  description = []

  # Different batch sizes
  for bs in batch_sizes:
    train_loader = t.utils.data.DataLoader(mnist_trainset, batch_size=bs, shuffle=True)
    test_loader = t.utils.data.DataLoader(mnist_testset, batch_size=bs, shuffle=True)
    print('Batch Size {}:'.format(bs))
    net_new = Net()
    optimizerr = t.optim.SGD(net_new.parameters(), lr=starting_lr, weight_decay=l2reg)
    scheduler = StepLR(optimizerr, 25, gamma=0.1)

    losses, train_accuracy, test_accuracy = train_model(net_new, num_epochs, train_loader, test_loader, optimizerr, scheduler, 'Step')

    losses_arr.append(losses)
    train_accuracy_arr.append(train_accuracy)
    test_accuracy_arr.append(test_accuracy)
    description.append('Starting LR:{}, L2Reg:{}, Batch Size:{}'.format(starting_lr, l2reg, bs))

    # save model
    ts_now = dt.datetime.now()
    unix_timestamp = dt.datetime.timestamp(ts_now)*1000
    model_save_name = str(unix_timestamp)
    path = F"{model_save_name}_L2Reg={l2reg}_bs{bs}_e{num_epochs}_SGD_step.pt"
    t.save(net.state_dict(), path)

  return description, losses_arr, train_accuracy_arr, test_accuracy_arr

# %%
import csv
def save_to_csv(filename, description, losses_arr, train_acc_arr, test_acc_arr):
  # Create a CSV file and write data to it
  with open(filename+'.csv', 'w', newline='') as csvfile:
    for i, desc in enumerate(description):
      fieldnames = ['Description', 'epoch', 'train_loss', 'train_accuracy', 'test_accuracy']
      writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
      writer.writeheader()
      for epoch, (loss, train, test) in enumerate(zip(losses_arr[i], train_acc_arr[i], test_acc_arr[i]), 1):
          writer.writerow({'Description':description[i], 'epoch': epoch, 'train_loss': loss, 'train_accuracy': train, 'test_accuracy': test})

# %% [markdown]
# ### Plotting- Starting LR=0.01
# #### Reg strength = 1e-5

# %%
lr = 0.01
l2reg = 1e-5
batch_sizes = [32, 64, 128, 256, 1000, 10000, 50000]
description, losses_arr, train_accuracy_arr, test_accuracy_arr = train_with_batches(lr, l2reg)
save_to_csv('Batches', description, losses_arr, train_accuracy_arr, test_accuracy_arr)
# Out:
# Batch Size 1:
# EPOCH 1:
#  batch 100 loss: 2.9444296142458914
#  batch 200 loss: 2.761859066504112
#  batch 300 loss: 2.7792041556516414
#  batch 400 loss: 2.555312749100849
#  batch 500 loss: 3.1970697918487714
#  batch 600 loss: 2.8204433414039203
#  batch 700 loss: 2.911965195867233
#  batch 800 loss: 2.9209188179834746
#  batch 900 loss: 3.011567201069083
#  batch 1000 loss: 2.932597738740733
#  batch 1100 loss: 3.1891358943935484
#  batch 1200 loss: 2.791743071353994
#  batch 1300 loss: 2.8252381711127237
#  batch 1400 loss: 2.7210345222960313
#  batch 1500 loss: 2.95427884247154
#  batch 1600 loss: 3.412584779635072
#  batch 1700 loss: 2.7506171143334357
#  batch 1800 loss: 2.6388688990630182
#  batch 1900 loss: 2.738911866264025
#  batch 2000 loss: 3.107839865811984
#  batch 2100 loss: 3.056819430205651
#  batch 2200 loss: 2.939740058649331
#  batch 2300 loss: 2.679292058610081
#  batch 2400 loss: 2.8690083588380366
#  batch 2500 loss: 2.662338998564228
#  batch 2600 loss: 2.9881004424957793
#  batch 2700 loss: 2.6437643200371483
#  batch 2800 loss: 3.141373592149466
#  batch 2900 loss: 3.271864374615252
#  batch 3000 loss: 2.677877227694844
#  batch 3100 loss: 3.075801434934547
#  batch 3200 loss: 3.150578046712326
#  batch 3300 loss: 2.7584534744633493
#  batch 3400 loss: 3.3606904239580033
#  batch 3500 loss: 2.938769781442825
#  batch 3600 loss: 2.5319246731651948
#  batch 3700 loss: 3.051187938085641
#  batch 3800 loss: 2.9341647353236113
#  batch 3900 loss: 2.8962307169148493
#  batch 4000 loss: 2.907842729478434
#  batch 4100 loss: 2.476222082829005
#  batch 4200 loss: 2.8490751616421037
#  batch 4300 loss: 2.68032520101493
#  batch 4400 loss: 2.7678209051582554
#  batch 4500 loss: 3.135455665594427
#  batch 4600 loss: 2.1958761216130007
#  batch 4700 loss: 3.1388487797678626
#  batch 4800 loss: 2.482803302570236
#  batch 4900 loss: 2.819533588759368
#  batch 5000 loss: 2.9840399095322936
#  batch 5100 loss: 2.55390042336192
#  batch 5200 loss: 2.900204645271929
#  batch 5300 loss: 3.168312170133504
#  batch 5400 loss: 2.886483261000831
#  batch 5500 loss: 2.792664133678918
#  batch 5600 loss: 3.240018283042591
#  batch 5700 loss: 2.6680751699896064
#  batch 5800 loss: 2.833023996260599
#  batch 5900 loss: 2.4871212044300774
#  batch 6000 loss: 2.6902898471150536
#  batch 6100 loss: 3.031231429835316
#  batch 6200 loss: 2.8206626284346568
#  batch 6300 loss: 2.943963694833219
#  batch 6400 loss: 2.7916145583003527
#  batch 6500 loss: 3.0609902351279743
#  batch 6600 loss: 2.741141513035109
#  batch 6700 loss: 2.820442585230339
#  batch 6800 loss: 2.9784854681789876
#  batch 6900 loss: 3.203353552399203
#  batch 7000 loss: 3.0282185189716984
#  batch 7100 loss: 2.59596508934992
#  batch 7200 loss: 3.2251856951418088
#  batch 7300 loss: 2.47804216548393
#  batch 7400 loss: 2.5062124112062154
#  batch 7500 loss: 3.2250356310606003
#  batch 7600 loss: 2.9209325587213972
#  batch 7700 loss: 2.758411483599575
#  batch 7800 loss: 2.6123339677922193
#  batch 7900 loss: 2.628909689243883
#  batch 8000 loss: 2.4278958136192523
#  batch 8100 loss: 2.409680106984597
#  batch 8200 loss: 2.8973723570880248
#  batch 8300 loss: 2.7317424529907295
#  batch 8400 loss: 3.2986321679275714
#  batch 8500 loss: 3.0373937489977108
#  batch 8600 loss: 2.5596779629448427
#  batch 8700 loss: 3.1553556609805673
#  batch 8800 loss: 3.030156340142712
#  batch 8900 loss: 3.1323254475035354
#  batch 9000 loss: 2.2079147463983095
#  batch 9100 loss: 3.04936165469815
#  batch 9200 loss: 2.7045594815909864
#  batch 9300 loss: 2.6587438673063297
#  batch 9400 loss: 2.9879927030811086
#  batch 9500 loss: 2.7278688450393385
#  batch 9600 loss: 2.4771849110512996
#  batch 9700 loss: 2.9638698838176696
#  batch 9800 loss: 3.2250538992774183
#  batch 9900 loss: 2.459586425450398
#  batch 10000 loss: 3.1588085197531472
#  batch 10100 loss: 2.3182939159661693
#  batch 10200 loss: 2.6645713222160703
#  batch 10300 loss: 2.7234513942117338
#  batch 10400 loss: 2.6870091477036477
#  batch 10500 loss: 3.1816809377352957
#  batch 10600 loss: 3.027777269536455
#  batch 10700 loss: 2.3556610077878544
#  batch 10800 loss: 3.452465571971261
#  batch 10900 loss: 2.721024824961787
#  batch 11000 loss: 2.941877976139294
#  batch 11100 loss: 2.5159441716544286
#  batch 11200 loss: 2.793816900451784
#  batch 11300 loss: 3.3794230855535714
#  batch 11400 loss: 2.8472666037305316
#  batch 11500 loss: 3.1916796870622783
#  batch 11600 loss: 2.545959103271707
#  batch 11700 loss: 2.708861608047737
#  batch 11800 loss: 2.656546136284586
#  batch 11900 loss: 3.1389231013634706
#  batch 12000 loss: 2.8774595286324622
#  batch 12100 loss: 3.471587116481678
#  batch 12200 loss: 3.2397944198489497
#  batch 12300 loss: 2.5812265742285856
#  batch 12400 loss: 2.36800583714376
#  batch 12500 loss: 2.712196325611867
#  batch 12600 loss: 2.4726969380263473
#  batch 12700 loss: 3.2942632591073924
#  batch 12800 loss: 2.6865954108059666
#  batch 12900 loss: 2.326790215538058
#  batch 13000 loss: 2.3237809614044274
#  batch 13100 loss: 2.7181226481182965
#  batch 13200 loss: 2.6919956643228944
#  batch 13300 loss: 3.2079617282748223
#  batch 13400 loss: 2.473221227605827
#  batch 13500 loss: 3.122345289187797
#  batch 13600 loss: 3.360784268733114
#  batch 13700 loss: 2.86515815643515
#  batch 13800 loss: 2.921019310444826
#  batch 13900 loss: 2.908215840182602
#  batch 14000 loss: 3.0084454027027823
#  batch 14100 loss: 2.778224434942494
#  batch 14200 loss: 2.6074751541180374
#  batch 14300 loss: 2.858801744169905
#  batch 14400 loss: 2.75367073004134
#  batch 14500 loss: 2.5453537729119127
#  batch 14600 loss: 2.4486577983375173
#  batch 14700 loss: 2.8558896987827573
#  batch 14800 loss: 2.9726044055988314
#  batch 14900 loss: 2.667678860059823
#  batch 15000 loss: 2.5165777519980477
#  batch 15100 loss: 2.731601779338671
#  batch 15200 loss: 2.758929751589603
#  batch 15300 loss: 2.785377453842666
#  batch 15400 loss: 2.885789159189153
#  batch 15500 loss: 2.859681913840468
#  batch 15600 loss: 3.124120922512375
#  batch 15700 loss: 2.6333189469649367
#  batch 15800 loss: 2.324604818451626
#  batch 15900 loss: 2.9055673987859314
#  batch 16000 loss: 2.447258222770324
#  batch 16100 loss: 2.7341156021802133
#  batch 16200 loss: 2.494022642194686
#  batch 16300 loss: 3.5089625745809574
#  batch 16400 loss: 2.4879704785137435
#  batch 16500 loss: 2.8294541758029665
#  batch 16600 loss: 2.6777680860502278
#  batch 16700 loss: 2.799554565157741
#  batch 16800 loss: 2.5535612102428784
#  batch 16900 loss: 2.8693726744474772
#  batch 17000 loss: 2.651500193523243
#  batch 17100 loss: 3.117170124333352
#  batch 17200 loss: 3.3323282745372853
#  batch 17300 loss: 3.124013389199972
#  batch 17400 loss: 2.674446788914502
#  batch 17500 loss: 2.8745692057014547
#  batch 17600 loss: 2.841886704722419
#  batch 17700 loss: 2.727078856316224
#  batch 17800 loss: 2.218620497243828
#  batch 17900 loss: 2.648668882147506
#  batch 18000 loss: 2.767664289702916
#  batch 18100 loss: 2.5255860473914074
#  batch 18200 loss: 2.644640547953604
#  batch 18300 loss: 2.645268270643428
#  batch 18400 loss: 2.7626365944210556
#  batch 18500 loss: 2.817195854174788
#  batch 18600 loss: 2.3991189090381524
#  batch 18700 loss: 2.8129020951559687
#  batch 18800 loss: 2.9475613982789217
#  batch 18900 loss: 2.6485388290823177
#  batch 19000 loss: 2.6675843223929405
#  batch 19100 loss: 2.707784314124874
#  batch 19200 loss: 2.9203783379867447
#  batch 19300 loss: 2.691013129744679
#  batch 19400 loss: 2.6941844818354004
#  batch 19500 loss: 2.9943396144487635
#  batch 19600 loss: 2.9546418234007366
#  batch 19700 loss: 2.8234155283574363
#  batch 19800 loss: 2.595827644574365
#  batch 19900 loss: 2.443350292992791
#  batch 20000 loss: 2.6629318887371483
#  batch 20100 loss: 2.443143101471069
#  batch 20200 loss: 2.635839501544833
#  batch 20300 loss: 2.801612444107668
#  batch 20400 loss: 2.9886092101270334
#  batch 20500 loss: 2.3424385327157053
#  batch 20600 loss: 3.317828105620574
#  batch 20700 loss: 2.942827091968793
#  batch 20800 loss: 2.8011909840954456
#  batch 20900 loss: 2.765674261511049
#  batch 21000 loss: 2.6861438386025838
#  batch 21100 loss: 2.774110753965506
#  batch 21200 loss: 2.586201195935382
#  batch 21300 loss: 2.53473877208593
#  batch 21400 loss: 2.670530082473378
#  batch 21500 loss: 2.7225245166867533
#  batch 21600 loss: 2.5604728567692474
#  batch 21700 loss: 2.6650531131039314
#  batch 21800 loss: 3.3118379197541254
#  batch 21900 loss: 2.9503996336829528
#  batch 22000 loss: 2.8817824269202537
#  batch 22100 loss: 2.429416584086139
#  batch 22200 loss: 2.6457285579161134
#  batch 22300 loss: 2.577920640842162
#  batch 22400 loss: 2.4702962678220683
#  batch 22500 loss: 2.8523764315358857
#  batch 22600 loss: 2.530163198386308
#  batch 22700 loss: 2.979365927619656
#  batch 22800 loss: 2.8920866435004062
#  batch 22900 loss: 3.1057492168896714
#  batch 23000 loss: 2.583099534107041
#  batch 23100 loss: 2.8809883505820473
#  batch 23200 loss: 2.9912010074988213
#  batch 23300 loss: 2.7310595215857028
#  batch 23400 loss: 2.639923467063927
#  batch 23500 loss: 3.0139727666758698
#  batch 23600 loss: 2.521938899600691
#  batch 23700 loss: 2.648389653423219
#  batch 23800 loss: 2.714181999862194
#  batch 23900 loss: 2.6821066055865956
#  batch 24000 loss: 2.5161114252482366
#  batch 24100 loss: 2.6421997096058476
#  batch 24200 loss: 2.9507336875488543
#  batch 24300 loss: 2.9026940513215957
#  batch 24400 loss: 2.652367595199911
#  batch 24500 loss: 3.0314474693552076
#  batch 24600 loss: 2.5807880551950073
#  batch 24700 loss: 3.0649286322828266
#  batch 24800 loss: 2.859726778040349
#  batch 24900 loss: 2.572576250976708
#  batch 25000 loss: 2.737383270804721
#  batch 25100 loss: 2.569549731119896
#  batch 25200 loss: 2.6269484622395796
#  batch 25300 loss: 2.5101866794595846
#  batch 25400 loss: 2.4716062353614143
#  batch 25500 loss: 2.837942572440952
#  batch 25600 loss: 2.6555884008295836
#  batch 25700 loss: 2.6081221663951237
#  batch 25800 loss: 2.625039648693055
#  batch 25900 loss: 2.860517871938646
#  batch 26000 loss: 2.7981324831786334
#  batch 26100 loss: 2.1892486609683965
#  batch 26200 loss: 2.8748856583794895
#  batch 26300 loss: 2.816944092699563
#  batch 26400 loss: 2.945259454715997
#  batch 26500 loss: 2.4459906620532275
#  batch 26600 loss: 2.546483625480905
#  batch 26700 loss: 2.779118156952318
#  batch 26800 loss: 2.613231898628874
#  batch 26900 loss: 2.751838695590268
#  batch 27000 loss: 2.617009422131314
#  batch 27100 loss: 2.6060284630813113
#  batch 27200 loss: 2.600937611279077
#  batch 27300 loss: 2.5382060189871116
#  batch 27400 loss: 3.084685305244639
#  batch 27500 loss: 2.6662703635236538
#  batch 27600 loss: 2.3788517364389192
#  batch 27700 loss: 2.8628193500265477
#  batch 27800 loss: 2.476634383227938
#  batch 27900 loss: 2.4268058501645373
#  batch 28000 loss: 2.4502262461034117
#  batch 28100 loss: 2.804179746229929
#  batch 28200 loss: 2.6845496547722543
#  batch 28300 loss: 2.6967485782824223
#  batch 28400 loss: 2.328248748885926
#  batch 28500 loss: 2.593402051035432
#  batch 28600 loss: 2.738766364348521
#  batch 28700 loss: 2.533426600303501
#  batch 28800 loss: 2.7080673934249626
#  batch 28900 loss: 2.7129892918904077
#  batch 29000 loss: 2.703314187526703
#  batch 29100 loss: 2.6203029794618304
#  batch 29200 loss: 2.5583275401045102
#  batch 29300 loss: 2.408562416805621
#  batch 29400 loss: 2.6747549882144086
#  batch 29500 loss: 2.6389434389589543
#  batch 29600 loss: 2.903329242320906
#  batch 29700 loss: 2.532489064487163
#  batch 29800 loss: 3.0635329218232075
#  batch 29900 loss: 2.893218639031838
#  batch 30000 loss: 2.3345247778785416
#  batch 30100 loss: 2.4007360597949448
#  batch 30200 loss: 2.732230098416503
#  batch 30300 loss: 2.7952779641160306
#  batch 30400 loss: 2.7272687289863824
#  batch 30500 loss: 3.1020956639270296
#  batch 30600 loss: 2.2710302957240494
#  batch 30700 loss: 2.6719734211382455
#  batch 30800 loss: 2.460561492368579
#  batch 30900 loss: 2.5903920786490198
#  batch 31000 loss: 2.7405642345206798
#  batch 31100 loss: 2.635701010819066
#  batch 31200 loss: 2.3498239852996132
#  batch 31300 loss: 2.978108382750015
#  batch 31400 loss: 2.864995480740903
#  batch 31500 loss: 2.4118387899034315
#  batch 31600 loss: 2.8313725136994945
#  batch 31700 loss: 3.075404816888076
#  batch 31800 loss: 2.825496140288942
#  batch 31900 loss: 2.7983483887951026
#  batch 32000 loss: 2.5986426548041344
#  batch 32100 loss: 2.434930344703862
#  batch 32200 loss: 2.339809999966128
#  batch 32300 loss: 2.835521493883716
#  batch 32400 loss: 2.63968948131238
#  batch 32500 loss: 2.6842118613095955
#  batch 32600 loss: 2.4368339740362717
#  batch 32700 loss: 2.4991587906569204
#  batch 32800 loss: 2.2215286165042833
#  batch 32900 loss: 3.104425497551647
#  batch 33000 loss: 2.3714478254880738
#  batch 33100 loss: 2.7783748689427012
#  batch 33200 loss: 2.6028300515142155
#  batch 33300 loss: 2.682678045967765
#  batch 33400 loss: 2.520081933584297
#  batch 33500 loss: 2.672908573292534
#  batch 33600 loss: 2.9520687958317833
#  batch 33700 loss: 2.410682050138712
#  batch 33800 loss: 2.483094929449071
#  batch 33900 loss: 2.590990055730108
#  batch 34000 loss: 2.436322567260795
#  batch 34100 loss: 2.9788141975256077
#  batch 34200 loss: 2.9194942293694477
#  batch 34300 loss: 2.558494796502926
#  batch 34400 loss: 2.31063976398255
#  batch 34500 loss: 2.9234326971542033
#  batch 34600 loss: 2.704783507429529
#  batch 34700 loss: 2.562450214724813
#  batch 34800 loss: 2.586926770935652
#  batch 34900 loss: 2.5411662600934504
#  batch 35000 loss: 2.539856431491171
#  batch 35100 loss: 2.4858644148061284
#  batch 35200 loss: 2.3986786849420243
#  batch 35300 loss: 2.528176071029155
#  batch 35400 loss: 2.8523099207099585
#  batch 35500 loss: 2.6265967780632127
#  batch 35600 loss: 2.4284663621001528
#  batch 35700 loss: 2.5705892414806293
#  batch 35800 loss: 2.5140214926048063
#  batch 35900 loss: 3.008132517350605
#  batch 36000 loss: 2.5005264944851295
#  batch 36100 loss: 2.924897214456396
#  batch 36200 loss: 2.9212350935931317
#  batch 36300 loss: 2.5900428457364613
#  batch 36400 loss: 2.9405294055210924
#  batch 36500 loss: 2.654775534644723
#  batch 36600 loss: 2.6553119038514343
#  batch 36700 loss: 2.340481476566565
#  batch 36800 loss: 2.8211735971827783
#  batch 36900 loss: 2.667656479566358
#  batch 37000 loss: 2.653525238125585
#  batch 37100 loss: 2.6111724271180536
#  batch 37200 loss: 2.7859876022787646
#  batch 37300 loss: 2.9503865365684034
#  batch 37400 loss: 2.8282047543057707
#  batch 37500 loss: 2.8078165166254623
#  batch 37600 loss: 2.5006298716634046
#  batch 37700 loss: 2.7111190698523386
#  batch 37800 loss: 2.455498046986031
#  batch 37900 loss: 2.9332200174897296
#  batch 38000 loss: 2.666234049934583
#  batch 38100 loss: 2.6105618565328768
#  batch 38200 loss: 2.4623601909117134
#  batch 38300 loss: 2.5904100964013197
#  batch 38400 loss: 2.5277887759823354
#  batch 38500 loss: 2.7600763110938624
#  batch 38600 loss: 2.6556303538026076
#  batch 38700 loss: 2.852513832013938
#  batch 38800 loss: 2.4667948533652817
#  batch 38900 loss: 2.5597374092607423
#  batch 39000 loss: 2.8478337653726338
#  batch 39100 loss: 2.5718990466126526
#  batch 39200 loss: 2.9092131598538256
#  batch 39300 loss: 2.6415146934613585
#  batch 39400 loss: 2.515744870938761
#  batch 39500 loss: 2.411199264973402
#  batch 39600 loss: 2.3862780070173857
#  batch 39700 loss: 2.7307398290921854
#  batch 39800 loss: 2.478268614787958
#  batch 39900 loss: 2.8927262074440874
#  batch 40000 loss: 2.6476066024109963
#  batch 40100 loss: 3.0300473561082617
#  batch 40200 loss: 2.457948412662372
#  batch 40300 loss: 2.646460637622513
#  batch 40400 loss: 2.7671583804418605
#  batch 40500 loss: 2.5700254648923875
#  batch 40600 loss: 2.5229513393248455
#  batch 40700 loss: 2.4121262141926856
#  batch 40800 loss: 2.3994354089628906
#  batch 40900 loss: 2.4031622764724307
#  batch 41000 loss: 2.6237763044598976
#  batch 41100 loss: 2.5367622813740307
#  batch 41200 loss: 2.877877185107209
#  batch 41300 loss: 2.7052981052378526
#  batch 41400 loss: 2.6045257259905337
#  batch 41500 loss: 2.873296302498784
#  batch 41600 loss: 2.7757794428622584
#  batch 41700 loss: 2.514238437328022
#  batch 41800 loss: 2.555197363250893
#  batch 41900 loss: 2.752377616927552
#  batch 42000 loss: 2.743596469326076
#  batch 42100 loss: 2.694064680300653
#  batch 42200 loss: 2.6365052898210184
#  batch 42300 loss: 2.6254418518813325
#  batch 42400 loss: 2.718737570060766
#  batch 42500 loss: 3.0306002789223565
#  batch 42600 loss: 2.541577454847502
#  batch 42700 loss: 2.52021601127577
#  batch 42800 loss: 2.242403313375835
#  batch 42900 loss: 2.3568529240065095
#  batch 43000 loss: 2.6888753660023212
#  batch 43100 loss: 2.426551165918348
#  batch 43200 loss: 2.571360532034305
#  batch 43300 loss: 2.7834256355548495
#  batch 43400 loss: 2.609738872783455
#  batch 43500 loss: 2.823707791939378
#  batch 43600 loss: 2.5495713413786145
#  batch 43700 loss: 2.702608993649483
#  batch 43800 loss: 2.702471662828175
#  batch 43900 loss: 2.7184197810382464
#  batch 44000 loss: 2.565750189475657
#  batch 44100 loss: 3.0613886427268153
#  batch 44200 loss: 2.8493068095561465
#  batch 44300 loss: 2.5591465557203628
#  batch 44400 loss: 2.4306529644980035
#  batch 44500 loss: 2.915611531314207
#  batch 44600 loss: 2.556490825273122
#  batch 44700 loss: 2.5310554555626004
#  batch 44800 loss: 2.957381555403117
#  batch 44900 loss: 2.8778636033649674
#  batch 45000 loss: 2.8152936365278354
#  batch 45100 loss: 2.51496280035004
#  batch 45200 loss: 2.436734994221988
#  batch 45300 loss: 2.568498960839934
#  batch 45400 loss: 2.705134966522455
#  batch 45500 loss: 2.5420492838614153
#  batch 45600 loss: 2.5885644810993838
#  batch 45700 loss: 2.6747216585604474
#  batch 45800 loss: 2.488021722228241
#  batch 45900 loss: 2.684103852152848
#  batch 46000 loss: 2.8764988710104444
#  batch 46100 loss: 2.4235733745270407
#  batch 46200 loss: 2.670773364775814
#  batch 46300 loss: 2.7620509618852522
#  batch 46400 loss: 2.56639906170848
#  batch 46500 loss: 2.6053857279056682
#  batch 46600 loss: 2.5295146652543825
#  batch 46700 loss: 2.504897966215999
#  batch 46800 loss: 2.5678465199220772
#  batch 46900 loss: 2.9305935960613714
#  batch 47000 loss: 2.71533145061243
#  batch 47100 loss: 2.629358253530663
#  batch 47200 loss: 2.7729689154482524
#  batch 47300 loss: 2.7536459625856695
#  batch 47400 loss: 2.705446774196606
#  batch 47500 loss: 2.8204942148595
#  batch 47600 loss: 2.8328758470603397
#  batch 47700 loss: 2.7687084570396836
#  batch 47800 loss: 2.615667315080245
#  batch 47900 loss: 2.7041587355732917
#  batch 48000 loss: 2.892383984518965
#  batch 48100 loss: 2.5498541452817154
#  batch 48200 loss: 2.4616351023252356
#  batch 48300 loss: 2.5867533647327208
#  batch 48400 loss: 2.3730318491537035
#  batch 48500 loss: 3.078576946975663
#  batch 48600 loss: 2.7281820582784713
#  batch 48700 loss: 2.609667303367751
#  batch 48800 loss: 2.172997242203418
#  batch 48900 loss: 2.8460012550351417
#  batch 49000 loss: 2.543990574518366
#  batch 49100 loss: 2.5235500109521443
#  batch 49200 loss: 3.3687125593051315
#  batch 49300 loss: 2.8429592609819543
#  batch 49400 loss: 2.5522281428292626
#  batch 49500 loss: 2.4628278043797764
#  batch 49600 loss: 3.1627237253096245
#  batch 49700 loss: 2.574067825321472
#  batch 49800 loss: 2.528923870563067
#  batch 49900 loss: 2.640707103028617
#  batch 50000 loss: 2.762132609696354
# lr 0.01 -> 0.01
# Train accuracy 16.2:
# Test accuracy 15.299999999999999:
# EPOCH 2:
#  batch 100 loss: 2.5725693760660944
#  batch 200 loss: 2.5332645736101402
#  batch 300 loss: 2.9087974688934626
#  batch 400 loss: 2.848472119348579
#  batch 500 loss: 2.724862889882079
#  batch 600 loss: 2.479684235687232
#  batch 700 loss: 2.9512812998838114
#  batch 800 loss: 2.375587003069741
#  batch 900 loss: 2.606354611446786
#  batch 1000 loss: 2.382287930306047
#  batch 1100 loss: 2.496325445565308
#  batch 1200 loss: 2.5438440168388663
#  batch 1300 loss: 2.3397360522781945
#  batch 1400 loss: 2.67345412375044
#  batch 1500 loss: 2.4747888001861837
#  batch 1600 loss: 2.3526246774522583
#  batch 1700 loss: 2.7844964553043248
#  batch 1800 loss: 2.712213424000656
#  batch 1900 loss: 2.747193757344503
#  batch 2000 loss: 2.9953626601810175
#  batch 2100 loss: 2.6196967611368747
#  batch 2200 loss: 2.5280392437637476
#  batch 2300 loss: 2.693759058182477
#  batch 2400 loss: 2.591241721555416
#  batch 2500 loss: 2.364083864771528
#  batch 2600 loss: 2.9316009619040413
#  batch 2700 loss: 2.650180706663523
#  batch 2800 loss: 2.5662404273438733
#  batch 2900 loss: 2.671826636932674
#  batch 3000 loss: 2.7199432903161505
#  batch 3100 loss: 2.2384127309152975
#  batch 3200 loss: 2.9590417173039123
#  batch 3300 loss: 2.4175228918145875
#  batch 3400 loss: 2.1643728676870158
#  batch 3500 loss: 2.836133784400299
#  batch 3600 loss: 2.4616300643607976
#  batch 3700 loss: 2.366510790441753
#  batch 3800 loss: 2.3567423173946325
#  batch 3900 loss: 2.9611368387002583
#  batch 4000 loss: 2.4472296627238395
#  batch 4100 loss: 2.8285723398758726
#  batch 4200 loss: 2.3050128398579544
#  batch 4300 loss: 2.486322318111779
#  batch 4400 loss: 2.8130161539920664
#  batch 4500 loss: 2.4108061366539233
#  batch 4600 loss: 2.2320681386018464
#  batch 4700 loss: 2.294728239496176
#  batch 4800 loss: 2.503783353325998
#  batch 4900 loss: 2.4095663527919386
#  batch 5000 loss: 2.7180819111836536
#  batch 5100 loss: 2.500749466489069
#  batch 5200 loss: 2.553174215349127
#  batch 5300 loss: 2.8067257966988834
#  batch 5400 loss: 2.5656738042971847
#  batch 5500 loss: 2.6798971125052775
#  batch 5600 loss: 2.8790757061167414
#  batch 5700 loss: 2.596214432735219
#  batch 5800 loss: 2.5982616364466957
#  batch 5900 loss: 2.507214572992962
#  batch 6000 loss: 2.429342677737586
#  batch 6100 loss: 2.5442333157896018
#  batch 6200 loss: 2.3742961199209094
#  batch 6300 loss: 2.4622550128371588
#  batch 6400 loss: 2.266581324677054
#  batch 6500 loss: 2.5267138759746737
#  batch 6600 loss: 2.4990623870557465
#  batch 6700 loss: 2.6300834602594843
#  batch 6800 loss: 2.732223135922104
#  batch 6900 loss: 2.4929272341670003
#  batch 7000 loss: 2.3350330709082847
#  batch 7100 loss: 2.20844663959404
#  batch 7200 loss: 2.5859114350643586
#  batch 7300 loss: 2.570054220163147
#  batch 7400 loss: 2.2486979276489
#  batch 7500 loss: 2.544628096264787
#  batch 7600 loss: 2.4649027937999928
#  batch 7700 loss: 2.7215268346944503
#  batch 7800 loss: 2.668786324339453
#  batch 7900 loss: 2.7371808495012373
#  batch 8000 loss: 2.5400467190233758
#  batch 8100 loss: 2.435120368832795
#  batch 8200 loss: 2.2999959190379378
#  batch 8300 loss: 3.068523892089361
#  batch 8400 loss: 2.8540589697507674
#  batch 8500 loss: 2.604078640998341
#  batch 8600 loss: 2.509286839487031
#  batch 8700 loss: 2.446610576793608
#  batch 8800 loss: 2.811359132939251
#  batch 8900 loss: 2.5378334638907107
#  batch 9000 loss: 2.5403032496101696
#  batch 9100 loss: 2.5026702542848307
#  batch 9200 loss: 2.367700204293942
#  batch 9300 loss: 2.79213844819993
#  batch 9400 loss: 2.305509068811007
#  batch 9500 loss: 2.547013700139578
#  batch 9600 loss: 2.2462456770351853
#  batch 9700 loss: 2.672702154807921
#  batch 9800 loss: 2.764639715858502
#  batch 9900 loss: 2.571359980236339
#  batch 10000 loss: 2.649981876797974
#  batch 10100 loss: 2.3100248707354694
#  batch 10200 loss: 2.6209460358318757
#  batch 10300 loss: 2.760495941758854
#  batch 10400 loss: 2.496143184285011
#  batch 10500 loss: 2.321814909981804
#  batch 10600 loss: 2.61295840007253
#  batch 10700 loss: 2.4975226771098096
#  batch 10800 loss: 2.7035389842726727
#  batch 10900 loss: 2.6053210083478917
#  batch 11000 loss: 2.264677528127822
#  batch 11100 loss: 2.5973156176404792
#  batch 11200 loss: 2.3985634959256275
#  batch 11300 loss: 2.3771366873034094
#  batch 11400 loss: 2.642455688370355
#  batch 11500 loss: 2.206353008541628
#  batch 11600 loss: 2.4747033444885163
#  batch 11700 loss: 2.3604692293737024
#  batch 11800 loss: 2.4985790248012383
#  batch 11900 loss: 2.489204756545332
#  batch 12000 loss: 2.473835208416058
#  batch 12100 loss: 2.3122685534498304
#  batch 12200 loss: 2.492150201717595
#  batch 12300 loss: 2.6955596341394448
#  batch 12400 loss: 2.698626639693923
#  batch 12500 loss: 2.9491731748985877
#  batch 12600 loss: 2.2876225718114394
#  batch 12700 loss: 2.7466137027781223
#  batch 12800 loss: 2.3492765817500185
#  batch 12900 loss: 2.863701159378979
#  batch 13000 loss: 2.3540613754442883
#  batch 13100 loss: 2.3485072859904177
#  batch 13200 loss: 2.1681053770016296
#  batch 13300 loss: 2.4407097937434448
#  batch 13400 loss: 2.5592088507763493
#  batch 13500 loss: 2.686781193988572
#  batch 13600 loss: 2.5766825266252273
#  batch 13700 loss: 2.6016964214659675
#  batch 13800 loss: 2.7203259429556783
#  batch 13900 loss: 2.3314043985714306
#  batch 14000 loss: 2.635900495316564
#  batch 14100 loss: 2.6711255900464677
#  batch 14200 loss: 2.5450262247258797
#  batch 14300 loss: 2.9564549561902824
#  batch 14400 loss: 2.266274064640238
#  batch 14500 loss: 2.7563127741462083
#  batch 14600 loss: 2.570095289610326
#  batch 14700 loss: 2.6441059253923593
#  batch 14800 loss: 2.7676073939999317
#  batch 14900 loss: 2.7874270545260513
#  batch 15000 loss: 2.573274001311511
#  batch 15100 loss: 2.8710747378514214
#  batch 15200 loss: 2.409983535466049
#  batch 15300 loss: 2.867398632927798
#  batch 15400 loss: 2.4388474832416525
#  batch 15500 loss: 2.3016453435929716
#  batch 15600 loss: 2.531644674257841
#  batch 15700 loss: 2.3926392244119596
#  batch 15800 loss: 2.5963452860177494
#  batch 15900 loss: 2.9690492585767045
#  batch 16000 loss: 2.4631071415543557
#  batch 16100 loss: 2.503279709072085
#  batch 16200 loss: 2.9387705437419935
#  batch 16300 loss: 2.6484307326702403
#  batch 16400 loss: 2.4797308545556733
#  batch 16500 loss: 2.705892234529455
#  batch 16600 loss: 2.540114966637921
#  batch 16700 loss: 2.614063166920009
#  batch 16800 loss: 2.4296166760986666
#  batch 16900 loss: 2.4830137673549997
#  batch 17000 loss: 3.0257187188221177
#  batch 17100 loss: 2.7321963747270637
#  batch 17200 loss: 2.5996989116526676
#  batch 17300 loss: 2.531342057363072
#  batch 17400 loss: 2.310693207933982
#  batch 17500 loss: 2.6423734964696632
#  batch 17600 loss: 2.6581233423610637
#  batch 17700 loss: 2.5483788833021594
#  batch 17800 loss: 2.4886133758272626
#  batch 17900 loss: 2.3498805076692952
#  batch 18000 loss: 2.530470418453406
#  batch 18100 loss: 2.7680359611293532
#  batch 18200 loss: 2.542239078526036
#  batch 18300 loss: 2.273301682873571
#  batch 18400 loss: 2.5607380624639338
#  batch 18500 loss: 2.6054726345837116
#  batch 18600 loss: 2.6120783154312814
#  batch 18700 loss: 2.6186934325424955
#  batch 18800 loss: 2.783947811142534
#  batch 18900 loss: 2.256092897795315
#  batch 19000 loss: 2.4514053784263523
#  batch 19100 loss: 2.4183191444689873
#  batch 19200 loss: 2.2263933451228968
#  batch 19300 loss: 2.468044307034179
#  batch 19400 loss: 2.454080243874878
#  batch 19500 loss: 2.160255736605304
#  batch 19600 loss: 2.529391709593474
#  batch 19700 loss: 2.32908985109676
#  batch 19800 loss: 2.5310607042188713
#  batch 19900 loss: 2.216627282666741
#  batch 20000 loss: 2.2377102972115925
#  batch 20100 loss: 2.7181189640276715
#  batch 20200 loss: 2.333163562586269
#  batch 20300 loss: 2.5184125176762975
#  batch 20400 loss: 2.2582870522738085
#  batch 20500 loss: 2.5175457661002065
#  batch 20600 loss: 2.663195888955961
#  batch 20700 loss: 2.486069361286172
#  batch 20800 loss: 2.5423695706991496
#  batch 20900 loss: 2.5366290147519748
#  batch 21000 loss: 2.5846905672282445
#  batch 21100 loss: 2.3963645516645373
#  batch 21200 loss: 2.5436419999736244
#  batch 21300 loss: 2.6969826012477274
#  batch 21400 loss: 2.557294037565307
#  batch 21500 loss: 2.4623311339877545
#  batch 21600 loss: 2.420914786068315
#  batch 21700 loss: 2.3727313473038794
#  batch 21800 loss: 2.3779701898093935
#  batch 21900 loss: 2.380795932836463
#  batch 22000 loss: 2.599092539700723
#  batch 22100 loss: 2.172331063831225
#  batch 22200 loss: 2.700718947715359
#  batch 22300 loss: 2.4966089030548755
#  batch 22400 loss: 2.2980183542088115
#  batch 22500 loss: 2.5181680103176767
#  batch 22600 loss: 2.39901794941685
#  batch 22700 loss: 2.728275794644578
#  batch 22800 loss: 2.299243130109462
#  batch 22900 loss: 2.678210640859634
#  batch 23000 loss: 2.7934883272022124
#  batch 23100 loss: 2.475911397682503
#  batch 23200 loss: 2.289434130685986
#  batch 23300 loss: 2.385942504629493
#  batch 23400 loss: 2.46222071748889
#  batch 23500 loss: 2.3974872510303338
#  batch 23600 loss: 2.505206007267816
#  batch 23700 loss: 2.286610058088618
#  batch 23800 loss: 2.480410075885793
#  batch 23900 loss: 2.837377164522186
#  batch 24000 loss: 2.183385296219585
#  batch 24100 loss: 2.627491349711704
#  batch 24200 loss: 2.3277162852082505
#  batch 24300 loss: 2.382821170934094
#  batch 24400 loss: 2.187346300266656
#  batch 24500 loss: 2.4313913133691996
#  batch 24600 loss: 2.649785743211396
#  batch 24700 loss: 2.640745924029452
#  batch 24800 loss: 2.103863804094295
#  batch 24900 loss: 2.7291527375420266
#  batch 25000 loss: 2.9736633238065404
#  batch 25100 loss: 2.373477426418394
#  batch 25200 loss: 2.800338751948433
#  batch 25300 loss: 2.238393436858896
#  batch 25400 loss: 2.4934744969120173
#  batch 25500 loss: 2.4475758678329114
#  batch 25600 loss: 2.2198322165873834
#  batch 25700 loss: 2.7116877299719273
#  batch 25800 loss: 2.711735254555533
#  batch 25900 loss: 2.651106768604368
#  batch 26000 loss: 2.5042556053775478
#  batch 26100 loss: 2.5985342933732682
#  batch 26200 loss: 2.4715847060997023
#  batch 26300 loss: 2.3239022926893087
#  batch 26400 loss: 2.536841044517049
#  batch 26500 loss: 2.402794614667073
#  batch 26600 loss: 2.759670576035569
#  batch 26700 loss: 2.619497409807518
#  batch 26800 loss: 2.265025007181839
#  batch 26900 loss: 2.5186194044207513
#  batch 27000 loss: 2.236110201232586
#  batch 27100 loss: 2.4821319755136666
#  batch 27200 loss: 2.303195652648137
#  batch 27300 loss: 2.4950951262426315
#  batch 27400 loss: 2.501753704137227
#  batch 27500 loss: 2.373351465078301
#  batch 27600 loss: 2.2643256232328715
#  batch 27700 loss: 2.2756754247153004
#  batch 27800 loss: 2.495831940663047
#  batch 27900 loss: 2.2753216607887587
#  batch 28000 loss: 2.41157336091323
#  batch 28100 loss: 2.216237471465647
#  batch 28200 loss: 2.606041284446801
#  batch 28300 loss: 2.8090584583751568
#  batch 28400 loss: 2.3482078826474027
#  batch 28500 loss: 2.4044728242821294
#  batch 28600 loss: 2.475068931042915
#  batch 28700 loss: 2.566825959114358
#  batch 28800 loss: 2.3506493464368394
#  batch 28900 loss: 2.400611420304667
#  batch 29000 loss: 2.4331929718102767
#  batch 29100 loss: 2.487868857969988
#  batch 29200 loss: 2.5078491708633375
#  batch 29300 loss: 2.557384083665091
#  batch 29400 loss: 2.373310565404563
#  batch 29500 loss: 2.299159576664315
#  batch 29600 loss: 2.433977517327294
#  batch 29700 loss: 2.369909778833389
#  batch 29800 loss: 2.3217170829698444
#  batch 29900 loss: 2.5133617348356347
#  batch 30000 loss: 2.41775295009953
#  batch 30100 loss: 2.7420315085433304
#  batch 30200 loss: 2.625827167313837
#  batch 30300 loss: 2.3302019929396796
#  batch 30400 loss: 2.101574933709344
#  batch 30500 loss: 2.3812718412582763
#  batch 30600 loss: 2.389488470382057
#  batch 30700 loss: 2.2161598839478653
#  batch 30800 loss: 2.1004598779521166
#  batch 30900 loss: 2.822593313482355
#  batch 31000 loss: 2.415189654080477
#  batch 31100 loss: 2.472303168409053
#  batch 31200 loss: 2.7718742675567047
#  batch 31300 loss: 2.2728937250734997
#  batch 31400 loss: 2.256959454951866
#  batch 31500 loss: 2.7476736797425385
#  batch 31600 loss: 2.588488139361143
#  batch 31700 loss: 2.3283402954604115
#  batch 31800 loss: 2.6168814555365496
#  batch 31900 loss: 2.5146270830368986
#  batch 32000 loss: 2.5079114439803423
#  batch 32100 loss: 2.744073700704612
#  batch 32200 loss: 2.4622717156261205
#  batch 32300 loss: 2.333948415007908
#  batch 32400 loss: 2.7320860328659182
#  batch 32500 loss: 2.5495515131764113
#  batch 32600 loss: 2.3094863147319846
#  batch 32700 loss: 2.6280021806946023
#  batch 32800 loss: 2.506561544314027
#  batch 32900 loss: 2.4406404573633336
#  batch 33000 loss: 2.3843817753380607
#  batch 33100 loss: 2.348699055894394
#  batch 33200 loss: 2.6594817261211574
#  batch 33300 loss: 2.5324057812354295
#  batch 33400 loss: 2.527452960475348
#  batch 33500 loss: 2.668512009757105
#  batch 33600 loss: 2.479935550289829
#  batch 33700 loss: 2.5326548093924064
#  batch 33800 loss: 2.485898215067573
#  batch 33900 loss: 2.304331783968446
#  batch 34000 loss: 2.3598390731104883
#  batch 34100 loss: 2.5934249015618116
#  batch 34200 loss: 2.3770733803635813
#  batch 34300 loss: 2.4256324737065005
#  batch 34400 loss: 2.3513839428615757
#  batch 34500 loss: 2.3896448269177926
#  batch 34600 loss: 2.8050421735471445
#  batch 34700 loss: 2.397801354929834
#  batch 34800 loss: 2.4548537601788847
#  batch 34900 loss: 2.850060059247771
#  batch 35000 loss: 2.5231116718659177
#  batch 35100 loss: 2.3597243644483386
#  batch 35200 loss: 2.5237733852188104
#  batch 35300 loss: 2.494653144782642
#  batch 35400 loss: 2.4718074436025925
#  batch 35500 loss: 2.388087844744941
#  batch 35600 loss: 2.78250397302254
#  batch 35700 loss: 2.33165072660287
#  batch 35800 loss: 2.306380013898197
#  batch 35900 loss: 2.260485773238397
#  batch 36000 loss: 2.2823879160422074
#  batch 36100 loss: 2.36262440620714
#  batch 36200 loss: 2.5264430665655526
#  batch 36300 loss: 2.443601995781937
#  batch 36400 loss: 2.7066414339582114
#  batch 36500 loss: 2.3983967503681196
#  batch 36600 loss: 2.2827675684646236
#  batch 36700 loss: 2.335642572057259
#  batch 36800 loss: 2.3114774543379464
#  batch 36900 loss: 2.410489801031708
#  batch 37000 loss: 2.487661550345365
#  batch 37100 loss: 2.1843240201304432
#  batch 37200 loss: 2.353482122005662
#  batch 37300 loss: 2.4362196766957642
#  batch 37400 loss: 2.7673718990979252
#  batch 37500 loss: 2.3829730911838305
#  batch 37600 loss: 2.528386922963546
#  batch 37700 loss: 2.789670250617055
#  batch 37800 loss: 2.34419016664061
#  batch 37900 loss: 2.254370875268214
#  batch 38000 loss: 2.22058792464808
#  batch 38100 loss: 2.473011633482165
#  batch 38200 loss: 2.1950833526309
#  batch 38300 loss: 2.28048759888279
#  batch 38400 loss: 2.38295470480704
#  batch 38500 loss: 2.635329451709986
#  batch 38600 loss: 2.48317407195148
#  batch 38700 loss: 2.8310209441227014
#  batch 38800 loss: 2.3207796680624595
#  batch 38900 loss: 2.460232953869654
#  batch 39000 loss: 2.2981594076706098
#  batch 39100 loss: 2.2156685206756084
#  batch 39200 loss: 2.4726189401652663
#  batch 39300 loss: 2.6288515967229613
#  batch 39400 loss: 2.3458780070446665
#  batch 39500 loss: 2.287812179166358
#  batch 39600 loss: 2.2508435557433404
#  batch 39700 loss: 2.3480245507066138
#  batch 39800 loss: 2.5089329508692026
#  batch 39900 loss: 2.3371633130628835
#  batch 40000 loss: 2.6429503359040245
#  batch 40100 loss: 2.1573296948266854
#  batch 40200 loss: 2.607148362635635
#  batch 40300 loss: 2.3777048908273355
#  batch 40400 loss: 2.477549466429409
#  batch 40500 loss: 2.3621373670120374
#  batch 40600 loss: 2.7945569363236427
#  batch 40700 loss: 2.2303929102778146
#  batch 40800 loss: 2.3293404910051185
#  batch 40900 loss: 2.498381589647606
#  batch 41000 loss: 2.749817898706533
#  batch 41100 loss: 2.303980424563924
#  batch 41200 loss: 2.386084201501217
#  batch 41300 loss: 2.2407967187598117
#  batch 41400 loss: 2.803345002653077
#  batch 41500 loss: 2.367416059244414
#  batch 41600 loss: 2.417423248135892
#  batch 41700 loss: 2.508784724697471
#  batch 41800 loss: 2.799943887134723
#  batch 41900 loss: 2.450252317367122
#  batch 42000 loss: 2.3597913187427912
#  batch 42100 loss: 2.314840767713431
#  batch 42200 loss: 2.677996519356875
#  batch 42300 loss: 2.279910149925854
#  batch 42400 loss: 2.4587971402553377
#  batch 42500 loss: 2.307757811330084
#  batch 42600 loss: 2.5986824700422586
#  batch 42700 loss: 2.4705905949394014
#  batch 42800 loss: 2.486744011202827
#  batch 42900 loss: 2.425934333463556
#  batch 43000 loss: 2.4033196989208228
#  batch 43100 loss: 2.4324991993565344
#  batch 43200 loss: 2.341330398357022
#  batch 43300 loss: 2.5825597485018807
#  batch 43400 loss: 2.287341773551889
#  batch 43500 loss: 2.8409758135792798
#  batch 43600 loss: 2.3857278784533262
#  batch 43700 loss: 2.2168553978996353
#  batch 43800 loss: 2.4944155102712102
#  batch 43900 loss: 2.4914290553404044
#  batch 44000 loss: 2.6471247570597187
#  batch 44100 loss: 2.348761208995711
#  batch 44200 loss: 2.3503210862126434
#  batch 44300 loss: 2.492357150601074
#  batch 44400 loss: 2.5778021064398127
#  batch 44500 loss: 2.4223382481261435
#  batch 44600 loss: 2.2867779075400905
#  batch 44700 loss: 2.450787610616535
#  batch 44800 loss: 2.496628782257285
#  batch 44900 loss: 2.7811847748048604
#  batch 45000 loss: 2.2880879378691317
#  batch 45100 loss: 2.214300495524112
#  batch 45200 loss: 2.4860345477424564
#  batch 45300 loss: 2.6325952753436286
#  batch 45400 loss: 2.3553968900993643
#  batch 45500 loss: 2.314567948980257
#  batch 45600 loss: 2.377790669640672
#  batch 45700 loss: 2.700536617844991
#  batch 45800 loss: 2.565224405314075
#  batch 45900 loss: 2.19251980859568
#  batch 46000 loss: 2.3528815919860064
#  batch 46100 loss: 2.605806373486412
#  batch 46200 loss: 2.4888515655747323
#  batch 46300 loss: 2.515269588264455
#  batch 46400 loss: 2.598023214748318
#  batch 46500 loss: 2.570509350319044
#  batch 46600 loss: 2.479729651069883
#  batch 46700 loss: 2.229971503969282
#  batch 46800 loss: 2.3861190940253434
#  batch 46900 loss: 2.62375589447096
#  batch 47000 loss: 2.4957524275151024
#  batch 47100 loss: 2.34184848907749
#  batch 47200 loss: 2.5908752934027643
#  batch 47300 loss: 2.4831500821188093
#  batch 47400 loss: 2.5625576885108603
#  batch 47500 loss: 2.5211109379353003
#  batch 47600 loss: 2.449869462600909
#  batch 47700 loss: 2.44970097579062
#  batch 47800 loss: 2.460552457435983
#  batch 47900 loss: 2.396411922913976
#  batch 48000 loss: 2.2756601409542783
#  batch 48100 loss: 2.3572866246824016
#  batch 48200 loss: 2.392435060636117
#  batch 48300 loss: 2.4012344253780613
#  batch 48400 loss: 2.4031444517520275
#  batch 48500 loss: 2.5462528223183427
#  batch 48600 loss: 2.4286168981716036
#  batch 48700 loss: 2.2725786959775656
#  batch 48800 loss: 2.201206931751693
#  batch 48900 loss: 2.3516017440659196
#  batch 49000 loss: 2.2702540947298346
#  batch 49100 loss: 2.3625927410225995
#  batch 49200 loss: 2.5199777423171326
#  batch 49300 loss: 2.5515306559368036
#  batch 49400 loss: 2.386403162109782
#  batch 49500 loss: 2.535459707302507
#  batch 49600 loss: 2.442068389072083
#  batch 49700 loss: 2.3553162797912957
#  batch 49800 loss: 2.3893137828049658
#  batch 49900 loss: 2.9608032168447966
#  batch 50000 loss: 2.3906127529894
# lr 0.01 -> 0.01
# Train accuracy 12.9:
# Test accuracy 11.4:
# EPOCH 3:
#  batch 100 loss: 2.2286400953680277
#  batch 200 loss: 2.2376682476140557
#  batch 300 loss: 2.346676567532122
#  batch 400 loss: 2.3227181752621253
#  batch 500 loss: 2.7872290696203708
#  batch 600 loss: 2.3883280491418555
#  batch 700 loss: 2.2900824647280387
#  batch 800 loss: 2.225834840544558
#  batch 900 loss: 2.1200075105100407
#  batch 1000 loss: 2.7019494898887935
#  batch 1100 loss: 2.303257253639147
#  batch 1200 loss: 2.4186199057009072
#  batch 1300 loss: 2.3276259696728085
#  batch 1400 loss: 2.2281197743287158
#  batch 1500 loss: 2.34726878147485
#  batch 1600 loss: 2.5062192570162005
#  batch 1700 loss: 2.2929419360918293
#  batch 1800 loss: 2.3917978631705044
#  batch 1900 loss: 2.194989354485878
#  batch 2000 loss: 2.392926243075053
#  batch 2100 loss: 2.5537872801162305
#  batch 2200 loss: 2.439074293422964
#  batch 2300 loss: 2.483266371497166
#  batch 2400 loss: 2.309750692313246
#  batch 2500 loss: 2.1974851912143096
#  batch 2600 loss: 2.323134070278611
#  batch 2700 loss: 2.006485825457894
#  batch 2800 loss: 2.2819853132451864
#  batch 2900 loss: 2.5222586578809567
#  batch 3000 loss: 2.434267397378571
#  batch 3100 loss: 2.8939886952348752
#  batch 3200 loss: 2.2295781571838416
#  batch 3300 loss: 2.5474077753722666
#  batch 3400 loss: 2.523916605655104
#  batch 3500 loss: 2.3383211726823356
#  batch 3600 loss: 2.2337257683937786
#  batch 3700 loss: 2.587794550048311
#  batch 3800 loss: 2.4024291871348398
#  batch 3900 loss: 2.4610658356640305
#  batch 4000 loss: 2.2689997636858608
#  batch 4100 loss: 2.590096393484855
#  batch 4200 loss: 2.3280407194799047
#  batch 4300 loss: 2.2041165238665394
#  batch 4400 loss: 2.4313991967116726
#  batch 4500 loss: 2.5197190261178184
#  batch 4600 loss: 2.397841511350125
#  batch 4700 loss: 2.3198397549195215
#  batch 4800 loss: 2.228484309546948
#  batch 4900 loss: 2.285957906521362
#  batch 5000 loss: 2.286912927725325
#  batch 5100 loss: 2.396232941203489
#  batch 5200 loss: 2.2652382446840056
#  batch 5300 loss: 2.4473081587895216
#  batch 5400 loss: 2.240635740799626
#  batch 5500 loss: 2.213183958637237
#  batch 5600 loss: 2.153883163474384
#  batch 5700 loss: 2.2290741810621695
#  batch 5800 loss: 2.491388977570896
#  batch 5900 loss: 2.265595131739974
#  batch 6000 loss: 2.421857263604179
#  batch 6100 loss: 2.290744077964305
#  batch 6200 loss: 2.430727701602736
#  batch 6300 loss: 2.3766338921662826
#  batch 6400 loss: 2.1804654544014195
#  batch 6500 loss: 2.235541225128108
#  batch 6600 loss: 2.2944744704850017
#  batch 6700 loss: 2.331878025010127
#  batch 6800 loss: 2.2681457643093745
#  batch 6900 loss: 2.3767234181532695
#  batch 7000 loss: 2.4147829952938626
#  batch 7100 loss: 2.1659958688408367
#  batch 7200 loss: 2.30221597708296
#  batch 7300 loss: 2.541012124166591
#  batch 7400 loss: 2.2282922144075017
#  batch 7500 loss: 2.457835393473506
#  batch 7600 loss: 2.2930792918839145
#  batch 7700 loss: 2.2455350987942073
#  batch 7800 loss: 2.3838919749451453
#  batch 7900 loss: 2.289140717560076
#  batch 8000 loss: 2.353466372347975
#  batch 8100 loss: 2.356372637764871
#  batch 8200 loss: 2.2374809196446948
#  batch 8300 loss: 2.273540308802621
#  batch 8400 loss: 2.103759651573548
#  batch 8500 loss: 2.6666228094087274
#  batch 8600 loss: 2.363835869235918
#  batch 8700 loss: 2.2173435108270496
#  batch 8800 loss: 2.6174403079715556
#  batch 8900 loss: 1.9656237253913014
#  batch 9000 loss: 2.448828428729221
#  batch 9100 loss: 2.404890385591425
#  batch 9200 loss: 2.3090290269255638
#  batch 9300 loss: 2.706679215974873
#  batch 9400 loss: 2.2788268292625617
#  batch 9500 loss: 2.435962872730906
#  batch 9600 loss: 2.1320190794545213
#  batch 9700 loss: 2.244932915854486
#  batch 9800 loss: 2.385953030074015
#  batch 9900 loss: 2.4275955849895716
#  batch 10000 loss: 2.4574613330751345
#  batch 10100 loss: 2.2551147449946574
#  batch 10200 loss: 2.2510312671770225
#  batch 10300 loss: 2.552258303375638
#  batch 10400 loss: 2.363502427430867
#  batch 10500 loss: 2.331518296459326
#  batch 10600 loss: 2.436226637107902
#  batch 10700 loss: 2.181787231314229
#  batch 10800 loss: 2.293627066160825
#  batch 10900 loss: 2.40883439976722
#  batch 11000 loss: 2.3073770620779577
#  batch 11100 loss: 2.209503569644148
#  batch 11200 loss: 2.4342690378533005
#  batch 11300 loss: 2.2817479354544776
#  batch 11400 loss: 2.2045305594757885
#  batch 11500 loss: 2.1941353594511734
#  batch 11600 loss: 2.3804835818964056
#  batch 11700 loss: 2.3591147908032872
#  batch 11800 loss: 2.1830650236613294
#  batch 11900 loss: 2.218884017004966
#  batch 12000 loss: 2.2686276807331067
#  batch 12100 loss: 2.470130712320097
#  batch 12200 loss: 2.2838222030911677
#  batch 12300 loss: 2.3436478879675224
#  batch 12400 loss: 2.404985415142437
#  batch 12500 loss: 2.31537083283416
#  batch 12600 loss: 2.3641469095174763
#  batch 12700 loss: 2.1887774916004856
#  batch 12800 loss: 2.2324959731815035
#  batch 12900 loss: 2.303746926691383
#  batch 13000 loss: 2.2146289955580096
#  batch 13100 loss: 2.3841569102415816
#  batch 13200 loss: 2.2442021493138236
#  batch 13300 loss: 2.315260910661309
#  batch 13400 loss: 2.379092653620743
#  batch 13500 loss: 2.4248124404356988
#  batch 13600 loss: 2.5453151697758587
#  batch 13700 loss: 2.4053518057765904
#  batch 13800 loss: 2.0031690169815466
#  batch 13900 loss: 2.423622244888684
#  batch 14000 loss: 2.414196086549132
#  batch 14100 loss: 2.3517623843020914
#  batch 14200 loss: 2.379806002168916
#  batch 14300 loss: 2.3656482161195345
#  batch 14400 loss: 2.3028040585122653
#  batch 14500 loss: 2.219249182430285
#  batch 14600 loss: 2.377973495423794
#  batch 14700 loss: 2.4373529903168674
#  batch 14800 loss: 2.3789359367348517
#  batch 14900 loss: 2.268182115261152
#  batch 15000 loss: 2.326424681823701
#  batch 15100 loss: 2.2394204979552885
#  batch 15200 loss: 2.1377390269883474
#  batch 15300 loss: 2.5764679030142723
#  batch 15400 loss: 2.3050245817378165
#  batch 15500 loss: 2.6115473918226235
#  batch 15600 loss: 2.5913832829892636
#  batch 15700 loss: 2.3230302665129057
#  batch 15800 loss: 2.411514428406954
#  batch 15900 loss: 2.3272533190401736
#  batch 16000 loss: 2.3180308257156867
#  batch 16100 loss: 2.4386758044501766
#  batch 16200 loss: 2.2428220261260865
#  batch 16300 loss: 2.2247562328962704
#  batch 16400 loss: 2.278004432611051
#  batch 16500 loss: 2.56305657124467
#  batch 16600 loss: 1.991753909839457
#  batch 16700 loss: 2.3357904129195957
#  batch 16800 loss: 2.5388242269829426
#  batch 16900 loss: 2.5862721815754774
#  batch 17000 loss: 2.330913158859023
#  batch 17100 loss: 2.3776117802232695
#  batch 17200 loss: 2.451590578289979
#  batch 17300 loss: 2.1067557815522013
#  batch 17400 loss: 2.2470298376629945
#  batch 17500 loss: 2.27362987505272
#  batch 17600 loss: 2.2006750839046436
#  batch 17700 loss: 2.523353699091822
#  batch 17800 loss: 2.216804673797451
#  batch 17900 loss: 2.285622470403905
#  batch 18000 loss: 2.47273904355854
#  batch 18100 loss: 2.359153403842613
#  batch 18200 loss: 2.261767333316675
#  batch 18300 loss: 2.3059882101113907
#  batch 18400 loss: 2.544494341036079
#  batch 18500 loss: 2.380578816290681
#  batch 18600 loss: 2.435138268060982
#  batch 18700 loss: 2.2974776535679062
#  batch 18800 loss: 2.6416468169413565
#  batch 18900 loss: 2.3235279627004637
#  batch 19000 loss: 2.2228966365894305
#  batch 19100 loss: 2.364702304272214
#  batch 19200 loss: 2.527271957001503
#  batch 19300 loss: 2.4187286149844294
#  batch 19400 loss: 2.2529938845726427
#  batch 19500 loss: 2.1661510995111892
#  batch 19600 loss: 2.1809750350590913
#  batch 19700 loss: 2.497214108002627
#  batch 19800 loss: 2.3796676921378817
#  batch 19900 loss: 2.457106459584502
#  batch 20000 loss: 2.4145119260273713
#  batch 20100 loss: 2.35924635335803
#  batch 20200 loss: 2.3011600575631017
#  batch 20300 loss: 2.403155595487697
#  batch 20400 loss: 2.0602857539127526
#  batch 20500 loss: 2.3505157050839625
#  batch 20600 loss: 2.424565721927197
#  batch 20700 loss: 2.3589597439238785
#  batch 20800 loss: 2.1607280403998446
#  batch 20900 loss: 2.1995536473981336
#  batch 21000 loss: 2.3699607216735603
#  batch 21100 loss: 2.160079054869566
#  batch 21200 loss: 2.748749244567662
#  batch 21300 loss: 2.5616767324507235
#  batch 21400 loss: 2.4269242749013937
#  batch 21500 loss: 2.4601525359158405
#  batch 21600 loss: 2.4117835123352234
#  batch 21700 loss: 2.3761726069822906
#  batch 21800 loss: 2.2228022061946104
#  batch 21900 loss: 2.4946668427791154
#  batch 22000 loss: 2.269242951010747
#  batch 22100 loss: 2.2575266900913267
#  batch 22200 loss: 2.244395812723302
#  batch 22300 loss: 2.4921987591311336
#  batch 22400 loss: 2.4905001968664875
#  batch 22500 loss: 2.4641438567359
#  batch 22600 loss: 2.332574306333097
#  batch 22700 loss: 2.293181676263921
#  batch 22800 loss: 2.417189749099198
#  batch 22900 loss: 2.350841148226391
#  batch 23000 loss: 2.347427543872468
#  batch 23100 loss: 2.3778940315965884
#  batch 23200 loss: 2.214101166850887
#  batch 23300 loss: 2.3985568774409898
#  batch 23400 loss: 2.3353979235386944
#  batch 23500 loss: 2.5135331665156992
#  batch 23600 loss: 2.314795763930306
#  batch 23700 loss: 2.3526968437912
#  batch 23800 loss: 2.420592194022283
#  batch 23900 loss: 2.1381976400036367
#  batch 24000 loss: 2.424499886094127
#  batch 24100 loss: 2.3358133759268096
#  batch 24200 loss: 2.2343343691222164
#  batch 24300 loss: 2.156786798723551
#  batch 24400 loss: 2.357906331720878
#  batch 24500 loss: 2.3771786538860753
#  batch 24600 loss: 2.6477392152250103
#  batch 24700 loss: 2.2840684309407515
#  batch 24800 loss: 2.374130751774646
#  batch 24900 loss: 2.2079566149270975
#  batch 25000 loss: 2.153781925715157
#  batch 25100 loss: 2.2139076421495885
#  batch 25200 loss: 2.3862941707530467
#  batch 25300 loss: 2.292595009384677
#  batch 25400 loss: 2.2301697803415665
#  batch 25500 loss: 2.2816347902907728
#  batch 25600 loss: 2.5343588735032743
#  batch 25700 loss: 2.3301777123403737
#  batch 25800 loss: 2.418827388882637
#  batch 25900 loss: 2.2385978306573815
#  batch 26000 loss: 2.439515171167295
#  batch 26100 loss: 2.437813579046633
#  batch 26200 loss: 2.2650563129968804
#  batch 26300 loss: 2.4781298149714712
#  batch 26400 loss: 2.384504687860608
#  batch 26500 loss: 2.3747608160972593
#  batch 26600 loss: 2.430100844948529
#  batch 26700 loss: 2.308432059725783
#  batch 26800 loss: 2.16504981098813
#  batch 26900 loss: 2.280861837983539
#  batch 27000 loss: 2.3234458961733613
#  batch 27100 loss: 2.2966733506694434
#  batch 27200 loss: 2.1301410660805415
#  batch 27300 loss: 2.487761108465493
#  batch 27400 loss: 2.2475903192842086
#  batch 27500 loss: 2.3068320243805647
#  batch 27600 loss: 2.1736962624266742
#  batch 27700 loss: 2.206576571041323
#  batch 27800 loss: 2.3715934698650383
#  batch 27900 loss: 2.3412480464378222
#  batch 28000 loss: 2.376639274886984
#  batch 28100 loss: 2.2931126809000855
#  batch 28200 loss: 2.4750963352271356
#  batch 28300 loss: 2.4423427091747
#  batch 28400 loss: 2.2312909431062873
# ...
# EPOCH 29:
# lr 0.001 -> 0.001
# Train accuracy 42.1:
# Test accuracy 41.3:
# EPOCH 30:
# lr 0.001 -> 0.001
# Train accuracy 42.1:
# Test accuracy 41.199999999999996:
# EPOCH 31:
# lr 0.001 -> 0.001
# Train accuracy 42.1:
# Test accuracy 41.3:
# EPOCH 32:
# lr 0.001 -> 0.001
# Train accuracy 42.1:
# Test accuracy 41.3:
# EPOCH 33:
# lr 0.001 -> 0.001
# Train accuracy 42.1:
# Test accuracy 41.199999999999996:
# EPOCH 34:
# lr 0.001 -> 0.001
# Train accuracy 42.199999999999996:
# Test accuracy 41.3:
# EPOCH 35:
# lr 0.001 -> 0.001
# Train accuracy 42.199999999999996:
# Test accuracy 41.3:
# EPOCH 36:
# lr 0.001 -> 0.001
# Train accuracy 42.199999999999996:
# Test accuracy 41.3:
# EPOCH 37:
# lr 0.001 -> 0.001
# Train accuracy 42.199999999999996:
# Test accuracy 41.3:
# EPOCH 38:
# lr 0.001 -> 0.001
# Train accuracy 42.199999999999996:
# Test accuracy 41.3:
# EPOCH 39:
# lr 0.001 -> 0.001
# Train accuracy 42.199999999999996:
# Test accuracy 41.3:
# EPOCH 40:
# lr 0.001 -> 0.001
# Train accuracy 42.199999999999996:
# Test accuracy 41.3:
# EPOCH 41:
# lr 0.001 -> 0.001
# Train accuracy 42.199999999999996:
# Test accuracy 41.3:
# EPOCH 42:
# lr 0.001 -> 0.001
# Train accuracy 42.199999999999996:
# Test accuracy 41.3:
# EPOCH 43:
# lr 0.001 -> 0.001
# Train accuracy 42.199999999999996:
# Test accuracy 41.3:
# EPOCH 44:
# lr 0.001 -> 0.001
# Train accuracy 42.199999999999996:
# Test accuracy 41.3:
# EPOCH 45:
# lr 0.001 -> 0.001
# Train accuracy 42.199999999999996:
# Test accuracy 41.3:
# EPOCH 46:
# lr 0.001 -> 0.001
# Train accuracy 42.199999999999996:
# Test accuracy 41.3:
# EPOCH 47:
# lr 0.001 -> 0.001
# Train accuracy 42.199999999999996:
# Test accuracy 41.3:
# EPOCH 48:
# lr 0.001 -> 0.001
# Train accuracy 42.3:
# Test accuracy 41.3:
# EPOCH 49:
# lr 0.001 -> 0.001
# Train accuracy 42.3:
# Test accuracy 41.4:
# EPOCH 50:
# lr 0.001 -> 0.0001
# Train accuracy 42.3:
# Test accuracy 41.4:
# EPOCH 51:
# lr 0.0001 -> 0.0001
# Train accuracy 42.3:
# Test accuracy 41.4:
# EPOCH 52:
# lr 0.0001 -> 0.0001
# Train accuracy 42.3:
# Test accuracy 41.4:
# EPOCH 53:
# lr 0.0001 -> 0.0001
# Train accuracy 42.3:
# Test accuracy 41.4:
# EPOCH 54:
# lr 0.0001 -> 0.0001
# Train accuracy 42.3:
# Test accuracy 41.4:
# EPOCH 55:
# lr 0.0001 -> 0.0001
# Train accuracy 42.3:
# Test accuracy 41.4:
# EPOCH 56:
# lr 0.0001 -> 0.0001
# Train accuracy 42.3:
# Test accuracy 41.4:
# EPOCH 57:
# lr 0.0001 -> 0.0001
# Train accuracy 42.3:
# Test accuracy 41.4:
# EPOCH 58:
# lr 0.0001 -> 0.0001
# Train accuracy 42.3:
# Test accuracy 41.4:
# EPOCH 59:
# lr 0.0001 -> 0.0001
# Train accuracy 42.3:
# Test accuracy 41.4:
# EPOCH 60:
# lr 0.0001 -> 0.0001
# Train accuracy 42.3:
# Test accuracy 41.4:
# EPOCH 61:
# lr 0.0001 -> 0.0001
# Train accuracy 42.3:
# Test accuracy 41.4:
# EPOCH 62:
# lr 0.0001 -> 0.0001
# Train accuracy 42.3:
# Test accuracy 41.4:
# EPOCH 63:
# lr 0.0001 -> 0.0001
# Train accuracy 42.3:
# Test accuracy 41.4:
# EPOCH 64:
# lr 0.0001 -> 0.0001
# Train accuracy 42.3:
# Test accuracy 41.4:
# EPOCH 65:
# lr 0.0001 -> 0.0001
# Train accuracy 42.3:
# Test accuracy 41.4:
# EPOCH 66:
# lr 0.0001 -> 0.0001
# Train accuracy 42.3:
# Test accuracy 41.4:
# EPOCH 67:
# lr 0.0001 -> 0.0001
# Train accuracy 42.3:
# Test accuracy 41.4:
# EPOCH 68:
# lr 0.0001 -> 0.0001
# Train accuracy 42.3:
# Test accuracy 41.4:
# EPOCH 69:
# lr 0.0001 -> 0.0001
# Train accuracy 42.3:
# Test accuracy 41.4:
# EPOCH 70:
# lr 0.0001 -> 0.0001
# Train accuracy 42.3:
# Test accuracy 41.4:
# EPOCH 71:
# lr 0.0001 -> 0.0001
# Train accuracy 42.3:
# Test accuracy 41.4:
# EPOCH 72:
# lr 0.0001 -> 0.0001
# Train accuracy 42.3:
# Test accuracy 41.4:
# EPOCH 73:
# lr 0.0001 -> 0.0001
# Train accuracy 42.3:
# Test accuracy 41.4:
# EPOCH 74:
# lr 0.0001 -> 0.0001
# Train accuracy 42.3:
# Test accuracy 41.4:
# EPOCH 75:
# lr 0.0001 -> 1e-05
# Train accuracy 42.3:
# Test accuracy 41.4:
# EPOCH 76:
# lr 1e-05 -> 1e-05
# Train accuracy 42.3:
# Test accuracy 41.4:
# EPOCH 77:
# lr 1e-05 -> 1e-05
# Train accuracy 42.3:
# Test accuracy 41.4:
# EPOCH 78:
# lr 1e-05 -> 1e-05
# Train accuracy 42.3:
# Test accuracy 41.4:
# EPOCH 79:
# lr 1e-05 -> 1e-05
# Train accuracy 42.3:
# Test accuracy 41.4:
# EPOCH 80:
# lr 1e-05 -> 1e-05
# Train accuracy 42.3:
# Test accuracy 41.4:
# Batch Size 10000:
# EPOCH 1:
# lr 0.01 -> 0.01
# Train accuracy 20.599999999999998:
# Test accuracy 20.599999999999998:
# EPOCH 2:
# lr 0.01 -> 0.01
# Train accuracy 24.5:
# Test accuracy 24.7:
# EPOCH 3:
# lr 0.01 -> 0.01
# Train accuracy 26.700000000000003:
# Test accuracy 26.8:
# EPOCH 4:
# lr 0.01 -> 0.01
# Train accuracy 28.000000000000004:
# Test accuracy 28.299999999999997:
# EPOCH 5:
# lr 0.01 -> 0.01
# Train accuracy 29.2:
# Test accuracy 29.099999999999998:
# EPOCH 6:
# lr 0.01 -> 0.01
# Train accuracy 30.0:
# Test accuracy 30.0:
# EPOCH 7:
# lr 0.01 -> 0.01
# Train accuracy 30.8:
# Test accuracy 31.0:
# EPOCH 8:
# lr 0.01 -> 0.01
# Train accuracy 31.5:
# Test accuracy 31.7:
# EPOCH 9:
# lr 0.01 -> 0.01
# Train accuracy 31.900000000000002:
# Test accuracy 32.5:
# EPOCH 10:
# lr 0.01 -> 0.01
# Train accuracy 32.5:
# Test accuracy 32.9:
# EPOCH 11:
# lr 0.01 -> 0.01
# Train accuracy 33.0:
# Test accuracy 33.5:
# EPOCH 12:
# lr 0.01 -> 0.01
# Train accuracy 33.4:
# Test accuracy 33.900000000000006:
# EPOCH 13:
# lr 0.01 -> 0.01
# Train accuracy 33.800000000000004:
# Test accuracy 34.300000000000004:
# EPOCH 14:
# lr 0.01 -> 0.01
# Train accuracy 34.1:
# Test accuracy 34.5:
# EPOCH 15:
# lr 0.01 -> 0.01
# Train accuracy 34.4:
# Test accuracy 34.699999999999996:
# EPOCH 16:
# lr 0.01 -> 0.01
# Train accuracy 34.699999999999996:
# Test accuracy 35.0:
# EPOCH 17:
# lr 0.01 -> 0.01
# Train accuracy 35.0:
# Test accuracy 35.3:
# EPOCH 18:
# lr 0.01 -> 0.01
# Train accuracy 35.199999999999996:
# Test accuracy 35.5:
# EPOCH 19:
# lr 0.01 -> 0.01
# Train accuracy 35.4:
# Test accuracy 35.6:
# EPOCH 20:
# lr 0.01 -> 0.01
# Train accuracy 35.6:
# Test accuracy 35.9:
# EPOCH 21:
# lr 0.01 -> 0.01
# Train accuracy 35.699999999999996:
# Test accuracy 36.0:
# EPOCH 22:
# lr 0.01 -> 0.01
# Train accuracy 35.9:
# Test accuracy 36.199999999999996:
# EPOCH 23:
# lr 0.01 -> 0.01
# Train accuracy 36.1:
# Test accuracy 36.3:
# EPOCH 24:
# lr 0.01 -> 0.01
# Train accuracy 36.199999999999996:
# Test accuracy 36.4:
# EPOCH 25:
# lr 0.01 -> 0.001
# Train accuracy 36.4:
# Test accuracy 36.6:
# EPOCH 26:
# lr 0.001 -> 0.001
# Train accuracy 36.4:
# Test accuracy 36.6:
# EPOCH 27:
# lr 0.001 -> 0.001
# Train accuracy 36.4:
# Test accuracy 36.6:
# EPOCH 28:
# lr 0.001 -> 0.001
# Train accuracy 36.5:
# Test accuracy 36.6:
# EPOCH 29:
# lr 0.001 -> 0.001
# Train accuracy 36.5:
# Test accuracy 36.6:
# EPOCH 30:
# lr 0.001 -> 0.001
# Train accuracy 36.5:
# Test accuracy 36.6:
# EPOCH 31:
# lr 0.001 -> 0.001
# Train accuracy 36.5:
# Test accuracy 36.6:
# EPOCH 32:
# lr 0.001 -> 0.001
# Train accuracy 36.5:
# Test accuracy 36.6:
# EPOCH 33:
# lr 0.001 -> 0.001
# Train accuracy 36.5:
# Test accuracy 36.6:
# EPOCH 34:
# lr 0.001 -> 0.001
# Train accuracy 36.5:
# Test accuracy 36.6:
# EPOCH 35:
# lr 0.001 -> 0.001
# Train accuracy 36.5:
# Test accuracy 36.7:
# EPOCH 36:
# lr 0.001 -> 0.001
# Train accuracy 36.6:
# Test accuracy 36.7:
# EPOCH 37:
# lr 0.001 -> 0.001
# Train accuracy 36.6:
# Test accuracy 36.7:
# EPOCH 38:
# lr 0.001 -> 0.001
# Train accuracy 36.6:
# Test accuracy 36.7:
# EPOCH 39:
# lr 0.001 -> 0.001
# Train accuracy 36.6:
# Test accuracy 36.7:
# EPOCH 40:
# lr 0.001 -> 0.001
# Train accuracy 36.6:
# Test accuracy 36.8:
# EPOCH 41:
# lr 0.001 -> 0.001
# Train accuracy 36.7:
# Test accuracy 36.8:
# EPOCH 42:
# lr 0.001 -> 0.001
# Train accuracy 36.7:
# Test accuracy 36.8:
# EPOCH 43:
# lr 0.001 -> 0.001
# Train accuracy 36.7:
# Test accuracy 36.8:
# EPOCH 44:
# lr 0.001 -> 0.001
# Train accuracy 36.7:
# Test accuracy 36.8:
# EPOCH 45:
# lr 0.001 -> 0.001
# Train accuracy 36.7:
# Test accuracy 36.8:
# EPOCH 46:
# lr 0.001 -> 0.001
# Train accuracy 36.7:
# Test accuracy 36.8:
# EPOCH 47:
# lr 0.001 -> 0.001
# Train accuracy 36.7:
# Test accuracy 36.8:
# EPOCH 48:
# lr 0.001 -> 0.001
# Train accuracy 36.7:
# Test accuracy 36.8:
# EPOCH 49:
# lr 0.001 -> 0.001
# Train accuracy 36.7:
# Test accuracy 36.8:
# EPOCH 50:
# lr 0.001 -> 0.0001
# Train accuracy 36.8:
# Test accuracy 36.8:
# EPOCH 51:
# lr 0.0001 -> 0.0001
# Train accuracy 36.8:
# Test accuracy 36.8:
# EPOCH 52:
# lr 0.0001 -> 0.0001
# Train accuracy 36.8:
# Test accuracy 36.8:
# EPOCH 53:
# lr 0.0001 -> 0.0001
# Train accuracy 36.8:
# Test accuracy 36.8:
# EPOCH 54:
# lr 0.0001 -> 0.0001
# Train accuracy 36.8:
# Test accuracy 36.8:
# EPOCH 55:
# lr 0.0001 -> 0.0001
# Train accuracy 36.8:
# Test accuracy 36.8:
# EPOCH 56:
# lr 0.0001 -> 0.0001
# Train accuracy 36.8:
# Test accuracy 36.8:
# EPOCH 57:
# lr 0.0001 -> 0.0001
# Train accuracy 36.8:
# Test accuracy 36.9:
# EPOCH 58:
# lr 0.0001 -> 0.0001
# Train accuracy 36.8:
# Test accuracy 36.9:
# EPOCH 59:
# lr 0.0001 -> 0.0001
# Train accuracy 36.8:
# Test accuracy 36.9:
# EPOCH 60:
# lr 0.0001 -> 0.0001
# Train accuracy 36.8:
# Test accuracy 36.9:
# EPOCH 61:
# lr 0.0001 -> 0.0001
# Train accuracy 36.8:
# Test accuracy 36.9:
# EPOCH 62:
# lr 0.0001 -> 0.0001
# Train accuracy 36.8:
# Test accuracy 36.9:
# EPOCH 63:
# lr 0.0001 -> 0.0001
# Train accuracy 36.8:
# Test accuracy 36.8:
# EPOCH 64:
# lr 0.0001 -> 0.0001
# Train accuracy 36.8:
# Test accuracy 36.8:
# EPOCH 65:
# lr 0.0001 -> 0.0001
# Train accuracy 36.8:
# Test accuracy 36.8:
# EPOCH 66:
# lr 0.0001 -> 0.0001
# Train accuracy 36.8:
# Test accuracy 36.8:
# EPOCH 67:
# lr 0.0001 -> 0.0001
# Train accuracy 36.8:
# Test accuracy 36.8:
# EPOCH 68:
# lr 0.0001 -> 0.0001
# Train accuracy 36.8:
# Test accuracy 36.8:
# EPOCH 69:
# lr 0.0001 -> 0.0001
# Train accuracy 36.8:
# Test accuracy 36.9:
# EPOCH 70:
# lr 0.0001 -> 0.0001
# Train accuracy 36.8:
# Test accuracy 36.9:
# EPOCH 71:
# lr 0.0001 -> 0.0001
# Train accuracy 36.8:
# Test accuracy 36.9:
# EPOCH 72:
# lr 0.0001 -> 0.0001
# Train accuracy 36.8:
# Test accuracy 36.9:
# EPOCH 73:
# lr 0.0001 -> 0.0001
# Train accuracy 36.8:
# Test accuracy 36.9:
# EPOCH 74:
# lr 0.0001 -> 0.0001
# Train accuracy 36.8:
# Test accuracy 36.9:
# EPOCH 75:
# lr 0.0001 -> 1e-05
# Train accuracy 36.8:
# Test accuracy 36.9:
# EPOCH 76:
# lr 1e-05 -> 1e-05
# Train accuracy 36.8:
# Test accuracy 36.9:
# EPOCH 77:
# lr 1e-05 -> 1e-05
# Train accuracy 36.8:
# Test accuracy 36.9:
# EPOCH 78:
# lr 1e-05 -> 1e-05
# Train accuracy 36.8:
# Test accuracy 36.9:
# EPOCH 79:
# lr 1e-05 -> 1e-05
# Train accuracy 36.8:
# Test accuracy 36.9:
# EPOCH 80:
# lr 1e-05 -> 1e-05
# Train accuracy 36.8:
# Test accuracy 36.9:
# Batch Size 50000:
# EPOCH 1:
# lr 0.01 -> 0.01
# Train accuracy 12.8:
# Test accuracy 12.6:
# EPOCH 2:
# lr 0.01 -> 0.01
# Train accuracy 15.4:
# Test accuracy 15.299999999999999:
# EPOCH 3:
# lr 0.01 -> 0.01
# Train accuracy 17.599999999999998:
# Test accuracy 17.4:
# EPOCH 4:
# lr 0.01 -> 0.01
# Train accuracy 19.2:
# Test accuracy 19.1:
# EPOCH 5:
# lr 0.01 -> 0.01
# Train accuracy 20.4:
# Test accuracy 20.0:
# EPOCH 6:
# lr 0.01 -> 0.01
# Train accuracy 21.3:
# Test accuracy 21.0:
# EPOCH 7:
# lr 0.01 -> 0.01
# Train accuracy 22.0:
# Test accuracy 21.7:
# EPOCH 8:
# lr 0.01 -> 0.01
# Train accuracy 22.7:
# Test accuracy 22.5:
# EPOCH 9:
# lr 0.01 -> 0.01
# Train accuracy 23.200000000000003:
# Test accuracy 23.0:
# EPOCH 10:
# lr 0.01 -> 0.01
# Train accuracy 23.7:
# Test accuracy 23.599999999999998:
# EPOCH 11:
# lr 0.01 -> 0.01
# Train accuracy 24.2:
# Test accuracy 24.099999999999998:
# EPOCH 12:
# lr 0.01 -> 0.01
# Train accuracy 24.7:
# Test accuracy 24.7:
# EPOCH 13:
# lr 0.01 -> 0.01
# Train accuracy 25.2:
# Test accuracy 25.2:
# EPOCH 14:
# lr 0.01 -> 0.01
# Train accuracy 25.7:
# Test accuracy 25.7:
# EPOCH 15:
# lr 0.01 -> 0.01
# Train accuracy 26.0:
# Test accuracy 26.200000000000003:
# EPOCH 16:
# lr 0.01 -> 0.01
# Train accuracy 26.5:
# Test accuracy 26.6:
# EPOCH 17:
# lr 0.01 -> 0.01
# Train accuracy 26.8:
# Test accuracy 27.0:
# EPOCH 18:
# lr 0.01 -> 0.01
# Train accuracy 27.1:
# Test accuracy 27.400000000000002:
# EPOCH 19:
# lr 0.01 -> 0.01
# Train accuracy 27.400000000000002:
# Test accuracy 27.700000000000003:
# EPOCH 20:
# lr 0.01 -> 0.01
# Train accuracy 27.700000000000003:
# Test accuracy 28.1:
# EPOCH 21:
# lr 0.01 -> 0.01
# Train accuracy 28.000000000000004:
# Test accuracy 28.299999999999997:
# EPOCH 22:
# lr 0.01 -> 0.01
# Train accuracy 28.199999999999996:
# Test accuracy 28.799999999999997:
# EPOCH 23:
# lr 0.01 -> 0.01
# Train accuracy 28.499999999999996:
# Test accuracy 28.999999999999996:
# EPOCH 24:
# lr 0.01 -> 0.01
# Train accuracy 28.799999999999997:
# Test accuracy 29.299999999999997:
# EPOCH 25:
# lr 0.01 -> 0.001
# Train accuracy 29.099999999999998:
# Test accuracy 29.5:
# EPOCH 26:
# lr 0.001 -> 0.001
# Train accuracy 29.099999999999998:
# Test accuracy 29.5:
# EPOCH 27:
# lr 0.001 -> 0.001
# Train accuracy 29.099999999999998:
# Test accuracy 29.5:
# EPOCH 28:
# lr 0.001 -> 0.001
# Train accuracy 29.099999999999998:
# Test accuracy 29.5:
# EPOCH 29:
# lr 0.001 -> 0.001
# Train accuracy 29.2:
# Test accuracy 29.5:
# EPOCH 30:
# lr 0.001 -> 0.001
# Train accuracy 29.2:
# Test accuracy 29.5:
# EPOCH 31:
# lr 0.001 -> 0.001
# Train accuracy 29.2:
# Test accuracy 29.599999999999998:
# EPOCH 32:
# lr 0.001 -> 0.001
# Train accuracy 29.2:
# Test accuracy 29.599999999999998:
# EPOCH 33:
# lr 0.001 -> 0.001
# Train accuracy 29.2:
# Test accuracy 29.599999999999998:
# EPOCH 34:
# lr 0.001 -> 0.001
# Train accuracy 29.299999999999997:
# Test accuracy 29.7:
# EPOCH 35:
# lr 0.001 -> 0.001
# Train accuracy 29.299999999999997:
# Test accuracy 29.7:
# EPOCH 36:
# lr 0.001 -> 0.001
# Train accuracy 29.299999999999997:
# Test accuracy 29.799999999999997:
# EPOCH 37:
# lr 0.001 -> 0.001
# Train accuracy 29.299999999999997:
# Test accuracy 29.7:
# EPOCH 38:
# lr 0.001 -> 0.001
# Train accuracy 29.4:
# Test accuracy 29.7:
# EPOCH 39:
# lr 0.001 -> 0.001
# Train accuracy 29.4:
# Test accuracy 29.799999999999997:
# EPOCH 40:
# lr 0.001 -> 0.001
# Train accuracy 29.4:
# Test accuracy 29.799999999999997:
# EPOCH 41:
# lr 0.001 -> 0.001
# Train accuracy 29.4:
# Test accuracy 29.799999999999997:
# EPOCH 42:
# lr 0.001 -> 0.001
# Train accuracy 29.5:
# Test accuracy 29.799999999999997:
# EPOCH 43:
# lr 0.001 -> 0.001
# Train accuracy 29.5:
# Test accuracy 29.799999999999997:
# EPOCH 44:
# lr 0.001 -> 0.001
# Train accuracy 29.5:
# Test accuracy 29.799999999999997:
# EPOCH 45:
# lr 0.001 -> 0.001
# Train accuracy 29.5:
# Test accuracy 29.799999999999997:
# EPOCH 46:
# lr 0.001 -> 0.001
# Train accuracy 29.5:
# Test accuracy 29.799999999999997:
# EPOCH 47:
# lr 0.001 -> 0.001
# Train accuracy 29.599999999999998:
# Test accuracy 29.9:
# EPOCH 48:
# lr 0.001 -> 0.001
# Train accuracy 29.599999999999998:
# Test accuracy 29.9:
# EPOCH 49:
# lr 0.001 -> 0.001
# Train accuracy 29.599999999999998:
# Test accuracy 29.9:
# EPOCH 50:
# lr 0.001 -> 0.0001
# Train accuracy 29.599999999999998:
# Test accuracy 29.9:
# EPOCH 51:
# lr 0.0001 -> 0.0001
# Train accuracy 29.599999999999998:
# Test accuracy 29.9:
# EPOCH 52:
# lr 0.0001 -> 0.0001
# Train accuracy 29.599999999999998:
# Test accuracy 29.9:
# EPOCH 53:
# lr 0.0001 -> 0.0001
# Train accuracy 29.599999999999998:
# Test accuracy 29.9:
# EPOCH 54:
# lr 0.0001 -> 0.0001
# Train accuracy 29.599999999999998:
# Test accuracy 29.9:
# EPOCH 55:
# lr 0.0001 -> 0.0001
# Train accuracy 29.599999999999998:
# Test accuracy 29.9:
# EPOCH 56:
# lr 0.0001 -> 0.0001
# Train accuracy 29.599999999999998:
# Test accuracy 29.9:
# EPOCH 57:
# lr 0.0001 -> 0.0001
# Train accuracy 29.599999999999998:
# Test accuracy 29.9:
# EPOCH 58:
# lr 0.0001 -> 0.0001
# Train accuracy 29.599999999999998:
# Test accuracy 29.9:
# EPOCH 59:
# lr 0.0001 -> 0.0001
# Train accuracy 29.599999999999998:
# Test accuracy 29.9:
# EPOCH 60:
# lr 0.0001 -> 0.0001
# Train accuracy 29.599999999999998:
# Test accuracy 29.9:
# EPOCH 61:
# lr 0.0001 -> 0.0001
# Train accuracy 29.599999999999998:
# Test accuracy 29.9:
# EPOCH 62:
# lr 0.0001 -> 0.0001
# Train accuracy 29.599999999999998:
# Test accuracy 29.9:
# EPOCH 63:
# lr 0.0001 -> 0.0001
# Train accuracy 29.599999999999998:
# Test accuracy 29.9:
# EPOCH 64:
# lr 0.0001 -> 0.0001
# Train accuracy 29.599999999999998:
# Test accuracy 29.9:
# EPOCH 65:
# lr 0.0001 -> 0.0001
# Train accuracy 29.599999999999998:
# Test accuracy 29.9:
# EPOCH 66:
# lr 0.0001 -> 0.0001
# Train accuracy 29.599999999999998:
# Test accuracy 29.9:
# EPOCH 67:
# lr 0.0001 -> 0.0001
# Train accuracy 29.599999999999998:
# Test accuracy 29.9:
# EPOCH 68:
# lr 0.0001 -> 0.0001
# Train accuracy 29.7:
# Test accuracy 29.9:
# EPOCH 69:
# lr 0.0001 -> 0.0001
# Train accuracy 29.599999999999998:
# Test accuracy 29.9:
# EPOCH 70:
# lr 0.0001 -> 0.0001
# Train accuracy 29.599999999999998:
# Test accuracy 29.9:
# EPOCH 71:
# lr 0.0001 -> 0.0001
# Train accuracy 29.7:
# Test accuracy 29.9:
# EPOCH 72:
# lr 0.0001 -> 0.0001
# Train accuracy 29.7:
# Test accuracy 29.9:
# EPOCH 73:
# lr 0.0001 -> 0.0001
# Train accuracy 29.7:
# Test accuracy 29.9:
# EPOCH 74:
# lr 0.0001 -> 0.0001
# Train accuracy 29.7:
# Test accuracy 29.9:
# EPOCH 75:
# lr 0.0001 -> 1e-05
# Train accuracy 29.7:
# Test accuracy 29.9:
# EPOCH 76:
# lr 1e-05 -> 1e-05
# Train accuracy 29.7:
# Test accuracy 29.9:
# EPOCH 77:
# lr 1e-05 -> 1e-05
# Train accuracy 29.7:
# Test accuracy 29.9:
# EPOCH 78:
# lr 1e-05 -> 1e-05
# Train accuracy 29.7:
# Test accuracy 29.9:
# EPOCH 79:
# lr 1e-05 -> 1e-05
# Train accuracy 29.7:
# Test accuracy 29.9:
# EPOCH 80:
# lr 1e-05 -> 1e-05
# Train accuracy 29.7:
# Test accuracy 29.9:

# %%
import numpy as np
epochs_arr = np.arange(0, len(losses_arr[0]))

# %%
# Plot training loss
x = np.array(epochs_arr)
for i,train_loss in enumerate(losses_arr):
  ypoints = np.array(train_loss)
  plt.plot(x, ypoints, label = description[i])

plt.xlabel("Epochs")
plt.ylabel("train Loss")
plt.legend()
plt.title('LR=0.01, Optimizer=SGD, L2 Regularization=1e-5')
plt.show()

# %%
# Plot training accuracy
x = np.array(epochs_arr)
for i,train_acc in enumerate(train_accuracy_arr):
  ypoints = np.array(train_acc)
  plt.plot(x, ypoints, label = description[i])

plt.xlabel("Epochs")
plt.ylabel("train Accuracy")
plt.legend()
plt.title('LR=0.01, Optimizer=SGD, L2 Regularization=1e-5')
plt.show()

# %%
# Plot test accuracy
x = np.array(epochs_arr)
for i,test_acc in enumerate(test_accuracy_arr):
  ypoints = np.array(test_acc)
  plt.plot(x, ypoints, label = description[i])

plt.xlabel("Epochs")
plt.ylabel("test Accuracy")
plt.legend()
plt.title('LR=0.01, Optimizer=SGD, L2 Regularization=1e-5')
plt.show()

# %%
# Plot test and training accuracy
x = np.array(epochs_arr)
for i,bs in enumerate(batch_sizes):
  ypoints_1 = np.array(train_accuracy_arr[i])
  ypoints_2 = np.array(test_accuracy_arr[i])
  plt.plot(x, ypoints_1, label = 'Train')
  plt.plot(x, ypoints_2, label = 'Test')
  plt.xlabel("Epochs")
  plt.ylabel("Accuracy")
  plt.legend()
  plt.title(F'LR=0.01, Optimizer=SGD, L2 Regularization=0, Batch size={bs}')
  plt.show()

# %% [markdown]
# ### Load model

# %%
model_save_name = '1695168105559.8071_Step_bs128_e30_SGD_ss10_gamma0.1_cifar'
path = F"{model_save_name}.pt"
net.load_state_dict(t.load(path))

# %%
test(net,test_loader)

# %%
#hello kuch likhlo warna inactivity timeout de dega yeh

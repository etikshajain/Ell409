# %%
import torch as t
import torchvision.datasets as datasets
import torchvision.transforms as transforms
import torch.nn as nn
import matplotlib.pyplot as plt
import torch.optim as optim
import torch.optim.lr_scheduler as lr_scheduler
from torch.optim.lr_scheduler import ReduceLROnPlateau, StepLR, ExponentialLR

# %% [markdown]
# ### Model

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net,self).__init__()
        self.linear1 = nn.Linear(3*32*32, 10)
        self.relu = nn.ReLU()

    def forward(self, img): #convert + flatten
        x = img.view(-1, 3*32*32)
        x = self.relu(self.linear1(x))
        return x
net = Net()

# %% [markdown]
# ### Hyperparams

# %%
num_epochs=100
after_every=100
loss_fn = nn.CrossEntropyLoss()
batch_size=128

# %%
import ssl
ssl._create_default_https_context = ssl._create_unverified_context
transform = transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5)),])

mnist_trainset = datasets.CIFAR10(root='./data', train=True, download=True, transform=transform)
train_loader = t.utils.data.DataLoader(mnist_trainset, batch_size=batch_size, shuffle=True)

mnist_testset = datasets.CIFAR10(root='./data', train=False, download=True, transform=transform)
test_loader = t.utils.data.DataLoader(mnist_testset, batch_size=batch_size, shuffle=True)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# (50000, 32, 32, 3)

# %% [markdown]
# ### Training

# %%
def train_one_epoch(model, epoch_index, optimizer, train_dataset):
    running_loss = 0.
    last_loss = 0.

    for i, data in enumerate(train_dataset):
        # Every data instance is an input + label pair
        # data.shape=torch.Size([10, 1, 28, 28]) --> 10 images,labels
        inputs, labels = data

        # Zero your gradients for every batch!
        optimizer.zero_grad()

        # Make predictions for this batch
        outputs = model(inputs.view(-1, 3*32*32))


        # Compute the loss and its gradients
        loss = loss_fn(outputs, labels)
        loss.backward()

        # Adjust learning weights
        optimizer.step()

        # Gather data and report
        running_loss += loss.item()

        if i % after_every == after_every-1:
            last_loss = running_loss / after_every # loss per after_every batches
            print(' batch {} loss: {}'.format(i + 1, last_loss))
            running_loss = 0.

    return last_loss

# %% [markdown]
# ### Evaluate

# %%
def test(model, loader):
  total=0
  correct=0
  model.eval()
  with t.no_grad():
      for data in loader:
          x, y = data
          output = model(x.view(-1, 3*32*32))
          for idx, i in enumerate(output):
              if t.argmax(i) == y[idx]:
                  correct +=1
              total +=1
  return round(correct/total, 3)*100

# %%
def train_model(model, epochs, train_dataset, test_dataset, optimizer, scheduler, LR_type):
  epoch_number = 0

  losses = []
  train_accuracy = []
  test_accuracy = []

  for epoch in range(epochs):
      print('EPOCH {}:'.format(epoch_number + 1))

      # Make sure gradient tracking is on, and do a pass over the data
      model.train(True)
      avg_loss = train_one_epoch(model, epoch_number,optimizer,train_dataset)
      losses.append(avg_loss)

      # Train accuracy
      train_acc = test(model, train_dataset)
      train_accuracy.append(train_acc)

      # Test accuracy
      test_acc = test(model, test_dataset)
      test_accuracy.append(test_acc)

      if LR_type=='Plateau':
        before_lr = optimizer.param_groups[0]["lr"]
        scheduler.step(avg_loss)
        after_lr = optimizer.param_groups[0]["lr"]
        print('lr {} -> {}'.format(before_lr, after_lr))

      elif LR_type!='None':
        before_lr = optimizer.param_groups[0]["lr"]
        scheduler.step()
        after_lr = optimizer.param_groups[0]["lr"]
        print('lr {} -> {}'.format(before_lr, after_lr))

      print('Train accuracy {}:'.format(train_acc))
      print('Test accuracy {}:'.format(test_acc))
      epoch_number += 1
  return losses, train_accuracy, test_accuracy

# %%
import datetime as dt

def train_with_reg(starting_lr):
  losses_arr = []
  train_accuracy_arr = []
  test_accuracy_arr = []
  regularization_strengths = [0, 1e-7, 1e-5, 1e-3, 1e-1, 1.0]
  description = []

  # Different Reg strengths
  for regularization_strength in regularization_strengths:
    print('Reg Strength {}:'.format(regularization_strength))
    net_new = Net()
    optimizerr = t.optim.SGD(net_new.parameters(), lr=starting_lr, weight_decay=regularization_strength)
    scheduler = StepLR(optimizerr, 25, gamma=0.1)

    losses, train_accuracy, test_accuracy = train_model(net_new, num_epochs, train_loader, test_loader, optimizerr, scheduler, 'Step')

    losses_arr.append(losses)
    train_accuracy_arr.append(train_accuracy)
    test_accuracy_arr.append(test_accuracy)
    description.append('Starting LR:{}, L2Reg:{}'.format(starting_lr, regularization_strength))

    # save model
    ts_now = dt.datetime.now()
    unix_timestamp = dt.datetime.timestamp(ts_now)*1000
    model_save_name = str(unix_timestamp)
    path = F"{model_save_name}_L2Reg={regularization_strength}_bs{128}_e{num_epochs}_SGD_LRStep_.pt"
    t.save(net.state_dict(), path)

  return description, losses_arr, train_accuracy_arr, test_accuracy_arr

# %%
import csv
def save_to_csv(filename, description, losses_arr, train_acc_arr, test_acc_arr):
  # Create a CSV file and write data to it
  with open(filename+'.csv', 'w', newline='') as csvfile:
    for i, desc in enumerate(description):
      fieldnames = ['Description', 'epoch', 'train_loss', 'train_accuracy', 'test_accuracy']
      writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
      writer.writeheader()
      for epoch, (loss, train, test) in enumerate(zip(losses_arr[i], train_acc_arr[i], test_acc_arr[i]), 1):
          writer.writerow({'Description':description[i], 'epoch': epoch, 'train_loss': loss, 'train_accuracy': train, 'test_accuracy': test})

# %% [markdown]
# ### Plotting- Starting LR=0.01
# #### Reg strengths = [0, 1e-7, 1e-5, 1e-3, 1e-1, 1.0]

# %%
lr = 0.01
regularization_strengths = [0, 1e-7, 1e-5, 1e-3, 1e-1, 1.0]
description, losses_arr, train_accuracy_arr, test_accuracy_arr = train_with_reg(lr)
save_to_csv('Regularisation_Step', description, losses_arr, train_accuracy_arr, test_accuracy_arr)
# Out:
# Reg Strength 0:
# EPOCH 1:
#  batch 100 loss: 2.0270689606666563
#  batch 200 loss: 1.8774386286735534
#  batch 300 loss: 1.842015701532364
# lr 0.01 -> 0.01
# Train accuracy 39.0:
# Test accuracy 38.6:
# EPOCH 2:
#  batch 100 loss: 1.794778413772583
#  batch 200 loss: 1.7937125694751739
#  batch 300 loss: 1.7653629744052888
# lr 0.01 -> 0.01
# Train accuracy 40.6:
# Test accuracy 40.2:
# EPOCH 3:
#  batch 100 loss: 1.7599763810634612
#  batch 200 loss: 1.7439782786369324
#  batch 300 loss: 1.7555349218845366
# lr 0.01 -> 0.01
# Train accuracy 41.699999999999996:
# Test accuracy 40.699999999999996:
# EPOCH 4:
#  batch 100 loss: 1.7358023405075074
#  batch 200 loss: 1.7374082493782044
#  batch 300 loss: 1.74824609041214
# lr 0.01 -> 0.01
# Train accuracy 42.1:
# Test accuracy 41.099999999999994:
# EPOCH 5:
#  batch 100 loss: 1.7150224936008454
#  batch 200 loss: 1.7189004707336426
#  batch 300 loss: 1.7343584954738618
# lr 0.01 -> 0.01
# Train accuracy 42.8:
# Test accuracy 41.4:
# EPOCH 6:
#  batch 100 loss: 1.7169190382957458
#  batch 200 loss: 1.715080713033676
#  batch 300 loss: 1.7054202890396117
# lr 0.01 -> 0.01
# Train accuracy 43.0:
# Test accuracy 41.6:
# EPOCH 7:
#  batch 100 loss: 1.6932263123989104
#  batch 200 loss: 1.703803243637085
#  batch 300 loss: 1.7154487228393556
# lr 0.01 -> 0.01
# Train accuracy 43.2:
# Test accuracy 41.4:
# EPOCH 8:
#  batch 100 loss: 1.687960832118988
#  batch 200 loss: 1.7034016847610474
#  batch 300 loss: 1.7050056099891662
# lr 0.01 -> 0.01
# Train accuracy 43.3:
# Test accuracy 41.3:
# EPOCH 9:
#  batch 100 loss: 1.6790659761428832
#  batch 200 loss: 1.7000548005104066
#  batch 300 loss: 1.6782243001461028
# lr 0.01 -> 0.01
# Train accuracy 43.5:
# Test accuracy 41.099999999999994:
# EPOCH 10:
#  batch 100 loss: 1.67317946434021
#  batch 200 loss: 1.6898528015613556
#  batch 300 loss: 1.6943280053138734
# lr 0.01 -> 0.01
# Train accuracy 43.1:
# Test accuracy 41.199999999999996:
# EPOCH 11:
#  batch 100 loss: 1.6819327294826507
#  batch 200 loss: 1.6800426280498504
#  batch 300 loss: 1.6909045004844665
# lr 0.01 -> 0.01
# Train accuracy 43.8:
# Test accuracy 41.3:
# EPOCH 12:
#  batch 100 loss: 1.6804672300815582
#  batch 200 loss: 1.6718735957145692
#  batch 300 loss: 1.6722356641292573
# lr 0.01 -> 0.01
# Train accuracy 44.2:
# Test accuracy 41.4:
# EPOCH 13:
#  batch 100 loss: 1.6672804856300354
#  batch 200 loss: 1.6767262029647827
#  batch 300 loss: 1.669964735507965
# lr 0.01 -> 0.01
# Train accuracy 44.1:
# Test accuracy 41.699999999999996:
# EPOCH 14:
#  batch 100 loss: 1.656935065984726
#  batch 200 loss: 1.6720637786388397
#  batch 300 loss: 1.6706435477733612
# lr 0.01 -> 0.01
# Train accuracy 44.2:
# Test accuracy 41.5:
# EPOCH 15:
#  batch 100 loss: 1.6479852616786956
#  batch 200 loss: 1.6629157865047455
#  batch 300 loss: 1.6768342065811157
# lr 0.01 -> 0.01
# Train accuracy 44.2:
# Test accuracy 41.099999999999994:
# EPOCH 16:
#  batch 100 loss: 1.669295974969864
#  batch 200 loss: 1.6473440647125244
#  batch 300 loss: 1.6671470999717712
# lr 0.01 -> 0.01
# Train accuracy 44.5:
# Test accuracy 41.4:
# EPOCH 17:
#  batch 100 loss: 1.6540942525863647
#  batch 200 loss: 1.6640231728553772
#  batch 300 loss: 1.6625788068771363
# lr 0.01 -> 0.01
# Train accuracy 44.3:
# Test accuracy 41.6:
# EPOCH 18:
#  batch 100 loss: 1.6463587498664856
#  batch 200 loss: 1.6652706623077393
#  batch 300 loss: 1.6593666934967042
# lr 0.01 -> 0.01
# Train accuracy 44.5:
# Test accuracy 41.199999999999996:
# EPOCH 19:
#  batch 100 loss: 1.6573659598827362
#  batch 200 loss: 1.6440919756889343
#  batch 300 loss: 1.6579749846458436
# lr 0.01 -> 0.01
# Train accuracy 44.5:
# Test accuracy 41.4:
# EPOCH 20:
#  batch 100 loss: 1.6415943121910095
#  batch 200 loss: 1.650167099237442
#  batch 300 loss: 1.6674474716186523
# lr 0.01 -> 0.01
# Train accuracy 45.1:
# Test accuracy 41.6:
# EPOCH 21:
#  batch 100 loss: 1.6574364280700684
#  batch 200 loss: 1.648163640499115
#  batch 300 loss: 1.6512719213962554
# lr 0.01 -> 0.01
# Train accuracy 45.0:
# Test accuracy 41.099999999999994:
# EPOCH 22:
#  batch 100 loss: 1.6595209777355193
#  batch 200 loss: 1.654493979215622
#  batch 300 loss: 1.6428123617172241
# lr 0.01 -> 0.01
# Train accuracy 44.9:
# Test accuracy 41.6:
# EPOCH 23:
#  batch 100 loss: 1.6544236314296723
#  batch 200 loss: 1.6455998170375823
#  batch 300 loss: 1.6466717910766602
# lr 0.01 -> 0.01
# Train accuracy 44.800000000000004:
# Test accuracy 41.6:
# EPOCH 24:
#  batch 100 loss: 1.6496239268779755
#  batch 200 loss: 1.6458284842967987
#  batch 300 loss: 1.638667641878128
# lr 0.01 -> 0.01
# Train accuracy 44.800000000000004:
# Test accuracy 41.199999999999996:
# EPOCH 25:
#  batch 100 loss: 1.6413249504566192
#  batch 200 loss: 1.6450130224227906
#  batch 300 loss: 1.637173707485199
# lr 0.01 -> 0.001
# Train accuracy 44.9:
# Test accuracy 41.5:
# EPOCH 26:
#  batch 100 loss: 1.6338082003593444
#  batch 200 loss: 1.61787691116333
#  batch 300 loss: 1.648492668867111
# lr 0.001 -> 0.001
# Train accuracy 45.6:
# Test accuracy 41.6:
# EPOCH 27:
#  batch 100 loss: 1.629979442358017
#  batch 200 loss: 1.644831931591034
#  batch 300 loss: 1.6206008350849153
# lr 0.001 -> 0.001
# Train accuracy 45.5:
# Test accuracy 41.699999999999996:
# EPOCH 28:
#  batch 100 loss: 1.6306055617332458
#  batch 200 loss: 1.623110728263855
#  batch 300 loss: 1.6367135119438172
# lr 0.001 -> 0.001
# Train accuracy 45.5:
# Test accuracy 41.9:
# EPOCH 29:
#  batch 100 loss: 1.624578458070755
#  batch 200 loss: 1.6240955424308776
#  batch 300 loss: 1.6389079928398131
# lr 0.001 -> 0.001
# Train accuracy 45.5:
# Test accuracy 41.699999999999996:
# EPOCH 30:
#  batch 100 loss: 1.631969965696335
#  batch 200 loss: 1.6155530905723572
#  batch 300 loss: 1.6453460896015166
# lr 0.001 -> 0.001
# Train accuracy 45.6:
# Test accuracy 41.6:
# EPOCH 31:
#  batch 100 loss: 1.6283786332607268
#  batch 200 loss: 1.635589325428009
#  batch 300 loss: 1.6210676991939545
# lr 0.001 -> 0.001
# Train accuracy 45.5:
# Test accuracy 41.6:
# EPOCH 32:
#  batch 100 loss: 1.6231234419345855
#  batch 200 loss: 1.6372670066356658
#  batch 300 loss: 1.6290678000450134
# lr 0.001 -> 0.001
# Train accuracy 45.5:
# Test accuracy 41.699999999999996:
# EPOCH 33:
#  batch 100 loss: 1.6309922599792481
#  batch 200 loss: 1.6315953302383424
#  batch 300 loss: 1.6305184197425842
# lr 0.001 -> 0.001
# Train accuracy 45.5:
# Test accuracy 41.8:
# EPOCH 34:
#  batch 100 loss: 1.6350176131725311
#  batch 200 loss: 1.63862438082695
#  batch 300 loss: 1.6202915477752686
# lr 0.001 -> 0.001
# Train accuracy 45.5:
# Test accuracy 41.699999999999996:
# EPOCH 35:
#  batch 100 loss: 1.6461851716041564
#  batch 200 loss: 1.6246065771579743
#  batch 300 loss: 1.6160239815711974
# lr 0.001 -> 0.001
# Train accuracy 45.6:
# Test accuracy 41.699999999999996:
# EPOCH 36:
#  batch 100 loss: 1.629974775314331
#  batch 200 loss: 1.6247514832019805
#  batch 300 loss: 1.632581295967102
# lr 0.001 -> 0.001
# Train accuracy 45.6:
# Test accuracy 41.699999999999996:
# EPOCH 37:
#  batch 100 loss: 1.621265137195587
#  batch 200 loss: 1.6342087757587433
#  batch 300 loss: 1.6356099832057953
# lr 0.001 -> 0.001
# Train accuracy 45.6:
# Test accuracy 41.699999999999996:
# EPOCH 38:
#  batch 100 loss: 1.6337971448898316
#  batch 200 loss: 1.611640591621399
#  batch 300 loss: 1.6369290030002595
# lr 0.001 -> 0.001
# Train accuracy 45.6:
# Test accuracy 41.699999999999996:
# EPOCH 39:
#  batch 100 loss: 1.6236496412754058
#  batch 200 loss: 1.632066432237625
#  batch 300 loss: 1.6351476955413817
# lr 0.001 -> 0.001
# Train accuracy 45.6:
# Test accuracy 41.8:
# EPOCH 40:
#  batch 100 loss: 1.6276268923282624
#  batch 200 loss: 1.6333017098903655
#  batch 300 loss: 1.6248373627662658
# lr 0.001 -> 0.001
# Train accuracy 45.6:
# Test accuracy 41.699999999999996:
# EPOCH 41:
#  batch 100 loss: 1.6333818352222442
#  batch 200 loss: 1.6279768466949462
#  batch 300 loss: 1.6296882367134093
# lr 0.001 -> 0.001
# Train accuracy 45.5:
# Test accuracy 41.8:
# EPOCH 42:
#  batch 100 loss: 1.630561273097992
#  batch 200 loss: 1.62806738615036
#  batch 300 loss: 1.6263131046295165
# lr 0.001 -> 0.001
# Train accuracy 45.6:
# Test accuracy 41.8:
# EPOCH 43:
#  batch 100 loss: 1.6266164684295654
#  batch 200 loss: 1.6392102456092834
#  batch 300 loss: 1.6282196581363677
# lr 0.001 -> 0.001
# Train accuracy 45.5:
# Test accuracy 41.699999999999996:
# EPOCH 44:
#  batch 100 loss: 1.6254062604904176
#  batch 200 loss: 1.6279575061798095
#  batch 300 loss: 1.6409109938144684
# lr 0.001 -> 0.001
# Train accuracy 45.6:
# Test accuracy 41.8:
# EPOCH 45:
#  batch 100 loss: 1.6321376597881316
#  batch 200 loss: 1.6289703345298767
#  batch 300 loss: 1.6197313368320465
# lr 0.001 -> 0.001
# Train accuracy 45.7:
# Test accuracy 41.699999999999996:
# EPOCH 46:
#  batch 100 loss: 1.6272203505039216
#  batch 200 loss: 1.6201768624782562
#  batch 300 loss: 1.6357942616939545
# lr 0.001 -> 0.001
# Train accuracy 45.7:
# Test accuracy 41.699999999999996:
# EPOCH 47:
#  batch 100 loss: 1.6364024555683137
#  batch 200 loss: 1.6264596962928772
#  batch 300 loss: 1.6119325864315033
# lr 0.001 -> 0.001
# Train accuracy 45.7:
# Test accuracy 41.699999999999996:
# EPOCH 48:
#  batch 100 loss: 1.6255638802051544
#  batch 200 loss: 1.62516632437706
#  batch 300 loss: 1.6351444971561433
# lr 0.001 -> 0.001
# Train accuracy 45.6:
# Test accuracy 41.699999999999996:
# EPOCH 49:
#  batch 100 loss: 1.6185069632530213
#  batch 200 loss: 1.6276443111896515
#  batch 300 loss: 1.6311585891246796
# lr 0.001 -> 0.001
# Train accuracy 45.6:
# Test accuracy 41.699999999999996:
# EPOCH 50:
#  batch 100 loss: 1.6397888517379762
#  batch 200 loss: 1.6197882354259492
#  batch 300 loss: 1.622858099937439
# lr 0.001 -> 0.0001
# Train accuracy 45.6:
# Test accuracy 41.699999999999996:
# EPOCH 51:
#  batch 100 loss: 1.6303040325641631
#  batch 200 loss: 1.6244666111469268
#  batch 300 loss: 1.6204594457149506
# lr 0.0001 -> 0.0001
# Train accuracy 45.6:
# Test accuracy 41.6:
# EPOCH 52:
#  batch 100 loss: 1.618264890909195
#  batch 200 loss: 1.6254381096363069
#  batch 300 loss: 1.6212633156776428
# lr 0.0001 -> 0.0001
# Train accuracy 45.6:
# Test accuracy 41.6:
# EPOCH 53:
#  batch 100 loss: 1.6255968236923217
#  batch 200 loss: 1.6320415925979614
#  batch 300 loss: 1.6254836583137513
# lr 0.0001 -> 0.0001
# Train accuracy 45.6:
# Test accuracy 41.6:
# EPOCH 54:
#  batch 100 loss: 1.6280581200122832
#  batch 200 loss: 1.6272157847881317
#  batch 300 loss: 1.6234440684318543
# lr 0.0001 -> 0.0001
# Train accuracy 45.6:
# Test accuracy 41.6:
# EPOCH 55:
#  batch 100 loss: 1.6251363909244538
#  batch 200 loss: 1.6386191427707673
#  batch 300 loss: 1.6293851912021637
# lr 0.0001 -> 0.0001
# Train accuracy 45.7:
# Test accuracy 41.6:
# EPOCH 56:
#  batch 100 loss: 1.6339359176158905
#  batch 200 loss: 1.6217551827430725
#  batch 300 loss: 1.615951532125473
# lr 0.0001 -> 0.0001
# Train accuracy 45.7:
# Test accuracy 41.6:
# EPOCH 57:
#  batch 100 loss: 1.6173461031913758
#  batch 200 loss: 1.6186345851421355
#  batch 300 loss: 1.628229044675827
# lr 0.0001 -> 0.0001
# Train accuracy 45.7:
# Test accuracy 41.6:
# EPOCH 58:
#  batch 100 loss: 1.6270323717594146
#  batch 200 loss: 1.6271255385875703
#  batch 300 loss: 1.6247441244125367
# lr 0.0001 -> 0.0001
# Train accuracy 45.7:
# Test accuracy 41.699999999999996:
# EPOCH 59:
#  batch 100 loss: 1.6199849319458008
#  batch 200 loss: 1.6309204816818237
#  batch 300 loss: 1.6234894728660583
# lr 0.0001 -> 0.0001
# Train accuracy 45.7:
# Test accuracy 41.6:
# EPOCH 60:
#  batch 100 loss: 1.6227671587467194
#  batch 200 loss: 1.628662782907486
#  batch 300 loss: 1.6259768295288086
# lr 0.0001 -> 0.0001
# Train accuracy 45.6:
# Test accuracy 41.6:
# EPOCH 61:
#  batch 100 loss: 1.627841854095459
#  batch 200 loss: 1.6222757256031037
#  batch 300 loss: 1.6306943023204803
# lr 0.0001 -> 0.0001
# Train accuracy 45.7:
# Test accuracy 41.699999999999996:
# EPOCH 62:
#  batch 100 loss: 1.6198789393901825
#  batch 200 loss: 1.6210521495342254
#  batch 300 loss: 1.6256083011627198
# lr 0.0001 -> 0.0001
# Train accuracy 45.7:
# Test accuracy 41.699999999999996:
# EPOCH 63:
#  batch 100 loss: 1.6243863022327423
#  batch 200 loss: 1.630451236963272
#  batch 300 loss: 1.631811978816986
# lr 0.0001 -> 0.0001
# Train accuracy 45.7:
# Test accuracy 41.6:
# EPOCH 64:
#  batch 100 loss: 1.6252218794822693
#  batch 200 loss: 1.6333209133148194
#  batch 300 loss: 1.6259109997749328
# lr 0.0001 -> 0.0001
# Train accuracy 45.7:
# Test accuracy 41.6:
# EPOCH 65:
#  batch 100 loss: 1.619392751455307
#  batch 200 loss: 1.631334148645401
#  batch 300 loss: 1.622983068227768
# lr 0.0001 -> 0.0001
# Train accuracy 45.7:
# Test accuracy 41.699999999999996:
# EPOCH 66:
#  batch 100 loss: 1.6180388844013214
#  batch 200 loss: 1.6312773871421813
#  batch 300 loss: 1.6325669157505036
# lr 0.0001 -> 0.0001
# Train accuracy 45.7:
# Test accuracy 41.699999999999996:
# EPOCH 67:
#  batch 100 loss: 1.618180012702942
#  batch 200 loss: 1.6237424671649934
#  batch 300 loss: 1.6349406945705414
# lr 0.0001 -> 0.0001
# Train accuracy 45.6:
# Test accuracy 41.699999999999996:
# EPOCH 68:
#  batch 100 loss: 1.623495239019394
#  batch 200 loss: 1.6159482610225677
#  batch 300 loss: 1.643940247297287
# lr 0.0001 -> 0.0001
# Train accuracy 45.7:
# Test accuracy 41.699999999999996:
# EPOCH 69:
#  batch 100 loss: 1.629834680557251
#  batch 200 loss: 1.6214695346355439
#  batch 300 loss: 1.626393231153488
# lr 0.0001 -> 0.0001
# Train accuracy 45.7:
# Test accuracy 41.699999999999996:
# EPOCH 70:
#  batch 100 loss: 1.6193960189819336
#  batch 200 loss: 1.6348620295524596
#  batch 300 loss: 1.6185062909126282
# lr 0.0001 -> 0.0001
# Train accuracy 45.7:
# Test accuracy 41.699999999999996:
# EPOCH 71:
#  batch 100 loss: 1.6312374031543733
#  batch 200 loss: 1.6200904631614685
#  batch 300 loss: 1.6251556396484375
# lr 0.0001 -> 0.0001
# Train accuracy 45.7:
# Test accuracy 41.699999999999996:
# EPOCH 72:
#  batch 100 loss: 1.6102500462532043
#  batch 200 loss: 1.6165753149986266
#  batch 300 loss: 1.6369199275970459
# lr 0.0001 -> 0.0001
# Train accuracy 45.7:
# Test accuracy 41.699999999999996:
# EPOCH 73:
#  batch 100 loss: 1.612621306180954
#  batch 200 loss: 1.627023845911026
#  batch 300 loss: 1.6189115071296691
# lr 0.0001 -> 0.0001
# Train accuracy 45.7:
# Test accuracy 41.699999999999996:
# EPOCH 74:
#  batch 100 loss: 1.6297123169898986
#  batch 200 loss: 1.625806795358658
#  batch 300 loss: 1.616038075685501
# lr 0.0001 -> 0.0001
# Train accuracy 45.7:
# Test accuracy 41.699999999999996:
# EPOCH 75:
#  batch 100 loss: 1.6254926908016205
#  batch 200 loss: 1.6206068074703217
#  batch 300 loss: 1.629141060113907
# lr 0.0001 -> 1e-05
# Train accuracy 45.7:
# Test accuracy 41.699999999999996:
# EPOCH 76:
#  batch 100 loss: 1.6170754730701447
#  batch 200 loss: 1.633232386112213
#  batch 300 loss: 1.6166500043869019
# lr 1e-05 -> 1e-05
# Train accuracy 45.7:
# Test accuracy 41.699999999999996:
# EPOCH 77:
#  batch 100 loss: 1.6276098334789275
#  batch 200 loss: 1.611037141084671
#  batch 300 loss: 1.622954877614975
# lr 1e-05 -> 1e-05
# Train accuracy 45.7:
# Test accuracy 41.699999999999996:
# EPOCH 78:
#  batch 100 loss: 1.6369125461578369
#  batch 200 loss: 1.6253409898281097
#  batch 300 loss: 1.6190559911727904
# lr 1e-05 -> 1e-05
# Train accuracy 45.7:
# Test accuracy 41.699999999999996:
# EPOCH 79:
#  batch 100 loss: 1.6258179938793182
#  batch 200 loss: 1.6188047528266907
#  batch 300 loss: 1.6351800906658172
# lr 1e-05 -> 1e-05
# Train accuracy 45.7:
# Test accuracy 41.699999999999996:
# EPOCH 80:
#  batch 100 loss: 1.6165299654006957
#  batch 200 loss: 1.621959649324417
#  batch 300 loss: 1.6317945778369904
# lr 1e-05 -> 1e-05
# Train accuracy 45.7:
# Test accuracy 41.699999999999996:
# EPOCH 81:
#  batch 100 loss: 1.6181432437896728
#  batch 200 loss: 1.6251284539699555
#  batch 300 loss: 1.6391914808750152
# lr 1e-05 -> 1e-05
# Train accuracy 45.7:
# Test accuracy 41.699999999999996:
# EPOCH 82:
#  batch 100 loss: 1.6347761511802674
#  batch 200 loss: 1.6301625561714173
#  batch 300 loss: 1.6198373901844025
# lr 1e-05 -> 1e-05
# Train accuracy 45.7:
# Test accuracy 41.699999999999996:
# EPOCH 83:
#  batch 100 loss: 1.6305136036872865
#  batch 200 loss: 1.6252437043190002
#  batch 300 loss: 1.616297334432602
# lr 1e-05 -> 1e-05
# Train accuracy 45.7:
# Test accuracy 41.699999999999996:
# EPOCH 84:
#  batch 100 loss: 1.613634752035141
#  batch 200 loss: 1.6445667374134063
#  batch 300 loss: 1.6216562700271606
# lr 1e-05 -> 1e-05
# Train accuracy 45.7:
# Test accuracy 41.699999999999996:
# EPOCH 85:
#  batch 100 loss: 1.6240329480171203
#  batch 200 loss: 1.623757436275482
#  batch 300 loss: 1.6222520983219146
# lr 1e-05 -> 1e-05
# Train accuracy 45.7:
# Test accuracy 41.699999999999996:
# EPOCH 86:
#  batch 100 loss: 1.6232477736473083
#  batch 200 loss: 1.6314346492290497
#  batch 300 loss: 1.632391928434372
# lr 1e-05 -> 1e-05
# Train accuracy 45.7:
# Test accuracy 41.699999999999996:
# EPOCH 87:
#  batch 100 loss: 1.6233215200901032
#  batch 200 loss: 1.6300530016422272
#  batch 300 loss: 1.6151133918762206
# lr 1e-05 -> 1e-05
# Train accuracy 45.7:
# Test accuracy 41.699999999999996:
# EPOCH 88:
#  batch 100 loss: 1.6120642280578614
#  batch 200 loss: 1.6454119396209717
#  batch 300 loss: 1.6279137933254242
# lr 1e-05 -> 1e-05
# Train accuracy 45.7:
# Test accuracy 41.699999999999996:
# EPOCH 89:
#  batch 100 loss: 1.6085123682022096
#  batch 200 loss: 1.635612872838974
#  batch 300 loss: 1.632766547203064
# lr 1e-05 -> 1e-05
# Train accuracy 45.7:
# Test accuracy 41.699999999999996:
# EPOCH 90:
#  batch 100 loss: 1.6322052013874053
#  batch 200 loss: 1.619299191236496
#  batch 300 loss: 1.6239417135715484
# lr 1e-05 -> 1e-05
# Train accuracy 45.7:
# Test accuracy 41.699999999999996:
# EPOCH 91:
#  batch 100 loss: 1.6245936810970307
#  batch 200 loss: 1.627931250333786
#  batch 300 loss: 1.6398955118656158
# lr 1e-05 -> 1e-05
# Train accuracy 45.6:
# Test accuracy 41.699999999999996:
# EPOCH 92:
#  batch 100 loss: 1.635198676586151
#  batch 200 loss: 1.6260425913333894
#  batch 300 loss: 1.6229400300979615
# lr 1e-05 -> 1e-05
# Train accuracy 45.6:
# Test accuracy 41.699999999999996:
# EPOCH 93:
#  batch 100 loss: 1.6189802670478821
#  batch 200 loss: 1.6246810746192932
#  batch 300 loss: 1.6181705367565156
# lr 1e-05 -> 1e-05
# Train accuracy 45.6:
# Test accuracy 41.699999999999996:
# EPOCH 94:
#  batch 100 loss: 1.6151179194450378
#  batch 200 loss: 1.6304701638221741
#  batch 300 loss: 1.6402676284313202
# lr 1e-05 -> 1e-05
# Train accuracy 45.6:
# Test accuracy 41.699999999999996:
# EPOCH 95:
#  batch 100 loss: 1.610913144350052
#  batch 200 loss: 1.637554975748062
#  batch 300 loss: 1.6288235759735108
# lr 1e-05 -> 1e-05
# Train accuracy 45.6:
# Test accuracy 41.699999999999996:
# EPOCH 96:
#  batch 100 loss: 1.6264464139938355
#  batch 200 loss: 1.6200654911994934
#  batch 300 loss: 1.6276883363723755
# lr 1e-05 -> 1e-05
# Train accuracy 45.6:
# Test accuracy 41.699999999999996:
# EPOCH 97:
#  batch 100 loss: 1.630745334625244
#  batch 200 loss: 1.6277063143253327
#  batch 300 loss: 1.61477863073349
# lr 1e-05 -> 1e-05
# Train accuracy 45.6:
# Test accuracy 41.699999999999996:
# EPOCH 98:
#  batch 100 loss: 1.6235689842700958
#  batch 200 loss: 1.6328163135051728
#  batch 300 loss: 1.630358943939209
# lr 1e-05 -> 1e-05
# Train accuracy 45.6:
# Test accuracy 41.699999999999996:
# EPOCH 99:
#  batch 100 loss: 1.6309157347679137
#  batch 200 loss: 1.6191412818431854
#  batch 300 loss: 1.6314533209800721
# lr 1e-05 -> 1e-05
# Train accuracy 45.7:
# Test accuracy 41.699999999999996:
# EPOCH 100:
#  batch 100 loss: 1.624961837530136
#  batch 200 loss: 1.629904361963272
#  batch 300 loss: 1.6264696872234345
# lr 1e-05 -> 1.0000000000000002e-06
# Train accuracy 45.7:
# Test accuracy 41.699999999999996:
# Reg Strength 1e-07:
# EPOCH 1:
#  batch 100 loss: 2.039669134616852
#  batch 200 loss: 1.8892216444015504
#  batch 300 loss: 1.8499545383453369
# lr 0.01 -> 0.01
# Train accuracy 39.5:
# Test accuracy 39.1:
# EPOCH 2:
#  batch 100 loss: 1.7919551932811737
#  batch 200 loss: 1.7956006669998168
#  batch 300 loss: 1.7809557259082793
# lr 0.01 -> 0.01
# Train accuracy 40.699999999999996:
# Test accuracy 39.2:
# EPOCH 3:
#  batch 100 loss: 1.7665808975696564
#  batch 200 loss: 1.74387988448143
#  batch 300 loss: 1.7566159689426422
# lr 0.01 -> 0.01
# Train accuracy 41.699999999999996:
# Test accuracy 40.8:
# EPOCH 4:
#  batch 100 loss: 1.72831817984581
#  batch 200 loss: 1.7456695592403413
#  batch 300 loss: 1.7314596557617188
# lr 0.01 -> 0.01
# Train accuracy 42.1:
# Test accuracy 40.9:
# EPOCH 5:
#  batch 100 loss: 1.7140933966636658
#  batch 200 loss: 1.7234672260284425
#  batch 300 loss: 1.723079923391342
# lr 0.01 -> 0.01
# Train accuracy 42.5:
# Test accuracy 41.0:
# EPOCH 6:
#  batch 100 loss: 1.7040098130702972
#  batch 200 loss: 1.7298717868328095
#  batch 300 loss: 1.7037792575359345
# lr 0.01 -> 0.01
# Train accuracy 42.8:
# Test accuracy 41.099999999999994:
# EPOCH 7:
#  batch 100 loss: 1.706536762714386
#  batch 200 loss: 1.7046638607978821
#  batch 300 loss: 1.7126371610164641
# lr 0.01 -> 0.01
# Train accuracy 43.1:
# Test accuracy 41.0:
# EPOCH 8:
#  batch 100 loss: 1.6917210614681244
#  batch 200 loss: 1.691517735719681
#  batch 300 loss: 1.7004253101348876
# lr 0.01 -> 0.01
# Train accuracy 42.6:
# Test accuracy 40.8:
# EPOCH 9:
#  batch 100 loss: 1.6992469573020934
#  batch 200 loss: 1.6793658745288849
#  batch 300 loss: 1.6917822718620301
# lr 0.01 -> 0.01
# Train accuracy 43.5:
# Test accuracy 41.099999999999994:
# EPOCH 10:
#  batch 100 loss: 1.6943086695671081
#  batch 200 loss: 1.6968045353889465
#  batch 300 loss: 1.6786223220825196
# lr 0.01 -> 0.01
# Train accuracy 43.3:
# Test accuracy 41.0:
# EPOCH 11:
#  batch 100 loss: 1.6731029653549194
#  batch 200 loss: 1.6793702673912048
#  batch 300 loss: 1.686690502166748
# lr 0.01 -> 0.01
# Train accuracy 43.5:
# Test accuracy 41.3:
# EPOCH 12:
#  batch 100 loss: 1.6779752159118653
#  batch 200 loss: 1.6794448721408843
#  batch 300 loss: 1.6835248577594757
# lr 0.01 -> 0.01
# Train accuracy 44.0:
# Test accuracy 41.4:
# EPOCH 13:
#  batch 100 loss: 1.6683281970024109
#  batch 200 loss: 1.6755665171146392
#  batch 300 loss: 1.677707234621048
# lr 0.01 -> 0.01
# Train accuracy 44.0:
# Test accuracy 41.5:
# EPOCH 14:
#  batch 100 loss: 1.659954501390457
#  batch 200 loss: 1.6806215929985047
#  batch 300 loss: 1.6740823471546173
# lr 0.01 -> 0.01
# Train accuracy 43.9:
# Test accuracy 41.6:
# EPOCH 15:
#  batch 100 loss: 1.6737930798530578
#  batch 200 loss: 1.6570817530155182
#  batch 300 loss: 1.6715215730667115
# lr 0.01 -> 0.01
# Train accuracy 44.2:
# Test accuracy 41.4:
# EPOCH 16:
#  batch 100 loss: 1.6408785498142242
#  batch 200 loss: 1.6787844455242158
#  batch 300 loss: 1.666001214981079
# lr 0.01 -> 0.01
# Train accuracy 44.6:
# Test accuracy 41.5:
# EPOCH 17:
#  batch 100 loss: 1.6636190974712373
#  batch 200 loss: 1.6711671733856202
#  batch 300 loss: 1.6564205050468446
# lr 0.01 -> 0.01
# Train accuracy 44.4:
# Test accuracy 40.9:
# EPOCH 18:
#  batch 100 loss: 1.643563199043274
#  batch 200 loss: 1.658634638786316
#  batch 300 loss: 1.6690713310241698
# lr 0.01 -> 0.01
# Train accuracy 44.4:
# Test accuracy 41.199999999999996:
# EPOCH 19:
#  batch 100 loss: 1.6538789033889771
#  batch 200 loss: 1.6506511819362641
#  batch 300 loss: 1.664399346113205
# lr 0.01 -> 0.01
# Train accuracy 44.800000000000004:
# Test accuracy 41.6:
# EPOCH 20:
#  batch 100 loss: 1.6682901000976562
#  batch 200 loss: 1.6566329777240754
#  batch 300 loss: 1.652437973022461
# lr 0.01 -> 0.01
# Train accuracy 44.7:
# Test accuracy 41.4:
# EPOCH 21:
#  batch 100 loss: 1.639338985681534
#  batch 200 loss: 1.6507616031169892
#  batch 300 loss: 1.6676729238033294
# lr 0.01 -> 0.01
# Train accuracy 44.6:
# Test accuracy 41.3:
# EPOCH 22:
#  batch 100 loss: 1.6444066298007964
#  batch 200 loss: 1.6512430095672608
#  batch 300 loss: 1.653293696641922
# lr 0.01 -> 0.01
# Train accuracy 44.9:
# Test accuracy 41.5:
# EPOCH 23:
#  batch 100 loss: 1.644332001209259
#  batch 200 loss: 1.65634859085083
#  batch 300 loss: 1.6472150564193726
# lr 0.01 -> 0.01
# Train accuracy 44.7:
# Test accuracy 41.6:
# EPOCH 24:
#  batch 100 loss: 1.6319023156166077
#  batch 200 loss: 1.6433618545532227
#  batch 300 loss: 1.6555958771705628
# lr 0.01 -> 0.01
# Train accuracy 45.1:
# Test accuracy 41.6:
# EPOCH 25:
#  batch 100 loss: 1.642611973285675
#  batch 200 loss: 1.6498114109039306
#  batch 300 loss: 1.6324910950660705
# lr 0.01 -> 0.001
# Train accuracy 45.2:
# Test accuracy 41.8:
# EPOCH 26:
#  batch 100 loss: 1.636413505077362
#  batch 200 loss: 1.6202178072929383
#  batch 300 loss: 1.630019555091858
# lr 0.001 -> 0.001
# Train accuracy 45.5:
# Test accuracy 41.8:
# EPOCH 27:
#  batch 100 loss: 1.6227693271636963
#  batch 200 loss: 1.6304382944107056
#  batch 300 loss: 1.6298889982700349
# lr 0.001 -> 0.001
# Train accuracy 45.4:
# Test accuracy 41.699999999999996:
# EPOCH 28:
#  batch 100 loss: 1.6260163581371307
#  batch 200 loss: 1.624598159790039
#  batch 300 loss: 1.6369238829612731
# lr 0.001 -> 0.001
# Train accuracy 45.4:
# Test accuracy 41.699999999999996:
# EPOCH 29:
#  batch 100 loss: 1.6350022411346437
#  batch 200 loss: 1.6364625132083892
#  batch 300 loss: 1.6317020571231842
# lr 0.001 -> 0.001
# Train accuracy 45.5:
# Test accuracy 41.9:
# EPOCH 30:
#  batch 100 loss: 1.63548362493515
#  batch 200 loss: 1.6349104416370392
#  batch 300 loss: 1.6276402795314788
# lr 0.001 -> 0.001
# Train accuracy 45.5:
# Test accuracy 41.9:
# EPOCH 31:
#  batch 100 loss: 1.6155447018146516
#  batch 200 loss: 1.642618271112442
#  batch 300 loss: 1.637331144809723
# lr 0.001 -> 0.001
# Train accuracy 45.6:
# Test accuracy 41.9:
# EPOCH 32:
#  batch 100 loss: 1.6201324164867401
#  batch 200 loss: 1.6248817765712738
#  batch 300 loss: 1.6486172699928283
# lr 0.001 -> 0.001
# Train accuracy 45.5:
# Test accuracy 41.8:
# EPOCH 33:
#  batch 100 loss: 1.621292817592621
#  batch 200 loss: 1.6332637786865234
#  batch 300 loss: 1.6263955640792847
# lr 0.001 -> 0.001
# Train accuracy 45.5:
# Test accuracy 41.699999999999996:
# EPOCH 34:
#  batch 100 loss: 1.6256834161281586
#  batch 200 loss: 1.628604907989502
#  batch 300 loss: 1.6286241495609284
# lr 0.001 -> 0.001
# Train accuracy 45.6:
# Test accuracy 41.8:
# EPOCH 35:
#  batch 100 loss: 1.6238242340087892
#  batch 200 loss: 1.6295944738388062
#  batch 300 loss: 1.6304640913009643
# lr 0.001 -> 0.001
# Train accuracy 45.5:
# Test accuracy 41.8:
# EPOCH 36:
#  batch 100 loss: 1.6343050384521485
#  batch 200 loss: 1.64243265748024
#  batch 300 loss: 1.605146757364273
# lr 0.001 -> 0.001
# Train accuracy 45.5:
# Test accuracy 41.8:
# EPOCH 37:
#  batch 100 loss: 1.645359365940094
#  batch 200 loss: 1.6246552217006682
#  batch 300 loss: 1.6229274451732636
# lr 0.001 -> 0.001
# Train accuracy 45.4:
# Test accuracy 42.0:
# EPOCH 38:
#  batch 100 loss: 1.6325562369823456
#  batch 200 loss: 1.6337607324123382
#  batch 300 loss: 1.6280284905433655
# lr 0.001 -> 0.001
# Train accuracy 45.6:
# Test accuracy 41.9:
# EPOCH 39:
#  batch 100 loss: 1.6427166318893434
#  batch 200 loss: 1.607193866968155
#  batch 300 loss: 1.6433850824832916
# lr 0.001 -> 0.001
# Train accuracy 45.5:
# Test accuracy 41.8:
# EPOCH 40:
#  batch 100 loss: 1.6270240938663483
#  batch 200 loss: 1.6339995634555817
#  batch 300 loss: 1.6274122834205627
# lr 0.001 -> 0.001
# Train accuracy 45.6:
# Test accuracy 41.9:
# EPOCH 41:
#  batch 100 loss: 1.635423368215561
#  batch 200 loss: 1.620169631242752
#  batch 300 loss: 1.6266689610481262
# lr 0.001 -> 0.001
# Train accuracy 45.5:
# Test accuracy 41.8:
# EPOCH 42:
#  batch 100 loss: 1.62052148938179
#  batch 200 loss: 1.632548792362213
#  batch 300 loss: 1.6328762018680572
# lr 0.001 -> 0.001
# Train accuracy 45.5:
# Test accuracy 41.9:
# EPOCH 43:
#  batch 100 loss: 1.649971764087677
#  batch 200 loss: 1.6224598813056945
#  batch 300 loss: 1.6246390593051911
# lr 0.001 -> 0.001
# Train accuracy 45.6:
# Test accuracy 41.8:
# EPOCH 44:
#  batch 100 loss: 1.631981716156006
#  batch 200 loss: 1.629665333032608
#  batch 300 loss: 1.6222143542766572
# lr 0.001 -> 0.001
# Train accuracy 45.6:
# Test accuracy 41.9:
# EPOCH 45:
#  batch 100 loss: 1.6357438004016875
#  batch 200 loss: 1.6194555139541627
#  batch 300 loss: 1.6252281403541564
# lr 0.001 -> 0.001
# Train accuracy 45.6:
# Test accuracy 41.9:
# EPOCH 46:
#  batch 100 loss: 1.6280035841464997
#  batch 200 loss: 1.6221751749515534
#  batch 300 loss: 1.6202957141399383
# lr 0.001 -> 0.001
# Train accuracy 45.6:
# Test accuracy 41.8:
# EPOCH 47:
#  batch 100 loss: 1.630729159116745
#  batch 200 loss: 1.6269378352165222
#  batch 300 loss: 1.6204703080654144
# lr 0.001 -> 0.001
# Train accuracy 45.6:
# Test accuracy 41.9:
# EPOCH 48:
#  batch 100 loss: 1.633816612958908
#  batch 200 loss: 1.623917499780655
#  batch 300 loss: 1.6293632864952088
# lr 0.001 -> 0.001
# Train accuracy 45.7:
# Test accuracy 41.8:
# EPOCH 49:
#  batch 100 loss: 1.6187616229057311
#  batch 200 loss: 1.624507030248642
#  batch 300 loss: 1.643883181810379
# lr 0.001 -> 0.001
# Train accuracy 45.6:
# Test accuracy 41.6:
# EPOCH 50:
#  batch 100 loss: 1.6125844752788543
#  batch 200 loss: 1.6297739732265473
#  batch 300 loss: 1.640268039703369
# lr 0.001 -> 0.0001
# Train accuracy 45.6:
# Test accuracy 41.8:
# EPOCH 51:
#  batch 100 loss: 1.6187834656238556
#  batch 200 loss: 1.6201454985141754
#  batch 300 loss: 1.6323087620735168
# lr 0.0001 -> 0.0001
# Train accuracy 45.6:
# Test accuracy 41.8:
# EPOCH 52:
#  batch 100 loss: 1.6239740800857545
#  batch 200 loss: 1.6128078734874725
#  batch 300 loss: 1.6425024855136872
# lr 0.0001 -> 0.0001
# Train accuracy 45.6:
# Test accuracy 41.9:
# EPOCH 53:
#  batch 100 loss: 1.6256010365486144
#  batch 200 loss: 1.6247530364990235
#  batch 300 loss: 1.6198146283626556
# lr 0.0001 -> 0.0001
# Train accuracy 45.6:
# Test accuracy 41.8:
# EPOCH 54:
#  batch 100 loss: 1.6116443717479705
#  batch 200 loss: 1.6352725183963777
#  batch 300 loss: 1.6452230572700501
# lr 0.0001 -> 0.0001
# Train accuracy 45.6:
# Test accuracy 41.9:
# EPOCH 55:
#  batch 100 loss: 1.6363202083110808
#  batch 200 loss: 1.6198044121265411
#  batch 300 loss: 1.6148318231105805
# lr 0.0001 -> 0.0001
# Train accuracy 45.6:
# Test accuracy 41.9:
# EPOCH 56:
#  batch 100 loss: 1.6256214809417724
#  batch 200 loss: 1.6173654222488403
#  batch 300 loss: 1.6371598589420318
# lr 0.0001 -> 0.0001
# Train accuracy 45.6:
# Test accuracy 41.9:
# EPOCH 57:
#  batch 100 loss: 1.609865701198578
#  batch 200 loss: 1.6311295545101165
#  batch 300 loss: 1.6262349367141724
# lr 0.0001 -> 0.0001
# Train accuracy 45.6:
# Test accuracy 41.9:
# EPOCH 58:
#  batch 100 loss: 1.6308595955371856
#  batch 200 loss: 1.6314625585079192
#  batch 300 loss: 1.6209626269340516
# lr 0.0001 -> 0.0001
# Train accuracy 45.6:
# Test accuracy 41.9:
# EPOCH 59:
#  batch 100 loss: 1.6235121381282807
#  batch 200 loss: 1.6397903811931611
#  batch 300 loss: 1.6188978815078736
# lr 0.0001 -> 0.0001
# Train accuracy 45.6:
# Test accuracy 41.9:
# EPOCH 60:
#  batch 100 loss: 1.617257423400879
#  batch 200 loss: 1.6258673214912414
#  batch 300 loss: 1.618764852285385
# lr 0.0001 -> 0.0001
# Train accuracy 45.6:
# Test accuracy 41.9:
# EPOCH 61:
#  batch 100 loss: 1.6322581946849823
#  batch 200 loss: 1.6191284358501434
#  batch 300 loss: 1.6374011409282685
# lr 0.0001 -> 0.0001
# Train accuracy 45.6:
# Test accuracy 41.9:
# EPOCH 62:
#  batch 100 loss: 1.631765582561493
#  batch 200 loss: 1.6251739597320556
#  batch 300 loss: 1.6295611095428466
# lr 0.0001 -> 0.0001
# Train accuracy 45.6:
# Test accuracy 41.9:
# EPOCH 63:
#  batch 100 loss: 1.6154641103744507
#  batch 200 loss: 1.6481083810329438
#  batch 300 loss: 1.6281795942783355
# lr 0.0001 -> 0.0001
# Train accuracy 45.6:
# Test accuracy 41.9:
# EPOCH 64:
#  batch 100 loss: 1.6178260469436645
#  batch 200 loss: 1.6279586231708527
#  batch 300 loss: 1.6271868062019348
# lr 0.0001 -> 0.0001
# Train accuracy 45.6:
# Test accuracy 41.9:
# EPOCH 65:
#  batch 100 loss: 1.6250739204883575
#  batch 200 loss: 1.6252509224414826
#  batch 300 loss: 1.6334530305862427
# lr 0.0001 -> 0.0001
# Train accuracy 45.6:
# Test accuracy 41.9:
# EPOCH 66:
#  batch 100 loss: 1.6297619819641114
#  batch 200 loss: 1.6242902886867523
#  batch 300 loss: 1.612569921016693
# lr 0.0001 -> 0.0001
# Train accuracy 45.6:
# Test accuracy 41.9:
# EPOCH 67:
#  batch 100 loss: 1.6242790174484254
#  batch 200 loss: 1.6288995361328125
#  batch 300 loss: 1.6324119400978088
# lr 0.0001 -> 0.0001
# Train accuracy 45.6:
# Test accuracy 41.9:
# EPOCH 68:
#  batch 100 loss: 1.6312357413768768
#  batch 200 loss: 1.612956576347351
#  batch 300 loss: 1.629150426387787
# lr 0.0001 -> 0.0001
# Train accuracy 45.6:
# Test accuracy 41.9:
# EPOCH 69:
#  batch 100 loss: 1.6229365861415863
#  batch 200 loss: 1.620250461101532
#  batch 300 loss: 1.6341645216941834
# lr 0.0001 -> 0.0001
# Train accuracy 45.6:
# Test accuracy 41.9:
# EPOCH 70:
#  batch 100 loss: 1.624807013273239
#  batch 200 loss: 1.6375867664813994
#  batch 300 loss: 1.6208359897136688
# lr 0.0001 -> 0.0001
# Train accuracy 45.6:
# Test accuracy 41.9:
# EPOCH 71:
#  batch 100 loss: 1.624104061126709
#  batch 200 loss: 1.636844778060913
#  batch 300 loss: 1.619959112405777
# lr 0.0001 -> 0.0001
# Train accuracy 45.6:
# Test accuracy 41.9:
# EPOCH 72:
#  batch 100 loss: 1.622397269010544
#  batch 200 loss: 1.6361331129074097
#  batch 300 loss: 1.629103933572769
# lr 0.0001 -> 0.0001
# Train accuracy 45.6:
# Test accuracy 41.9:
# EPOCH 73:
#  batch 100 loss: 1.626054027080536
#  batch 200 loss: 1.623777551651001
#  batch 300 loss: 1.6281706941127778
# lr 0.0001 -> 0.0001
# Train accuracy 45.6:
# Test accuracy 41.9:
# EPOCH 74:
#  batch 100 loss: 1.623989987373352
#  batch 200 loss: 1.6096014475822449
#  batch 300 loss: 1.647402685880661
# lr 0.0001 -> 0.0001
# Train accuracy 45.6:
# Test accuracy 41.9:
# EPOCH 75:
#  batch 100 loss: 1.605710538625717
#  batch 200 loss: 1.635635894536972
#  batch 300 loss: 1.6311677265167237
# lr 0.0001 -> 1e-05
# Train accuracy 45.6:
# Test accuracy 41.9:
# EPOCH 76:
#  batch 100 loss: 1.6147270166873933
#  batch 200 loss: 1.640488965511322
#  batch 300 loss: 1.6270872473716735
# lr 1e-05 -> 1e-05
# Train accuracy 45.6:
# Test accuracy 41.9:
# EPOCH 77:
#  batch 100 loss: 1.6241197085380554
#  batch 200 loss: 1.6203412771224976
#  batch 300 loss: 1.6159051406383513
# lr 1e-05 -> 1e-05
# Train accuracy 45.6:
# Test accuracy 41.9:
# EPOCH 78:
#  batch 100 loss: 1.6139693129062653
#  batch 200 loss: 1.6411540865898133
#  batch 300 loss: 1.6361867022514343
# lr 1e-05 -> 1e-05
# Train accuracy 45.6:
# Test accuracy 41.9:
# EPOCH 79:
#  batch 100 loss: 1.6326758182048797
#  batch 200 loss: 1.631574639081955
#  batch 300 loss: 1.6188756394386292
# lr 1e-05 -> 1e-05
# Train accuracy 45.6:
# Test accuracy 41.9:
# EPOCH 80:
#  batch 100 loss: 1.6376829183101653
#  batch 200 loss: 1.6119723808765412
#  batch 300 loss: 1.6275024557113646
# lr 1e-05 -> 1e-05
# Train accuracy 45.6:
# Test accuracy 41.9:
# EPOCH 81:
#  batch 100 loss: 1.6222863900661468
#  batch 200 loss: 1.6254289221763611
#  batch 300 loss: 1.620479507446289
# lr 1e-05 -> 1e-05
# Train accuracy 45.6:
# Test accuracy 41.9:
# EPOCH 82:
#  batch 100 loss: 1.6261986625194549
#  batch 200 loss: 1.6290608084201812
#  batch 300 loss: 1.6258177423477174
# lr 1e-05 -> 1e-05
# Train accuracy 45.6:
# Test accuracy 41.9:
# EPOCH 83:
#  batch 100 loss: 1.6148224425315858
#  batch 200 loss: 1.6214243566989899
#  batch 300 loss: 1.6389004015922546
# lr 1e-05 -> 1e-05
# Train accuracy 45.6:
# Test accuracy 41.9:
# EPOCH 84:
#  batch 100 loss: 1.628174364566803
#  batch 200 loss: 1.6354954409599305
#  batch 300 loss: 1.6130390071868896
# lr 1e-05 -> 1e-05
# Train accuracy 45.6:
# Test accuracy 41.9:
# EPOCH 85:
#  batch 100 loss: 1.6327729082107545
#  batch 200 loss: 1.6238984942436219
#  batch 300 loss: 1.623797436952591
# lr 1e-05 -> 1e-05
# Train accuracy 45.6:
# Test accuracy 41.9:
# EPOCH 86:
#  batch 100 loss: 1.634320204257965
#  batch 200 loss: 1.6166133272647858
#  batch 300 loss: 1.6330521619319915
# lr 1e-05 -> 1e-05
# Train accuracy 45.6:
# Test accuracy 41.9:
# EPOCH 87:
#  batch 100 loss: 1.6196527564525605
#  batch 200 loss: 1.6363773429393769
#  batch 300 loss: 1.6251677060127259
# lr 1e-05 -> 1e-05
# Train accuracy 45.6:
# Test accuracy 41.9:
# EPOCH 88:
#  batch 100 loss: 1.6205258452892304
#  batch 200 loss: 1.6112108325958252
#  batch 300 loss: 1.6458661937713623
# lr 1e-05 -> 1e-05
# Train accuracy 45.6:
# Test accuracy 41.9:
# EPOCH 89:
#  batch 100 loss: 1.6272021901607514
#  batch 200 loss: 1.6109206080436707
#  batch 300 loss: 1.6350324082374572
# lr 1e-05 -> 1e-05
# Train accuracy 45.6:
# Test accuracy 41.9:
# EPOCH 90:
#  batch 100 loss: 1.6258304226398468
#  batch 200 loss: 1.6292260074615479
#  batch 300 loss: 1.6135111927986145
# lr 1e-05 -> 1e-05
# Train accuracy 45.6:
# Test accuracy 41.9:
# EPOCH 91:
#  batch 100 loss: 1.626722949743271
#  batch 200 loss: 1.6308249199390412
#  batch 300 loss: 1.6130548119544983
# lr 1e-05 -> 1e-05
# Train accuracy 45.6:
# Test accuracy 41.9:
# EPOCH 92:
#  batch 100 loss: 1.6336263501644135
#  batch 200 loss: 1.6165395855903626
#  batch 300 loss: 1.6356868398189546
# lr 1e-05 -> 1e-05
# Train accuracy 45.6:
# Test accuracy 41.9:
# EPOCH 93:
#  batch 100 loss: 1.6338525247573852
#  batch 200 loss: 1.6252621352672576
#  batch 300 loss: 1.6318208873271942
# lr 1e-05 -> 1e-05
# Train accuracy 45.6:
# Test accuracy 41.9:
# EPOCH 94:
#  batch 100 loss: 1.6380435574054717
#  batch 200 loss: 1.6226507782936097
#  batch 300 loss: 1.6128462207317353
# lr 1e-05 -> 1e-05
# Train accuracy 45.6:
# Test accuracy 41.9:
# EPOCH 95:
#  batch 100 loss: 1.6143162202835084
#  batch 200 loss: 1.633171434402466
#  batch 300 loss: 1.627503024339676
# lr 1e-05 -> 1e-05
# Train accuracy 45.6:
# Test accuracy 41.9:
# EPOCH 96:
#  batch 100 loss: 1.6332399678230285
#  batch 200 loss: 1.6251715958118438
#  batch 300 loss: 1.6131916415691376
# lr 1e-05 -> 1e-05
# Train accuracy 45.6:
# Test accuracy 41.9:
# EPOCH 97:
#  batch 100 loss: 1.623394695520401
#  batch 200 loss: 1.6288431894779205
#  batch 300 loss: 1.616837215423584
# lr 1e-05 -> 1e-05
# Train accuracy 45.6:
# Test accuracy 41.9:
# EPOCH 98:
#  batch 100 loss: 1.6344001245498658
#  batch 200 loss: 1.6239209914207458
#  batch 300 loss: 1.621730133295059
# lr 1e-05 -> 1e-05
# Train accuracy 45.6:
# Test accuracy 41.9:
# EPOCH 99:
#  batch 100 loss: 1.6210111308097839
#  batch 200 loss: 1.626149033308029
#  batch 300 loss: 1.634069823026657
# lr 1e-05 -> 1e-05
# Train accuracy 45.6:
# Test accuracy 41.9:
# EPOCH 100:
#  batch 100 loss: 1.6227723705768584
#  batch 200 loss: 1.6297280240058898
#  batch 300 loss: 1.626020337343216
# lr 1e-05 -> 1.0000000000000002e-06
# Train accuracy 45.6:
# Test accuracy 41.9:
# Reg Strength 1e-05:
# EPOCH 1:
#  batch 100 loss: 2.0329069781303404
#  batch 200 loss: 1.878766289949417
#  batch 300 loss: 1.843531893491745
# lr 0.01 -> 0.01
# Train accuracy 39.0:
# Test accuracy 38.9:
# EPOCH 2:
#  batch 100 loss: 1.8002419674396515
#  batch 200 loss: 1.762915461063385
#  batch 300 loss: 1.7762771439552307
# lr 0.01 -> 0.01
# Train accuracy 40.699999999999996:
# Test accuracy 39.900000000000006:
# EPOCH 3:
#  batch 100 loss: 1.755698540210724
#  batch 200 loss: 1.7481861186027527
#  batch 300 loss: 1.7625296473503114
# lr 0.01 -> 0.01
# Train accuracy 41.4:
# Test accuracy 40.2:
# EPOCH 4:
#  batch 100 loss: 1.7371698749065398
#  batch 200 loss: 1.740015892982483
#  batch 300 loss: 1.7373310601711274
# lr 0.01 -> 0.01
# Train accuracy 42.1:
# Test accuracy 40.9:
# EPOCH 5:
#  batch 100 loss: 1.727495583295822
#  batch 200 loss: 1.723682190179825
#  batch 300 loss: 1.719640212059021
# lr 0.01 -> 0.01
# Train accuracy 42.699999999999996:
# Test accuracy 41.199999999999996:
# EPOCH 6:
#  batch 100 loss: 1.712754513025284
#  batch 200 loss: 1.7169068014621736
#  batch 300 loss: 1.7145668971538544
# lr 0.01 -> 0.01
# Train accuracy 42.699999999999996:
# Test accuracy 40.9:
# EPOCH 7:
#  batch 100 loss: 1.7198372972011566
#  batch 200 loss: 1.700068597793579
#  batch 300 loss: 1.702724597454071
# lr 0.01 -> 0.01
# Train accuracy 42.9:
# Test accuracy 41.099999999999994:
# EPOCH 8:
#  batch 100 loss: 1.689811429977417
#  batch 200 loss: 1.7012539732456207
#  batch 300 loss: 1.7039660120010376
# lr 0.01 -> 0.01
# Train accuracy 43.2:
# Test accuracy 41.3:
# EPOCH 9:
#  batch 100 loss: 1.692396115064621
#  batch 200 loss: 1.691511195898056
#  batch 300 loss: 1.6989175748825074
# lr 0.01 -> 0.01
# Train accuracy 43.7:
# Test accuracy 41.4:
# EPOCH 10:
#  batch 100 loss: 1.6868318831920623
#  batch 200 loss: 1.6875531136989594
#  batch 300 loss: 1.682062178850174
# lr 0.01 -> 0.01
# Train accuracy 43.6:
# Test accuracy 41.199999999999996:
# EPOCH 11:
#  batch 100 loss: 1.68971116065979
#  batch 200 loss: 1.6712230348587036
#  batch 300 loss: 1.671689772605896
# lr 0.01 -> 0.01
# Train accuracy 43.8:
# Test accuracy 41.4:
# EPOCH 12:
#  batch 100 loss: 1.6752967858314514
#  batch 200 loss: 1.6773123598098756
#  batch 300 loss: 1.6809865427017212
# lr 0.01 -> 0.01
# Train accuracy 44.0:
# Test accuracy 41.4:
# EPOCH 13:
#  batch 100 loss: 1.6900843179225922
#  batch 200 loss: 1.6677229773998261
#  batch 300 loss: 1.6620340061187744
# lr 0.01 -> 0.01
# Train accuracy 44.2:
# Test accuracy 41.9:
# EPOCH 14:
#  batch 100 loss: 1.670709147453308
#  batch 200 loss: 1.6709820544719696
#  batch 300 loss: 1.662893614768982
# lr 0.01 -> 0.01
# Train accuracy 44.1:
# Test accuracy 41.3:
# EPOCH 15:
#  batch 100 loss: 1.6631337678432465
#  batch 200 loss: 1.6681142044067383
#  batch 300 loss: 1.669116359949112
# lr 0.01 -> 0.01
# Train accuracy 44.2:
# Test accuracy 41.6:
# EPOCH 16:
#  batch 100 loss: 1.6618038880825043
#  batch 200 loss: 1.6602793264389037
#  batch 300 loss: 1.6667486774921416
# lr 0.01 -> 0.01
# Train accuracy 44.2:
# Test accuracy 41.8:
# EPOCH 17:
#  batch 100 loss: 1.6557579469680785
#  batch 200 loss: 1.6544945406913758
#  batch 300 loss: 1.6621569871902466
# lr 0.01 -> 0.01
# Train accuracy 44.4:
# Test accuracy 41.4:
# EPOCH 18:
#  batch 100 loss: 1.654441204071045
#  batch 200 loss: 1.6539094817638398
#  batch 300 loss: 1.6677214050292968
# lr 0.01 -> 0.01
# Train accuracy 44.6:
# Test accuracy 41.5:
# EPOCH 19:
#  batch 100 loss: 1.6548405420780181
#  batch 200 loss: 1.6504960930347443
#  batch 300 loss: 1.6600085759162904
# lr 0.01 -> 0.01
# Train accuracy 44.800000000000004:
# Test accuracy 41.699999999999996:
# EPOCH 20:
#  batch 100 loss: 1.6505693900585174
#  batch 200 loss: 1.6506762111186981
#  batch 300 loss: 1.6602859354019166
# lr 0.01 -> 0.01
# Train accuracy 44.7:
# Test accuracy 41.6:
# EPOCH 21:
#  batch 100 loss: 1.641953971385956
#  batch 200 loss: 1.6352638125419616
#  batch 300 loss: 1.6646990168094635
# lr 0.01 -> 0.01
# Train accuracy 45.2:
# Test accuracy 41.4:
# EPOCH 22:
#  batch 100 loss: 1.6360812401771545
#  batch 200 loss: 1.6481250059604644
#  batch 300 loss: 1.6589320015907287
# lr 0.01 -> 0.01
# Train accuracy 44.9:
# Test accuracy 41.5:
# EPOCH 23:
#  batch 100 loss: 1.6549136471748351
#  batch 200 loss: 1.6495251905918122
#  batch 300 loss: 1.6505187726020814
# lr 0.01 -> 0.01
# Train accuracy 45.0:
# Test accuracy 41.6:
# EPOCH 24:
#  batch 100 loss: 1.6391817128658295
#  batch 200 loss: 1.6551891362667084
#  batch 300 loss: 1.6373167109489442
# lr 0.01 -> 0.01
# Train accuracy 45.4:
# Test accuracy 41.9:
# EPOCH 25:
#  batch 100 loss: 1.6418466293811798
#  batch 200 loss: 1.6204475164413452
#  batch 300 loss: 1.6554958534240722
# lr 0.01 -> 0.001
# Train accuracy 45.1:
# Test accuracy 41.099999999999994:
# EPOCH 26:
#  batch 100 loss: 1.6245680975914
#  batch 200 loss: 1.6462829172611237
#  batch 300 loss: 1.6287325084209443
# lr 0.001 -> 0.001
# Train accuracy 45.6:
# Test accuracy 41.8:
# EPOCH 27:
#  batch 100 loss: 1.6217898440361023
#  batch 200 loss: 1.6469525575637818
#  batch 300 loss: 1.628857628107071
# lr 0.001 -> 0.001
# Train accuracy 45.6:
# Test accuracy 41.699999999999996:
# EPOCH 28:
#  batch 100 loss: 1.631591832637787
#  batch 200 loss: 1.6313716268539429
#  batch 300 loss: 1.6360019278526305
# lr 0.001 -> 0.001
# Train accuracy 45.6:
# Test accuracy 41.699999999999996:
# EPOCH 29:
#  batch 100 loss: 1.6263703286647797
#  batch 200 loss: 1.6272039246559142
#  batch 300 loss: 1.6323728084564209
# lr 0.001 -> 0.001
# Train accuracy 45.5:
# Test accuracy 41.8:
# EPOCH 30:
#  batch 100 loss: 1.635160790681839
#  batch 200 loss: 1.6359386014938355
#  batch 300 loss: 1.6335833537578583
# lr 0.001 -> 0.001
# Train accuracy 45.6:
# Test accuracy 41.8:
# EPOCH 31:
#  batch 100 loss: 1.631789903640747
#  batch 200 loss: 1.6174427247047425
#  batch 300 loss: 1.6295953464508057
# lr 0.001 -> 0.001
# Train accuracy 45.6:
# Test accuracy 41.699999999999996:
# EPOCH 32:
#  batch 100 loss: 1.6131919765472411
#  batch 200 loss: 1.6388891351222992
#  batch 300 loss: 1.642361022233963
# lr 0.001 -> 0.001
# Train accuracy 45.6:
# Test accuracy 41.8:
# EPOCH 33:
#  batch 100 loss: 1.624279601573944
#  batch 200 loss: 1.630738112926483
#  batch 300 loss: 1.6280824053287506
# lr 0.001 -> 0.001
# Train accuracy 45.6:
# Test accuracy 41.9:
# EPOCH 34:
#  batch 100 loss: 1.6353928279876708
#  batch 200 loss: 1.6259084594249726
#  batch 300 loss: 1.6340169882774354
# lr 0.001 -> 0.001
# Train accuracy 45.5:
# Test accuracy 42.0:
# EPOCH 35:
#  batch 100 loss: 1.626146960258484
#  batch 200 loss: 1.63351921916008
#  batch 300 loss: 1.6236353194713593
# lr 0.001 -> 0.001
# Train accuracy 45.5:
# Test accuracy 41.9:
# EPOCH 36:
#  batch 100 loss: 1.632069138288498
#  batch 200 loss: 1.6254728496074677
#  batch 300 loss: 1.632174199819565
# lr 0.001 -> 0.001
# Train accuracy 45.5:
# Test accuracy 41.699999999999996:
# EPOCH 37:
#  batch 100 loss: 1.6238026189804078
#  batch 200 loss: 1.6299231612682343
#  batch 300 loss: 1.6396501970291137
# lr 0.001 -> 0.001
# Train accuracy 45.6:
# Test accuracy 41.9:
# EPOCH 38:
#  batch 100 loss: 1.6286175882816314
#  batch 200 loss: 1.6340293717384338
#  batch 300 loss: 1.6199525249004365
# lr 0.001 -> 0.001
# Train accuracy 45.6:
# Test accuracy 41.8:
# EPOCH 39:
#  batch 100 loss: 1.6314888906478882
#  batch 200 loss: 1.6286233425140382
#  batch 300 loss: 1.627276817560196
# lr 0.001 -> 0.001
# Train accuracy 45.6:
# Test accuracy 41.8:
# EPOCH 40:
#  batch 100 loss: 1.6308404886722565
#  batch 200 loss: 1.6238134562969209
#  batch 300 loss: 1.6359902477264405
# lr 0.001 -> 0.001
# Train accuracy 45.7:
# Test accuracy 41.8:
# EPOCH 41:
#  batch 100 loss: 1.619880177974701
#  batch 200 loss: 1.6209945571422577
#  batch 300 loss: 1.6401694595813752
# lr 0.001 -> 0.001
# Train accuracy 45.7:
# Test accuracy 41.9:
# EPOCH 42:
#  batch 100 loss: 1.6342529046535492
#  batch 200 loss: 1.6250439715385436
#  batch 300 loss: 1.610687735080719
# lr 0.001 -> 0.001
# Train accuracy 45.6:
# Test accuracy 41.6:
# EPOCH 43:
#  batch 100 loss: 1.6411003518104552
#  batch 200 loss: 1.638786108493805
#  batch 300 loss: 1.612506148815155
# lr 0.001 -> 0.001
# Train accuracy 45.7:
# Test accuracy 41.699999999999996:
# EPOCH 44:
#  batch 100 loss: 1.647299543619156
#  batch 200 loss: 1.636245265007019
#  batch 300 loss: 1.6088640904426574
# lr 0.001 -> 0.001
# Train accuracy 45.6:
# Test accuracy 41.699999999999996:
# EPOCH 45:
#  batch 100 loss: 1.6312516832351684
#  batch 200 loss: 1.622095707654953
#  batch 300 loss: 1.6289262676239014
# lr 0.001 -> 0.001
# Train accuracy 45.6:
# Test accuracy 41.9:
# EPOCH 46:
#  batch 100 loss: 1.6448044097423553
#  batch 200 loss: 1.6222569954395294
#  batch 300 loss: 1.619184980392456
# lr 0.001 -> 0.001
# Train accuracy 45.7:
# Test accuracy 41.699999999999996:
# EPOCH 47:
#  batch 100 loss: 1.621831021308899
#  batch 200 loss: 1.6288742852210998
#  batch 300 loss: 1.626912980079651
# lr 0.001 -> 0.001
# Train accuracy 45.7:
# Test accuracy 41.8:
# EPOCH 48:
#  batch 100 loss: 1.6180099523067475
#  batch 200 loss: 1.6342601490020752
#  batch 300 loss: 1.6417210805416107
# lr 0.001 -> 0.001
# Train accuracy 45.6:
# Test accuracy 41.8:
# EPOCH 49:
#  batch 100 loss: 1.6242394602298738
#  batch 200 loss: 1.6128989481925964
#  batch 300 loss: 1.6440913522243499
# lr 0.001 -> 0.001
# Train accuracy 45.7:
# Test accuracy 41.699999999999996:
# EPOCH 50:
#  batch 100 loss: 1.6238391411304474
#  batch 200 loss: 1.6324000549316406
#  batch 300 loss: 1.6245536637306213
# lr 0.001 -> 0.0001
# Train accuracy 45.6:
# Test accuracy 41.8:
# EPOCH 51:
#  batch 100 loss: 1.62333225607872
#  batch 200 loss: 1.6273330330848694
#  batch 300 loss: 1.619669620990753
# lr 0.0001 -> 0.0001
# Train accuracy 45.7:
# Test accuracy 41.8:
# EPOCH 52:
#  batch 100 loss: 1.6231389904022218
#  batch 200 loss: 1.643081283569336
#  batch 300 loss: 1.6177625167369842
# lr 0.0001 -> 0.0001
# Train accuracy 45.7:
# Test accuracy 41.8:
# EPOCH 53:
#  batch 100 loss: 1.6190750432014465
#  batch 200 loss: 1.6271683943271638
#  batch 300 loss: 1.622978810071945
# lr 0.0001 -> 0.0001
# Train accuracy 45.7:
# Test accuracy 41.8:
# EPOCH 54:
#  batch 100 loss: 1.6123490929603577
#  batch 200 loss: 1.6219445943832398
#  batch 300 loss: 1.640853865146637
# lr 0.0001 -> 0.0001
# Train accuracy 45.7:
# Test accuracy 41.8:
# EPOCH 55:
#  batch 100 loss: 1.63404221534729
#  batch 200 loss: 1.6263661754131318
#  batch 300 loss: 1.6093860340118409
# lr 0.0001 -> 0.0001
# Train accuracy 45.7:
# Test accuracy 41.699999999999996:
# EPOCH 56:
#  batch 100 loss: 1.6324375188350677
#  batch 200 loss: 1.625581957101822
#  batch 300 loss: 1.6211682188510894
# lr 0.0001 -> 0.0001
# Train accuracy 45.7:
# Test accuracy 41.699999999999996:
# EPOCH 57:
#  batch 100 loss: 1.6259118402004242
#  batch 200 loss: 1.629314329624176
#  batch 300 loss: 1.6322549819946288
# lr 0.0001 -> 0.0001
# Train accuracy 45.7:
# Test accuracy 41.699999999999996:
# EPOCH 58:
#  batch 100 loss: 1.6196136629581452
#  batch 200 loss: 1.6338551676273345
#  batch 300 loss: 1.6103562963008882
# lr 0.0001 -> 0.0001
# Train accuracy 45.7:
# Test accuracy 41.699999999999996:
# EPOCH 59:
#  batch 100 loss: 1.6294376575946807
#  batch 200 loss: 1.623632161617279
#  batch 300 loss: 1.6298993813991547
# lr 0.0001 -> 0.0001
# Train accuracy 45.7:
# Test accuracy 41.699999999999996:
# EPOCH 60:
#  batch 100 loss: 1.6421503901481629
#  batch 200 loss: 1.6174807798862458
#  batch 300 loss: 1.630567775964737
# lr 0.0001 -> 0.0001
# Train accuracy 45.7:
# Test accuracy 41.699999999999996:
# EPOCH 61:
#  batch 100 loss: 1.6351671862602233
#  batch 200 loss: 1.6193924403190614
#  batch 300 loss: 1.622135684490204
# lr 0.0001 -> 0.0001
# Train accuracy 45.7:
# Test accuracy 41.699999999999996:
# EPOCH 62:
#  batch 100 loss: 1.6266756355762482
#  batch 200 loss: 1.6207837164402008
#  batch 300 loss: 1.629052758216858
# lr 0.0001 -> 0.0001
# Train accuracy 45.7:
# Test accuracy 41.699999999999996:
# EPOCH 63:
#  batch 100 loss: 1.6240192317962647
#  batch 200 loss: 1.6129390442371367
#  batch 300 loss: 1.6314839959144591
# lr 0.0001 -> 0.0001
# Train accuracy 45.7:
# Test accuracy 41.699999999999996:
# EPOCH 64:
#  batch 100 loss: 1.6245375049114228
#  batch 200 loss: 1.6384625566005706
#  batch 300 loss: 1.6191421473026275
# lr 0.0001 -> 0.0001
# Train accuracy 45.7:
# ...
# EPOCH 11:
#  batch 100 loss: 1.9462361073493957
#  batch 200 loss: 1.9455581545829772
#  batch 300 loss: 1.9368762564659119
# lr 0.01 -> 0.01
# Train accuracy 35.9:
# Test accuracy 36.4:
# EPOCH 12:
#  batch 100 loss: 1.943891613483429
#  batch 200 loss: 1.9286761736869813
#  batch 300 loss: 1.9446776342391967
# lr 0.01 -> 0.01
# Train accuracy 36.199999999999996:
# Test accuracy 36.1:
# EPOCH 13:
#  batch 100 loss: 1.9503056454658507
#  batch 200 loss: 1.9457338345050812
#  batch 300 loss: 1.9327877926826478
# lr 0.01 -> 0.01
# Train accuracy 35.0:
# Test accuracy 35.0:
# EPOCH 14:
#  batch 100 loss: 1.9312149453163148
#  batch 200 loss: 1.9467460584640504
#  batch 300 loss: 1.942148995399475
# lr 0.01 -> 0.01
# Train accuracy 36.0:
# Test accuracy 35.8:
# EPOCH 15:
#  batch 100 loss: 1.9447178626060486
#  batch 200 loss: 1.933113422393799
#  batch 300 loss: 1.9395129549503327
# lr 0.01 -> 0.01
# Train accuracy 35.3:
# Test accuracy 35.4:
# EPOCH 16:
#  batch 100 loss: 1.9420693957805633
#  batch 200 loss: 1.9338943767547607
#  batch 300 loss: 1.9508483278751374
# lr 0.01 -> 0.01
# Train accuracy 35.6:
# Test accuracy 35.9:
# EPOCH 17:
#  batch 100 loss: 1.9488036441802978
#  batch 200 loss: 1.9504272150993347
#  batch 300 loss: 1.95015420794487
# lr 0.01 -> 0.01
# Train accuracy 35.5:
# Test accuracy 35.6:
# EPOCH 18:
#  batch 100 loss: 1.9377210283279418
#  batch 200 loss: 1.942834677696228
#  batch 300 loss: 1.9430052387714385
# lr 0.01 -> 0.01
# Train accuracy 35.199999999999996:
# Test accuracy 35.5:
# EPOCH 19:
#  batch 100 loss: 1.9435404932498932
#  batch 200 loss: 1.9443103682994842
#  batch 300 loss: 1.9366729593276977
# lr 0.01 -> 0.01
# Train accuracy 35.3:
# Test accuracy 35.5:
# EPOCH 20:
#  batch 100 loss: 1.9525857019424437
#  batch 200 loss: 1.9310722875595092
#  batch 300 loss: 1.938727867603302
# lr 0.01 -> 0.01
# Train accuracy 36.199999999999996:
# Test accuracy 36.5:
# EPOCH 21:
#  batch 100 loss: 1.9446041882038116
#  batch 200 loss: 1.945587215423584
#  batch 300 loss: 1.9349159359931947
# lr 0.01 -> 0.01
# Train accuracy 35.8:
# Test accuracy 36.1:
# EPOCH 22:
#  batch 100 loss: 1.944377908706665
#  batch 200 loss: 1.9351397693157195
#  batch 300 loss: 1.9422321343421936
# lr 0.01 -> 0.01
# Train accuracy 35.4:
# Test accuracy 35.3:
# EPOCH 23:
#  batch 100 loss: 1.942006299495697
#  batch 200 loss: 1.942301380634308
#  batch 300 loss: 1.9429801988601685
# lr 0.01 -> 0.01
# Train accuracy 35.0:
# Test accuracy 35.5:
# EPOCH 24:
#  batch 100 loss: 1.9451543176174164
#  batch 200 loss: 1.9439845633506776
#  batch 300 loss: 1.9430880761146545
# lr 0.01 -> 0.01
# Train accuracy 36.0:
# Test accuracy 36.199999999999996:
# EPOCH 25:
#  batch 100 loss: 1.93979332447052
#  batch 200 loss: 1.9442146134376526
#  batch 300 loss: 1.9368275797367096
# lr 0.01 -> 0.001
# Train accuracy 35.199999999999996:
# Test accuracy 35.199999999999996:
# EPOCH 26:
#  batch 100 loss: 1.9338332569599153
#  batch 200 loss: 1.934202870130539
#  batch 300 loss: 1.9486439514160157
# lr 0.001 -> 0.001
# Train accuracy 36.6:
# Test accuracy 36.8:
# EPOCH 27:
#  batch 100 loss: 1.9301468539237976
#  batch 200 loss: 1.9335875248908996
#  batch 300 loss: 1.9410634088516234
# lr 0.001 -> 0.001
# Train accuracy 36.4:
# Test accuracy 36.8:
# EPOCH 28:
#  batch 100 loss: 1.9288396036624909
#  batch 200 loss: 1.9326788246631623
#  batch 300 loss: 1.9339552927017212
# lr 0.001 -> 0.001
# Train accuracy 36.7:
# Test accuracy 36.5:
# EPOCH 29:
#  batch 100 loss: 1.9288278126716614
#  batch 200 loss: 1.941940931081772
#  batch 300 loss: 1.931892727613449
# lr 0.001 -> 0.001
# Train accuracy 36.8:
# Test accuracy 36.8:
# EPOCH 30:
#  batch 100 loss: 1.9381722927093505
#  batch 200 loss: 1.9261527514457704
#  batch 300 loss: 1.9377165615558625
# lr 0.001 -> 0.001
# Train accuracy 36.7:
# Test accuracy 36.7:
# EPOCH 31:
#  batch 100 loss: 1.93857515335083
#  batch 200 loss: 1.9241350150108338
#  batch 300 loss: 1.9415710473060608
# lr 0.001 -> 0.001
# Train accuracy 36.5:
# Test accuracy 36.7:
# EPOCH 32:
#  batch 100 loss: 1.941716227531433
#  batch 200 loss: 1.9323272621631622
#  batch 300 loss: 1.9349960422515868
# lr 0.001 -> 0.001
# Train accuracy 36.6:
# Test accuracy 36.8:
# EPOCH 33:
#  batch 100 loss: 1.9293710970878601
#  batch 200 loss: 1.936954071521759
#  batch 300 loss: 1.9309737980365753
# lr 0.001 -> 0.001
# Train accuracy 36.7:
# Test accuracy 36.7:
# EPOCH 34:
#  batch 100 loss: 1.9268642282485962
#  batch 200 loss: 1.9310778486728668
#  batch 300 loss: 1.9346897912025451
# lr 0.001 -> 0.001
# Train accuracy 36.7:
# Test accuracy 36.7:
# EPOCH 35:
#  batch 100 loss: 1.939729175567627
#  batch 200 loss: 1.9320202922821046
#  batch 300 loss: 1.9334862756729125
# lr 0.001 -> 0.001
# Train accuracy 36.7:
# Test accuracy 36.6:
# EPOCH 36:
#  batch 100 loss: 1.9352661347389222
#  batch 200 loss: 1.9242728340625763
#  batch 300 loss: 1.9422822666168214
# lr 0.001 -> 0.001
# Train accuracy 36.6:
# Test accuracy 36.7:
# EPOCH 37:
#  batch 100 loss: 1.9363789546489716
#  batch 200 loss: 1.9302600014209748
#  batch 300 loss: 1.9280347454547881
# lr 0.001 -> 0.001
# Train accuracy 36.7:
# Test accuracy 36.8:
# EPOCH 38:
#  batch 100 loss: 1.9478675544261932
#  batch 200 loss: 1.9355602848529816
#  batch 300 loss: 1.930888842344284
# lr 0.001 -> 0.001
# Train accuracy 36.5:
# Test accuracy 36.7:
# EPOCH 39:
#  batch 100 loss: 1.9318608915805817
#  batch 200 loss: 1.936034655570984
#  batch 300 loss: 1.9341354835033417
# lr 0.001 -> 0.001
# Train accuracy 36.5:
# Test accuracy 36.6:
# EPOCH 40:
#  batch 100 loss: 1.936261034011841
#  batch 200 loss: 1.9311262476444244
#  batch 300 loss: 1.9349675476551056
# lr 0.001 -> 0.001
# Train accuracy 36.6:
# Test accuracy 36.6:
# EPOCH 41:
#  batch 100 loss: 1.9300308072566985
#  batch 200 loss: 1.9289226341247558
#  batch 300 loss: 1.9387510883808137
# lr 0.001 -> 0.001
# Train accuracy 36.7:
# Test accuracy 36.6:
# EPOCH 42:
#  batch 100 loss: 1.9352357745170594
#  batch 200 loss: 1.9285906267166137
#  batch 300 loss: 1.9376456773281097
# lr 0.001 -> 0.001
# Train accuracy 36.8:
# Test accuracy 36.6:
# EPOCH 43:
#  batch 100 loss: 1.9341324937343598
#  batch 200 loss: 1.936624345779419
#  batch 300 loss: 1.929628483057022
# lr 0.001 -> 0.001
# Train accuracy 36.7:
# Test accuracy 36.7:
# EPOCH 44:
#  batch 100 loss: 1.9336634528636933
#  batch 200 loss: 1.9398307347297667
#  batch 300 loss: 1.9316596376895905
# lr 0.001 -> 0.001
# Train accuracy 36.6:
# Test accuracy 36.5:
# EPOCH 45:
#  batch 100 loss: 1.9398008453845978
#  batch 200 loss: 1.9310736525058747
#  batch 300 loss: 1.931479916572571
# lr 0.001 -> 0.001
# Train accuracy 36.5:
# Test accuracy 36.6:
# EPOCH 46:
#  batch 100 loss: 1.93411066532135
#  batch 200 loss: 1.929479249715805
#  batch 300 loss: 1.9319560849666595
# lr 0.001 -> 0.001
# Train accuracy 36.4:
# Test accuracy 36.6:
# EPOCH 47:
#  batch 100 loss: 1.940117268562317
#  batch 200 loss: 1.933241330385208
#  batch 300 loss: 1.9353104531764984
# lr 0.001 -> 0.001
# Train accuracy 36.8:
# Test accuracy 36.8:
# EPOCH 48:
#  batch 100 loss: 1.9332974982261657
#  batch 200 loss: 1.9365806329250335
#  batch 300 loss: 1.9355491364002229
# lr 0.001 -> 0.001
# Train accuracy 36.6:
# Test accuracy 36.5:
# EPOCH 49:
#  batch 100 loss: 1.9369906294345856
#  batch 200 loss: 1.9277346241474151
#  batch 300 loss: 1.9393617963790895
# lr 0.001 -> 0.001
# Train accuracy 36.6:
# Test accuracy 36.7:
# EPOCH 50:
#  batch 100 loss: 1.9367747366428376
#  batch 200 loss: 1.9334737050533295
#  batch 300 loss: 1.9407172751426698
# lr 0.001 -> 0.0001
# Train accuracy 36.6:
# Test accuracy 36.6:
# EPOCH 51:
#  batch 100 loss: 1.9419887816905976
#  batch 200 loss: 1.9245165038108825
#  batch 300 loss: 1.9371376144886017
# lr 0.0001 -> 0.0001
# Train accuracy 36.7:
# Test accuracy 36.7:
# EPOCH 52:
#  batch 100 loss: 1.9340278065204621
#  batch 200 loss: 1.9334401762485505
#  batch 300 loss: 1.9375583732128143
# lr 0.0001 -> 0.0001
# Train accuracy 36.7:
# Test accuracy 36.8:
# EPOCH 53:
#  batch 100 loss: 1.9273347210884095
#  batch 200 loss: 1.9286926865577698
#  batch 300 loss: 1.9390388584136964
# lr 0.0001 -> 0.0001
# Train accuracy 36.7:
# Test accuracy 36.8:
# EPOCH 54:
#  batch 100 loss: 1.9312118303775787
#  batch 200 loss: 1.9272795796394349
#  batch 300 loss: 1.9275969910621642
# lr 0.0001 -> 0.0001
# Train accuracy 36.7:
# Test accuracy 36.7:
# EPOCH 55:
#  batch 100 loss: 1.9290048563480378
#  batch 200 loss: 1.9403128111362458
#  batch 300 loss: 1.9343483352661133
# lr 0.0001 -> 0.0001
# Train accuracy 36.7:
# Test accuracy 36.8:
# EPOCH 56:
#  batch 100 loss: 1.9339965283870697
#  batch 200 loss: 1.930436029434204
#  batch 300 loss: 1.9352920138835907
# lr 0.0001 -> 0.0001
# Train accuracy 36.7:
# Test accuracy 36.7:
# EPOCH 57:
#  batch 100 loss: 1.9311021173000336
#  batch 200 loss: 1.925789281129837
#  batch 300 loss: 1.9372734642028808
# lr 0.0001 -> 0.0001
# Train accuracy 36.7:
# Test accuracy 36.7:
# EPOCH 58:
#  batch 100 loss: 1.9296620976924896
#  batch 200 loss: 1.9380560719966888
#  batch 300 loss: 1.9301565825939178
# lr 0.0001 -> 0.0001
# Train accuracy 36.7:
# Test accuracy 36.7:
# EPOCH 59:
#  batch 100 loss: 1.9225454640388489
#  batch 200 loss: 1.9377083802223205
#  batch 300 loss: 1.9361615431308747
# lr 0.0001 -> 0.0001
# Train accuracy 36.7:
# Test accuracy 36.7:
# EPOCH 60:
#  batch 100 loss: 1.9331860876083373
#  batch 200 loss: 1.9322270774841308
#  batch 300 loss: 1.9375175201892854
# lr 0.0001 -> 0.0001
# Train accuracy 36.7:
# Test accuracy 36.7:
# EPOCH 61:
#  batch 100 loss: 1.9358874678611755
#  batch 200 loss: 1.937666916847229
#  batch 300 loss: 1.9295567870140076
# lr 0.0001 -> 0.0001
# Train accuracy 36.7:
# Test accuracy 36.7:
# EPOCH 62:
#  batch 100 loss: 1.9321335232257844
#  batch 200 loss: 1.9326793110370637
#  batch 300 loss: 1.930917888879776
# lr 0.0001 -> 0.0001
# Train accuracy 36.7:
# Test accuracy 36.7:
# EPOCH 63:
#  batch 100 loss: 1.9238445138931275
#  batch 200 loss: 1.935912195444107
#  batch 300 loss: 1.9301304531097412
# lr 0.0001 -> 0.0001
# Train accuracy 36.7:
# Test accuracy 36.7:
# EPOCH 64:
#  batch 100 loss: 1.938059743642807
#  batch 200 loss: 1.9331810426712037
#  batch 300 loss: 1.9297172677516938
# lr 0.0001 -> 0.0001
# Train accuracy 36.7:
# Test accuracy 36.8:
# EPOCH 65:
#  batch 100 loss: 1.9298581862449646
#  batch 200 loss: 1.9378183448314668
#  batch 300 loss: 1.9295674991607665
# lr 0.0001 -> 0.0001
# Train accuracy 36.7:
# Test accuracy 36.7:
# EPOCH 66:
#  batch 100 loss: 1.9383384561538697
#  batch 200 loss: 1.9302080118656157
#  batch 300 loss: 1.9312577593326568
# lr 0.0001 -> 0.0001
# Train accuracy 36.7:
# Test accuracy 36.7:
# EPOCH 67:
#  batch 100 loss: 1.9273375415802
#  batch 200 loss: 1.9321543526649476
#  batch 300 loss: 1.934919409751892
# lr 0.0001 -> 0.0001
# Train accuracy 36.7:
# Test accuracy 36.7:
# EPOCH 68:
#  batch 100 loss: 1.9301211106777192
#  batch 200 loss: 1.9376217782497407
#  batch 300 loss: 1.9283110225200653
# lr 0.0001 -> 0.0001
# Train accuracy 36.7:
# Test accuracy 36.7:
# EPOCH 69:
#  batch 100 loss: 1.9246792781352997
#  batch 200 loss: 1.9293824052810669
#  batch 300 loss: 1.9353357553482056
# lr 0.0001 -> 0.0001
# Train accuracy 36.7:
# Test accuracy 36.7:
# EPOCH 70:
#  batch 100 loss: 1.9326046931743621
#  batch 200 loss: 1.9345358192920685
#  batch 300 loss: 1.931535279750824
# lr 0.0001 -> 0.0001
# Train accuracy 36.7:
# Test accuracy 36.7:
# EPOCH 71:
#  batch 100 loss: 1.926397864818573
#  batch 200 loss: 1.9404253351688385
#  batch 300 loss: 1.93512451171875
# lr 0.0001 -> 0.0001
# Train accuracy 36.7:
# Test accuracy 36.7:
# EPOCH 72:
#  batch 100 loss: 1.9371332466602325
#  batch 200 loss: 1.9325926578044892
#  batch 300 loss: 1.9346392619609833
# lr 0.0001 -> 0.0001
# Train accuracy 36.7:
# Test accuracy 36.7:
# EPOCH 73:
#  batch 100 loss: 1.9290782344341277
#  batch 200 loss: 1.9360029184818268
#  batch 300 loss: 1.9311902081966401
# lr 0.0001 -> 0.0001
# Train accuracy 36.7:
# Test accuracy 36.8:
# EPOCH 74:
#  batch 100 loss: 1.9285746443271636
#  batch 200 loss: 1.930215039253235
#  batch 300 loss: 1.9371718192100524
# lr 0.0001 -> 0.0001
# Train accuracy 36.7:
# Test accuracy 36.8:
# EPOCH 75:
#  batch 100 loss: 1.936862485408783
#  batch 200 loss: 1.9310081219673156
#  batch 300 loss: 1.9288747370243073
# lr 0.0001 -> 1e-05
# Train accuracy 36.7:
# Test accuracy 36.8:
# EPOCH 76:
#  batch 100 loss: 1.9375221025943756
#  batch 200 loss: 1.936857578754425
#  batch 300 loss: 1.9341981709003448
# lr 1e-05 -> 1e-05
# Train accuracy 36.7:
# Test accuracy 36.8:
# EPOCH 77:
#  batch 100 loss: 1.9341208279132842
#  batch 200 loss: 1.9303098726272583
#  batch 300 loss: 1.9338415908813475
# lr 1e-05 -> 1e-05
# Train accuracy 36.7:
# Test accuracy 36.8:
# EPOCH 78:
#  batch 100 loss: 1.9266503250598908
#  batch 200 loss: 1.933880797624588
#  batch 300 loss: 1.9321319794654845
# lr 1e-05 -> 1e-05
# Train accuracy 36.7:
# Test accuracy 36.8:
# EPOCH 79:
#  batch 100 loss: 1.9267779088020325
#  batch 200 loss: 1.9338471794128418
#  batch 300 loss: 1.9373503994941712
# lr 1e-05 -> 1e-05
# Train accuracy 36.7:
# Test accuracy 36.8:
# EPOCH 80:
#  batch 100 loss: 1.9422306621074676
#  batch 200 loss: 1.9360604035854339
#  batch 300 loss: 1.928179738521576
# lr 1e-05 -> 1e-05
# Train accuracy 36.7:
# Test accuracy 36.8:
# EPOCH 81:
#  batch 100 loss: 1.9419530129432678
#  batch 200 loss: 1.9325803804397583
#  batch 300 loss: 1.9359761738777161
# lr 1e-05 -> 1e-05
# Train accuracy 36.7:
# Test accuracy 36.8:
# EPOCH 82:
#  batch 100 loss: 1.9370221614837646
#  batch 200 loss: 1.931040858030319
#  batch 300 loss: 1.9279464721679687
# lr 1e-05 -> 1e-05
# Train accuracy 36.7:
# Test accuracy 36.8:
# EPOCH 83:
#  batch 100 loss: 1.9299252390861512
#  batch 200 loss: 1.9356096148490907
#  batch 300 loss: 1.9353436386585237
# lr 1e-05 -> 1e-05
# Train accuracy 36.7:
# Test accuracy 36.8:
# EPOCH 84:
#  batch 100 loss: 1.9326633167266847
#  batch 200 loss: 1.9330918860435486
#  batch 300 loss: 1.9277626645565034
# lr 1e-05 -> 1e-05
# Train accuracy 36.7:
# Test accuracy 36.7:
# EPOCH 85:
#  batch 100 loss: 1.9319836270809174
#  batch 200 loss: 1.927193763256073
#  batch 300 loss: 1.929406225681305
# lr 1e-05 -> 1e-05
# Train accuracy 36.7:
# Test accuracy 36.7:
# EPOCH 86:
#  batch 100 loss: 1.9351040041446685
#  batch 200 loss: 1.9317104017734528
#  batch 300 loss: 1.932958221435547
# lr 1e-05 -> 1e-05
# Train accuracy 36.7:
# Test accuracy 36.7:
# EPOCH 87:
#  batch 100 loss: 1.9365134119987488
#  batch 200 loss: 1.924699568748474
#  batch 300 loss: 1.9366923677921295
# lr 1e-05 -> 1e-05
# Train accuracy 36.7:
# Test accuracy 36.7:
# EPOCH 88:
#  batch 100 loss: 1.9313776671886445
#  batch 200 loss: 1.93638449549675
#  batch 300 loss: 1.932688021659851
# lr 1e-05 -> 1e-05
# Train accuracy 36.7:
# Test accuracy 36.7:
# EPOCH 89:
#  batch 100 loss: 1.931600613594055
#  batch 200 loss: 1.935447825193405
#  batch 300 loss: 1.9415780079364777
# lr 1e-05 -> 1e-05
# Train accuracy 36.7:
# Test accuracy 36.7:
# EPOCH 90:
#  batch 100 loss: 1.930987037420273
#  batch 200 loss: 1.9279627394676209
#  batch 300 loss: 1.937433931827545
# lr 1e-05 -> 1e-05
# Train accuracy 36.7:
# Test accuracy 36.7:
# EPOCH 91:
#  batch 100 loss: 1.931948847770691
#  batch 200 loss: 1.9354017901420593
#  batch 300 loss: 1.9318961369991303
# lr 1e-05 -> 1e-05
# Train accuracy 36.7:
# Test accuracy 36.7:
# EPOCH 92:
#  batch 100 loss: 1.931702558994293
#  batch 200 loss: 1.9297416615486145
#  batch 300 loss: 1.9401325130462646
# lr 1e-05 -> 1e-05
# Train accuracy 36.7:
# Test accuracy 36.7:
# EPOCH 93:
#  batch 100 loss: 1.9281923818588256
#  batch 200 loss: 1.9334910202026367
#  batch 300 loss: 1.9377770483493806
# lr 1e-05 -> 1e-05
# Train accuracy 36.7:
# Test accuracy 36.7:
# EPOCH 94:
#  batch 100 loss: 1.9341949462890624
#  batch 200 loss: 1.931904844045639
#  batch 300 loss: 1.9341424000263214
# lr 1e-05 -> 1e-05
# Train accuracy 36.7:
# Test accuracy 36.7:
# EPOCH 95:
#  batch 100 loss: 1.938387770652771
#  batch 200 loss: 1.9242991387844086
#  batch 300 loss: 1.9354349422454833
# lr 1e-05 -> 1e-05
# Train accuracy 36.7:
# Test accuracy 36.7:
# EPOCH 96:
#  batch 100 loss: 1.9324271869659424
#  batch 200 loss: 1.9346970748901366
#  batch 300 loss: 1.9372814309597015
# lr 1e-05 -> 1e-05
# Train accuracy 36.7:
# Test accuracy 36.7:
# EPOCH 97:
#  batch 100 loss: 1.9342292499542237
#  batch 200 loss: 1.9323209977149964
#  batch 300 loss: 1.9328196692466735
# lr 1e-05 -> 1e-05
# Train accuracy 36.7:
# Test accuracy 36.7:
# EPOCH 98:
#  batch 100 loss: 1.933284330368042
#  batch 200 loss: 1.9306655836105346
#  batch 300 loss: 1.9353756082057954
# lr 1e-05 -> 1e-05
# Train accuracy 36.7:
# Test accuracy 36.7:
# EPOCH 99:
#  batch 100 loss: 1.9328949975967407
#  batch 200 loss: 1.9330323839187622
#  batch 300 loss: 1.9344944620132447
# lr 1e-05 -> 1e-05
# Train accuracy 36.7:
# Test accuracy 36.7:
# EPOCH 100:
#  batch 100 loss: 1.932285178899765
#  batch 200 loss: 1.9390484249591828
#  batch 300 loss: 1.9276139950752258
# lr 1e-05 -> 1.0000000000000002e-06
# Train accuracy 36.7:
# Test accuracy 36.7:

# %%
import numpy as np
epochs_arr = np.arange(0, len(losses_arr[0]))

# %%
# Plot training loss
x = np.array(epochs_arr)
for i,train_loss in enumerate(losses_arr):
  ypoints = np.array(train_loss)
  plt.plot(x, ypoints, label = regularization_strengths[i])

plt.xlabel("Epochs")
plt.ylabel("train Loss")
plt.legend()
plt.title('LR=0.01, Scheduler=Step, Batch_size=128, Optimizer=SGD, L2 Regularization')
plt.show()

# %%
# Plot training accuracy
x = np.array(epochs_arr)
for i,train_acc in enumerate(train_accuracy_arr):
  ypoints = np.array(train_acc)
  plt.plot(x, ypoints, label = regularization_strengths[i])

plt.xlabel("Epochs")
plt.ylabel("train Accuracy")
plt.legend()
plt.title('LR=0.01, Scheduler=Step, Batch_size=128, Optimizer=SGD, L2 Regularization')
plt.show()

# %%
# Plot test accuracy
x = np.array(epochs_arr)
for i,test_acc in enumerate(test_accuracy_arr):
  ypoints = np.array(test_acc)
  plt.plot(x, ypoints, label = regularization_strengths[i])

plt.xlabel("Epochs")
plt.ylabel("test Accuracy")
plt.legend()
plt.title('LR=0.01, Scheduler=Step, Batch_size=128, Optimizer=SGD, L2 Regularization')
plt.show()

# %%
# Plot test and training accuracy
x = np.array(epochs_arr)
for i,reg in enumerate(regularization_strengths):
  ypoints_1 = np.array(train_accuracy_arr[i])
  ypoints_2 = np.array(test_accuracy_arr[i])
  plt.plot(x, ypoints_1, label = 'Train')
  plt.plot(x, ypoints_2, label = 'Test')
  plt.xlabel("Epochs")
  plt.ylabel("Accuracy")
  plt.legend()
  plt.title(F'LR=0.01, Scheduler=Step, Batch_size=128, Optimizer=SGD, L2 Regularization={reg}')
  plt.show()

# %% [markdown]
# ### Load model

# %%
model_save_name = '1695168105559.8071_Step_bs128_e30_SGD_ss10_gamma0.1_cifar'
path = F"{model_save_name}.pt"
net.load_state_dict(t.load(path))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 from google.colab import drive
#       2 drive.mount('/content/drive/')
#       3 model_save_name = '1695168105559.8071_Step_bs128_e30_SGD_ss10_gamma0.1_cifar'
#
# ModuleNotFoundError: No module named 'google.colab'

# %%
test(net,test_loader)

# %%
#hello kuch likhlo warna inactivity timeout de dega yeh
